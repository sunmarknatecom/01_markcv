# %% [markdown]
# <a href="https://colab.research.google.com/github/sunmarknatecom/01_markcv/blob/master/bonespect_train2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from glob import glob
import numpy as np
import cv2, os, copy, shutil
import matplotlib.pyplot as plt
from PIL import Image
from random import randint

# DEEP LEARNING MODULES
import tensorflow as tf
from keras import backend as K
from keras.losses import binary_crossentropy
from keras.optimizers import Adam

from keras.layers import Input, Conv2D, MaxPooling2D, Conv2DTranspose, BatchNormalization, concatenate
from keras.models import Model
from skimage.metrics import structural_similarity as ssim

# %%
inputNpyList = sorted(glob("/content/drive/MyDrive/Bone_SPECT/inputData/*.npy"))
labelNpyList = sorted(glob("/content/drive/MyDrive/Bone_SPECT/labelData/*.npy"))

# %%
inputNpyList[0]
# Out:
# '/content/drive/MyDrive/Bone_SPECT/inputData/23060101_input.npy'

# %%
testImg = np.load(inputNpyList[0])

# %%
plt.imshow(testImg, cmap='gray_r')
plt.show()

# %%
for i in range(238):
    tempInput = inputNpyList[i].split("/")[-1][-18:-10]
    tempLabel = labelNpyList[i].split("/")[-1][-18:-10]
    if tempInput != tempLabel:
        print(i)
    else:
        continue

# %%
inputObj = []
labelObj = []
sizesImg = []

for i in range(238):
    tempInputObj = np.load(inputNpyList[i])
    tempInputObj = np.array(tempInputObj, dtype=np.uint16)
    tempLabelObj = np.load(labelNpyList[i])
    tempLabelObj = np.array(tempLabelObj, dtype=np.uint16)
    sizesImg.append(np.shape(tempInputObj)[0])
    inputObj.append(tempInputObj)
    labelObj.append(tempLabelObj)

# %%
MAX_SIZE = 1024

# %%
train_imgs = []
train_lbls = []

# %%
for i in range(238):
    io_x, ioy = np.shape(inputObj[i])
    if io_x != MAX_SIZE:
        diffIOx = MAX_SIZE - io_x
        zeroPadding = np.zeros((diffIOx,256))
        tempInput = np.vstack([inputObj[i],zeroPadding])
        tempLabel = np.vstack([labelObj[i],zeroPadding])
        train_imgs.append(tempInput)
        train_lbls.append(tempLabel)
    else:
        train_imgs.append(inputObj[i])
        train_lbls.append(labelObj[i])

# %%
temp_train_imgs = np.array(train_imgs)
temp_train_lbls = np.array(train_lbls)

# %%
temp_train_lbls[temp_train_lbls >=1] = 1

# %%
split_num = 200

# %%
train_imgs = temp_train_imgs[:split_num,...]
valid_imgs = temp_train_imgs[split_num:,...]
train_msks = temp_train_lbls[:split_num,...]
valid_msks = temp_train_lbls[split_num:,...]

# %%
train_imgs = np.array(train_imgs, dtype=np.float32)
train_msks = np.array(train_msks, dtype=np.float32)
valid_imgs = np.array(valid_imgs, dtype=np.float32)
valid_msks = np.array(valid_msks, dtype=np.float32)

train_msks = np.reshape(train_msks, (*train_msks.shape, 1))
valid_msks = np.reshape(valid_msks, (*valid_msks.shape, 1))

train_dataset = tf.data.Dataset.from_tensor_slices((train_imgs, train_msks))
test_dataset = tf.data.Dataset.from_tensor_slices((valid_imgs, valid_msks))

# %%
# %matplotlib inline

rand_num = randint(1,len(train_imgs))

fig = plt.figure(0, figsize=(20, 20))
fig.add_subplot(1, 2, 1)
plt.imshow(train_imgs[rand_num], cmap='gray_r')
fig.add_subplot(1, 2, 2)
plt.imshow(np.squeeze(train_msks[rand_num]), cmap='gray_r')

# %%
test_img = train_imgs[10] * np.squeeze(train_msks[10])

# %%
plt.figure(0, figsize=(20, 20))
plt.imshow(test_img, cmap="gray_r")
plt.show()

# %%
inputs = Input((MAX_SIZE, 256, 1))
bnorm1 = BatchNormalization()(inputs)
conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(bnorm1)
conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv1)
pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(pool1)
conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv2)
pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(pool2)
conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv3)
pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(pool3)
conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv4)
pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)

conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(pool4)
conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(conv5)

up6 = concatenate([Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(conv5), conv4], axis=3)
conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(up6)
conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv6)

up7 = concatenate([Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(conv6), conv3], axis=3)
conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(up7)
conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv7)

up8 = concatenate([Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(conv7), conv2], axis=3)
conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(up8)
conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv8)

up9 = concatenate([Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(conv8), conv1], axis=3)
conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(up9)
conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv9)

conv10 = Conv2D(1, (1, 1), activation='sigmoid')(conv9)

model = Model(inputs=[inputs], outputs=[conv10])

# %%
import tensorflow as tf
import keras.backend as K
from keras.losses import binary_crossentropy

beta = 0.25
alpha = 0.25
gamma = 2
epsilon = 1e-5
smooth = 1

def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + K.epsilon()) / (K.sum(y_true_f) + K.sum(y_pred_f) + K.epsilon())

def generalized_dice_coefficient(y_true, y_pred):
    smooth = 1.
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    score = (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return score

def dice_loss(y_true, y_pred):
    loss = 1 - generalized_dice_coefficient(y_true, y_pred)
    return loss

def bce_dice_loss(y_true, y_pred):
    loss = binary_crossentropy(y_true, y_pred) + dice_loss(y_true, y_pred)
    return loss / 2.0

# %%
initial_learning_rate = 5e-6

lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate,
    decay_steps=100000,
    decay_rate=0.96,
    staircase=True)

callbacks = [tf.keras.callbacks.ModelCheckpoint(
    filepath="mymodel_{epoch}.h5",
    save_best_only=True,
    monitor='val_loss',
    verbose=1)]

# %%
model.compile(Adam(learning_rate=lr_schedule), bce_dice_loss, metrics=[binary_crossentropy, generalized_dice_coefficient])

# %%
model.fit(train_imgs, train_msks, batch_size=10, epochs=200, callbacks=callbacks, validation_data=(valid_imgs, valid_msks))
# Out:
# Epoch 1/200
# 20/20 [==============================] - ETA: 0s - loss: 0.8316 - binary_crossentropy: 0.6983 - generalized_dice_coefficient: 0.0352
# Epoch 1: val_loss improved from inf to 0.82873, saving model to mymodel_1.h5
# 20/20 [==============================] - 22s 233ms/step - loss: 0.8316 - binary_crossentropy: 0.6983 - generalized_dice_coefficient: 0.0352 - val_loss: 0.8287 - val_binary_crossentropy: 0.6936 - val_generalized_dice_coefficient: 0.0362
# Epoch 2/200
# 20/20 [==============================] - ETA: 0s - loss: 0.8303 - binary_crossentropy: 0.6952 - generalized_dice_coefficient: 0.0347
# Epoch 2: val_loss improved from 0.82873 to 0.82771, saving model to mymodel_2.h5
# 20/20 [==============================] - 2s 118ms/step - loss: 0.8303 - binary_crossentropy: 0.6952 - generalized_dice_coefficient: 0.0347 - val_loss: 0.8277 - val_binary_crossentropy: 0.6905 - val_generalized_dice_coefficient: 0.0352
# Epoch 3/200
# 20/20 [==============================] - ETA: 0s - loss: 0.8290 - binary_crossentropy: 0.6922 - generalized_dice_coefficient: 0.0341
# Epoch 3: val_loss improved from 0.82771 to 0.82683, saving model to mymodel_3.h5
# 20/20 [==============================] - 2s 117ms/step - loss: 0.8290 - binary_crossentropy: 0.6922 - generalized_dice_coefficient: 0.0341 - val_loss: 0.8268 - val_binary_crossentropy: 0.6880 - val_generalized_dice_coefficient: 0.0344
# Epoch 4/200
# 20/20 [==============================] - ETA: 0s - loss: 0.8279 - binary_crossentropy: 0.6893 - generalized_dice_coefficient: 0.0335
# Epoch 4: val_loss improved from 0.82683 to 0.82596, saving model to mymodel_4.h5
# 20/20 [==============================] - 2s 118ms/step - loss: 0.8279 - binary_crossentropy: 0.6893 - generalized_dice_coefficient: 0.0335 - val_loss: 0.8260 - val_binary_crossentropy: 0.6857 - val_generalized_dice_coefficient: 0.0338
# Epoch 5/200
# 20/20 [==============================] - ETA: 0s - loss: 0.8267 - binary_crossentropy: 0.6864 - generalized_dice_coefficient: 0.0330
# Epoch 5: val_loss improved from 0.82596 to 0.82509, saving model to mymodel_5.h5
# 20/20 [==============================] - 2s 117ms/step - loss: 0.8267 - binary_crossentropy: 0.6864 - generalized_dice_coefficient: 0.0330 - val_loss: 0.8251 - val_binary_crossentropy: 0.6834 - val_generalized_dice_coefficient: 0.0333
# Epoch 6/200
# 20/20 [==============================] - ETA: 0s - loss: 0.8256 - binary_crossentropy: 0.6836 - generalized_dice_coefficient: 0.0325
# Epoch 6: val_loss improved from 0.82509 to 0.82428, saving model to mymodel_6.h5
# 20/20 [==============================] - 2s 117ms/step - loss: 0.8256 - binary_crossentropy: 0.6836 - generalized_dice_coefficient: 0.0325 - val_loss: 0.8243 - val_binary_crossentropy: 0.6813 - val_generalized_dice_coefficient: 0.0328
# Epoch 7/200
# 20/20 [==============================] - ETA: 0s - loss: 0.8246 - binary_crossentropy: 0.6811 - generalized_dice_coefficient: 0.0319
# Epoch 7: val_loss improved from 0.82428 to 0.82344, saving model to mymodel_7.h5
# 20/20 [==============================] - 2s 117ms/step - loss: 0.8246 - binary_crossentropy: 0.6811 - generalized_dice_coefficient: 0.0319 - val_loss: 0.8234 - val_binary_crossentropy: 0.6792 - val_generalized_dice_coefficient: 0.0323
# Epoch 8/200
# 20/20 [==============================] - ETA: 0s - loss: 0.8236 - binary_crossentropy: 0.6786 - generalized_dice_coefficient: 0.0314
# Epoch 8: val_loss improved from 0.82344 to 0.82257, saving model to mymodel_8.h5
# 20/20 [==============================] - 2s 117ms/step - loss: 0.8236 - binary_crossentropy: 0.6786 - generalized_dice_coefficient: 0.0314 - val_loss: 0.8226 - val_binary_crossentropy: 0.6770 - val_generalized_dice_coefficient: 0.0318
# Epoch 9/200
# 20/20 [==============================] - ETA: 0s - loss: 0.8225 - binary_crossentropy: 0.6758 - generalized_dice_coefficient: 0.0308
# Epoch 9: val_loss improved from 0.82257 to 0.82159, saving model to mymodel_9.h5
# 20/20 [==============================] - 2s 118ms/step - loss: 0.8225 - binary_crossentropy: 0.6758 - generalized_dice_coefficient: 0.0308 - val_loss: 0.8216 - val_binary_crossentropy: 0.6745 - val_generalized_dice_coefficient: 0.0313
# Epoch 10/200
# 20/20 [==============================] - ETA: 0s - loss: 0.8214 - binary_crossentropy: 0.6728 - generalized_dice_coefficient: 0.0301
# Epoch 10: val_loss improved from 0.82159 to 0.82040, saving model to mymodel_10.h5
# 20/20 [==============================] - 2s 118ms/step - loss: 0.8214 - binary_crossentropy: 0.6728 - generalized_dice_coefficient: 0.0301 - val_loss: 0.8204 - val_binary_crossentropy: 0.6713 - val_generalized_dice_coefficient: 0.0305
# Epoch 11/200
# 20/20 [==============================] - ETA: 0s - loss: 0.8198 - binary_crossentropy: 0.6686 - generalized_dice_coefficient: 0.0290
# Epoch 11: val_loss improved from 0.82040 to 0.81876, saving model to mymodel_11.h5
# 20/20 [==============================] - 2s 117ms/step - loss: 0.8198 - binary_crossentropy: 0.6686 - generalized_dice_coefficient: 0.0290 - val_loss: 0.8188 - val_binary_crossentropy: 0.6669 - val_generalized_dice_coefficient: 0.0294
# Epoch 12/200
# 20/20 [==============================] - ETA: 0s - loss: 0.8175 - binary_crossentropy: 0.6624 - generalized_dice_coefficient: 0.0273
# Epoch 12: val_loss improved from 0.81876 to 0.81589, saving model to mymodel_12.h5
# 20/20 [==============================] - 2s 118ms/step - loss: 0.8175 - binary_crossentropy: 0.6624 - generalized_dice_coefficient: 0.0273 - val_loss: 0.8159 - val_binary_crossentropy: 0.6592 - val_generalized_dice_coefficient: 0.0274
# Epoch 13/200
# 20/20 [==============================] - ETA: 0s - loss: 0.8116 - binary_crossentropy: 0.6477 - generalized_dice_coefficient: 0.0244
# Epoch 13: val_loss improved from 0.81589 to 0.80299, saving model to mymodel_13.h5
# 20/20 [==============================] - 2s 117ms/step - loss: 0.8116 - binary_crossentropy: 0.6477 - generalized_dice_coefficient: 0.0244 - val_loss: 0.8030 - val_binary_crossentropy: 0.6281 - val_generalized_dice_coefficient: 0.0221
# Epoch 14/200
# 20/20 [==============================] - ETA: 0s - loss: 0.7771 - binary_crossentropy: 0.5691 - generalized_dice_coefficient: 0.0148
# Epoch 14: val_loss improved from 0.80299 to 0.73991, saving model to mymodel_14.h5
# 20/20 [==============================] - 2s 117ms/step - loss: 0.7771 - binary_crossentropy: 0.5691 - generalized_dice_coefficient: 0.0148 - val_loss: 0.7399 - val_binary_crossentropy: 0.4872 - val_generalized_dice_coefficient: 0.0075
# Epoch 15/200
# 20/20 [==============================] - ETA: 0s - loss: 0.7034 - binary_crossentropy: 0.4117 - generalized_dice_coefficient: 0.0048
# Epoch 15: val_loss improved from 0.73991 to 0.68358, saving model to mymodel_15.h5
# 20/20 [==============================] - 2s 117ms/step - loss: 0.7034 - binary_crossentropy: 0.4117 - generalized_dice_coefficient: 0.0048 - val_loss: 0.6836 - val_binary_crossentropy: 0.3691 - val_generalized_dice_coefficient: 0.0020
# Epoch 16/200
# 20/20 [==============================] - ETA: 0s - loss: 0.6607 - binary_crossentropy: 0.3260 - generalized_dice_coefficient: 0.0046
# Epoch 16: val_loss improved from 0.68358 to 0.64555, saving model to mymodel_16.h5
# 20/20 [==============================] - 2s 118ms/step - loss: 0.6607 - binary_crossentropy: 0.3260 - generalized_dice_coefficient: 0.0046 - val_loss: 0.6455 - val_binary_crossentropy: 0.2950 - val_generalized_dice_coefficient: 0.0040
# Epoch 17/200
# 20/20 [==============================] - ETA: 0s - loss: 0.6287 - binary_crossentropy: 0.2629 - generalized_dice_coefficient: 0.0056
# Epoch 17: val_loss improved from 0.64555 to 0.61623, saving model to mymodel_17.h5
# 20/20 [==============================] - 2s 117ms/step - loss: 0.6287 - binary_crossentropy: 0.2629 - generalized_dice_coefficient: 0.0056 - val_loss: 0.6162 - val_binary_crossentropy: 0.2383 - val_generalized_dice_coefficient: 0.0060
# Epoch 18/200
# 20/20 [==============================] - ETA: 0s - loss: 0.6019 - binary_crossentropy: 0.2120 - generalized_dice_coefficient: 0.0081
# Epoch 18: val_loss improved from 0.61623 to 0.59026, saving model to mymodel_18.h5
# 20/20 [==============================] - 2s 117ms/step - loss: 0.6019 - binary_crossentropy: 0.2120 - generalized_dice_coefficient: 0.0081 - val_loss: 0.5903 - val_binary_crossentropy: 0.1899 - val_generalized_dice_coefficient: 0.0096
# Epoch 19/200
# 20/20 [==============================] - ETA: 0s - loss: 0.5776 - binary_crossentropy: 0.1666 - generalized_dice_coefficient: 0.0115
# Epoch 19: val_loss improved from 0.59026 to 0.56450, saving model to mymodel_19.h5
# 20/20 [==============================] - 2s 116ms/step - loss: 0.5776 - binary_crossentropy: 0.1666 - generalized_dice_coefficient: 0.0115 - val_loss: 0.5645 - val_binary_crossentropy: 0.1471 - val_generalized_dice_coefficient: 0.0183
# Epoch 20/200
# 20/20 [==============================] - ETA: 0s - loss: 0.5518 - binary_crossentropy: 0.1258 - generalized_dice_coefficient: 0.0222
# Epoch 20: val_loss improved from 0.56450 to 0.53331, saving model to mymodel_20.h5
# 20/20 [==============================] - 2s 117ms/step - loss: 0.5518 - binary_crossentropy: 0.1258 - generalized_dice_coefficient: 0.0222 - val_loss: 0.5333 - val_binary_crossentropy: 0.1065 - val_generalized_dice_coefficient: 0.0400
# Epoch 21/200
# 20/20 [==============================] - ETA: 0s - loss: 0.5151 - binary_crossentropy: 0.0877 - generalized_dice_coefficient: 0.0575
# Epoch 21: val_loss improved from 0.53331 to 0.48265, saving model to mymodel_21.h5
# 20/20 [==============================] - 2s 117ms/step - loss: 0.5151 - binary_crossentropy: 0.0877 - generalized_dice_coefficient: 0.0575 - val_loss: 0.4826 - val_binary_crossentropy: 0.0710 - val_generalized_dice_coefficient: 0.1052
# Epoch 22/200
# 20/20 [==============================] - ETA: 0s - loss: 0.4616 - binary_crossentropy: 0.0656 - generalized_dice_coefficient: 0.1423
# Epoch 22: val_loss improved from 0.48265 to 0.43252, saving model to mymodel_22.h5
# 20/20 [==============================] - 2s 117ms/step - loss: 0.4616 - binary_crossentropy: 0.0656 - generalized_dice_coefficient: 0.1423 - val_loss: 0.4325 - val_binary_crossentropy: 0.0614 - val_generalized_dice_coefficient: 0.1956
# Epoch 23/200
# 20/20 [==============================] - ETA: 0s - loss: 0.4271 - binary_crossentropy: 0.0677 - generalized_dice_coefficient: 0.2136
# Epoch 23: val_loss improved from 0.43252 to 0.41120, saving model to mymodel_23.h5
# 20/20 [==============================] - 2s 117ms/step - loss: 0.4271 - binary_crossentropy: 0.0677 - generalized_dice_coefficient: 0.2136 - val_loss: 0.4112 - val_binary_crossentropy: 0.0635 - val_generalized_dice_coefficient: 0.2403
# Epoch 24/200
# 20/20 [==============================] - ETA: 0s - loss: 0.4047 - binary_crossentropy: 0.0644 - generalized_dice_coefficient: 0.2550
# Epoch 24: val_loss improved from 0.41120 to 0.38683, saving model to mymodel_24.h5
# 20/20 [==============================] - 2s 116ms/step - loss: 0.4047 - binary_crossentropy: 0.0644 - generalized_dice_coefficient: 0.2550 - val_loss: 0.3868 - val_binary_crossentropy: 0.0543 - val_generalized_dice_coefficient: 0.2803
# Epoch 25/200
# 20/20 [==============================] - ETA: 0s - loss: 0.3746 - binary_crossentropy: 0.0554 - generalized_dice_coefficient: 0.3061
# Epoch 25: val_loss improved from 0.38683 to 0.35224, saving model to mymodel_25.h5
# 20/20 [==============================] - 2s 116ms/step - loss: 0.3746 - binary_crossentropy: 0.0554 - generalized_dice_coefficient: 0.3061 - val_loss: 0.3522 - val_binary_crossentropy: 0.0456 - val_generalized_dice_coefficient: 0.3408
# Epoch 26/200
# 20/20 [==============================] - ETA: 0s - loss: 0.3392 - binary_crossentropy: 0.0488 - generalized_dice_coefficient: 0.3705
# Epoch 26: val_loss improved from 0.35224 to 0.31717, saving model to mymodel_26.h5
# 20/20 [==============================] - 2s 116ms/step - loss: 0.3392 - binary_crossentropy: 0.0488 - generalized_dice_coefficient: 0.3705 - val_loss: 0.3172 - val_binary_crossentropy: 0.0374 - val_generalized_dice_coefficient: 0.4019
# Epoch 27/200
# 20/20 [==============================] - ETA: 0s - loss: 0.3110 - binary_crossentropy: 0.0463 - generalized_dice_coefficient: 0.4243
# Epoch 27: val_loss improved from 0.31717 to 0.29479, saving model to mymodel_27.h5
# 20/20 [==============================] - 2s 116ms/step - loss: 0.3110 - binary_crossentropy: 0.0463 - generalized_dice_coefficient: 0.4243 - val_loss: 0.2948 - val_binary_crossentropy: 0.0344 - val_generalized_dice_coefficient: 0.4434
# Epoch 28/200
# 20/20 [==============================] - ETA: 0s - loss: 0.2935 - binary_crossentropy: 0.0448 - generalized_dice_coefficient: 0.4577
# Epoch 28: val_loss improved from 0.29479 to 0.28240, saving model to mymodel_28.h5
# 20/20 [==============================] - 2s 116ms/step - loss: 0.2935 - binary_crossentropy: 0.0448 - generalized_dice_coefficient: 0.4577 - val_loss: 0.2824 - val_binary_crossentropy: 0.0322 - val_generalized_dice_coefficient: 0.4659
# Epoch 29/200
# 20/20 [==============================] - ETA: 0s - loss: 0.2883 - binary_crossentropy: 0.0473 - generalized_dice_coefficient: 0.4708
# Epoch 29: val_loss improved from 0.28240 to 0.27416, saving model to mymodel_29.h5
# 20/20 [==============================] - 2s 116ms/step - loss: 0.2883 - binary_crossentropy: 0.0473 - generalized_dice_coefficient: 0.4708 - val_loss: 0.2742 - val_binary_crossentropy: 0.0334 - val_generalized_dice_coefficient: 0.4836
# Epoch 30/200
# 20/20 [==============================] - ETA: 0s - loss: 0.2780 - binary_crossentropy: 0.0452 - generalized_dice_coefficient: 0.4893
# Epoch 30: val_loss improved from 0.27416 to 0.26440, saving model to mymodel_30.h5
# 20/20 [==============================] - 2s 116ms/step - loss: 0.2780 - binary_crossentropy: 0.0452 - generalized_dice_coefficient: 0.4893 - val_loss: 0.2644 - val_binary_crossentropy: 0.0303 - val_generalized_dice_coefficient: 0.5002
# Epoch 31/200
# 20/20 [==============================] - ETA: 0s - loss: 0.2679 - binary_crossentropy: 0.0411 - generalized_dice_coefficient: 0.5053
# Epoch 31: val_loss improved from 0.26440 to 0.25713, saving model to mymodel_31.h5
# 20/20 [==============================] - 2s 116ms/step - loss: 0.2679 - binary_crossentropy: 0.0411 - generalized_dice_coefficient: 0.5053 - val_loss: 0.2571 - val_binary_crossentropy: 0.0299 - val_generalized_dice_coefficient: 0.5143
# Epoch 32/200
# 20/20 [==============================] - ETA: 0s - loss: 0.2596 - binary_crossentropy: 0.0437 - generalized_dice_coefficient: 0.5246
# Epoch 32: val_loss improved from 0.25713 to 0.25005, saving model to mymodel_32.h5
# 20/20 [==============================] - 2s 117ms/step - loss: 0.2596 - binary_crossentropy: 0.0437 - generalized_dice_coefficient: 0.5246 - val_loss: 0.2500 - val_binary_crossentropy: 0.0297 - val_generalized_dice_coefficient: 0.5282
# Epoch 33/200
# 20/20 [==============================] - ETA: 0s - loss: 0.2555 - binary_crossentropy: 0.0429 - generalized_dice_coefficient: 0.5319
# Epoch 33: val_loss improved from 0.25005 to 0.24412, saving model to mymodel_33.h5
# 20/20 [==============================] - 2s 118ms/step - loss: 0.2555 - binary_crossentropy: 0.0429 - generalized_dice_coefficient: 0.5319 - val_loss: 0.2441 - val_binary_crossentropy: 0.0291 - val_generalized_dice_coefficient: 0.5397
# Epoch 34/200
# 20/20 [==============================] - ETA: 0s - loss: 0.2476 - binary_crossentropy: 0.0423 - generalized_dice_coefficient: 0.5472
# Epoch 34: val_loss improved from 0.24412 to 0.23922, saving model to mymodel_34.h5
# 20/20 [==============================] - 2s 117ms/step - loss: 0.2476 - binary_crossentropy: 0.0423 - generalized_dice_coefficient: 0.5472 - val_loss: 0.2392 - val_binary_crossentropy: 0.0272 - val_generalized_dice_coefficient: 0.5474
# Epoch 35/200
# 20/20 [==============================] - ETA: 0s - loss: 0.2431 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.5535
# Epoch 35: val_loss improved from 0.23922 to 0.23188, saving model to mymodel_35.h5
# 20/20 [==============================] - 2s 116ms/step - loss: 0.2431 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.5535 - val_loss: 0.2319 - val_binary_crossentropy: 0.0281 - val_generalized_dice_coefficient: 0.5631
# Epoch 36/200
# 20/20 [==============================] - ETA: 0s - loss: 0.2350 - binary_crossentropy: 0.0399 - generalized_dice_coefficient: 0.5699
# Epoch 36: val_loss improved from 0.23188 to 0.22703, saving model to mymodel_36.h5
# 20/20 [==============================] - 2s 116ms/step - loss: 0.2350 - binary_crossentropy: 0.0399 - generalized_dice_coefficient: 0.5699 - val_loss: 0.2270 - val_binary_crossentropy: 0.0273 - val_generalized_dice_coefficient: 0.5718
# Epoch 37/200
# 20/20 [==============================] - ETA: 0s - loss: 0.2283 - binary_crossentropy: 0.0384 - generalized_dice_coefficient: 0.5817
# Epoch 37: val_loss improved from 0.22703 to 0.22156, saving model to mymodel_37.h5
# 20/20 [==============================] - 2s 117ms/step - loss: 0.2283 - binary_crossentropy: 0.0384 - generalized_dice_coefficient: 0.5817 - val_loss: 0.2216 - val_binary_crossentropy: 0.0276 - val_generalized_dice_coefficient: 0.5832
# Epoch 38/200
# 20/20 [==============================] - ETA: 0s - loss: 0.2252 - binary_crossentropy: 0.0390 - generalized_dice_coefficient: 0.5885
# Epoch 38: val_loss improved from 0.22156 to 0.21789, saving model to mymodel_38.h5
# 20/20 [==============================] - 2s 117ms/step - loss: 0.2252 - binary_crossentropy: 0.0390 - generalized_dice_coefficient: 0.5885 - val_loss: 0.2179 - val_binary_crossentropy: 0.0280 - val_generalized_dice_coefficient: 0.5908
# Epoch 39/200
# 20/20 [==============================] - ETA: 0s - loss: 0.2181 - binary_crossentropy: 0.0367 - generalized_dice_coefficient: 0.6005
# Epoch 39: val_loss improved from 0.21789 to 0.21187, saving model to mymodel_39.h5
# 20/20 [==============================] - 2s 117ms/step - loss: 0.2181 - binary_crossentropy: 0.0367 - generalized_dice_coefficient: 0.6005 - val_loss: 0.2119 - val_binary_crossentropy: 0.0261 - val_generalized_dice_coefficient: 0.6008
# Epoch 40/200
# 20/20 [==============================] - ETA: 0s - loss: 0.2098 - binary_crossentropy: 0.0361 - generalized_dice_coefficient: 0.6165
# Epoch 40: val_loss improved from 0.21187 to 0.20810, saving model to mymodel_40.h5
# 20/20 [==============================] - 2s 117ms/step - loss: 0.2098 - binary_crossentropy: 0.0361 - generalized_dice_coefficient: 0.6165 - val_loss: 0.2081 - val_binary_crossentropy: 0.0279 - val_generalized_dice_coefficient: 0.6105
# Epoch 41/200
# 20/20 [==============================] - ETA: 0s - loss: 0.2081 - binary_crossentropy: 0.0366 - generalized_dice_coefficient: 0.6204
# Epoch 41: val_loss improved from 0.20810 to 0.20247, saving model to mymodel_41.h5
# 20/20 [==============================] - 2s 117ms/step - loss: 0.2081 - binary_crossentropy: 0.0366 - generalized_dice_coefficient: 0.6204 - val_loss: 0.2025 - val_binary_crossentropy: 0.0252 - val_generalized_dice_coefficient: 0.6189
# Epoch 42/200
# 20/20 [==============================] - ETA: 0s - loss: 0.2018 - binary_crossentropy: 0.0372 - generalized_dice_coefficient: 0.6336
# Epoch 42: val_loss improved from 0.20247 to 0.19740, saving model to mymodel_42.h5
# 20/20 [==============================] - 2s 117ms/step - loss: 0.2018 - binary_crossentropy: 0.0372 - generalized_dice_coefficient: 0.6336 - val_loss: 0.1974 - val_binary_crossentropy: 0.0264 - val_generalized_dice_coefficient: 0.6302
# Epoch 43/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1962 - binary_crossentropy: 0.0350 - generalized_dice_coefficient: 0.6427
# Epoch 43: val_loss improved from 0.19740 to 0.19265, saving model to mymodel_43.h5
# 20/20 [==============================] - 2s 117ms/step - loss: 0.1962 - binary_crossentropy: 0.0350 - generalized_dice_coefficient: 0.6427 - val_loss: 0.1926 - val_binary_crossentropy: 0.0274 - val_generalized_dice_coefficient: 0.6409
# Epoch 44/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1901 - binary_crossentropy: 0.0348 - generalized_dice_coefficient: 0.6545
# Epoch 44: val_loss improved from 0.19265 to 0.18655, saving model to mymodel_44.h5
# 20/20 [==============================] - 2s 116ms/step - loss: 0.1901 - binary_crossentropy: 0.0348 - generalized_dice_coefficient: 0.6545 - val_loss: 0.1865 - val_binary_crossentropy: 0.0253 - val_generalized_dice_coefficient: 0.6506
# Epoch 45/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1851 - binary_crossentropy: 0.0346 - generalized_dice_coefficient: 0.6644
# Epoch 45: val_loss improved from 0.18655 to 0.18190, saving model to mymodel_45.h5
# 20/20 [==============================] - 2s 117ms/step - loss: 0.1851 - binary_crossentropy: 0.0346 - generalized_dice_coefficient: 0.6644 - val_loss: 0.1819 - val_binary_crossentropy: 0.0283 - val_generalized_dice_coefficient: 0.6633
# Epoch 46/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1798 - binary_crossentropy: 0.0345 - generalized_dice_coefficient: 0.6749
# Epoch 46: val_loss improved from 0.18190 to 0.17866, saving model to mymodel_46.h5
# 20/20 [==============================] - 2s 117ms/step - loss: 0.1798 - binary_crossentropy: 0.0345 - generalized_dice_coefficient: 0.6749 - val_loss: 0.1787 - val_binary_crossentropy: 0.0248 - val_generalized_dice_coefficient: 0.6655
# Epoch 47/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1725 - binary_crossentropy: 0.0342 - generalized_dice_coefficient: 0.6891
# Epoch 47: val_loss improved from 0.17866 to 0.16935, saving model to mymodel_47.h5
# 20/20 [==============================] - 2s 116ms/step - loss: 0.1725 - binary_crossentropy: 0.0342 - generalized_dice_coefficient: 0.6891 - val_loss: 0.1694 - val_binary_crossentropy: 0.0305 - val_generalized_dice_coefficient: 0.6902
# Epoch 48/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1615 - binary_crossentropy: 0.0335 - generalized_dice_coefficient: 0.7105
# Epoch 48: val_loss improved from 0.16935 to 0.15747, saving model to mymodel_48.h5
# 20/20 [==============================] - 2s 117ms/step - loss: 0.1615 - binary_crossentropy: 0.0335 - generalized_dice_coefficient: 0.7105 - val_loss: 0.1575 - val_binary_crossentropy: 0.0269 - val_generalized_dice_coefficient: 0.7101
# Epoch 49/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1546 - binary_crossentropy: 0.0353 - generalized_dice_coefficient: 0.7261
# Epoch 49: val_loss improved from 0.15747 to 0.15000, saving model to mymodel_49.h5
# 20/20 [==============================] - 2s 116ms/step - loss: 0.1546 - binary_crossentropy: 0.0353 - generalized_dice_coefficient: 0.7261 - val_loss: 0.1500 - val_binary_crossentropy: 0.0291 - val_generalized_dice_coefficient: 0.7271
# Epoch 50/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1480 - binary_crossentropy: 0.0356 - generalized_dice_coefficient: 0.7395
# Epoch 50: val_loss improved from 0.15000 to 0.14227, saving model to mymodel_50.h5
# 20/20 [==============================] - 2s 117ms/step - loss: 0.1480 - binary_crossentropy: 0.0356 - generalized_dice_coefficient: 0.7395 - val_loss: 0.1423 - val_binary_crossentropy: 0.0289 - val_generalized_dice_coefficient: 0.7420
# Epoch 51/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1427 - binary_crossentropy: 0.0362 - generalized_dice_coefficient: 0.7509
# Epoch 51: val_loss improved from 0.14227 to 0.13594, saving model to mymodel_51.h5
# 20/20 [==============================] - 2s 116ms/step - loss: 0.1427 - binary_crossentropy: 0.0362 - generalized_dice_coefficient: 0.7509 - val_loss: 0.1359 - val_binary_crossentropy: 0.0293 - val_generalized_dice_coefficient: 0.7552
# Epoch 52/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1391 - binary_crossentropy: 0.0370 - generalized_dice_coefficient: 0.7587
# Epoch 52: val_loss improved from 0.13594 to 0.13003, saving model to mymodel_52.h5
# 20/20 [==============================] - 2s 117ms/step - loss: 0.1391 - binary_crossentropy: 0.0370 - generalized_dice_coefficient: 0.7587 - val_loss: 0.1300 - val_binary_crossentropy: 0.0313 - val_generalized_dice_coefficient: 0.7690
# Epoch 53/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1345 - binary_crossentropy: 0.0395 - generalized_dice_coefficient: 0.7705
# Epoch 53: val_loss improved from 0.13003 to 0.12945, saving model to mymodel_53.h5
# 20/20 [==============================] - 2s 117ms/step - loss: 0.1345 - binary_crossentropy: 0.0395 - generalized_dice_coefficient: 0.7705 - val_loss: 0.1295 - val_binary_crossentropy: 0.0321 - val_generalized_dice_coefficient: 0.7709
# Epoch 54/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1320 - binary_crossentropy: 0.0386 - generalized_dice_coefficient: 0.7746
# Epoch 54: val_loss improved from 0.12945 to 0.12628, saving model to mymodel_54.h5
# 20/20 [==============================] - 2s 117ms/step - loss: 0.1320 - binary_crossentropy: 0.0386 - generalized_dice_coefficient: 0.7746 - val_loss: 0.1263 - val_binary_crossentropy: 0.0338 - val_generalized_dice_coefficient: 0.7790
# Epoch 55/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1316 - binary_crossentropy: 0.0405 - generalized_dice_coefficient: 0.7772
# Epoch 55: val_loss improved from 0.12628 to 0.12333, saving model to mymodel_55.h5
# 20/20 [==============================] - 2s 117ms/step - loss: 0.1316 - binary_crossentropy: 0.0405 - generalized_dice_coefficient: 0.7772 - val_loss: 0.1233 - val_binary_crossentropy: 0.0353 - val_generalized_dice_coefficient: 0.7864
# Epoch 56/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1284 - binary_crossentropy: 0.0419 - generalized_dice_coefficient: 0.7851
# Epoch 56: val_loss improved from 0.12333 to 0.12238, saving model to mymodel_56.h5
# 20/20 [==============================] - 2s 117ms/step - loss: 0.1284 - binary_crossentropy: 0.0419 - generalized_dice_coefficient: 0.7851 - val_loss: 0.1224 - val_binary_crossentropy: 0.0347 - val_generalized_dice_coefficient: 0.7878
# Epoch 57/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1265 - binary_crossentropy: 0.0394 - generalized_dice_coefficient: 0.7864
# Epoch 57: val_loss improved from 0.12238 to 0.12012, saving model to mymodel_57.h5
# 20/20 [==============================] - 2s 116ms/step - loss: 0.1265 - binary_crossentropy: 0.0394 - generalized_dice_coefficient: 0.7864 - val_loss: 0.1201 - val_binary_crossentropy: 0.0342 - val_generalized_dice_coefficient: 0.7919
# Epoch 58/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1294 - binary_crossentropy: 0.0412 - generalized_dice_coefficient: 0.7824
# Epoch 58: val_loss did not improve from 0.12012
# 20/20 [==============================] - 2s 105ms/step - loss: 0.1294 - binary_crossentropy: 0.0412 - generalized_dice_coefficient: 0.7824 - val_loss: 0.1202 - val_binary_crossentropy: 0.0347 - val_generalized_dice_coefficient: 0.7921
# Epoch 59/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1258 - binary_crossentropy: 0.0392 - generalized_dice_coefficient: 0.7876
# Epoch 59: val_loss improved from 0.12012 to 0.11923, saving model to mymodel_59.h5
# 20/20 [==============================] - 2s 117ms/step - loss: 0.1258 - binary_crossentropy: 0.0392 - generalized_dice_coefficient: 0.7876 - val_loss: 0.1192 - val_binary_crossentropy: 0.0346 - val_generalized_dice_coefficient: 0.7940
# Epoch 60/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1256 - binary_crossentropy: 0.0407 - generalized_dice_coefficient: 0.7896
# Epoch 60: val_loss improved from 0.11923 to 0.11810, saving model to mymodel_60.h5
# 20/20 [==============================] - 2s 116ms/step - loss: 0.1256 - binary_crossentropy: 0.0407 - generalized_dice_coefficient: 0.7896 - val_loss: 0.1181 - val_binary_crossentropy: 0.0347 - val_generalized_dice_coefficient: 0.7964
# Epoch 61/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1245 - binary_crossentropy: 0.0410 - generalized_dice_coefficient: 0.7920
# Epoch 61: val_loss improved from 0.11810 to 0.11767, saving model to mymodel_61.h5
# 20/20 [==============================] - 2s 116ms/step - loss: 0.1245 - binary_crossentropy: 0.0410 - generalized_dice_coefficient: 0.7920 - val_loss: 0.1177 - val_binary_crossentropy: 0.0354 - val_generalized_dice_coefficient: 0.7979
# Epoch 62/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1234 - binary_crossentropy: 0.0397 - generalized_dice_coefficient: 0.7929
# Epoch 62: val_loss did not improve from 0.11767
# 20/20 [==============================] - 2s 105ms/step - loss: 0.1234 - binary_crossentropy: 0.0397 - generalized_dice_coefficient: 0.7929 - val_loss: 0.1180 - val_binary_crossentropy: 0.0348 - val_generalized_dice_coefficient: 0.7967
# Epoch 63/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1214 - binary_crossentropy: 0.0388 - generalized_dice_coefficient: 0.7960
# Epoch 63: val_loss improved from 0.11767 to 0.11608, saving model to mymodel_63.h5
# 20/20 [==============================] - 2s 116ms/step - loss: 0.1214 - binary_crossentropy: 0.0388 - generalized_dice_coefficient: 0.7960 - val_loss: 0.1161 - val_binary_crossentropy: 0.0349 - val_generalized_dice_coefficient: 0.8007
# Epoch 64/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1234 - binary_crossentropy: 0.0414 - generalized_dice_coefficient: 0.7946
# Epoch 64: val_loss did not improve from 0.11608
# 20/20 [==============================] - 2s 105ms/step - loss: 0.1234 - binary_crossentropy: 0.0414 - generalized_dice_coefficient: 0.7946 - val_loss: 0.1219 - val_binary_crossentropy: 0.0380 - val_generalized_dice_coefficient: 0.7918
# Epoch 65/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1230 - binary_crossentropy: 0.0397 - generalized_dice_coefficient: 0.7937
# Epoch 65: val_loss did not improve from 0.11608
# 20/20 [==============================] - 2s 106ms/step - loss: 0.1230 - binary_crossentropy: 0.0397 - generalized_dice_coefficient: 0.7937 - val_loss: 0.1190 - val_binary_crossentropy: 0.0367 - val_generalized_dice_coefficient: 0.7964
# Epoch 66/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1202 - binary_crossentropy: 0.0387 - generalized_dice_coefficient: 0.7983
# Epoch 66: val_loss did not improve from 0.11608
# 20/20 [==============================] - 2s 105ms/step - loss: 0.1202 - binary_crossentropy: 0.0387 - generalized_dice_coefficient: 0.7983 - val_loss: 0.1163 - val_binary_crossentropy: 0.0358 - val_generalized_dice_coefficient: 0.8011
# Epoch 67/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1196 - binary_crossentropy: 0.0390 - generalized_dice_coefficient: 0.7999
# Epoch 67: val_loss improved from 0.11608 to 0.11463, saving model to mymodel_67.h5
# 20/20 [==============================] - 2s 116ms/step - loss: 0.1196 - binary_crossentropy: 0.0390 - generalized_dice_coefficient: 0.7999 - val_loss: 0.1146 - val_binary_crossentropy: 0.0348 - val_generalized_dice_coefficient: 0.8035
# Epoch 68/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1202 - binary_crossentropy: 0.0390 - generalized_dice_coefficient: 0.7987
# Epoch 68: val_loss improved from 0.11463 to 0.11415, saving model to mymodel_68.h5
# 20/20 [==============================] - 2s 116ms/step - loss: 0.1202 - binary_crossentropy: 0.0390 - generalized_dice_coefficient: 0.7987 - val_loss: 0.1142 - val_binary_crossentropy: 0.0343 - val_generalized_dice_coefficient: 0.8039
# Epoch 69/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1198 - binary_crossentropy: 0.0399 - generalized_dice_coefficient: 0.8003
# Epoch 69: val_loss improved from 0.11415 to 0.11364, saving model to mymodel_69.h5
# 20/20 [==============================] - 2s 117ms/step - loss: 0.1198 - binary_crossentropy: 0.0399 - generalized_dice_coefficient: 0.8003 - val_loss: 0.1136 - val_binary_crossentropy: 0.0339 - val_generalized_dice_coefficient: 0.8045
# Epoch 70/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1171 - binary_crossentropy: 0.0360 - generalized_dice_coefficient: 0.8018
# Epoch 70: val_loss did not improve from 0.11364
# 20/20 [==============================] - 2s 105ms/step - loss: 0.1171 - binary_crossentropy: 0.0360 - generalized_dice_coefficient: 0.8018 - val_loss: 0.1140 - val_binary_crossentropy: 0.0346 - val_generalized_dice_coefficient: 0.8045
# Epoch 71/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1186 - binary_crossentropy: 0.0377 - generalized_dice_coefficient: 0.8005
# Epoch 71: val_loss did not improve from 0.11364
# 20/20 [==============================] - 2s 105ms/step - loss: 0.1186 - binary_crossentropy: 0.0377 - generalized_dice_coefficient: 0.8005 - val_loss: 0.1140 - val_binary_crossentropy: 0.0350 - val_generalized_dice_coefficient: 0.8049
# Epoch 72/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1183 - binary_crossentropy: 0.0385 - generalized_dice_coefficient: 0.8019
# Epoch 72: val_loss improved from 0.11364 to 0.11338, saving model to mymodel_72.h5
# 20/20 [==============================] - 2s 117ms/step - loss: 0.1183 - binary_crossentropy: 0.0385 - generalized_dice_coefficient: 0.8019 - val_loss: 0.1134 - val_binary_crossentropy: 0.0345 - val_generalized_dice_coefficient: 0.8057
# Epoch 73/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1158 - binary_crossentropy: 0.0364 - generalized_dice_coefficient: 0.8048
# Epoch 73: val_loss improved from 0.11338 to 0.11271, saving model to mymodel_73.h5
# 20/20 [==============================] - 2s 117ms/step - loss: 0.1158 - binary_crossentropy: 0.0364 - generalized_dice_coefficient: 0.8048 - val_loss: 0.1127 - val_binary_crossentropy: 0.0344 - val_generalized_dice_coefficient: 0.8069
# Epoch 74/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1150 - binary_crossentropy: 0.0372 - generalized_dice_coefficient: 0.8071
# Epoch 74: val_loss did not improve from 0.11271
# 20/20 [==============================] - 2s 107ms/step - loss: 0.1150 - binary_crossentropy: 0.0372 - generalized_dice_coefficient: 0.8071 - val_loss: 0.1143 - val_binary_crossentropy: 0.0345 - val_generalized_dice_coefficient: 0.8038
# Epoch 75/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1169 - binary_crossentropy: 0.0373 - generalized_dice_coefficient: 0.8036
# Epoch 75: val_loss did not improve from 0.11271
# 20/20 [==============================] - 2s 106ms/step - loss: 0.1169 - binary_crossentropy: 0.0373 - generalized_dice_coefficient: 0.8036 - val_loss: 0.1133 - val_binary_crossentropy: 0.0356 - val_generalized_dice_coefficient: 0.8071
# Epoch 76/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1163 - binary_crossentropy: 0.0382 - generalized_dice_coefficient: 0.8056
# Epoch 76: val_loss did not improve from 0.11271
# 20/20 [==============================] - 2s 105ms/step - loss: 0.1163 - binary_crossentropy: 0.0382 - generalized_dice_coefficient: 0.8056 - val_loss: 0.1138 - val_binary_crossentropy: 0.0345 - val_generalized_dice_coefficient: 0.8051
# Epoch 77/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1154 - binary_crossentropy: 0.0366 - generalized_dice_coefficient: 0.8058
# Epoch 77: val_loss improved from 0.11271 to 0.11209, saving model to mymodel_77.h5
# 20/20 [==============================] - 2s 117ms/step - loss: 0.1154 - binary_crossentropy: 0.0366 - generalized_dice_coefficient: 0.8058 - val_loss: 0.1121 - val_binary_crossentropy: 0.0347 - val_generalized_dice_coefficient: 0.8084
# Epoch 78/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1188 - binary_crossentropy: 0.0387 - generalized_dice_coefficient: 0.8011
# Epoch 78: val_loss did not improve from 0.11209
# 20/20 [==============================] - 2s 106ms/step - loss: 0.1188 - binary_crossentropy: 0.0387 - generalized_dice_coefficient: 0.8011 - val_loss: 0.1136 - val_binary_crossentropy: 0.0345 - val_generalized_dice_coefficient: 0.8054
# Epoch 79/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1163 - binary_crossentropy: 0.0365 - generalized_dice_coefficient: 0.8038
# Epoch 79: val_loss did not improve from 0.11209
# 20/20 [==============================] - 2s 105ms/step - loss: 0.1163 - binary_crossentropy: 0.0365 - generalized_dice_coefficient: 0.8038 - val_loss: 0.1170 - val_binary_crossentropy: 0.0385 - val_generalized_dice_coefficient: 0.8029
# Epoch 80/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1178 - binary_crossentropy: 0.0399 - generalized_dice_coefficient: 0.8042
# Epoch 80: val_loss improved from 0.11209 to 0.11120, saving model to mymodel_80.h5
# 20/20 [==============================] - 2s 116ms/step - loss: 0.1178 - binary_crossentropy: 0.0399 - generalized_dice_coefficient: 0.8042 - val_loss: 0.1112 - val_binary_crossentropy: 0.0335 - val_generalized_dice_coefficient: 0.8091
# Epoch 81/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1158 - binary_crossentropy: 0.0359 - generalized_dice_coefficient: 0.8042
# Epoch 81: val_loss improved from 0.11120 to 0.11058, saving model to mymodel_81.h5
# 20/20 [==============================] - 2s 117ms/step - loss: 0.1158 - binary_crossentropy: 0.0359 - generalized_dice_coefficient: 0.8042 - val_loss: 0.1106 - val_binary_crossentropy: 0.0330 - val_generalized_dice_coefficient: 0.8098
# Epoch 82/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1134 - binary_crossentropy: 0.0357 - generalized_dice_coefficient: 0.8090
# Epoch 82: val_loss did not improve from 0.11058
# 20/20 [==============================] - 2s 106ms/step - loss: 0.1134 - binary_crossentropy: 0.0357 - generalized_dice_coefficient: 0.8090 - val_loss: 0.1118 - val_binary_crossentropy: 0.0337 - val_generalized_dice_coefficient: 0.8082
# Epoch 83/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1133 - binary_crossentropy: 0.0358 - generalized_dice_coefficient: 0.8091
# Epoch 83: val_loss did not improve from 0.11058
# 20/20 [==============================] - 2s 105ms/step - loss: 0.1133 - binary_crossentropy: 0.0358 - generalized_dice_coefficient: 0.8091 - val_loss: 0.1109 - val_binary_crossentropy: 0.0341 - val_generalized_dice_coefficient: 0.8104
# Epoch 84/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1128 - binary_crossentropy: 0.0356 - generalized_dice_coefficient: 0.8100
# Epoch 84: val_loss did not improve from 0.11058
# 20/20 [==============================] - 2s 105ms/step - loss: 0.1128 - binary_crossentropy: 0.0356 - generalized_dice_coefficient: 0.8100 - val_loss: 0.1108 - val_binary_crossentropy: 0.0339 - val_generalized_dice_coefficient: 0.8102
# Epoch 85/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1144 - binary_crossentropy: 0.0375 - generalized_dice_coefficient: 0.8087
# Epoch 85: val_loss did not improve from 0.11058
# 20/20 [==============================] - 2s 106ms/step - loss: 0.1144 - binary_crossentropy: 0.0375 - generalized_dice_coefficient: 0.8087 - val_loss: 0.1119 - val_binary_crossentropy: 0.0353 - val_generalized_dice_coefficient: 0.8097
# Epoch 86/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1116 - binary_crossentropy: 0.0358 - generalized_dice_coefficient: 0.8127
# Epoch 86: val_loss did not improve from 0.11058
# 20/20 [==============================] - 2s 105ms/step - loss: 0.1116 - binary_crossentropy: 0.0358 - generalized_dice_coefficient: 0.8127 - val_loss: 0.1142 - val_binary_crossentropy: 0.0340 - val_generalized_dice_coefficient: 0.8037
# Epoch 87/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1117 - binary_crossentropy: 0.0357 - generalized_dice_coefficient: 0.8124
# Epoch 87: val_loss improved from 0.11058 to 0.11056, saving model to mymodel_87.h5
# 20/20 [==============================] - 2s 117ms/step - loss: 0.1117 - binary_crossentropy: 0.0357 - generalized_dice_coefficient: 0.8124 - val_loss: 0.1106 - val_binary_crossentropy: 0.0341 - val_generalized_dice_coefficient: 0.8110
# Epoch 88/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1120 - binary_crossentropy: 0.0347 - generalized_dice_coefficient: 0.8108
# Epoch 88: val_loss improved from 0.11056 to 0.10977, saving model to mymodel_88.h5
# 20/20 [==============================] - 2s 116ms/step - loss: 0.1120 - binary_crossentropy: 0.0347 - generalized_dice_coefficient: 0.8108 - val_loss: 0.1098 - val_binary_crossentropy: 0.0331 - val_generalized_dice_coefficient: 0.8115
# Epoch 89/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1117 - binary_crossentropy: 0.0353 - generalized_dice_coefficient: 0.8119
# Epoch 89: val_loss did not improve from 0.10977
# 20/20 [==============================] - 2s 105ms/step - loss: 0.1117 - binary_crossentropy: 0.0353 - generalized_dice_coefficient: 0.8119 - val_loss: 0.1100 - val_binary_crossentropy: 0.0334 - val_generalized_dice_coefficient: 0.8113
# Epoch 90/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1111 - binary_crossentropy: 0.0349 - generalized_dice_coefficient: 0.8126
# Epoch 90: val_loss did not improve from 0.10977
# 20/20 [==============================] - 2s 105ms/step - loss: 0.1111 - binary_crossentropy: 0.0349 - generalized_dice_coefficient: 0.8126 - val_loss: 0.1107 - val_binary_crossentropy: 0.0330 - val_generalized_dice_coefficient: 0.8097
# Epoch 91/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1122 - binary_crossentropy: 0.0349 - generalized_dice_coefficient: 0.8105
# Epoch 91: val_loss did not improve from 0.10977
# 20/20 [==============================] - 2s 105ms/step - loss: 0.1122 - binary_crossentropy: 0.0349 - generalized_dice_coefficient: 0.8105 - val_loss: 0.1105 - val_binary_crossentropy: 0.0341 - val_generalized_dice_coefficient: 0.8110
# Epoch 92/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1135 - binary_crossentropy: 0.0362 - generalized_dice_coefficient: 0.8092
# Epoch 92: val_loss did not improve from 0.10977
# 20/20 [==============================] - 2s 106ms/step - loss: 0.1135 - binary_crossentropy: 0.0362 - generalized_dice_coefficient: 0.8092 - val_loss: 0.1128 - val_binary_crossentropy: 0.0366 - val_generalized_dice_coefficient: 0.8093
# Epoch 93/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1161 - binary_crossentropy: 0.0392 - generalized_dice_coefficient: 0.8069
# Epoch 93: val_loss improved from 0.10977 to 0.10905, saving model to mymodel_93.h5
# 20/20 [==============================] - 2s 117ms/step - loss: 0.1161 - binary_crossentropy: 0.0392 - generalized_dice_coefficient: 0.8069 - val_loss: 0.1090 - val_binary_crossentropy: 0.0328 - val_generalized_dice_coefficient: 0.8126
# Epoch 94/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1114 - binary_crossentropy: 0.0340 - generalized_dice_coefficient: 0.8112
# Epoch 94: val_loss did not improve from 0.10905
# 20/20 [==============================] - 2s 106ms/step - loss: 0.1114 - binary_crossentropy: 0.0340 - generalized_dice_coefficient: 0.8112 - val_loss: 0.1096 - val_binary_crossentropy: 0.0319 - val_generalized_dice_coefficient: 0.8107
# Epoch 95/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1100 - binary_crossentropy: 0.0335 - generalized_dice_coefficient: 0.8135
# Epoch 95: val_loss improved from 0.10905 to 0.10827, saving model to mymodel_95.h5
# 20/20 [==============================] - 2s 116ms/step - loss: 0.1100 - binary_crossentropy: 0.0335 - generalized_dice_coefficient: 0.8135 - val_loss: 0.1083 - val_binary_crossentropy: 0.0322 - val_generalized_dice_coefficient: 0.8137
# Epoch 96/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1084 - binary_crossentropy: 0.0338 - generalized_dice_coefficient: 0.8170
# Epoch 96: val_loss improved from 0.10827 to 0.10807, saving model to mymodel_96.h5
# 20/20 [==============================] - 2s 118ms/step - loss: 0.1084 - binary_crossentropy: 0.0338 - generalized_dice_coefficient: 0.8170 - val_loss: 0.1081 - val_binary_crossentropy: 0.0327 - val_generalized_dice_coefficient: 0.8146
# Epoch 97/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1106 - binary_crossentropy: 0.0347 - generalized_dice_coefficient: 0.8134
# Epoch 97: val_loss did not improve from 0.10807
# 20/20 [==============================] - 2s 106ms/step - loss: 0.1106 - binary_crossentropy: 0.0347 - generalized_dice_coefficient: 0.8134 - val_loss: 0.1081 - val_binary_crossentropy: 0.0325 - val_generalized_dice_coefficient: 0.8142
# Epoch 98/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1094 - binary_crossentropy: 0.0341 - generalized_dice_coefficient: 0.8152
# Epoch 98: val_loss did not improve from 0.10807
# 20/20 [==============================] - 2s 106ms/step - loss: 0.1094 - binary_crossentropy: 0.0341 - generalized_dice_coefficient: 0.8152 - val_loss: 0.1119 - val_binary_crossentropy: 0.0344 - val_generalized_dice_coefficient: 0.8086
# Epoch 99/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1135 - binary_crossentropy: 0.0379 - generalized_dice_coefficient: 0.8109
# Epoch 99: val_loss improved from 0.10807 to 0.10752, saving model to mymodel_99.h5
# 20/20 [==============================] - 2s 116ms/step - loss: 0.1135 - binary_crossentropy: 0.0379 - generalized_dice_coefficient: 0.8109 - val_loss: 0.1075 - val_binary_crossentropy: 0.0323 - val_generalized_dice_coefficient: 0.8153
# Epoch 100/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1086 - binary_crossentropy: 0.0329 - generalized_dice_coefficient: 0.8158
# Epoch 100: val_loss did not improve from 0.10752
# 20/20 [==============================] - 2s 106ms/step - loss: 0.1086 - binary_crossentropy: 0.0329 - generalized_dice_coefficient: 0.8158 - val_loss: 0.1100 - val_binary_crossentropy: 0.0324 - val_generalized_dice_coefficient: 0.8106
# Epoch 101/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1096 - binary_crossentropy: 0.0332 - generalized_dice_coefficient: 0.8140
# Epoch 101: val_loss did not improve from 0.10752
# 20/20 [==============================] - 2s 106ms/step - loss: 0.1096 - binary_crossentropy: 0.0332 - generalized_dice_coefficient: 0.8140 - val_loss: 0.1077 - val_binary_crossentropy: 0.0323 - val_generalized_dice_coefficient: 0.8149
# Epoch 102/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1122 - binary_crossentropy: 0.0356 - generalized_dice_coefficient: 0.8112
# Epoch 102: val_loss did not improve from 0.10752
# 20/20 [==============================] - 2s 105ms/step - loss: 0.1122 - binary_crossentropy: 0.0356 - generalized_dice_coefficient: 0.8112 - val_loss: 0.1096 - val_binary_crossentropy: 0.0327 - val_generalized_dice_coefficient: 0.8114
# Epoch 103/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1090 - binary_crossentropy: 0.0335 - generalized_dice_coefficient: 0.8156
# Epoch 103: val_loss did not improve from 0.10752
# 20/20 [==============================] - 2s 106ms/step - loss: 0.1090 - binary_crossentropy: 0.0335 - generalized_dice_coefficient: 0.8156 - val_loss: 0.1079 - val_binary_crossentropy: 0.0323 - val_generalized_dice_coefficient: 0.8145
# Epoch 104/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1095 - binary_crossentropy: 0.0333 - generalized_dice_coefficient: 0.8142
# Epoch 104: val_loss improved from 0.10752 to 0.10727, saving model to mymodel_104.h5
# 20/20 [==============================] - 2s 116ms/step - loss: 0.1095 - binary_crossentropy: 0.0333 - generalized_dice_coefficient: 0.8142 - val_loss: 0.1073 - val_binary_crossentropy: 0.0321 - val_generalized_dice_coefficient: 0.8157
# Epoch 105/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1079 - binary_crossentropy: 0.0332 - generalized_dice_coefficient: 0.8174
# Epoch 105: val_loss did not improve from 0.10727
# 20/20 [==============================] - 2s 105ms/step - loss: 0.1079 - binary_crossentropy: 0.0332 - generalized_dice_coefficient: 0.8174 - val_loss: 0.1074 - val_binary_crossentropy: 0.0318 - val_generalized_dice_coefficient: 0.8150
# Epoch 106/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1093 - binary_crossentropy: 0.0343 - generalized_dice_coefficient: 0.8158
# Epoch 106: val_loss improved from 0.10727 to 0.10715, saving model to mymodel_106.h5
# ...
# 20/20 [==============================] - 2s 106ms/step - loss: 0.1045 - binary_crossentropy: 0.0305 - generalized_dice_coefficient: 0.8215 - val_loss: 0.1047 - val_binary_crossentropy: 0.0300 - val_generalized_dice_coefficient: 0.8186
# Epoch 165/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1017 - binary_crossentropy: 0.0304 - generalized_dice_coefficient: 0.8271
# Epoch 165: val_loss did not improve from 0.10370
# 20/20 [==============================] - 2s 106ms/step - loss: 0.1017 - binary_crossentropy: 0.0304 - generalized_dice_coefficient: 0.8271 - val_loss: 0.1046 - val_binary_crossentropy: 0.0303 - val_generalized_dice_coefficient: 0.8193
# Epoch 166/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1041 - binary_crossentropy: 0.0314 - generalized_dice_coefficient: 0.8232
# Epoch 166: val_loss did not improve from 0.10370
# 20/20 [==============================] - 2s 106ms/step - loss: 0.1041 - binary_crossentropy: 0.0314 - generalized_dice_coefficient: 0.8232 - val_loss: 0.1043 - val_binary_crossentropy: 0.0311 - val_generalized_dice_coefficient: 0.8208
# Epoch 167/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1043 - binary_crossentropy: 0.0319 - generalized_dice_coefficient: 0.8232
# Epoch 167: val_loss did not improve from 0.10370
# 20/20 [==============================] - 2s 106ms/step - loss: 0.1043 - binary_crossentropy: 0.0319 - generalized_dice_coefficient: 0.8232 - val_loss: 0.1042 - val_binary_crossentropy: 0.0291 - val_generalized_dice_coefficient: 0.8188
# Epoch 168/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1034 - binary_crossentropy: 0.0306 - generalized_dice_coefficient: 0.8239
# Epoch 168: val_loss improved from 0.10370 to 0.10363, saving model to mymodel_168.h5
# 20/20 [==============================] - 2s 116ms/step - loss: 0.1034 - binary_crossentropy: 0.0306 - generalized_dice_coefficient: 0.8239 - val_loss: 0.1036 - val_binary_crossentropy: 0.0298 - val_generalized_dice_coefficient: 0.8206
# Epoch 169/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1103 - binary_crossentropy: 0.0314 - generalized_dice_coefficient: 0.8108
# Epoch 169: val_loss did not improve from 0.10363
# 20/20 [==============================] - 2s 105ms/step - loss: 0.1103 - binary_crossentropy: 0.0314 - generalized_dice_coefficient: 0.8108 - val_loss: 0.1242 - val_binary_crossentropy: 0.0364 - val_generalized_dice_coefficient: 0.7858
# Epoch 170/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1256 - binary_crossentropy: 0.0486 - generalized_dice_coefficient: 0.7974
# Epoch 170: val_loss did not improve from 0.10363
# 20/20 [==============================] - 2s 105ms/step - loss: 0.1256 - binary_crossentropy: 0.0486 - generalized_dice_coefficient: 0.7974 - val_loss: 0.1146 - val_binary_crossentropy: 0.0383 - val_generalized_dice_coefficient: 0.8075
# Epoch 171/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1148 - binary_crossentropy: 0.0427 - generalized_dice_coefficient: 0.8131
# Epoch 171: val_loss did not improve from 0.10363
# 20/20 [==============================] - 2s 106ms/step - loss: 0.1148 - binary_crossentropy: 0.0427 - generalized_dice_coefficient: 0.8131 - val_loss: 0.1059 - val_binary_crossentropy: 0.0301 - val_generalized_dice_coefficient: 0.8164
# Epoch 172/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1096 - binary_crossentropy: 0.0341 - generalized_dice_coefficient: 0.8150
# Epoch 172: val_loss did not improve from 0.10363
# 20/20 [==============================] - 2s 106ms/step - loss: 0.1096 - binary_crossentropy: 0.0341 - generalized_dice_coefficient: 0.8150 - val_loss: 0.1053 - val_binary_crossentropy: 0.0276 - val_generalized_dice_coefficient: 0.8151
# Epoch 173/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1051 - binary_crossentropy: 0.0301 - generalized_dice_coefficient: 0.8198
# Epoch 173: val_loss did not improve from 0.10363
# 20/20 [==============================] - 2s 106ms/step - loss: 0.1051 - binary_crossentropy: 0.0301 - generalized_dice_coefficient: 0.8198 - val_loss: 0.1047 - val_binary_crossentropy: 0.0281 - val_generalized_dice_coefficient: 0.8167
# Epoch 174/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1061 - binary_crossentropy: 0.0311 - generalized_dice_coefficient: 0.8190
# Epoch 174: val_loss did not improve from 0.10363
# 20/20 [==============================] - 2s 105ms/step - loss: 0.1061 - binary_crossentropy: 0.0311 - generalized_dice_coefficient: 0.8190 - val_loss: 0.1045 - val_binary_crossentropy: 0.0282 - val_generalized_dice_coefficient: 0.8173
# Epoch 175/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1051 - binary_crossentropy: 0.0302 - generalized_dice_coefficient: 0.8201
# Epoch 175: val_loss did not improve from 0.10363
# 20/20 [==============================] - 2s 106ms/step - loss: 0.1051 - binary_crossentropy: 0.0302 - generalized_dice_coefficient: 0.8201 - val_loss: 0.1038 - val_binary_crossentropy: 0.0286 - val_generalized_dice_coefficient: 0.8190
# Epoch 176/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1030 - binary_crossentropy: 0.0299 - generalized_dice_coefficient: 0.8238
# Epoch 176: val_loss did not improve from 0.10363
# 20/20 [==============================] - 2s 105ms/step - loss: 0.1030 - binary_crossentropy: 0.0299 - generalized_dice_coefficient: 0.8238 - val_loss: 0.1048 - val_binary_crossentropy: 0.0299 - val_generalized_dice_coefficient: 0.8185
# Epoch 177/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1021 - binary_crossentropy: 0.0302 - generalized_dice_coefficient: 0.8260
# Epoch 177: val_loss did not improve from 0.10363
# 20/20 [==============================] - 2s 106ms/step - loss: 0.1021 - binary_crossentropy: 0.0302 - generalized_dice_coefficient: 0.8260 - val_loss: 0.1039 - val_binary_crossentropy: 0.0291 - val_generalized_dice_coefficient: 0.8193
# Epoch 178/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1024 - binary_crossentropy: 0.0300 - generalized_dice_coefficient: 0.8252
# Epoch 178: val_loss did not improve from 0.10363
# 20/20 [==============================] - 2s 105ms/step - loss: 0.1024 - binary_crossentropy: 0.0300 - generalized_dice_coefficient: 0.8252 - val_loss: 0.1040 - val_binary_crossentropy: 0.0296 - val_generalized_dice_coefficient: 0.8197
# Epoch 179/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1018 - binary_crossentropy: 0.0306 - generalized_dice_coefficient: 0.8270
# Epoch 179: val_loss improved from 0.10363 to 0.10231, saving model to mymodel_179.h5
# 20/20 [==============================] - 2s 117ms/step - loss: 0.1018 - binary_crossentropy: 0.0306 - generalized_dice_coefficient: 0.8270 - val_loss: 0.1023 - val_binary_crossentropy: 0.0297 - val_generalized_dice_coefficient: 0.8232
# Epoch 180/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1023 - binary_crossentropy: 0.0311 - generalized_dice_coefficient: 0.8265
# Epoch 180: val_loss did not improve from 0.10231
# 20/20 [==============================] - 2s 106ms/step - loss: 0.1023 - binary_crossentropy: 0.0311 - generalized_dice_coefficient: 0.8265 - val_loss: 0.1045 - val_binary_crossentropy: 0.0309 - val_generalized_dice_coefficient: 0.8202
# Epoch 181/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1005 - binary_crossentropy: 0.0306 - generalized_dice_coefficient: 0.8296
# Epoch 181: val_loss did not improve from 0.10231
# 20/20 [==============================] - 2s 105ms/step - loss: 0.1005 - binary_crossentropy: 0.0306 - generalized_dice_coefficient: 0.8296 - val_loss: 0.1033 - val_binary_crossentropy: 0.0302 - val_generalized_dice_coefficient: 0.8218
# Epoch 182/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1018 - binary_crossentropy: 0.0303 - generalized_dice_coefficient: 0.8267
# Epoch 182: val_loss did not improve from 0.10231
# 20/20 [==============================] - 2s 106ms/step - loss: 0.1018 - binary_crossentropy: 0.0303 - generalized_dice_coefficient: 0.8267 - val_loss: 0.1024 - val_binary_crossentropy: 0.0292 - val_generalized_dice_coefficient: 0.8226
# Epoch 183/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0996 - binary_crossentropy: 0.0294 - generalized_dice_coefficient: 0.8303
# Epoch 183: val_loss did not improve from 0.10231
# 20/20 [==============================] - 2s 106ms/step - loss: 0.0996 - binary_crossentropy: 0.0294 - generalized_dice_coefficient: 0.8303 - val_loss: 0.1044 - val_binary_crossentropy: 0.0293 - val_generalized_dice_coefficient: 0.8185
# Epoch 184/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0993 - binary_crossentropy: 0.0292 - generalized_dice_coefficient: 0.8306
# Epoch 184: val_loss did not improve from 0.10231
# 20/20 [==============================] - 2s 106ms/step - loss: 0.0993 - binary_crossentropy: 0.0292 - generalized_dice_coefficient: 0.8306 - val_loss: 0.1024 - val_binary_crossentropy: 0.0293 - val_generalized_dice_coefficient: 0.8225
# Epoch 185/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1003 - binary_crossentropy: 0.0294 - generalized_dice_coefficient: 0.8287
# Epoch 185: val_loss did not improve from 0.10231
# 20/20 [==============================] - 2s 105ms/step - loss: 0.1003 - binary_crossentropy: 0.0294 - generalized_dice_coefficient: 0.8287 - val_loss: 0.1087 - val_binary_crossentropy: 0.0306 - val_generalized_dice_coefficient: 0.8111
# Epoch 186/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1017 - binary_crossentropy: 0.0300 - generalized_dice_coefficient: 0.8265
# Epoch 186: val_loss did not improve from 0.10231
# 20/20 [==============================] - 2s 106ms/step - loss: 0.1017 - binary_crossentropy: 0.0300 - generalized_dice_coefficient: 0.8265 - val_loss: 0.1029 - val_binary_crossentropy: 0.0294 - val_generalized_dice_coefficient: 0.8216
# Epoch 187/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0990 - binary_crossentropy: 0.0287 - generalized_dice_coefficient: 0.8307
# Epoch 187: val_loss improved from 0.10231 to 0.10222, saving model to mymodel_187.h5
# 20/20 [==============================] - 2s 116ms/step - loss: 0.0990 - binary_crossentropy: 0.0287 - generalized_dice_coefficient: 0.8307 - val_loss: 0.1022 - val_binary_crossentropy: 0.0289 - val_generalized_dice_coefficient: 0.8225
# Epoch 188/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0979 - binary_crossentropy: 0.0283 - generalized_dice_coefficient: 0.8326
# Epoch 188: val_loss improved from 0.10222 to 0.10219, saving model to mymodel_188.h5
# 20/20 [==============================] - 2s 116ms/step - loss: 0.0979 - binary_crossentropy: 0.0283 - generalized_dice_coefficient: 0.8326 - val_loss: 0.1022 - val_binary_crossentropy: 0.0293 - val_generalized_dice_coefficient: 0.8230
# Epoch 189/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0987 - binary_crossentropy: 0.0289 - generalized_dice_coefficient: 0.8315
# Epoch 189: val_loss improved from 0.10219 to 0.10198, saving model to mymodel_189.h5
# 20/20 [==============================] - 2s 116ms/step - loss: 0.0987 - binary_crossentropy: 0.0289 - generalized_dice_coefficient: 0.8315 - val_loss: 0.1020 - val_binary_crossentropy: 0.0289 - val_generalized_dice_coefficient: 0.8230
# Epoch 190/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0992 - binary_crossentropy: 0.0288 - generalized_dice_coefficient: 0.8305
# Epoch 190: val_loss did not improve from 0.10198
# 20/20 [==============================] - 2s 105ms/step - loss: 0.0992 - binary_crossentropy: 0.0288 - generalized_dice_coefficient: 0.8305 - val_loss: 0.1027 - val_binary_crossentropy: 0.0296 - val_generalized_dice_coefficient: 0.8224
# Epoch 191/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0992 - binary_crossentropy: 0.0289 - generalized_dice_coefficient: 0.8305
# Epoch 191: val_loss did not improve from 0.10198
# 20/20 [==============================] - 2s 105ms/step - loss: 0.0992 - binary_crossentropy: 0.0289 - generalized_dice_coefficient: 0.8305 - val_loss: 0.1030 - val_binary_crossentropy: 0.0292 - val_generalized_dice_coefficient: 0.8212
# Epoch 192/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1099 - binary_crossentropy: 0.0337 - generalized_dice_coefficient: 0.8139
# Epoch 192: val_loss did not improve from 0.10198
# 20/20 [==============================] - 2s 106ms/step - loss: 0.1099 - binary_crossentropy: 0.0337 - generalized_dice_coefficient: 0.8139 - val_loss: 0.1110 - val_binary_crossentropy: 0.0330 - val_generalized_dice_coefficient: 0.8089
# Epoch 193/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1073 - binary_crossentropy: 0.0348 - generalized_dice_coefficient: 0.8202
# Epoch 193: val_loss did not improve from 0.10198
# 20/20 [==============================] - 2s 105ms/step - loss: 0.1073 - binary_crossentropy: 0.0348 - generalized_dice_coefficient: 0.8202 - val_loss: 0.1063 - val_binary_crossentropy: 0.0317 - val_generalized_dice_coefficient: 0.8174
# Epoch 194/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1016 - binary_crossentropy: 0.0293 - generalized_dice_coefficient: 0.8262
# Epoch 194: val_loss did not improve from 0.10198
# 20/20 [==============================] - 2s 106ms/step - loss: 0.1016 - binary_crossentropy: 0.0293 - generalized_dice_coefficient: 0.8262 - val_loss: 0.1033 - val_binary_crossentropy: 0.0277 - val_generalized_dice_coefficient: 0.8192
# Epoch 195/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0990 - binary_crossentropy: 0.0278 - generalized_dice_coefficient: 0.8297
# Epoch 195: val_loss improved from 0.10198 to 0.10181, saving model to mymodel_195.h5
# 20/20 [==============================] - 2s 117ms/step - loss: 0.0990 - binary_crossentropy: 0.0278 - generalized_dice_coefficient: 0.8297 - val_loss: 0.1018 - val_binary_crossentropy: 0.0279 - val_generalized_dice_coefficient: 0.8224
# Epoch 196/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0983 - binary_crossentropy: 0.0277 - generalized_dice_coefficient: 0.8311
# Epoch 196: val_loss did not improve from 0.10181
# 20/20 [==============================] - 2s 106ms/step - loss: 0.0983 - binary_crossentropy: 0.0277 - generalized_dice_coefficient: 0.8311 - val_loss: 0.1032 - val_binary_crossentropy: 0.0283 - val_generalized_dice_coefficient: 0.8200
# Epoch 197/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1016 - binary_crossentropy: 0.0292 - generalized_dice_coefficient: 0.8259
# Epoch 197: val_loss did not improve from 0.10181
# 20/20 [==============================] - 2s 105ms/step - loss: 0.1016 - binary_crossentropy: 0.0292 - generalized_dice_coefficient: 0.8259 - val_loss: 0.1032 - val_binary_crossentropy: 0.0297 - val_generalized_dice_coefficient: 0.8215
# Epoch 198/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1028 - binary_crossentropy: 0.0315 - generalized_dice_coefficient: 0.8260
# Epoch 198: val_loss did not improve from 0.10181
# 20/20 [==============================] - 2s 106ms/step - loss: 0.1028 - binary_crossentropy: 0.0315 - generalized_dice_coefficient: 0.8260 - val_loss: 0.1031 - val_binary_crossentropy: 0.0289 - val_generalized_dice_coefficient: 0.8206
# Epoch 199/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0990 - binary_crossentropy: 0.0280 - generalized_dice_coefficient: 0.8299
# Epoch 199: val_loss did not improve from 0.10181
# 20/20 [==============================] - 2s 105ms/step - loss: 0.0990 - binary_crossentropy: 0.0280 - generalized_dice_coefficient: 0.8299 - val_loss: 0.1021 - val_binary_crossentropy: 0.0280 - val_generalized_dice_coefficient: 0.8219
# Epoch 200/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0976 - binary_crossentropy: 0.0278 - generalized_dice_coefficient: 0.8326
# Epoch 200: val_loss did not improve from 0.10181
# 20/20 [==============================] - 2s 105ms/step - loss: 0.0976 - binary_crossentropy: 0.0278 - generalized_dice_coefficient: 0.8326 - val_loss: 0.1022 - val_binary_crossentropy: 0.0285 - val_generalized_dice_coefficient: 0.8222

# %%
srcPath = "/content/drive/MyDrive/Bone_SPECT/upload.zip"
dstPath = "/content/drive/MyDrive/Bone_SPECT"

import zipfile

with zipfile.ZipFile(srcPath, 'r') as zip_ref:
    zip_ref.extractall(dstPath)
