# %% [markdown]
# <a href="https://colab.research.google.com/github/sunmarknatecom/01_markcv/blob/master/s2_training_class_only_L.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from glob import glob
import numpy as np
import cv2, os, copy, shutil
import matplotlib.pyplot as plt
from random import randint

# DEEP LEARNING MODULES
import tensorflow as tf
from keras import backend as K
from keras.losses import binary_crossentropy
from keras.optimizers import Adam

from keras.layers import Input, Conv2D, MaxPooling2D, Conv2DTranspose, BatchNormalization, concatenate
from keras.models import Model

import tensorflow as tf
import keras.backend as K
from keras.losses import binary_crossentropy
from keras.losses import categorical_crossentropy

# %% [markdown]
# 1. data/inputData -> normalization
# 2. data/inputRawData --> 원래
# 3. data/labelData -> 위치보정 label

# %%
MAX_SIZE = 512
split_num = 500
model_path = "/content/drive/MyDrive/Bone_SPECT/models/mymodel_local_{epoch}.h5"
model_summary_path = "/content/drive/MyDrive/Bone_SPECT/training_history_local.pkl"
basic_learning_rate = 3e-5

# %%
temp_train_imgs = np.load("/content/drive/MyDrive/Bone_SPECT/data/inputData.npy")
temp_train_lbls = np.load("/content/drive/MyDrive/Bone_SPECT/data/labelData.npy")

# %%
# 0: BG, 1: C, 2: T, 3: L
temp_train_lbls[temp_train_lbls<=0]=0
temp_train_lbls[temp_train_lbls>1]=1

# %%
temp_train_lbls[temp_train_lbls<=13]=0
temp_train_lbls[temp_train_lbls>13]=1

# %%
np.unique(temp_train_lbls[0])
# Out:
# array([0, 1], dtype=uint16)

# %%
# temp_train_lbls = tf.one_hot(temp_train_lbls, depth=4, dtype=tf.uint8)

# %%
train_imgs = temp_train_imgs[:split_num,...]
valid_imgs = temp_train_imgs[split_num:,...]
train_msks = temp_train_lbls[:split_num,...]
valid_msks = temp_train_lbls[split_num:,...]

# %%
train_imgs = np.array(train_imgs, dtype=np.float32)
train_msks = np.array(train_msks, dtype=np.float32)
valid_imgs = np.array(valid_imgs, dtype=np.float32)
valid_msks = np.array(valid_msks, dtype=np.float32)

train_msks = np.reshape(train_msks, (*train_msks.shape, 1))
valid_msks = np.reshape(valid_msks, (*valid_msks.shape, 1))

train_dataset = tf.data.Dataset.from_tensor_slices((train_imgs, train_msks))
test_dataset = tf.data.Dataset.from_tensor_slices((valid_imgs, valid_msks))

# %%
print(np.shape(train_imgs))
print(np.shape(train_msks))
# Out:
# (500, 512, 256)
# (500, 512, 256, 1)

# %%
# %matplotlib inline

rand_num = randint(1,len(train_imgs))

fig = plt.figure(0, figsize=(20, 20))
fig.add_subplot(1, 2, 1)
plt.imshow(train_imgs[rand_num]*13, cmap='gray_r')
fig.add_subplot(1, 2, 2)
plt.imshow(train_msks[rand_num], cmap='gray_r')

# %% [markdown]
# # Construct the model

# %%
CLASS_NUM = 1

# %%
inputs = Input((MAX_SIZE, 256, 1))
bnorm1 = BatchNormalization()(inputs)
conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(bnorm1)
conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv1)
pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(pool1)
conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv2)
pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(pool2)
conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv3)
pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(pool3)
conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv4)
pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)

conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(pool4)
conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(conv5)

up6 = concatenate([Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(conv5), conv4], axis=3)
conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(up6)
conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv6)

up7 = concatenate([Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(conv6), conv3], axis=3)
conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(up7)
conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv7)

up8 = concatenate([Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(conv7), conv2], axis=3)
conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(up8)
conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv8)

up9 = concatenate([Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(conv8), conv1], axis=3)
conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(up9)
conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv9)

conv10 = Conv2D(CLASS_NUM, (1, 1), activation='sigmoid')(conv9)

model = Model(inputs=[inputs], outputs=[conv10])

# %%
# reference https://github.com/SoftwareImpacts/SIMPAC-2021-46/tree/master

beta = 0.25
alpha = 0.25
gamma = 2
epsilon = 1e-5
smooth = 1

def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + K.epsilon()) / (K.sum(y_true_f) + K.sum(y_pred_f) + K.epsilon())

def generalized_dice_coefficient(y_true, y_pred):
    smooth = 1.
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    score = (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return score

def dice_loss(y_true, y_pred):
    loss = 1 - generalized_dice_coefficient(y_true, y_pred)
    return loss

def bce_dice_loss(y_true, y_pred):
    loss = binary_crossentropy(y_true, y_pred) + dice_loss(y_true, y_pred)
    return loss / 2.0

def cce_dice_loss(y_true, y_pred):
    ce_loss = categorical_crossentropy(y_true, y_pred)
    dice = dice_loss(y_true, y_pred)
    loss = ce_loss + dice
    return loss

# %%
initial_learning_rate = basic_learning_rate

lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate,
    decay_steps=10,
    decay_rate=0.96,
    staircase=True)

callbacks = [tf.keras.callbacks.ModelCheckpoint(
    filepath=model_path,
    save_best_only=True,
    monitor='val_loss',
    verbose=1)]

# %%
model.compile(Adam(learning_rate=lr_schedule), bce_dice_loss, metrics=[binary_crossentropy, generalized_dice_coefficient])

# %%
model_history = model.fit(train_imgs, train_msks, batch_size=20, epochs=200, callbacks=callbacks, validation_data=(valid_imgs, valid_msks))
# Out:
# Epoch 1/200
# 25/25 [==============================] - ETA: 0s - loss: 0.8285 - binary_crossentropy: 0.6814 - generalized_dice_coefficient: 0.0244
# Epoch 1: val_loss improved from inf to 0.83287, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_local_1.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 25/25 [==============================] - 32s 478ms/step - loss: 0.8285 - binary_crossentropy: 0.6814 - generalized_dice_coefficient: 0.0244 - val_loss: 0.8329 - val_binary_crossentropy: 0.6862 - val_generalized_dice_coefficient: 0.0205
# Epoch 2/200
# 25/25 [==============================] - ETA: 0s - loss: 0.8105 - binary_crossentropy: 0.6415 - generalized_dice_coefficient: 0.0205
# Epoch 2: val_loss improved from 0.83287 to 0.82656, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_local_2.h5
# 25/25 [==============================] - 7s 279ms/step - loss: 0.8105 - binary_crossentropy: 0.6415 - generalized_dice_coefficient: 0.0205 - val_loss: 0.8266 - val_binary_crossentropy: 0.6731 - val_generalized_dice_coefficient: 0.0199
# Epoch 3/200
# 25/25 [==============================] - ETA: 0s - loss: 0.7584 - binary_crossentropy: 0.5302 - generalized_dice_coefficient: 0.0133
# Epoch 3: val_loss improved from 0.82656 to 0.74584, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_local_3.h5
# 25/25 [==============================] - 7s 272ms/step - loss: 0.7584 - binary_crossentropy: 0.5302 - generalized_dice_coefficient: 0.0133 - val_loss: 0.7458 - val_binary_crossentropy: 0.5047 - val_generalized_dice_coefficient: 0.0130
# Epoch 4/200
# 25/25 [==============================] - ETA: 0s - loss: 0.6152 - binary_crossentropy: 0.2355 - generalized_dice_coefficient: 0.0051
# Epoch 4: val_loss improved from 0.74584 to 0.67987, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_local_4.h5
# 25/25 [==============================] - 8s 332ms/step - loss: 0.6152 - binary_crossentropy: 0.2355 - generalized_dice_coefficient: 0.0051 - val_loss: 0.6799 - val_binary_crossentropy: 0.3729 - val_generalized_dice_coefficient: 0.0132
# Epoch 5/200
# 25/25 [==============================] - ETA: 0s - loss: 0.5581 - binary_crossentropy: 0.1276 - generalized_dice_coefficient: 0.0113
# Epoch 5: val_loss improved from 0.67987 to 0.63611, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_local_5.h5
# 25/25 [==============================] - 8s 326ms/step - loss: 0.5581 - binary_crossentropy: 0.1276 - generalized_dice_coefficient: 0.0113 - val_loss: 0.6361 - val_binary_crossentropy: 0.2920 - val_generalized_dice_coefficient: 0.0198
# Epoch 6/200
# 25/25 [==============================] - ETA: 0s - loss: 0.5159 - binary_crossentropy: 0.0711 - generalized_dice_coefficient: 0.0392
# Epoch 6: val_loss improved from 0.63611 to 0.56458, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_local_6.h5
# 25/25 [==============================] - 7s 278ms/step - loss: 0.5159 - binary_crossentropy: 0.0711 - generalized_dice_coefficient: 0.0392 - val_loss: 0.5646 - val_binary_crossentropy: 0.1699 - val_generalized_dice_coefficient: 0.0407
# Epoch 7/200
# 25/25 [==============================] - ETA: 0s - loss: 0.4703 - binary_crossentropy: 0.0608 - generalized_dice_coefficient: 0.1203
# Epoch 7: val_loss improved from 0.56458 to 0.50261, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_local_7.h5
# 25/25 [==============================] - 7s 275ms/step - loss: 0.4703 - binary_crossentropy: 0.0608 - generalized_dice_coefficient: 0.1203 - val_loss: 0.5026 - val_binary_crossentropy: 0.0865 - val_generalized_dice_coefficient: 0.0813
# Epoch 8/200
# 25/25 [==============================] - ETA: 0s - loss: 0.4156 - binary_crossentropy: 0.0515 - generalized_dice_coefficient: 0.2203
# Epoch 8: val_loss improved from 0.50261 to 0.46650, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_local_8.h5
# 25/25 [==============================] - 7s 273ms/step - loss: 0.4156 - binary_crossentropy: 0.0515 - generalized_dice_coefficient: 0.2203 - val_loss: 0.4665 - val_binary_crossentropy: 0.0624 - val_generalized_dice_coefficient: 0.1295
# Epoch 9/200
# 25/25 [==============================] - ETA: 0s - loss: 0.3677 - binary_crossentropy: 0.0444 - generalized_dice_coefficient: 0.3089
# Epoch 9: val_loss improved from 0.46650 to 0.42120, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_local_9.h5
# 25/25 [==============================] - 7s 279ms/step - loss: 0.3677 - binary_crossentropy: 0.0444 - generalized_dice_coefficient: 0.3089 - val_loss: 0.4212 - val_binary_crossentropy: 0.0420 - val_generalized_dice_coefficient: 0.1996
# Epoch 10/200
# 25/25 [==============================] - ETA: 0s - loss: 0.3421 - binary_crossentropy: 0.0415 - generalized_dice_coefficient: 0.3572
# Epoch 10: val_loss improved from 0.42120 to 0.40354, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_local_10.h5
# 25/25 [==============================] - 7s 274ms/step - loss: 0.3421 - binary_crossentropy: 0.0415 - generalized_dice_coefficient: 0.3572 - val_loss: 0.4035 - val_binary_crossentropy: 0.0368 - val_generalized_dice_coefficient: 0.2298
# Epoch 11/200
# 25/25 [==============================] - ETA: 0s - loss: 0.3165 - binary_crossentropy: 0.0370 - generalized_dice_coefficient: 0.4040
# Epoch 11: val_loss improved from 0.40354 to 0.39508, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_local_11.h5
# 25/25 [==============================] - 7s 277ms/step - loss: 0.3165 - binary_crossentropy: 0.0370 - generalized_dice_coefficient: 0.4040 - val_loss: 0.3951 - val_binary_crossentropy: 0.0350 - val_generalized_dice_coefficient: 0.2449
# Epoch 12/200
# 25/25 [==============================] - ETA: 0s - loss: 0.2970 - binary_crossentropy: 0.0337 - generalized_dice_coefficient: 0.4396
# Epoch 12: val_loss improved from 0.39508 to 0.35874, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_local_12.h5
# 25/25 [==============================] - 8s 330ms/step - loss: 0.2970 - binary_crossentropy: 0.0337 - generalized_dice_coefficient: 0.4396 - val_loss: 0.3587 - val_binary_crossentropy: 0.0278 - val_generalized_dice_coefficient: 0.3103
# Epoch 13/200
# 25/25 [==============================] - ETA: 0s - loss: 0.2759 - binary_crossentropy: 0.0305 - generalized_dice_coefficient: 0.4787
# Epoch 13: val_loss improved from 0.35874 to 0.34148, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_local_13.h5
# 25/25 [==============================] - 7s 275ms/step - loss: 0.2759 - binary_crossentropy: 0.0305 - generalized_dice_coefficient: 0.4787 - val_loss: 0.3415 - val_binary_crossentropy: 0.0257 - val_generalized_dice_coefficient: 0.3428
# Epoch 14/200
# 25/25 [==============================] - ETA: 0s - loss: 0.2591 - binary_crossentropy: 0.0294 - generalized_dice_coefficient: 0.5111
# Epoch 14: val_loss improved from 0.34148 to 0.32058, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_local_14.h5
# 25/25 [==============================] - 8s 329ms/step - loss: 0.2591 - binary_crossentropy: 0.0294 - generalized_dice_coefficient: 0.5111 - val_loss: 0.3206 - val_binary_crossentropy: 0.0240 - val_generalized_dice_coefficient: 0.3829
# Epoch 15/200
# 25/25 [==============================] - ETA: 0s - loss: 0.2424 - binary_crossentropy: 0.0280 - generalized_dice_coefficient: 0.5431
# Epoch 15: val_loss improved from 0.32058 to 0.28785, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_local_15.h5
# 25/25 [==============================] - 7s 273ms/step - loss: 0.2424 - binary_crossentropy: 0.0280 - generalized_dice_coefficient: 0.5431 - val_loss: 0.2878 - val_binary_crossentropy: 0.0224 - val_generalized_dice_coefficient: 0.4468
# Epoch 16/200
# 25/25 [==============================] - ETA: 0s - loss: 0.2268 - binary_crossentropy: 0.0287 - generalized_dice_coefficient: 0.5751
# Epoch 16: val_loss improved from 0.28785 to 0.26954, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_local_16.h5
# 25/25 [==============================] - 8s 334ms/step - loss: 0.2268 - binary_crossentropy: 0.0287 - generalized_dice_coefficient: 0.5751 - val_loss: 0.2695 - val_binary_crossentropy: 0.0227 - val_generalized_dice_coefficient: 0.4837
# Epoch 17/200
# 25/25 [==============================] - ETA: 0s - loss: 0.2076 - binary_crossentropy: 0.0294 - generalized_dice_coefficient: 0.6142
# Epoch 17: val_loss improved from 0.26954 to 0.26424, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_local_17.h5
# 25/25 [==============================] - 7s 271ms/step - loss: 0.2076 - binary_crossentropy: 0.0294 - generalized_dice_coefficient: 0.6142 - val_loss: 0.2642 - val_binary_crossentropy: 0.0249 - val_generalized_dice_coefficient: 0.4964
# Epoch 18/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1909 - binary_crossentropy: 0.0304 - generalized_dice_coefficient: 0.6486
# Epoch 18: val_loss improved from 0.26424 to 0.23206, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_local_18.h5
# 25/25 [==============================] - 7s 277ms/step - loss: 0.1909 - binary_crossentropy: 0.0304 - generalized_dice_coefficient: 0.6486 - val_loss: 0.2321 - val_binary_crossentropy: 0.0253 - val_generalized_dice_coefficient: 0.5612
# Epoch 19/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1768 - binary_crossentropy: 0.0304 - generalized_dice_coefficient: 0.6767
# Epoch 19: val_loss improved from 0.23206 to 0.22440, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_local_19.h5
# 25/25 [==============================] - 7s 275ms/step - loss: 0.1768 - binary_crossentropy: 0.0304 - generalized_dice_coefficient: 0.6767 - val_loss: 0.2244 - val_binary_crossentropy: 0.0269 - val_generalized_dice_coefficient: 0.5782
# Epoch 20/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1685 - binary_crossentropy: 0.0318 - generalized_dice_coefficient: 0.6947
# Epoch 20: val_loss improved from 0.22440 to 0.21380, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_local_20.h5
# 25/25 [==============================] - 7s 277ms/step - loss: 0.1685 - binary_crossentropy: 0.0318 - generalized_dice_coefficient: 0.6947 - val_loss: 0.2138 - val_binary_crossentropy: 0.0293 - val_generalized_dice_coefficient: 0.6017
# Epoch 21/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1660 - binary_crossentropy: 0.0327 - generalized_dice_coefficient: 0.7007
# Epoch 21: val_loss improved from 0.21380 to 0.20462, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_local_21.h5
# 25/25 [==============================] - 7s 276ms/step - loss: 0.1660 - binary_crossentropy: 0.0327 - generalized_dice_coefficient: 0.7007 - val_loss: 0.2046 - val_binary_crossentropy: 0.0311 - val_generalized_dice_coefficient: 0.6220
# Epoch 22/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1608 - binary_crossentropy: 0.0326 - generalized_dice_coefficient: 0.7110
# Epoch 22: val_loss improved from 0.20462 to 0.20374, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_local_22.h5
# 25/25 [==============================] - 7s 282ms/step - loss: 0.1608 - binary_crossentropy: 0.0326 - generalized_dice_coefficient: 0.7110 - val_loss: 0.2037 - val_binary_crossentropy: 0.0317 - val_generalized_dice_coefficient: 0.6243
# Epoch 23/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1584 - binary_crossentropy: 0.0319 - generalized_dice_coefficient: 0.7150
# Epoch 23: val_loss improved from 0.20374 to 0.19723, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_local_23.h5
# 25/25 [==============================] - 8s 334ms/step - loss: 0.1584 - binary_crossentropy: 0.0319 - generalized_dice_coefficient: 0.7150 - val_loss: 0.1972 - val_binary_crossentropy: 0.0325 - val_generalized_dice_coefficient: 0.6381
# Epoch 24/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1557 - binary_crossentropy: 0.0318 - generalized_dice_coefficient: 0.7203
# Epoch 24: val_loss did not improve from 0.19723
# 25/25 [==============================] - 6s 258ms/step - loss: 0.1557 - binary_crossentropy: 0.0318 - generalized_dice_coefficient: 0.7203 - val_loss: 0.2072 - val_binary_crossentropy: 0.0368 - val_generalized_dice_coefficient: 0.6225
# Epoch 25/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1553 - binary_crossentropy: 0.0314 - generalized_dice_coefficient: 0.7208
# Epoch 25: val_loss did not improve from 0.19723
# 25/25 [==============================] - 8s 311ms/step - loss: 0.1553 - binary_crossentropy: 0.0314 - generalized_dice_coefficient: 0.7208 - val_loss: 0.1990 - val_binary_crossentropy: 0.0350 - val_generalized_dice_coefficient: 0.6370
# Epoch 26/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1521 - binary_crossentropy: 0.0305 - generalized_dice_coefficient: 0.7263
# Epoch 26: val_loss improved from 0.19723 to 0.19640, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_local_26.h5
# 25/25 [==============================] - 7s 272ms/step - loss: 0.1521 - binary_crossentropy: 0.0305 - generalized_dice_coefficient: 0.7263 - val_loss: 0.1964 - val_binary_crossentropy: 0.0349 - val_generalized_dice_coefficient: 0.6422
# Epoch 27/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1511 - binary_crossentropy: 0.0304 - generalized_dice_coefficient: 0.7283
# Epoch 27: val_loss improved from 0.19640 to 0.19214, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_local_27.h5
# 25/25 [==============================] - 7s 275ms/step - loss: 0.1511 - binary_crossentropy: 0.0304 - generalized_dice_coefficient: 0.7283 - val_loss: 0.1921 - val_binary_crossentropy: 0.0349 - val_generalized_dice_coefficient: 0.6507
# Epoch 28/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1527 - binary_crossentropy: 0.0318 - generalized_dice_coefficient: 0.7264
# Epoch 28: val_loss did not improve from 0.19214
# 25/25 [==============================] - 6s 255ms/step - loss: 0.1527 - binary_crossentropy: 0.0318 - generalized_dice_coefficient: 0.7264 - val_loss: 0.1977 - val_binary_crossentropy: 0.0378 - val_generalized_dice_coefficient: 0.6425
# Epoch 29/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1507 - binary_crossentropy: 0.0309 - generalized_dice_coefficient: 0.7295
# Epoch 29: val_loss did not improve from 0.19214
# 25/25 [==============================] - 6s 258ms/step - loss: 0.1507 - binary_crossentropy: 0.0309 - generalized_dice_coefficient: 0.7295 - val_loss: 0.1923 - val_binary_crossentropy: 0.0362 - val_generalized_dice_coefficient: 0.6518
# Epoch 30/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1491 - binary_crossentropy: 0.0301 - generalized_dice_coefficient: 0.7318
# Epoch 30: val_loss improved from 0.19214 to 0.18951, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_local_30.h5
# 25/25 [==============================] - 7s 271ms/step - loss: 0.1491 - binary_crossentropy: 0.0301 - generalized_dice_coefficient: 0.7318 - val_loss: 0.1895 - val_binary_crossentropy: 0.0355 - val_generalized_dice_coefficient: 0.6565
# Epoch 31/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1495 - binary_crossentropy: 0.0307 - generalized_dice_coefficient: 0.7318
# Epoch 31: val_loss improved from 0.18951 to 0.18906, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_local_31.h5
# 25/25 [==============================] - 7s 275ms/step - loss: 0.1495 - binary_crossentropy: 0.0307 - generalized_dice_coefficient: 0.7318 - val_loss: 0.1891 - val_binary_crossentropy: 0.0356 - val_generalized_dice_coefficient: 0.6576
# Epoch 32/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1502 - binary_crossentropy: 0.0313 - generalized_dice_coefficient: 0.7309
# Epoch 32: val_loss did not improve from 0.18906
# 25/25 [==============================] - 6s 253ms/step - loss: 0.1502 - binary_crossentropy: 0.0313 - generalized_dice_coefficient: 0.7309 - val_loss: 0.1915 - val_binary_crossentropy: 0.0375 - val_generalized_dice_coefficient: 0.6546
# Epoch 33/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1473 - binary_crossentropy: 0.0298 - generalized_dice_coefficient: 0.7351
# Epoch 33: val_loss did not improve from 0.18906
# 25/25 [==============================] - 6s 259ms/step - loss: 0.1473 - binary_crossentropy: 0.0298 - generalized_dice_coefficient: 0.7351 - val_loss: 0.1891 - val_binary_crossentropy: 0.0364 - val_generalized_dice_coefficient: 0.6582
# Epoch 34/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1462 - binary_crossentropy: 0.0298 - generalized_dice_coefficient: 0.7373
# Epoch 34: val_loss did not improve from 0.18906
# 25/25 [==============================] - 6s 255ms/step - loss: 0.1462 - binary_crossentropy: 0.0298 - generalized_dice_coefficient: 0.7373 - val_loss: 0.1913 - val_binary_crossentropy: 0.0372 - val_generalized_dice_coefficient: 0.6546
# Epoch 35/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1455 - binary_crossentropy: 0.0294 - generalized_dice_coefficient: 0.7384
# Epoch 35: val_loss did not improve from 0.18906
# 25/25 [==============================] - 6s 258ms/step - loss: 0.1455 - binary_crossentropy: 0.0294 - generalized_dice_coefficient: 0.7384 - val_loss: 0.1910 - val_binary_crossentropy: 0.0374 - val_generalized_dice_coefficient: 0.6554
# Epoch 36/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1460 - binary_crossentropy: 0.0296 - generalized_dice_coefficient: 0.7376
# Epoch 36: val_loss did not improve from 0.18906
# 25/25 [==============================] - 6s 255ms/step - loss: 0.1460 - binary_crossentropy: 0.0296 - generalized_dice_coefficient: 0.7376 - val_loss: 0.1895 - val_binary_crossentropy: 0.0371 - val_generalized_dice_coefficient: 0.6582
# Epoch 37/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1457 - binary_crossentropy: 0.0294 - generalized_dice_coefficient: 0.7380
# Epoch 37: val_loss improved from 0.18906 to 0.18739, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_local_37.h5
# 25/25 [==============================] - 7s 275ms/step - loss: 0.1457 - binary_crossentropy: 0.0294 - generalized_dice_coefficient: 0.7380 - val_loss: 0.1874 - val_binary_crossentropy: 0.0365 - val_generalized_dice_coefficient: 0.6617
# Epoch 38/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1452 - binary_crossentropy: 0.0293 - generalized_dice_coefficient: 0.7390
# Epoch 38: val_loss did not improve from 0.18739
# 25/25 [==============================] - 6s 254ms/step - loss: 0.1452 - binary_crossentropy: 0.0293 - generalized_dice_coefficient: 0.7390 - val_loss: 0.1876 - val_binary_crossentropy: 0.0366 - val_generalized_dice_coefficient: 0.6615
# Epoch 39/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1463 - binary_crossentropy: 0.0297 - generalized_dice_coefficient: 0.7371
# Epoch 39: val_loss did not improve from 0.18739
# 25/25 [==============================] - 6s 259ms/step - loss: 0.1463 - binary_crossentropy: 0.0297 - generalized_dice_coefficient: 0.7371 - val_loss: 0.1882 - val_binary_crossentropy: 0.0370 - val_generalized_dice_coefficient: 0.6607
# Epoch 40/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1451 - binary_crossentropy: 0.0295 - generalized_dice_coefficient: 0.7393
# Epoch 40: val_loss did not improve from 0.18739
# 25/25 [==============================] - 6s 253ms/step - loss: 0.1451 - binary_crossentropy: 0.0295 - generalized_dice_coefficient: 0.7393 - val_loss: 0.1884 - val_binary_crossentropy: 0.0370 - val_generalized_dice_coefficient: 0.6603
# Epoch 41/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1443 - binary_crossentropy: 0.0293 - generalized_dice_coefficient: 0.7407
# Epoch 41: val_loss did not improve from 0.18739
# 25/25 [==============================] - 8s 311ms/step - loss: 0.1443 - binary_crossentropy: 0.0293 - generalized_dice_coefficient: 0.7407 - val_loss: 0.1878 - val_binary_crossentropy: 0.0370 - val_generalized_dice_coefficient: 0.6613
# Epoch 42/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1440 - binary_crossentropy: 0.0291 - generalized_dice_coefficient: 0.7412
# Epoch 42: val_loss improved from 0.18739 to 0.18553, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_local_42.h5
# 25/25 [==============================] - 7s 275ms/step - loss: 0.1440 - binary_crossentropy: 0.0291 - generalized_dice_coefficient: 0.7412 - val_loss: 0.1855 - val_binary_crossentropy: 0.0362 - val_generalized_dice_coefficient: 0.6652
# Epoch 43/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1445 - binary_crossentropy: 0.0293 - generalized_dice_coefficient: 0.7403
# Epoch 43: val_loss did not improve from 0.18553
# 25/25 [==============================] - 6s 257ms/step - loss: 0.1445 - binary_crossentropy: 0.0293 - generalized_dice_coefficient: 0.7403 - val_loss: 0.1858 - val_binary_crossentropy: 0.0364 - val_generalized_dice_coefficient: 0.6648
# Epoch 44/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1433 - binary_crossentropy: 0.0291 - generalized_dice_coefficient: 0.7424
# Epoch 44: val_loss did not improve from 0.18553
# 25/25 [==============================] - 6s 254ms/step - loss: 0.1433 - binary_crossentropy: 0.0291 - generalized_dice_coefficient: 0.7424 - val_loss: 0.1889 - val_binary_crossentropy: 0.0374 - val_generalized_dice_coefficient: 0.6596
# Epoch 45/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1444 - binary_crossentropy: 0.0292 - generalized_dice_coefficient: 0.7404
# Epoch 45: val_loss did not improve from 0.18553
# 25/25 [==============================] - 6s 254ms/step - loss: 0.1444 - binary_crossentropy: 0.0292 - generalized_dice_coefficient: 0.7404 - val_loss: 0.1867 - val_binary_crossentropy: 0.0367 - val_generalized_dice_coefficient: 0.6634
# Epoch 46/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1438 - binary_crossentropy: 0.0293 - generalized_dice_coefficient: 0.7417
# Epoch 46: val_loss did not improve from 0.18553
# 25/25 [==============================] - 6s 252ms/step - loss: 0.1438 - binary_crossentropy: 0.0293 - generalized_dice_coefficient: 0.7417 - val_loss: 0.1861 - val_binary_crossentropy: 0.0366 - val_generalized_dice_coefficient: 0.6645
# Epoch 47/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1433 - binary_crossentropy: 0.0290 - generalized_dice_coefficient: 0.7423
# Epoch 47: val_loss did not improve from 0.18553
# 25/25 [==============================] - 6s 257ms/step - loss: 0.1433 - binary_crossentropy: 0.0290 - generalized_dice_coefficient: 0.7423 - val_loss: 0.1875 - val_binary_crossentropy: 0.0370 - val_generalized_dice_coefficient: 0.6620
# Epoch 48/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1428 - binary_crossentropy: 0.0290 - generalized_dice_coefficient: 0.7434
# Epoch 48: val_loss did not improve from 0.18553
# 25/25 [==============================] - 6s 253ms/step - loss: 0.1428 - binary_crossentropy: 0.0290 - generalized_dice_coefficient: 0.7434 - val_loss: 0.1872 - val_binary_crossentropy: 0.0370 - val_generalized_dice_coefficient: 0.6626
# Epoch 49/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1431 - binary_crossentropy: 0.0290 - generalized_dice_coefficient: 0.7428
# Epoch 49: val_loss did not improve from 0.18553
# 25/25 [==============================] - 6s 257ms/step - loss: 0.1431 - binary_crossentropy: 0.0290 - generalized_dice_coefficient: 0.7428 - val_loss: 0.1863 - val_binary_crossentropy: 0.0368 - val_generalized_dice_coefficient: 0.6642
# Epoch 50/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1433 - binary_crossentropy: 0.0291 - generalized_dice_coefficient: 0.7426
# Epoch 50: val_loss did not improve from 0.18553
# 25/25 [==============================] - 6s 258ms/step - loss: 0.1433 - binary_crossentropy: 0.0291 - generalized_dice_coefficient: 0.7426 - val_loss: 0.1863 - val_binary_crossentropy: 0.0367 - val_generalized_dice_coefficient: 0.6642
# Epoch 51/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1431 - binary_crossentropy: 0.0290 - generalized_dice_coefficient: 0.7428
# Epoch 51: val_loss did not improve from 0.18553
# 25/25 [==============================] - 8s 313ms/step - loss: 0.1431 - binary_crossentropy: 0.0290 - generalized_dice_coefficient: 0.7428 - val_loss: 0.1863 - val_binary_crossentropy: 0.0367 - val_generalized_dice_coefficient: 0.6642
# Epoch 52/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1433 - binary_crossentropy: 0.0292 - generalized_dice_coefficient: 0.7426
# Epoch 52: val_loss did not improve from 0.18553
# 25/25 [==============================] - 6s 253ms/step - loss: 0.1433 - binary_crossentropy: 0.0292 - generalized_dice_coefficient: 0.7426 - val_loss: 0.1868 - val_binary_crossentropy: 0.0369 - val_generalized_dice_coefficient: 0.6634
# Epoch 53/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1431 - binary_crossentropy: 0.0290 - generalized_dice_coefficient: 0.7429
# Epoch 53: val_loss did not improve from 0.18553
# 25/25 [==============================] - 6s 255ms/step - loss: 0.1431 - binary_crossentropy: 0.0290 - generalized_dice_coefficient: 0.7429 - val_loss: 0.1867 - val_binary_crossentropy: 0.0368 - val_generalized_dice_coefficient: 0.6634
# Epoch 54/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1434 - binary_crossentropy: 0.0289 - generalized_dice_coefficient: 0.7422
# Epoch 54: val_loss did not improve from 0.18553
# 25/25 [==============================] - 6s 254ms/step - loss: 0.1434 - binary_crossentropy: 0.0289 - generalized_dice_coefficient: 0.7422 - val_loss: 0.1864 - val_binary_crossentropy: 0.0367 - val_generalized_dice_coefficient: 0.6640
# Epoch 55/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1425 - binary_crossentropy: 0.0289 - generalized_dice_coefficient: 0.7438
# Epoch 55: val_loss did not improve from 0.18553
# 25/25 [==============================] - 6s 256ms/step - loss: 0.1425 - binary_crossentropy: 0.0289 - generalized_dice_coefficient: 0.7438 - val_loss: 0.1864 - val_binary_crossentropy: 0.0367 - val_generalized_dice_coefficient: 0.6639
# Epoch 56/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1429 - binary_crossentropy: 0.0289 - generalized_dice_coefficient: 0.7431
# Epoch 56: val_loss did not improve from 0.18553
# 25/25 [==============================] - 6s 254ms/step - loss: 0.1429 - binary_crossentropy: 0.0289 - generalized_dice_coefficient: 0.7431 - val_loss: 0.1861 - val_binary_crossentropy: 0.0367 - val_generalized_dice_coefficient: 0.6645
# Epoch 57/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1426 - binary_crossentropy: 0.0288 - generalized_dice_coefficient: 0.7435
# Epoch 57: val_loss did not improve from 0.18553
# 25/25 [==============================] - 6s 258ms/step - loss: 0.1426 - binary_crossentropy: 0.0288 - generalized_dice_coefficient: 0.7435 - val_loss: 0.1862 - val_binary_crossentropy: 0.0368 - val_generalized_dice_coefficient: 0.6643
# Epoch 58/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1425 - binary_crossentropy: 0.0290 - generalized_dice_coefficient: 0.7440
# Epoch 58: val_loss did not improve from 0.18553
# 25/25 [==============================] - 6s 253ms/step - loss: 0.1425 - binary_crossentropy: 0.0290 - generalized_dice_coefficient: 0.7440 - val_loss: 0.1864 - val_binary_crossentropy: 0.0368 - val_generalized_dice_coefficient: 0.6641
# Epoch 59/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1428 - binary_crossentropy: 0.0288 - generalized_dice_coefficient: 0.7432
# Epoch 59: val_loss did not improve from 0.18553
# 25/25 [==============================] - 6s 257ms/step - loss: 0.1428 - binary_crossentropy: 0.0288 - generalized_dice_coefficient: 0.7432 - val_loss: 0.1866 - val_binary_crossentropy: 0.0369 - val_generalized_dice_coefficient: 0.6638
# Epoch 60/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1420 - binary_crossentropy: 0.0286 - generalized_dice_coefficient: 0.7446
# Epoch 60: val_loss did not improve from 0.18553
# 25/25 [==============================] - 6s 255ms/step - loss: 0.1420 - binary_crossentropy: 0.0286 - generalized_dice_coefficient: 0.7446 - val_loss: 0.1859 - val_binary_crossentropy: 0.0367 - val_generalized_dice_coefficient: 0.6649
# Epoch 61/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1431 - binary_crossentropy: 0.0290 - generalized_dice_coefficient: 0.7427
# Epoch 61: val_loss did not improve from 0.18553
# 25/25 [==============================] - 8s 311ms/step - loss: 0.1431 - binary_crossentropy: 0.0290 - generalized_dice_coefficient: 0.7427 - val_loss: 0.1862 - val_binary_crossentropy: 0.0367 - val_generalized_dice_coefficient: 0.6645
# Epoch 62/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1428 - binary_crossentropy: 0.0290 - generalized_dice_coefficient: 0.7434
# Epoch 62: val_loss did not improve from 0.18553
# 25/25 [==============================] - 6s 254ms/step - loss: 0.1428 - binary_crossentropy: 0.0290 - generalized_dice_coefficient: 0.7434 - val_loss: 0.1866 - val_binary_crossentropy: 0.0369 - val_generalized_dice_coefficient: 0.6637
# Epoch 63/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1424 - binary_crossentropy: 0.0287 - generalized_dice_coefficient: 0.7439
# Epoch 63: val_loss did not improve from 0.18553
# 25/25 [==============================] - 6s 255ms/step - loss: 0.1424 - binary_crossentropy: 0.0287 - generalized_dice_coefficient: 0.7439 - val_loss: 0.1863 - val_binary_crossentropy: 0.0368 - val_generalized_dice_coefficient: 0.6642
# Epoch 64/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1425 - binary_crossentropy: 0.0290 - generalized_dice_coefficient: 0.7441
# Epoch 64: val_loss did not improve from 0.18553
# 25/25 [==============================] - 6s 254ms/step - loss: 0.1425 - binary_crossentropy: 0.0290 - generalized_dice_coefficient: 0.7441 - val_loss: 0.1862 - val_binary_crossentropy: 0.0368 - val_generalized_dice_coefficient: 0.6645
# Epoch 65/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1420 - binary_crossentropy: 0.0286 - generalized_dice_coefficient: 0.7446
# Epoch 65: val_loss did not improve from 0.18553
# 25/25 [==============================] - 6s 259ms/step - loss: 0.1420 - binary_crossentropy: 0.0286 - generalized_dice_coefficient: 0.7446 - val_loss: 0.1861 - val_binary_crossentropy: 0.0368 - val_generalized_dice_coefficient: 0.6646
# Epoch 66/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1427 - binary_crossentropy: 0.0290 - generalized_dice_coefficient: 0.7436
# Epoch 66: val_loss did not improve from 0.18553
# 25/25 [==============================] - 6s 254ms/step - loss: 0.1427 - binary_crossentropy: 0.0290 - generalized_dice_coefficient: 0.7436 - val_loss: 0.1860 - val_binary_crossentropy: 0.0367 - val_generalized_dice_coefficient: 0.6648
# Epoch 67/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1420 - binary_crossentropy: 0.0286 - generalized_dice_coefficient: 0.7445
# Epoch 67: val_loss did not improve from 0.18553
# 25/25 [==============================] - 8s 310ms/step - loss: 0.1420 - binary_crossentropy: 0.0286 - generalized_dice_coefficient: 0.7445 - val_loss: 0.1862 - val_binary_crossentropy: 0.0368 - val_generalized_dice_coefficient: 0.6644
# Epoch 68/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1430 - binary_crossentropy: 0.0290 - generalized_dice_coefficient: 0.7430
# Epoch 68: val_loss did not improve from 0.18553
# 25/25 [==============================] - 6s 255ms/step - loss: 0.1430 - binary_crossentropy: 0.0290 - generalized_dice_coefficient: 0.7430 - val_loss: 0.1863 - val_binary_crossentropy: 0.0368 - val_generalized_dice_coefficient: 0.6643
# Epoch 69/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1421 - binary_crossentropy: 0.0289 - generalized_dice_coefficient: 0.7447
# Epoch 69: val_loss did not improve from 0.18553
# 25/25 [==============================] - 6s 256ms/step - loss: 0.1421 - binary_crossentropy: 0.0289 - generalized_dice_coefficient: 0.7447 - val_loss: 0.1862 - val_binary_crossentropy: 0.0368 - val_generalized_dice_coefficient: 0.6645
# Epoch 70/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1424 - binary_crossentropy: 0.0288 - generalized_dice_coefficient: 0.7441
# Epoch 70: val_loss did not improve from 0.18553
# 25/25 [==============================] - 6s 256ms/step - loss: 0.1424 - binary_crossentropy: 0.0288 - generalized_dice_coefficient: 0.7441 - val_loss: 0.1862 - val_binary_crossentropy: 0.0368 - val_generalized_dice_coefficient: 0.6645
# Epoch 71/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1424 - binary_crossentropy: 0.0287 - generalized_dice_coefficient: 0.7440
# Epoch 71: val_loss did not improve from 0.18553
# 25/25 [==============================] - 6s 259ms/step - loss: 0.1424 - binary_crossentropy: 0.0287 - generalized_dice_coefficient: 0.7440 - val_loss: 0.1863 - val_binary_crossentropy: 0.0368 - val_generalized_dice_coefficient: 0.6642
# Epoch 72/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1433 - binary_crossentropy: 0.0291 - generalized_dice_coefficient: 0.7425
# Epoch 72: val_loss did not improve from 0.18553
# 25/25 [==============================] - 6s 253ms/step - loss: 0.1433 - binary_crossentropy: 0.0291 - generalized_dice_coefficient: 0.7425 - val_loss: 0.1863 - val_binary_crossentropy: 0.0368 - val_generalized_dice_coefficient: 0.6643
# Epoch 73/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1424 - binary_crossentropy: 0.0289 - generalized_dice_coefficient: 0.7441
# Epoch 73: val_loss did not improve from 0.18553
# 25/25 [==============================] - 6s 258ms/step - loss: 0.1424 - binary_crossentropy: 0.0289 - generalized_dice_coefficient: 0.7441 - val_loss: 0.1863 - val_binary_crossentropy: 0.0368 - val_generalized_dice_coefficient: 0.6643
# Epoch 74/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1426 - binary_crossentropy: 0.0289 - generalized_dice_coefficient: 0.7438
# Epoch 74: val_loss did not improve from 0.18553
# 25/25 [==============================] - 6s 255ms/step - loss: 0.1426 - binary_crossentropy: 0.0289 - generalized_dice_coefficient: 0.7438 - val_loss: 0.1863 - val_binary_crossentropy: 0.0368 - val_generalized_dice_coefficient: 0.6642
# Epoch 75/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1429 - binary_crossentropy: 0.0290 - generalized_dice_coefficient: 0.7432
# Epoch 75: val_loss did not improve from 0.18553
# 25/25 [==============================] - 6s 258ms/step - loss: 0.1429 - binary_crossentropy: 0.0290 - generalized_dice_coefficient: 0.7432 - val_loss: 0.1862 - val_binary_crossentropy: 0.0368 - val_generalized_dice_coefficient: 0.6644
# Epoch 76/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1424 - binary_crossentropy: 0.0288 - generalized_dice_coefficient: 0.7441
# Epoch 76: val_loss did not improve from 0.18553
# 25/25 [==============================] - 6s 255ms/step - loss: 0.1424 - binary_crossentropy: 0.0288 - generalized_dice_coefficient: 0.7441 - val_loss: 0.1863 - val_binary_crossentropy: 0.0368 - val_generalized_dice_coefficient: 0.6643
# Epoch 77/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1420 - binary_crossentropy: 0.0288 - generalized_dice_coefficient: 0.7448
# Epoch 77: val_loss did not improve from 0.18553
# 25/25 [==============================] - 8s 310ms/step - loss: 0.1420 - binary_crossentropy: 0.0288 - generalized_dice_coefficient: 0.7448 - val_loss: 0.1863 - val_binary_crossentropy: 0.0368 - val_generalized_dice_coefficient: 0.6643
# Epoch 78/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1433 - binary_crossentropy: 0.0290 - generalized_dice_coefficient: 0.7425
# Epoch 78: val_loss did not improve from 0.18553
# 25/25 [==============================] - 6s 253ms/step - loss: 0.1433 - binary_crossentropy: 0.0290 - generalized_dice_coefficient: 0.7425 - val_loss: 0.1862 - val_binary_crossentropy: 0.0368 - val_generalized_dice_coefficient: 0.6644
# Epoch 79/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1421 - binary_crossentropy: 0.0288 - generalized_dice_coefficient: 0.7446
# Epoch 79: val_loss did not improve from 0.18553
# 25/25 [==============================] - 6s 260ms/step - loss: 0.1421 - binary_crossentropy: 0.0288 - generalized_dice_coefficient: 0.7446 - val_loss: 0.1862 - val_binary_crossentropy: 0.0368 - val_generalized_dice_coefficient: 0.6644
# Epoch 80/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1425 - binary_crossentropy: 0.0288 - generalized_dice_coefficient: 0.7438
# Epoch 80: val_loss did not improve from 0.18553
# 25/25 [==============================] - 6s 253ms/step - loss: 0.1425 - binary_crossentropy: 0.0288 - generalized_dice_coefficient: 0.7438 - val_loss: 0.1862 - val_binary_crossentropy: 0.0368 - val_generalized_dice_coefficient: 0.6644
# Epoch 81/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1423 - binary_crossentropy: 0.0289 - generalized_dice_coefficient: 0.7442
# Epoch 81: val_loss did not improve from 0.18553
# 25/25 [==============================] - 6s 260ms/step - loss: 0.1423 - binary_crossentropy: 0.0289 - generalized_dice_coefficient: 0.7442 - val_loss: 0.1862 - val_binary_crossentropy: 0.0368 - val_generalized_dice_coefficient: 0.6645
# Epoch 82/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1419 - binary_crossentropy: 0.0287 - generalized_dice_coefficient: 0.7448
# Epoch 82: val_loss did not improve from 0.18553
# 25/25 [==============================] - 6s 255ms/step - loss: 0.1419 - binary_crossentropy: 0.0287 - generalized_dice_coefficient: 0.7448 - val_loss: 0.1862 - val_binary_crossentropy: 0.0368 - val_generalized_dice_coefficient: 0.6644
# Epoch 83/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1425 - binary_crossentropy: 0.0291 - generalized_dice_coefficient: 0.7440
# Epoch 83: val_loss did not improve from 0.18553
# 25/25 [==============================] - 6s 258ms/step - loss: 0.1425 - binary_crossentropy: 0.0291 - generalized_dice_coefficient: 0.7440 - val_loss: 0.1862 - val_binary_crossentropy: 0.0368 - val_generalized_dice_coefficient: 0.6644
# Epoch 84/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1427 - binary_crossentropy: 0.0289 - generalized_dice_coefficient: 0.7435
# Epoch 84: val_loss did not improve from 0.18553
# 25/25 [==============================] - 6s 253ms/step - loss: 0.1427 - binary_crossentropy: 0.0289 - generalized_dice_coefficient: 0.7435 - val_loss: 0.1862 - val_binary_crossentropy: 0.0368 - val_generalized_dice_coefficient: 0.6645
# Epoch 85/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1414 - binary_crossentropy: 0.0285 - generalized_dice_coefficient: 0.7456
# Epoch 85: val_loss did not improve from 0.18553
# 25/25 [==============================] - 6s 258ms/step - loss: 0.1414 - binary_crossentropy: 0.0285 - generalized_dice_coefficient: 0.7456 - val_loss: 0.1862 - val_binary_crossentropy: 0.0368 - val_generalized_dice_coefficient: 0.6644
# Epoch 86/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1429 - binary_crossentropy: 0.0289 - generalized_dice_coefficient: 0.7430
# Epoch 86: val_loss did not improve from 0.18553
# 25/25 [==============================] - 6s 253ms/step - loss: 0.1429 - binary_crossentropy: 0.0289 - generalized_dice_coefficient: 0.7430 - val_loss: 0.1862 - val_binary_crossentropy: 0.0368 - val_generalized_dice_coefficient: 0.6645
# Epoch 87/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1422 - binary_crossentropy: 0.0290 - generalized_dice_coefficient: 0.7445
# Epoch 87: val_loss did not improve from 0.18553
# 25/25 [==============================] - 6s 258ms/step - loss: 0.1422 - binary_crossentropy: 0.0290 - generalized_dice_coefficient: 0.7445 - val_loss: 0.1861 - val_binary_crossentropy: 0.0368 - val_generalized_dice_coefficient: 0.6646
# Epoch 88/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1429 - binary_crossentropy: 0.0290 - generalized_dice_coefficient: 0.7432
# Epoch 88: val_loss did not improve from 0.18553
# 25/25 [==============================] - 6s 253ms/step - loss: 0.1429 - binary_crossentropy: 0.0290 - generalized_dice_coefficient: 0.7432 - val_loss: 0.1862 - val_binary_crossentropy: 0.0368 - val_generalized_dice_coefficient: 0.6645
# Epoch 89/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1423 - binary_crossentropy: 0.0289 - generalized_dice_coefficient: 0.7444
# Epoch 89: val_loss did not improve from 0.18553
# 25/25 [==============================] - 6s 258ms/step - loss: 0.1423 - binary_crossentropy: 0.0289 - generalized_dice_coefficient: 0.7444 - val_loss: 0.1862 - val_binary_crossentropy: 0.0368 - val_generalized_dice_coefficient: 0.6645
# Epoch 90/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1430 - binary_crossentropy: 0.0290 - generalized_dice_coefficient: 0.7430
# Epoch 90: val_loss did not improve from 0.18553
# 25/25 [==============================] - 6s 254ms/step - loss: 0.1430 - binary_crossentropy: 0.0290 - generalized_dice_coefficient: 0.7430 - val_loss: 0.1862 - val_binary_crossentropy: 0.0368 - val_generalized_dice_coefficient: 0.6645
# Epoch 91/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1423 - binary_crossentropy: 0.0288 - generalized_dice_coefficient: 0.7441
# Epoch 91: val_loss did not improve from 0.18553
# 25/25 [==============================] - 6s 257ms/step - loss: 0.1423 - binary_crossentropy: 0.0288 - generalized_dice_coefficient: 0.7441 - val_loss: 0.1862 - val_binary_crossentropy: 0.0368 - val_generalized_dice_coefficient: 0.6645
# Epoch 92/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1423 - binary_crossentropy: 0.0286 - generalized_dice_coefficient: 0.7441
# Epoch 92: val_loss did not improve from 0.18553
# 25/25 [==============================] - 6s 254ms/step - loss: 0.1423 - binary_crossentropy: 0.0286 - generalized_dice_coefficient: 0.7441 - val_loss: 0.1862 - val_binary_crossentropy: 0.0368 - val_generalized_dice_coefficient: 0.6645
# Epoch 93/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1420 - binary_crossentropy: 0.0287 - generalized_dice_coefficient: 0.7448
# Epoch 93: val_loss did not improve from 0.18553
# 25/25 [==============================] - 6s 258ms/step - loss: 0.1420 - binary_crossentropy: 0.0287 - generalized_dice_coefficient: 0.7448 - val_loss: 0.1862 - val_binary_crossentropy: 0.0368 - val_generalized_dice_coefficient: 0.6645
# Epoch 94/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1425 - binary_crossentropy: 0.0288 - generalized_dice_coefficient: 0.7438
# Epoch 94: val_loss did not improve from 0.18553
# 25/25 [==============================] - 6s 255ms/step - loss: 0.1425 - binary_crossentropy: 0.0288 - generalized_dice_coefficient: 0.7438 - val_loss: 0.1862 - val_binary_crossentropy: 0.0368 - val_generalized_dice_coefficient: 0.6645
# Epoch 95/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1427 - binary_crossentropy: 0.0288 - generalized_dice_coefficient: 0.7434
# Epoch 95: val_loss did not improve from 0.18553
# 25/25 [==============================] - 6s 259ms/step - loss: 0.1427 - binary_crossentropy: 0.0288 - generalized_dice_coefficient: 0.7434 - val_loss: 0.1862 - val_binary_crossentropy: 0.0368 - val_generalized_dice_coefficient: 0.6645
# Epoch 96/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1426 - binary_crossentropy: 0.0288 - generalized_dice_coefficient: 0.7437
# Epoch 96: val_loss did not improve from 0.18553
# 25/25 [==============================] - 6s 254ms/step - loss: 0.1426 - binary_crossentropy: 0.0288 - generalized_dice_coefficient: 0.7437 - val_loss: 0.1861 - val_binary_crossentropy: 0.0368 - val_generalized_dice_coefficient: 0.6646
# Epoch 97/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1424 - binary_crossentropy: 0.0289 - generalized_dice_coefficient: 0.7440
# Epoch 97: val_loss did not improve from 0.18553
# 25/25 [==============================] - 6s 262ms/step - loss: 0.1424 - binary_crossentropy: 0.0289 - generalized_dice_coefficient: 0.7440 - val_loss: 0.1861 - val_binary_crossentropy: 0.0368 - val_generalized_dice_coefficient: 0.6646
# Epoch 98/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1422 - binary_crossentropy: 0.0288 - generalized_dice_coefficient: 0.7444
# Epoch 98: val_loss did not improve from 0.18553
# 25/25 [==============================] - 6s 258ms/step - loss: 0.1422 - binary_crossentropy: 0.0288 - generalized_dice_coefficient: 0.7444 - val_loss: 0.1861 - val_binary_crossentropy: 0.0368 - val_generalized_dice_coefficient: 0.6646
# Epoch 99/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1420 - binary_crossentropy: 0.0289 - generalized_dice_coefficient: 0.7448
# Epoch 99: val_loss did not improve from 0.18553
# 25/25 [==============================] - 8s 308ms/step - loss: 0.1420 - binary_crossentropy: 0.0289 - generalized_dice_coefficient: 0.7448 - val_loss: 0.1861 - val_binary_crossentropy: 0.0368 - val_generalized_dice_coefficient: 0.6646
# Epoch 100/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1427 - binary_crossentropy: 0.0287 - generalized_dice_coefficient: 0.7433
# Epoch 100: val_loss did not improve from 0.18553
# 25/25 [==============================] - 6s 255ms/step - loss: 0.1427 - binary_crossentropy: 0.0287 - generalized_dice_coefficient: 0.7433 - val_loss: 0.1861 - val_binary_crossentropy: 0.0368 - val_generalized_dice_coefficient: 0.6646
# Epoch 101/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1424 - binary_crossentropy: 0.0289 - generalized_dice_coefficient: 0.7441
# Epoch 101: val_loss did not improve from 0.18553
# 25/25 [==============================] - 6s 258ms/step - loss: 0.1424 - binary_crossentropy: 0.0289 - generalized_dice_coefficient: 0.7441 - val_loss: 0.1861 - val_binary_crossentropy: 0.0368 - val_generalized_dice_coefficient: 0.6645
# Epoch 102/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1421 - binary_crossentropy: 0.0288 - generalized_dice_coefficient: 0.7445
# Epoch 102: val_loss did not improve from 0.18553
# 25/25 [==============================] - 6s 252ms/step - loss: 0.1421 - binary_crossentropy: 0.0288 - generalized_dice_coefficient: 0.7445 - val_loss: 0.1861 - val_binary_crossentropy: 0.0368 - val_generalized_dice_coefficient: 0.6645
# Epoch 103/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1428 - binary_crossentropy: 0.0291 - generalized_dice_coefficient: 0.7434
# Epoch 103: val_loss did not improve from 0.18553
# 25/25 [==============================] - 6s 255ms/step - loss: 0.1428 - binary_crossentropy: 0.0291 - generalized_dice_coefficient: 0.7434 - val_loss: 0.1861 - val_binary_crossentropy: 0.0368 - val_generalized_dice_coefficient: 0.6645
# Epoch 104/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1426 - binary_crossentropy: 0.0288 - generalized_dice_coefficient: 0.7436
# Epoch 104: val_loss did not improve from 0.18553
# 25/25 [==============================] - 6s 255ms/step - loss: 0.1426 - binary_crossentropy: 0.0288 - generalized_dice_coefficient: 0.7436 - val_loss: 0.1861 - val_binary_crossentropy: 0.0368 - val_generalized_dice_coefficient: 0.6646
# Epoch 105/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1425 - binary_crossentropy: 0.0288 - generalized_dice_coefficient: 0.7437
# Epoch 105: val_loss did not improve from 0.18553
# 25/25 [==============================] - 6s 260ms/step - loss: 0.1425 - binary_crossentropy: 0.0288 - generalized_dice_coefficient: 0.7437 - val_loss: 0.1861 - val_binary_crossentropy: 0.0368 - val_generalized_dice_coefficient: 0.6646
# Epoch 106/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1422 - binary_crossentropy: 0.0287 - generalized_dice_coefficient: 0.7443
# Epoch 106: val_loss did not improve from 0.18553
# ...
# Epoch 164/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1425 - binary_crossentropy: 0.0290 - generalized_dice_coefficient: 0.7440
# Epoch 164: val_loss did not improve from 0.18553
# 25/25 [==============================] - 6s 254ms/step - loss: 0.1425 - binary_crossentropy: 0.0290 - generalized_dice_coefficient: 0.7440 - val_loss: 0.1861 - val_binary_crossentropy: 0.0368 - val_generalized_dice_coefficient: 0.6646
# Epoch 165/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1424 - binary_crossentropy: 0.0290 - generalized_dice_coefficient: 0.7442
# Epoch 165: val_loss did not improve from 0.18553
# 25/25 [==============================] - 6s 258ms/step - loss: 0.1424 - binary_crossentropy: 0.0290 - generalized_dice_coefficient: 0.7442 - val_loss: 0.1861 - val_binary_crossentropy: 0.0368 - val_generalized_dice_coefficient: 0.6645
# Epoch 166/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1433 - binary_crossentropy: 0.0290 - generalized_dice_coefficient: 0.7425
# Epoch 166: val_loss did not improve from 0.18553
# 25/25 [==============================] - 6s 256ms/step - loss: 0.1433 - binary_crossentropy: 0.0290 - generalized_dice_coefficient: 0.7425 - val_loss: 0.1861 - val_binary_crossentropy: 0.0368 - val_generalized_dice_coefficient: 0.6645
# Epoch 167/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1423 - binary_crossentropy: 0.0290 - generalized_dice_coefficient: 0.7444
# Epoch 167: val_loss did not improve from 0.18553
# 25/25 [==============================] - 8s 312ms/step - loss: 0.1423 - binary_crossentropy: 0.0290 - generalized_dice_coefficient: 0.7444 - val_loss: 0.1861 - val_binary_crossentropy: 0.0368 - val_generalized_dice_coefficient: 0.6645
# Epoch 168/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1418 - binary_crossentropy: 0.0289 - generalized_dice_coefficient: 0.7453
# Epoch 168: val_loss did not improve from 0.18553
# 25/25 [==============================] - 6s 253ms/step - loss: 0.1418 - binary_crossentropy: 0.0289 - generalized_dice_coefficient: 0.7453 - val_loss: 0.1862 - val_binary_crossentropy: 0.0368 - val_generalized_dice_coefficient: 0.6645
# Epoch 169/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1430 - binary_crossentropy: 0.0290 - generalized_dice_coefficient: 0.7429
# Epoch 169: val_loss did not improve from 0.18553
# 25/25 [==============================] - 6s 257ms/step - loss: 0.1430 - binary_crossentropy: 0.0290 - generalized_dice_coefficient: 0.7429 - val_loss: 0.1862 - val_binary_crossentropy: 0.0368 - val_generalized_dice_coefficient: 0.6645
# Epoch 170/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1422 - binary_crossentropy: 0.0289 - generalized_dice_coefficient: 0.7445
# Epoch 170: val_loss did not improve from 0.18553
# 25/25 [==============================] - 6s 254ms/step - loss: 0.1422 - binary_crossentropy: 0.0289 - generalized_dice_coefficient: 0.7445 - val_loss: 0.1862 - val_binary_crossentropy: 0.0368 - val_generalized_dice_coefficient: 0.6645
# Epoch 171/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1421 - binary_crossentropy: 0.0286 - generalized_dice_coefficient: 0.7445
# Epoch 171: val_loss did not improve from 0.18553
# 25/25 [==============================] - 6s 259ms/step - loss: 0.1421 - binary_crossentropy: 0.0286 - generalized_dice_coefficient: 0.7445 - val_loss: 0.1862 - val_binary_crossentropy: 0.0368 - val_generalized_dice_coefficient: 0.6645
# Epoch 172/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1426 - binary_crossentropy: 0.0290 - generalized_dice_coefficient: 0.7439
# Epoch 172: val_loss did not improve from 0.18553
# 25/25 [==============================] - 6s 255ms/step - loss: 0.1426 - binary_crossentropy: 0.0290 - generalized_dice_coefficient: 0.7439 - val_loss: 0.1861 - val_binary_crossentropy: 0.0368 - val_generalized_dice_coefficient: 0.6645
# Epoch 173/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1417 - binary_crossentropy: 0.0288 - generalized_dice_coefficient: 0.7454
# Epoch 173: val_loss did not improve from 0.18553
# 25/25 [==============================] - 6s 262ms/step - loss: 0.1417 - binary_crossentropy: 0.0288 - generalized_dice_coefficient: 0.7454 - val_loss: 0.1861 - val_binary_crossentropy: 0.0368 - val_generalized_dice_coefficient: 0.6645
# Epoch 174/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1420 - binary_crossentropy: 0.0288 - generalized_dice_coefficient: 0.7449
# Epoch 174: val_loss did not improve from 0.18553
# 25/25 [==============================] - 6s 255ms/step - loss: 0.1420 - binary_crossentropy: 0.0288 - generalized_dice_coefficient: 0.7449 - val_loss: 0.1862 - val_binary_crossentropy: 0.0368 - val_generalized_dice_coefficient: 0.6645
# Epoch 175/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1423 - binary_crossentropy: 0.0289 - generalized_dice_coefficient: 0.7442
# Epoch 175: val_loss did not improve from 0.18553
# 25/25 [==============================] - 6s 260ms/step - loss: 0.1423 - binary_crossentropy: 0.0289 - generalized_dice_coefficient: 0.7442 - val_loss: 0.1862 - val_binary_crossentropy: 0.0368 - val_generalized_dice_coefficient: 0.6645
# Epoch 176/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1424 - binary_crossentropy: 0.0288 - generalized_dice_coefficient: 0.7439
# Epoch 176: val_loss did not improve from 0.18553
# 25/25 [==============================] - 6s 254ms/step - loss: 0.1424 - binary_crossentropy: 0.0288 - generalized_dice_coefficient: 0.7439 - val_loss: 0.1862 - val_binary_crossentropy: 0.0368 - val_generalized_dice_coefficient: 0.6645
# Epoch 177/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1428 - binary_crossentropy: 0.0289 - generalized_dice_coefficient: 0.7433
# Epoch 177: val_loss did not improve from 0.18553
# 25/25 [==============================] - 6s 259ms/step - loss: 0.1428 - binary_crossentropy: 0.0289 - generalized_dice_coefficient: 0.7433 - val_loss: 0.1861 - val_binary_crossentropy: 0.0368 - val_generalized_dice_coefficient: 0.6645
# Epoch 178/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1424 - binary_crossentropy: 0.0289 - generalized_dice_coefficient: 0.7441
# Epoch 178: val_loss did not improve from 0.18553
# 25/25 [==============================] - 6s 255ms/step - loss: 0.1424 - binary_crossentropy: 0.0289 - generalized_dice_coefficient: 0.7441 - val_loss: 0.1861 - val_binary_crossentropy: 0.0368 - val_generalized_dice_coefficient: 0.6645
# Epoch 179/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1424 - binary_crossentropy: 0.0289 - generalized_dice_coefficient: 0.7441
# Epoch 179: val_loss did not improve from 0.18553
# 25/25 [==============================] - 8s 314ms/step - loss: 0.1424 - binary_crossentropy: 0.0289 - generalized_dice_coefficient: 0.7441 - val_loss: 0.1862 - val_binary_crossentropy: 0.0368 - val_generalized_dice_coefficient: 0.6645
# Epoch 180/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1428 - binary_crossentropy: 0.0290 - generalized_dice_coefficient: 0.7435
# Epoch 180: val_loss did not improve from 0.18553
# 25/25 [==============================] - 6s 256ms/step - loss: 0.1428 - binary_crossentropy: 0.0290 - generalized_dice_coefficient: 0.7435 - val_loss: 0.1861 - val_binary_crossentropy: 0.0368 - val_generalized_dice_coefficient: 0.6645
# Epoch 181/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1432 - binary_crossentropy: 0.0290 - generalized_dice_coefficient: 0.7426
# Epoch 181: val_loss did not improve from 0.18553
# 25/25 [==============================] - 6s 259ms/step - loss: 0.1432 - binary_crossentropy: 0.0290 - generalized_dice_coefficient: 0.7426 - val_loss: 0.1862 - val_binary_crossentropy: 0.0368 - val_generalized_dice_coefficient: 0.6645
# Epoch 182/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1422 - binary_crossentropy: 0.0290 - generalized_dice_coefficient: 0.7446
# Epoch 182: val_loss did not improve from 0.18553
# 25/25 [==============================] - 6s 256ms/step - loss: 0.1422 - binary_crossentropy: 0.0290 - generalized_dice_coefficient: 0.7446 - val_loss: 0.1861 - val_binary_crossentropy: 0.0368 - val_generalized_dice_coefficient: 0.6645
# Epoch 183/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1425 - binary_crossentropy: 0.0288 - generalized_dice_coefficient: 0.7439
# Epoch 183: val_loss did not improve from 0.18553
# 25/25 [==============================] - 6s 262ms/step - loss: 0.1425 - binary_crossentropy: 0.0288 - generalized_dice_coefficient: 0.7439 - val_loss: 0.1861 - val_binary_crossentropy: 0.0368 - val_generalized_dice_coefficient: 0.6645
# Epoch 184/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1420 - binary_crossentropy: 0.0288 - generalized_dice_coefficient: 0.7448
# Epoch 184: val_loss did not improve from 0.18553
# 25/25 [==============================] - 8s 317ms/step - loss: 0.1420 - binary_crossentropy: 0.0288 - generalized_dice_coefficient: 0.7448 - val_loss: 0.1861 - val_binary_crossentropy: 0.0368 - val_generalized_dice_coefficient: 0.6645
# Epoch 185/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1431 - binary_crossentropy: 0.0290 - generalized_dice_coefficient: 0.7428
# Epoch 185: val_loss did not improve from 0.18553
# 25/25 [==============================] - 8s 332ms/step - loss: 0.1431 - binary_crossentropy: 0.0290 - generalized_dice_coefficient: 0.7428 - val_loss: 0.1861 - val_binary_crossentropy: 0.0368 - val_generalized_dice_coefficient: 0.6645
# Epoch 186/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1424 - binary_crossentropy: 0.0289 - generalized_dice_coefficient: 0.7441
# Epoch 186: val_loss did not improve from 0.18553
# 25/25 [==============================] - 6s 254ms/step - loss: 0.1424 - binary_crossentropy: 0.0289 - generalized_dice_coefficient: 0.7441 - val_loss: 0.1861 - val_binary_crossentropy: 0.0368 - val_generalized_dice_coefficient: 0.6645
# Epoch 187/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1418 - binary_crossentropy: 0.0285 - generalized_dice_coefficient: 0.7449
# Epoch 187: val_loss did not improve from 0.18553
# 25/25 [==============================] - 6s 257ms/step - loss: 0.1418 - binary_crossentropy: 0.0285 - generalized_dice_coefficient: 0.7449 - val_loss: 0.1861 - val_binary_crossentropy: 0.0368 - val_generalized_dice_coefficient: 0.6646
# Epoch 188/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1434 - binary_crossentropy: 0.0291 - generalized_dice_coefficient: 0.7424
# Epoch 188: val_loss did not improve from 0.18553
# 25/25 [==============================] - 6s 255ms/step - loss: 0.1434 - binary_crossentropy: 0.0291 - generalized_dice_coefficient: 0.7424 - val_loss: 0.1861 - val_binary_crossentropy: 0.0368 - val_generalized_dice_coefficient: 0.6646
# Epoch 189/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1426 - binary_crossentropy: 0.0288 - generalized_dice_coefficient: 0.7437
# Epoch 189: val_loss did not improve from 0.18553
# 25/25 [==============================] - 6s 259ms/step - loss: 0.1426 - binary_crossentropy: 0.0288 - generalized_dice_coefficient: 0.7437 - val_loss: 0.1861 - val_binary_crossentropy: 0.0368 - val_generalized_dice_coefficient: 0.6646
# Epoch 190/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1432 - binary_crossentropy: 0.0291 - generalized_dice_coefficient: 0.7427
# Epoch 190: val_loss did not improve from 0.18553
# 25/25 [==============================] - 6s 255ms/step - loss: 0.1432 - binary_crossentropy: 0.0291 - generalized_dice_coefficient: 0.7427 - val_loss: 0.1861 - val_binary_crossentropy: 0.0368 - val_generalized_dice_coefficient: 0.6645
# Epoch 191/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1418 - binary_crossentropy: 0.0285 - generalized_dice_coefficient: 0.7448
# Epoch 191: val_loss did not improve from 0.18553
# 25/25 [==============================] - 7s 264ms/step - loss: 0.1418 - binary_crossentropy: 0.0285 - generalized_dice_coefficient: 0.7448 - val_loss: 0.1861 - val_binary_crossentropy: 0.0368 - val_generalized_dice_coefficient: 0.6646
# Epoch 192/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1422 - binary_crossentropy: 0.0289 - generalized_dice_coefficient: 0.7444
# Epoch 192: val_loss did not improve from 0.18553
# 25/25 [==============================] - 6s 258ms/step - loss: 0.1422 - binary_crossentropy: 0.0289 - generalized_dice_coefficient: 0.7444 - val_loss: 0.1861 - val_binary_crossentropy: 0.0368 - val_generalized_dice_coefficient: 0.6646
# Epoch 193/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1424 - binary_crossentropy: 0.0289 - generalized_dice_coefficient: 0.7441
# Epoch 193: val_loss did not improve from 0.18553
# 25/25 [==============================] - 6s 261ms/step - loss: 0.1424 - binary_crossentropy: 0.0289 - generalized_dice_coefficient: 0.7441 - val_loss: 0.1861 - val_binary_crossentropy: 0.0368 - val_generalized_dice_coefficient: 0.6646
# Epoch 194/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1420 - binary_crossentropy: 0.0287 - generalized_dice_coefficient: 0.7448
# Epoch 194: val_loss did not improve from 0.18553
# 25/25 [==============================] - 6s 254ms/step - loss: 0.1420 - binary_crossentropy: 0.0287 - generalized_dice_coefficient: 0.7448 - val_loss: 0.1861 - val_binary_crossentropy: 0.0368 - val_generalized_dice_coefficient: 0.6646
# Epoch 195/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1428 - binary_crossentropy: 0.0288 - generalized_dice_coefficient: 0.7432
# Epoch 195: val_loss did not improve from 0.18553
# 25/25 [==============================] - 7s 264ms/step - loss: 0.1428 - binary_crossentropy: 0.0288 - generalized_dice_coefficient: 0.7432 - val_loss: 0.1861 - val_binary_crossentropy: 0.0368 - val_generalized_dice_coefficient: 0.6646
# Epoch 196/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1424 - binary_crossentropy: 0.0289 - generalized_dice_coefficient: 0.7441
# Epoch 196: val_loss did not improve from 0.18553
# 25/25 [==============================] - 6s 254ms/step - loss: 0.1424 - binary_crossentropy: 0.0289 - generalized_dice_coefficient: 0.7441 - val_loss: 0.1861 - val_binary_crossentropy: 0.0368 - val_generalized_dice_coefficient: 0.6646
# Epoch 197/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1420 - binary_crossentropy: 0.0287 - generalized_dice_coefficient: 0.7446
# Epoch 197: val_loss did not improve from 0.18553
# 25/25 [==============================] - 6s 255ms/step - loss: 0.1420 - binary_crossentropy: 0.0287 - generalized_dice_coefficient: 0.7446 - val_loss: 0.1861 - val_binary_crossentropy: 0.0368 - val_generalized_dice_coefficient: 0.6646
# Epoch 198/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1423 - binary_crossentropy: 0.0289 - generalized_dice_coefficient: 0.7442
# Epoch 198: val_loss did not improve from 0.18553
# 25/25 [==============================] - 6s 259ms/step - loss: 0.1423 - binary_crossentropy: 0.0289 - generalized_dice_coefficient: 0.7442 - val_loss: 0.1861 - val_binary_crossentropy: 0.0368 - val_generalized_dice_coefficient: 0.6645
# Epoch 199/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1429 - binary_crossentropy: 0.0290 - generalized_dice_coefficient: 0.7433
# Epoch 199: val_loss did not improve from 0.18553
# 25/25 [==============================] - 6s 259ms/step - loss: 0.1429 - binary_crossentropy: 0.0290 - generalized_dice_coefficient: 0.7433 - val_loss: 0.1861 - val_binary_crossentropy: 0.0368 - val_generalized_dice_coefficient: 0.6646
# Epoch 200/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1429 - binary_crossentropy: 0.0291 - generalized_dice_coefficient: 0.7433
# Epoch 200: val_loss did not improve from 0.18553
# 25/25 [==============================] - 6s 257ms/step - loss: 0.1429 - binary_crossentropy: 0.0291 - generalized_dice_coefficient: 0.7433 - val_loss: 0.1861 - val_binary_crossentropy: 0.0368 - val_generalized_dice_coefficient: 0.6645

# %%
prd_img = model.predict(np.array([train_imgs[4]]))
# Out:
# 1/1 [==============================] - 0s 35ms/step

# %%
plt.imshow(np.round(np.squeeze(prd_img[0])), cmap='gray_r')
plt.show()

# %%
plt.imshow(np.squeeze(train_imgs[1]), cmap="gray_r")
plt.show()

# %%
plt.imshow(train_msks[1], cmap="gray_r")
plt.show()

# %%
output_img = np.round(np.squeeze(prd_img[0]))

# %%
import pickle
with open(model_summary_path, 'wb') as file:
    pickle.dump(model_history.history, file)

# %%
loss = model_history.history['loss']
val_loss = model_history.history['val_loss']

plt.figure()
plt.plot(model_history.epoch, loss, 'r', label='Training loss')
plt.plot(model_history.epoch, val_loss, 'bo', label='Validation loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss Value')
plt.ylim([0, 1])
plt.legend()
plt.show()

# %%
# 재시도시
del model
