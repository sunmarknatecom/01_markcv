# %% [markdown]
# <a href="https://colab.research.google.com/github/sunmarknatecom/01_markcv/blob/master/bonespect_train_0828.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from glob import glob
import numpy as np
import cv2, os, copy, shutil
import matplotlib.pyplot as plt
from PIL import Image
from random import randint

# DEEP LEARNING MODULES
import tensorflow as tf
from keras import backend as K
from keras.losses import binary_crossentropy
from keras.optimizers import Adam

from keras.layers import Input, Conv2D, MaxPooling2D, Conv2DTranspose, BatchNormalization, concatenate
from keras.models import Model
from skimage.metrics import structural_similarity as ssim

# %%
inputNpyList = sorted(glob("/content/drive/MyDrive/Bone_SPECT/inputData/*.npy"))
labelNpyList = sorted(glob("/content/drive/MyDrive/Bone_SPECT/labelData/*.npy"))

# %%
inputNpyList[0]
# Out:
# '/content/drive/MyDrive/Bone_SPECT/inputData/23060101_input.npy'

# %%
testImg = np.load(inputNpyList[0])

# %%
plt.imshow(testImg, cmap='gray_r')
plt.show()

# %%
for i in range(238):
    tempInput = inputNpyList[i].split("/")[-1][-18:-10]
    tempLabel = labelNpyList[i].split("/")[-1][-18:-10]
    if tempInput != tempLabel:
        print(i)
    else:
        continue

# %%
inputObj = []
labelObj = []
sizesImg = []

for i in range(238):
    tempInputObj = np.load(inputNpyList[i])
    tempInputObj = np.array(tempInputObj, dtype=np.uint16)
    tempLabelObj = np.load(labelNpyList[i])
    tempLabelObj = np.array(tempLabelObj, dtype=np.uint16)
    sizesImg.append(np.shape(tempInputObj)[0])
    inputObj.append(tempInputObj)
    labelObj.append(tempLabelObj)

# %%
MAX_SIZE = 1024

# %%
train_imgs = []
train_lbls = []

# %%
for i in range(238):
    io_x, ioy = np.shape(inputObj[i])
    if io_x != MAX_SIZE:
        diffIOx = MAX_SIZE - io_x
        zeroPadding = np.zeros((diffIOx,256))
        tempInput = np.vstack([inputObj[i],zeroPadding])
        tempLabel = np.vstack([labelObj[i],zeroPadding])
        train_imgs.append(tempInput)
        train_lbls.append(tempLabel)
    else:
        train_imgs.append(inputObj[i])
        train_lbls.append(labelObj[i])

# %%
temp_train_imgs = np.array(train_imgs)
temp_train_lbls = np.array(train_lbls)

# %%
temp_train_lbls[temp_train_lbls >=1] = 1

# %%
split_num = 200

# %%
train_imgs = temp_train_imgs[:split_num,...]
valid_imgs = temp_train_imgs[split_num:,...]
train_msks = temp_train_lbls[:split_num,...]
valid_msks = temp_train_lbls[split_num:,...]

# %%
train_imgs = np.array(train_imgs, dtype=np.float32)
train_msks = np.array(train_msks, dtype=np.float32)
valid_imgs = np.array(valid_imgs, dtype=np.float32)
valid_msks = np.array(valid_msks, dtype=np.float32)

train_msks = np.reshape(train_msks, (*train_msks.shape, 1))
valid_msks = np.reshape(valid_msks, (*valid_msks.shape, 1))

train_dataset = tf.data.Dataset.from_tensor_slices((train_imgs, train_msks))
test_dataset = tf.data.Dataset.from_tensor_slices((valid_imgs, valid_msks))

# %%
# %matplotlib inline

rand_num = randint(1,len(train_imgs))

fig = plt.figure(0, figsize=(20, 20))
fig.add_subplot(1, 2, 1)
plt.imshow(train_imgs[rand_num], cmap='gray_r')
fig.add_subplot(1, 2, 2)
plt.imshow(np.squeeze(train_msks[rand_num]), cmap='gray_r')

# %%
test_img = train_imgs[10] * np.squeeze(train_msks[10])

# %%
plt.figure(0, figsize=(20, 20))
plt.imshow(test_img, cmap="gray_r")
plt.show()

# %%
inputs = Input((MAX_SIZE, 256, 1))
bnorm1 = BatchNormalization()(inputs)
conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(bnorm1)
conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv1)
pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(pool1)
conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv2)
pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(pool2)
conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv3)
pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(pool3)
conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv4)
pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)

conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(pool4)
conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(conv5)

up6 = concatenate([Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(conv5), conv4], axis=3)
conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(up6)
conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv6)

up7 = concatenate([Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(conv6), conv3], axis=3)
conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(up7)
conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv7)

up8 = concatenate([Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(conv7), conv2], axis=3)
conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(up8)
conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv8)

up9 = concatenate([Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(conv8), conv1], axis=3)
conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(up9)
conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv9)

conv10 = Conv2D(1, (1, 1), activation='sigmoid')(conv9)

model = Model(inputs=[inputs], outputs=[conv10])

# %%
import tensorflow as tf
import keras.backend as K
from keras.losses import binary_crossentropy

beta = 0.25
alpha = 0.25
gamma = 2
epsilon = 1e-5
smooth = 1

def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + K.epsilon()) / (K.sum(y_true_f) + K.sum(y_pred_f) + K.epsilon())

def generalized_dice_coefficient(y_true, y_pred):
    smooth = 1.
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    score = (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return score

def dice_loss(y_true, y_pred):
    loss = 1 - generalized_dice_coefficient(y_true, y_pred)
    return loss

def bce_dice_loss(y_true, y_pred):
    loss = binary_crossentropy(y_true, y_pred) + dice_loss(y_true, y_pred)
    return loss / 2.0

# %%
initial_learning_rate = 5e-6

lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate,
    decay_steps=100000,
    decay_rate=0.96,
    staircase=True)

callbacks = [tf.keras.callbacks.ModelCheckpoint(
    filepath="/content/drive/MyDrive/Bone_SPECT/models/mymodel_{epoch}.h5",
    save_best_only=True,
    monitor='val_loss',
    verbose=1)]

# %%
model.compile(Adam(learning_rate=lr_schedule), bce_dice_loss, metrics=[binary_crossentropy, generalized_dice_coefficient])

# %%
model.fit(train_imgs, train_msks, batch_size=10, epochs=200, callbacks=callbacks, validation_data=(valid_imgs, valid_msks))
# Out:
# Epoch 1/200
# 20/20 [==============================] - ETA: 0s - loss: 0.8321 - binary_crossentropy: 0.7006 - generalized_dice_coefficient: 0.0364
# Epoch 1: val_loss improved from inf to 0.83213, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_1.h5
# 20/20 [==============================] - 21s 336ms/step - loss: 0.8321 - binary_crossentropy: 0.7006 - generalized_dice_coefficient: 0.0364 - val_loss: 0.8321 - val_binary_crossentropy: 0.7031 - val_generalized_dice_coefficient: 0.0390
# Epoch 2/200
# 20/20 [==============================] - ETA: 0s - loss: 0.8306 - binary_crossentropy: 0.6971 - generalized_dice_coefficient: 0.0358
# Epoch 2: val_loss improved from 0.83213 to 0.82950, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_2.h5
# 20/20 [==============================] - 4s 226ms/step - loss: 0.8306 - binary_crossentropy: 0.6971 - generalized_dice_coefficient: 0.0358 - val_loss: 0.8295 - val_binary_crossentropy: 0.6960 - val_generalized_dice_coefficient: 0.0371
# Epoch 3/200
# 20/20 [==============================] - ETA: 0s - loss: 0.8294 - binary_crossentropy: 0.6939 - generalized_dice_coefficient: 0.0352
# Epoch 3: val_loss improved from 0.82950 to 0.82800, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_3.h5
# 20/20 [==============================] - 4s 225ms/step - loss: 0.8294 - binary_crossentropy: 0.6939 - generalized_dice_coefficient: 0.0352 - val_loss: 0.8280 - val_binary_crossentropy: 0.6920 - val_generalized_dice_coefficient: 0.0361
# Epoch 4/200
# 20/20 [==============================] - ETA: 0s - loss: 0.8282 - binary_crossentropy: 0.6910 - generalized_dice_coefficient: 0.0346
# Epoch 4: val_loss improved from 0.82800 to 0.82685, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_4.h5
# 20/20 [==============================] - 4s 224ms/step - loss: 0.8282 - binary_crossentropy: 0.6910 - generalized_dice_coefficient: 0.0346 - val_loss: 0.8268 - val_binary_crossentropy: 0.6889 - val_generalized_dice_coefficient: 0.0353
# Epoch 5/200
# 20/20 [==============================] - ETA: 0s - loss: 0.8271 - binary_crossentropy: 0.6882 - generalized_dice_coefficient: 0.0340
# Epoch 5: val_loss improved from 0.82685 to 0.82583, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_5.h5
# 20/20 [==============================] - 4s 224ms/step - loss: 0.8271 - binary_crossentropy: 0.6882 - generalized_dice_coefficient: 0.0340 - val_loss: 0.8258 - val_binary_crossentropy: 0.6861 - val_generalized_dice_coefficient: 0.0345
# Epoch 6/200
# 20/20 [==============================] - ETA: 0s - loss: 0.8261 - binary_crossentropy: 0.6854 - generalized_dice_coefficient: 0.0333
# Epoch 6: val_loss improved from 0.82583 to 0.82483, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_6.h5
# 20/20 [==============================] - 4s 223ms/step - loss: 0.8261 - binary_crossentropy: 0.6854 - generalized_dice_coefficient: 0.0333 - val_loss: 0.8248 - val_binary_crossentropy: 0.6833 - val_generalized_dice_coefficient: 0.0337
# Epoch 7/200
# 20/20 [==============================] - ETA: 0s - loss: 0.8250 - binary_crossentropy: 0.6825 - generalized_dice_coefficient: 0.0326
# Epoch 7: val_loss improved from 0.82483 to 0.82376, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_7.h5
# 20/20 [==============================] - 4s 224ms/step - loss: 0.8250 - binary_crossentropy: 0.6825 - generalized_dice_coefficient: 0.0326 - val_loss: 0.8238 - val_binary_crossentropy: 0.6804 - val_generalized_dice_coefficient: 0.0329
# Epoch 8/200
# 20/20 [==============================] - ETA: 0s - loss: 0.8237 - binary_crossentropy: 0.6793 - generalized_dice_coefficient: 0.0318
# Epoch 8: val_loss improved from 0.82376 to 0.82245, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_8.h5
# 20/20 [==============================] - 4s 224ms/step - loss: 0.8237 - binary_crossentropy: 0.6793 - generalized_dice_coefficient: 0.0318 - val_loss: 0.8224 - val_binary_crossentropy: 0.6771 - val_generalized_dice_coefficient: 0.0322
# Epoch 9/200
# 20/20 [==============================] - ETA: 0s - loss: 0.8220 - binary_crossentropy: 0.6750 - generalized_dice_coefficient: 0.0310
# Epoch 9: val_loss improved from 0.82245 to 0.82044, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_9.h5
# 20/20 [==============================] - 4s 222ms/step - loss: 0.8220 - binary_crossentropy: 0.6750 - generalized_dice_coefficient: 0.0310 - val_loss: 0.8204 - val_binary_crossentropy: 0.6721 - val_generalized_dice_coefficient: 0.0313
# Epoch 10/200
# 20/20 [==============================] - ETA: 0s - loss: 0.8188 - binary_crossentropy: 0.6674 - generalized_dice_coefficient: 0.0297
# Epoch 10: val_loss improved from 0.82044 to 0.81592, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_10.h5
# 20/20 [==============================] - 4s 224ms/step - loss: 0.8188 - binary_crossentropy: 0.6674 - generalized_dice_coefficient: 0.0297 - val_loss: 0.8159 - val_binary_crossentropy: 0.6614 - val_generalized_dice_coefficient: 0.0296
# Epoch 11/200
# 20/20 [==============================] - ETA: 0s - loss: 0.8089 - binary_crossentropy: 0.6441 - generalized_dice_coefficient: 0.0264
# Epoch 11: val_loss improved from 0.81592 to 0.79644, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_11.h5
# 20/20 [==============================] - 4s 223ms/step - loss: 0.8089 - binary_crossentropy: 0.6441 - generalized_dice_coefficient: 0.0264 - val_loss: 0.7964 - val_binary_crossentropy: 0.6159 - val_generalized_dice_coefficient: 0.0230
# Epoch 12/200
# 20/20 [==============================] - ETA: 0s - loss: 0.7679 - binary_crossentropy: 0.5501 - generalized_dice_coefficient: 0.0142
# Epoch 12: val_loss improved from 0.79644 to 0.73693, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_12.h5
# 20/20 [==============================] - 4s 224ms/step - loss: 0.7679 - binary_crossentropy: 0.5501 - generalized_dice_coefficient: 0.0142 - val_loss: 0.7369 - val_binary_crossentropy: 0.4792 - val_generalized_dice_coefficient: 0.0054
# Epoch 13/200
# 20/20 [==============================] - ETA: 0s - loss: 0.7138 - binary_crossentropy: 0.4321 - generalized_dice_coefficient: 0.0045
# Epoch 13: val_loss improved from 0.73693 to 0.70004, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_13.h5
# 20/20 [==============================] - 4s 224ms/step - loss: 0.7138 - binary_crossentropy: 0.4321 - generalized_dice_coefficient: 0.0045 - val_loss: 0.7000 - val_binary_crossentropy: 0.4025 - val_generalized_dice_coefficient: 0.0025
# Epoch 14/200
# 20/20 [==============================] - ETA: 0s - loss: 0.6779 - binary_crossentropy: 0.3605 - generalized_dice_coefficient: 0.0047
# Epoch 14: val_loss improved from 0.70004 to 0.66409, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_14.h5
# 20/20 [==============================] - 4s 224ms/step - loss: 0.6779 - binary_crossentropy: 0.3605 - generalized_dice_coefficient: 0.0047 - val_loss: 0.6641 - val_binary_crossentropy: 0.3317 - val_generalized_dice_coefficient: 0.0036
# Epoch 15/200
# 20/20 [==============================] - ETA: 0s - loss: 0.6430 - binary_crossentropy: 0.2914 - generalized_dice_coefficient: 0.0054
# Epoch 15: val_loss improved from 0.66409 to 0.62929, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_15.h5
# 20/20 [==============================] - 4s 225ms/step - loss: 0.6430 - binary_crossentropy: 0.2914 - generalized_dice_coefficient: 0.0054 - val_loss: 0.6293 - val_binary_crossentropy: 0.2639 - val_generalized_dice_coefficient: 0.0055
# Epoch 16/200
# 20/20 [==============================] - ETA: 0s - loss: 0.6098 - binary_crossentropy: 0.2269 - generalized_dice_coefficient: 0.0073
# Epoch 16: val_loss improved from 0.62929 to 0.59385, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_16.h5
# 20/20 [==============================] - 4s 225ms/step - loss: 0.6098 - binary_crossentropy: 0.2269 - generalized_dice_coefficient: 0.0073 - val_loss: 0.5938 - val_binary_crossentropy: 0.1969 - val_generalized_dice_coefficient: 0.0094
# Epoch 17/200
# 20/20 [==============================] - ETA: 0s - loss: 0.5755 - binary_crossentropy: 0.1640 - generalized_dice_coefficient: 0.0129
# Epoch 17: val_loss improved from 0.59385 to 0.55613, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_17.h5
# 20/20 [==============================] - 4s 224ms/step - loss: 0.5755 - binary_crossentropy: 0.1640 - generalized_dice_coefficient: 0.0129 - val_loss: 0.5561 - val_binary_crossentropy: 0.1348 - val_generalized_dice_coefficient: 0.0227
# Epoch 18/200
# 20/20 [==============================] - ETA: 0s - loss: 0.5355 - binary_crossentropy: 0.1081 - generalized_dice_coefficient: 0.0370
# Epoch 18: val_loss improved from 0.55613 to 0.50310, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_18.h5
# 20/20 [==============================] - 4s 225ms/step - loss: 0.5355 - binary_crossentropy: 0.1081 - generalized_dice_coefficient: 0.0370 - val_loss: 0.5031 - val_binary_crossentropy: 0.0842 - val_generalized_dice_coefficient: 0.0777
# Epoch 19/200
# 20/20 [==============================] - ETA: 0s - loss: 0.4728 - binary_crossentropy: 0.0689 - generalized_dice_coefficient: 0.1233
# Epoch 19: val_loss improved from 0.50310 to 0.43429, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_19.h5
# 20/20 [==============================] - 4s 225ms/step - loss: 0.4728 - binary_crossentropy: 0.0689 - generalized_dice_coefficient: 0.1233 - val_loss: 0.4343 - val_binary_crossentropy: 0.0588 - val_generalized_dice_coefficient: 0.1896
# Epoch 20/200
# 20/20 [==============================] - ETA: 0s - loss: 0.4246 - binary_crossentropy: 0.0648 - generalized_dice_coefficient: 0.2155
# Epoch 20: val_loss improved from 0.43429 to 0.40596, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_20.h5
# 20/20 [==============================] - 4s 226ms/step - loss: 0.4246 - binary_crossentropy: 0.0648 - generalized_dice_coefficient: 0.2155 - val_loss: 0.4060 - val_binary_crossentropy: 0.0615 - val_generalized_dice_coefficient: 0.2489
# Epoch 21/200
# 20/20 [==============================] - ETA: 0s - loss: 0.3989 - binary_crossentropy: 0.0648 - generalized_dice_coefficient: 0.2671
# Epoch 21: val_loss improved from 0.40596 to 0.37896, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_21.h5
# 20/20 [==============================] - 4s 225ms/step - loss: 0.3989 - binary_crossentropy: 0.0648 - generalized_dice_coefficient: 0.2671 - val_loss: 0.3790 - val_binary_crossentropy: 0.0541 - val_generalized_dice_coefficient: 0.2960
# Epoch 22/200
# 20/20 [==============================] - ETA: 0s - loss: 0.3632 - binary_crossentropy: 0.0565 - generalized_dice_coefficient: 0.3302
# Epoch 22: val_loss improved from 0.37896 to 0.33931, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_22.h5
# 20/20 [==============================] - 4s 223ms/step - loss: 0.3632 - binary_crossentropy: 0.0565 - generalized_dice_coefficient: 0.3302 - val_loss: 0.3393 - val_binary_crossentropy: 0.0454 - val_generalized_dice_coefficient: 0.3666
# Epoch 23/200
# 20/20 [==============================] - ETA: 0s - loss: 0.3197 - binary_crossentropy: 0.0477 - generalized_dice_coefficient: 0.4083
# Epoch 23: val_loss improved from 0.33931 to 0.30278, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_23.h5
# 20/20 [==============================] - 4s 224ms/step - loss: 0.3197 - binary_crossentropy: 0.0477 - generalized_dice_coefficient: 0.4083 - val_loss: 0.3028 - val_binary_crossentropy: 0.0384 - val_generalized_dice_coefficient: 0.4319
# Epoch 24/200
# 20/20 [==============================] - ETA: 0s - loss: 0.2925 - binary_crossentropy: 0.0466 - generalized_dice_coefficient: 0.4617
# Epoch 24: val_loss improved from 0.30278 to 0.27724, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_24.h5
# 20/20 [==============================] - 4s 225ms/step - loss: 0.2925 - binary_crossentropy: 0.0466 - generalized_dice_coefficient: 0.4617 - val_loss: 0.2772 - val_binary_crossentropy: 0.0344 - val_generalized_dice_coefficient: 0.4788
# Epoch 25/200
# 20/20 [==============================] - ETA: 0s - loss: 0.2750 - binary_crossentropy: 0.0461 - generalized_dice_coefficient: 0.4961
# Epoch 25: val_loss improved from 0.27724 to 0.26175, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_25.h5
# 20/20 [==============================] - 4s 226ms/step - loss: 0.2750 - binary_crossentropy: 0.0461 - generalized_dice_coefficient: 0.4961 - val_loss: 0.2617 - val_binary_crossentropy: 0.0325 - val_generalized_dice_coefficient: 0.5078
# Epoch 26/200
# 20/20 [==============================] - ETA: 0s - loss: 0.2609 - binary_crossentropy: 0.0449 - generalized_dice_coefficient: 0.5231
# Epoch 26: val_loss improved from 0.26175 to 0.24954, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_26.h5
# 20/20 [==============================] - 4s 224ms/step - loss: 0.2609 - binary_crossentropy: 0.0449 - generalized_dice_coefficient: 0.5231 - val_loss: 0.2495 - val_binary_crossentropy: 0.0311 - val_generalized_dice_coefficient: 0.5308
# Epoch 27/200
# 20/20 [==============================] - ETA: 0s - loss: 0.2453 - binary_crossentropy: 0.0427 - generalized_dice_coefficient: 0.5522
# Epoch 27: val_loss improved from 0.24954 to 0.23952, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_27.h5
# 20/20 [==============================] - 5s 228ms/step - loss: 0.2453 - binary_crossentropy: 0.0427 - generalized_dice_coefficient: 0.5522 - val_loss: 0.2395 - val_binary_crossentropy: 0.0312 - val_generalized_dice_coefficient: 0.5509
# Epoch 28/200
# 20/20 [==============================] - ETA: 0s - loss: 0.2406 - binary_crossentropy: 0.0452 - generalized_dice_coefficient: 0.5641
# Epoch 28: val_loss improved from 0.23952 to 0.23167, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_28.h5
# 20/20 [==============================] - 4s 225ms/step - loss: 0.2406 - binary_crossentropy: 0.0452 - generalized_dice_coefficient: 0.5641 - val_loss: 0.2317 - val_binary_crossentropy: 0.0296 - val_generalized_dice_coefficient: 0.5649
# Epoch 29/200
# 20/20 [==============================] - ETA: 0s - loss: 0.2352 - binary_crossentropy: 0.0457 - generalized_dice_coefficient: 0.5753
# Epoch 29: val_loss improved from 0.23167 to 0.22417, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_29.h5
# 20/20 [==============================] - 4s 225ms/step - loss: 0.2352 - binary_crossentropy: 0.0457 - generalized_dice_coefficient: 0.5753 - val_loss: 0.2242 - val_binary_crossentropy: 0.0287 - val_generalized_dice_coefficient: 0.5791
# Epoch 30/200
# 20/20 [==============================] - ETA: 0s - loss: 0.2255 - binary_crossentropy: 0.0431 - generalized_dice_coefficient: 0.5921
# Epoch 30: val_loss improved from 0.22417 to 0.21941, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_30.h5
# 20/20 [==============================] - 4s 226ms/step - loss: 0.2255 - binary_crossentropy: 0.0431 - generalized_dice_coefficient: 0.5921 - val_loss: 0.2194 - val_binary_crossentropy: 0.0296 - val_generalized_dice_coefficient: 0.5896
# Epoch 31/200
# 20/20 [==============================] - ETA: 0s - loss: 0.2169 - binary_crossentropy: 0.0406 - generalized_dice_coefficient: 0.6068
# Epoch 31: val_loss improved from 0.21941 to 0.21229, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_31.h5
# 20/20 [==============================] - 4s 225ms/step - loss: 0.2169 - binary_crossentropy: 0.0406 - generalized_dice_coefficient: 0.6068 - val_loss: 0.2123 - val_binary_crossentropy: 0.0287 - val_generalized_dice_coefficient: 0.6027
# Epoch 32/200
# 20/20 [==============================] - ETA: 0s - loss: 0.2084 - binary_crossentropy: 0.0405 - generalized_dice_coefficient: 0.6236
# Epoch 32: val_loss improved from 0.21229 to 0.20470, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_32.h5
# 20/20 [==============================] - 4s 225ms/step - loss: 0.2084 - binary_crossentropy: 0.0405 - generalized_dice_coefficient: 0.6236 - val_loss: 0.2047 - val_binary_crossentropy: 0.0272 - val_generalized_dice_coefficient: 0.6162
# Epoch 33/200
# 20/20 [==============================] - ETA: 0s - loss: 0.2055 - binary_crossentropy: 0.0404 - generalized_dice_coefficient: 0.6293
# Epoch 33: val_loss improved from 0.20470 to 0.19963, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_33.h5
# 20/20 [==============================] - 4s 224ms/step - loss: 0.2055 - binary_crossentropy: 0.0404 - generalized_dice_coefficient: 0.6293 - val_loss: 0.1996 - val_binary_crossentropy: 0.0261 - val_generalized_dice_coefficient: 0.6253
# Epoch 34/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1983 - binary_crossentropy: 0.0386 - generalized_dice_coefficient: 0.6421
# Epoch 34: val_loss improved from 0.19963 to 0.19309, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_34.h5
# 20/20 [==============================] - 4s 225ms/step - loss: 0.1983 - binary_crossentropy: 0.0386 - generalized_dice_coefficient: 0.6421 - val_loss: 0.1931 - val_binary_crossentropy: 0.0265 - val_generalized_dice_coefficient: 0.6389
# Epoch 35/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1953 - binary_crossentropy: 0.0402 - generalized_dice_coefficient: 0.6495
# Epoch 35: val_loss improved from 0.19309 to 0.18838, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_35.h5
# 20/20 [==============================] - 4s 224ms/step - loss: 0.1953 - binary_crossentropy: 0.0402 - generalized_dice_coefficient: 0.6495 - val_loss: 0.1884 - val_binary_crossentropy: 0.0265 - val_generalized_dice_coefficient: 0.6482
# Epoch 36/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1880 - binary_crossentropy: 0.0369 - generalized_dice_coefficient: 0.6610
# Epoch 36: val_loss improved from 0.18838 to 0.18287, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_36.h5
# 20/20 [==============================] - 4s 226ms/step - loss: 0.1880 - binary_crossentropy: 0.0369 - generalized_dice_coefficient: 0.6610 - val_loss: 0.1829 - val_binary_crossentropy: 0.0253 - val_generalized_dice_coefficient: 0.6582
# Epoch 37/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1826 - binary_crossentropy: 0.0382 - generalized_dice_coefficient: 0.6730
# Epoch 37: val_loss improved from 0.18287 to 0.17987, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_37.h5
# 20/20 [==============================] - 4s 225ms/step - loss: 0.1826 - binary_crossentropy: 0.0382 - generalized_dice_coefficient: 0.6730 - val_loss: 0.1799 - val_binary_crossentropy: 0.0249 - val_generalized_dice_coefficient: 0.6636
# Epoch 38/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1789 - binary_crossentropy: 0.0369 - generalized_dice_coefficient: 0.6791
# Epoch 38: val_loss improved from 0.17987 to 0.17758, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_38.h5
# 20/20 [==============================] - 5s 227ms/step - loss: 0.1789 - binary_crossentropy: 0.0369 - generalized_dice_coefficient: 0.6791 - val_loss: 0.1776 - val_binary_crossentropy: 0.0285 - val_generalized_dice_coefficient: 0.6720
# Epoch 39/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1758 - binary_crossentropy: 0.0365 - generalized_dice_coefficient: 0.6849
# Epoch 39: val_loss improved from 0.17758 to 0.17025, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_39.h5
# 20/20 [==============================] - 4s 225ms/step - loss: 0.1758 - binary_crossentropy: 0.0365 - generalized_dice_coefficient: 0.6849 - val_loss: 0.1702 - val_binary_crossentropy: 0.0278 - val_generalized_dice_coefficient: 0.6859
# Epoch 40/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1679 - binary_crossentropy: 0.0382 - generalized_dice_coefficient: 0.7025
# Epoch 40: val_loss improved from 0.17025 to 0.16537, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_40.h5
# 20/20 [==============================] - 4s 225ms/step - loss: 0.1679 - binary_crossentropy: 0.0382 - generalized_dice_coefficient: 0.7025 - val_loss: 0.1654 - val_binary_crossentropy: 0.0269 - val_generalized_dice_coefficient: 0.6946
# Epoch 41/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1665 - binary_crossentropy: 0.0376 - generalized_dice_coefficient: 0.7046
# Epoch 41: val_loss improved from 0.16537 to 0.16009, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_41.h5
# 20/20 [==============================] - 4s 224ms/step - loss: 0.1665 - binary_crossentropy: 0.0376 - generalized_dice_coefficient: 0.7046 - val_loss: 0.1601 - val_binary_crossentropy: 0.0257 - val_generalized_dice_coefficient: 0.7040
# Epoch 42/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1575 - binary_crossentropy: 0.0357 - generalized_dice_coefficient: 0.7207
# Epoch 42: val_loss improved from 0.16009 to 0.15597, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_42.h5
# 20/20 [==============================] - 4s 225ms/step - loss: 0.1575 - binary_crossentropy: 0.0357 - generalized_dice_coefficient: 0.7207 - val_loss: 0.1560 - val_binary_crossentropy: 0.0263 - val_generalized_dice_coefficient: 0.7126
# Epoch 43/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1554 - binary_crossentropy: 0.0332 - generalized_dice_coefficient: 0.7224
# Epoch 43: val_loss improved from 0.15597 to 0.15342, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_43.h5
# 20/20 [==============================] - 4s 224ms/step - loss: 0.1554 - binary_crossentropy: 0.0332 - generalized_dice_coefficient: 0.7224 - val_loss: 0.1534 - val_binary_crossentropy: 0.0293 - val_generalized_dice_coefficient: 0.7207
# Epoch 44/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1524 - binary_crossentropy: 0.0370 - generalized_dice_coefficient: 0.7322
# Epoch 44: val_loss improved from 0.15342 to 0.14750, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_44.h5
# 20/20 [==============================] - 4s 225ms/step - loss: 0.1524 - binary_crossentropy: 0.0370 - generalized_dice_coefficient: 0.7322 - val_loss: 0.1475 - val_binary_crossentropy: 0.0263 - val_generalized_dice_coefficient: 0.7295
# Epoch 45/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1490 - binary_crossentropy: 0.0358 - generalized_dice_coefficient: 0.7378
# Epoch 45: val_loss improved from 0.14750 to 0.14615, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_45.h5
# 20/20 [==============================] - 4s 225ms/step - loss: 0.1490 - binary_crossentropy: 0.0358 - generalized_dice_coefficient: 0.7378 - val_loss: 0.1462 - val_binary_crossentropy: 0.0266 - val_generalized_dice_coefficient: 0.7325
# Epoch 46/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1424 - binary_crossentropy: 0.0355 - generalized_dice_coefficient: 0.7507
# Epoch 46: val_loss improved from 0.14615 to 0.13805, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_46.h5
# 20/20 [==============================] - 4s 225ms/step - loss: 0.1424 - binary_crossentropy: 0.0355 - generalized_dice_coefficient: 0.7507 - val_loss: 0.1380 - val_binary_crossentropy: 0.0285 - val_generalized_dice_coefficient: 0.7505
# Epoch 47/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1411 - binary_crossentropy: 0.0380 - generalized_dice_coefficient: 0.7558
# Epoch 47: val_loss improved from 0.13805 to 0.13420, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_47.h5
# 20/20 [==============================] - 4s 225ms/step - loss: 0.1411 - binary_crossentropy: 0.0380 - generalized_dice_coefficient: 0.7558 - val_loss: 0.1342 - val_binary_crossentropy: 0.0289 - val_generalized_dice_coefficient: 0.7585
# Epoch 48/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1382 - binary_crossentropy: 0.0382 - generalized_dice_coefficient: 0.7618
# Epoch 48: val_loss improved from 0.13420 to 0.13161, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_48.h5
# 20/20 [==============================] - 4s 226ms/step - loss: 0.1382 - binary_crossentropy: 0.0382 - generalized_dice_coefficient: 0.7618 - val_loss: 0.1316 - val_binary_crossentropy: 0.0316 - val_generalized_dice_coefficient: 0.7663
# Epoch 49/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1358 - binary_crossentropy: 0.0388 - generalized_dice_coefficient: 0.7671
# Epoch 49: val_loss improved from 0.13161 to 0.12924, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_49.h5
# 20/20 [==============================] - 4s 225ms/step - loss: 0.1358 - binary_crossentropy: 0.0388 - generalized_dice_coefficient: 0.7671 - val_loss: 0.1292 - val_binary_crossentropy: 0.0332 - val_generalized_dice_coefficient: 0.7726
# Epoch 50/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1323 - binary_crossentropy: 0.0397 - generalized_dice_coefficient: 0.7750
# Epoch 50: val_loss improved from 0.12924 to 0.12904, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_50.h5
# 20/20 [==============================] - 5s 227ms/step - loss: 0.1323 - binary_crossentropy: 0.0397 - generalized_dice_coefficient: 0.7750 - val_loss: 0.1290 - val_binary_crossentropy: 0.0357 - val_generalized_dice_coefficient: 0.7754
# Epoch 51/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1305 - binary_crossentropy: 0.0390 - generalized_dice_coefficient: 0.7781
# Epoch 51: val_loss improved from 0.12904 to 0.12460, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_51.h5
# 20/20 [==============================] - 4s 225ms/step - loss: 0.1305 - binary_crossentropy: 0.0390 - generalized_dice_coefficient: 0.7781 - val_loss: 0.1246 - val_binary_crossentropy: 0.0337 - val_generalized_dice_coefficient: 0.7824
# Epoch 52/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1300 - binary_crossentropy: 0.0405 - generalized_dice_coefficient: 0.7806
# Epoch 52: val_loss did not improve from 0.12460
# 20/20 [==============================] - 4s 207ms/step - loss: 0.1300 - binary_crossentropy: 0.0405 - generalized_dice_coefficient: 0.7806 - val_loss: 0.1253 - val_binary_crossentropy: 0.0337 - val_generalized_dice_coefficient: 0.7811
# Epoch 53/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1285 - binary_crossentropy: 0.0424 - generalized_dice_coefficient: 0.7855
# Epoch 53: val_loss improved from 0.12460 to 0.12199, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_53.h5
# 20/20 [==============================] - 4s 225ms/step - loss: 0.1285 - binary_crossentropy: 0.0424 - generalized_dice_coefficient: 0.7855 - val_loss: 0.1220 - val_binary_crossentropy: 0.0351 - val_generalized_dice_coefficient: 0.7890
# Epoch 54/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1271 - binary_crossentropy: 0.0417 - generalized_dice_coefficient: 0.7874
# Epoch 54: val_loss improved from 0.12199 to 0.12180, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_54.h5
# 20/20 [==============================] - 4s 224ms/step - loss: 0.1271 - binary_crossentropy: 0.0417 - generalized_dice_coefficient: 0.7874 - val_loss: 0.1218 - val_binary_crossentropy: 0.0355 - val_generalized_dice_coefficient: 0.7898
# Epoch 55/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1270 - binary_crossentropy: 0.0409 - generalized_dice_coefficient: 0.7870
# Epoch 55: val_loss improved from 0.12180 to 0.11962, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_55.h5
# 20/20 [==============================] - 4s 225ms/step - loss: 0.1270 - binary_crossentropy: 0.0409 - generalized_dice_coefficient: 0.7870 - val_loss: 0.1196 - val_binary_crossentropy: 0.0340 - val_generalized_dice_coefficient: 0.7929
# Epoch 56/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1254 - binary_crossentropy: 0.0405 - generalized_dice_coefficient: 0.7897
# Epoch 56: val_loss did not improve from 0.11962
# 20/20 [==============================] - 4s 207ms/step - loss: 0.1254 - binary_crossentropy: 0.0405 - generalized_dice_coefficient: 0.7897 - val_loss: 0.1235 - val_binary_crossentropy: 0.0358 - val_generalized_dice_coefficient: 0.7871
# Epoch 57/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1263 - binary_crossentropy: 0.0427 - generalized_dice_coefficient: 0.7900
# Epoch 57: val_loss improved from 0.11962 to 0.11925, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_57.h5
# 20/20 [==============================] - 4s 224ms/step - loss: 0.1263 - binary_crossentropy: 0.0427 - generalized_dice_coefficient: 0.7900 - val_loss: 0.1192 - val_binary_crossentropy: 0.0343 - val_generalized_dice_coefficient: 0.7939
# Epoch 58/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1234 - binary_crossentropy: 0.0418 - generalized_dice_coefficient: 0.7949
# Epoch 58: val_loss did not improve from 0.11925
# 20/20 [==============================] - 4s 208ms/step - loss: 0.1234 - binary_crossentropy: 0.0418 - generalized_dice_coefficient: 0.7949 - val_loss: 0.1204 - val_binary_crossentropy: 0.0349 - val_generalized_dice_coefficient: 0.7922
# Epoch 59/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1247 - binary_crossentropy: 0.0413 - generalized_dice_coefficient: 0.7919
# Epoch 59: val_loss improved from 0.11925 to 0.11855, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_59.h5
# 20/20 [==============================] - 4s 225ms/step - loss: 0.1247 - binary_crossentropy: 0.0413 - generalized_dice_coefficient: 0.7919 - val_loss: 0.1185 - val_binary_crossentropy: 0.0351 - val_generalized_dice_coefficient: 0.7959
# Epoch 60/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1244 - binary_crossentropy: 0.0426 - generalized_dice_coefficient: 0.7939
# Epoch 60: val_loss did not improve from 0.11855
# 20/20 [==============================] - 4s 207ms/step - loss: 0.1244 - binary_crossentropy: 0.0426 - generalized_dice_coefficient: 0.7939 - val_loss: 0.1207 - val_binary_crossentropy: 0.0362 - val_generalized_dice_coefficient: 0.7925
# Epoch 61/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1234 - binary_crossentropy: 0.0410 - generalized_dice_coefficient: 0.7942
# Epoch 61: val_loss improved from 0.11855 to 0.11616, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_61.h5
# 20/20 [==============================] - 4s 225ms/step - loss: 0.1234 - binary_crossentropy: 0.0410 - generalized_dice_coefficient: 0.7942 - val_loss: 0.1162 - val_binary_crossentropy: 0.0343 - val_generalized_dice_coefficient: 0.8000
# Epoch 62/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1231 - binary_crossentropy: 0.0415 - generalized_dice_coefficient: 0.7953
# Epoch 62: val_loss did not improve from 0.11616
# 20/20 [==============================] - 4s 207ms/step - loss: 0.1231 - binary_crossentropy: 0.0415 - generalized_dice_coefficient: 0.7953 - val_loss: 0.1193 - val_binary_crossentropy: 0.0345 - val_generalized_dice_coefficient: 0.7940
# Epoch 63/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1221 - binary_crossentropy: 0.0406 - generalized_dice_coefficient: 0.7965
# Epoch 63: val_loss improved from 0.11616 to 0.11502, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_63.h5
# 20/20 [==============================] - 4s 224ms/step - loss: 0.1221 - binary_crossentropy: 0.0406 - generalized_dice_coefficient: 0.7965 - val_loss: 0.1150 - val_binary_crossentropy: 0.0343 - val_generalized_dice_coefficient: 0.8023
# Epoch 64/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1206 - binary_crossentropy: 0.0401 - generalized_dice_coefficient: 0.7990
# Epoch 64: val_loss did not improve from 0.11502
# 20/20 [==============================] - 4s 208ms/step - loss: 0.1206 - binary_crossentropy: 0.0401 - generalized_dice_coefficient: 0.7990 - val_loss: 0.1159 - val_binary_crossentropy: 0.0344 - val_generalized_dice_coefficient: 0.8007
# Epoch 65/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1209 - binary_crossentropy: 0.0398 - generalized_dice_coefficient: 0.7980
# Epoch 65: val_loss did not improve from 0.11502
# 20/20 [==============================] - 4s 207ms/step - loss: 0.1209 - binary_crossentropy: 0.0398 - generalized_dice_coefficient: 0.7980 - val_loss: 0.1157 - val_binary_crossentropy: 0.0354 - val_generalized_dice_coefficient: 0.8019
# Epoch 66/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1198 - binary_crossentropy: 0.0391 - generalized_dice_coefficient: 0.7995
# Epoch 66: val_loss did not improve from 0.11502
# 20/20 [==============================] - 4s 207ms/step - loss: 0.1198 - binary_crossentropy: 0.0391 - generalized_dice_coefficient: 0.7995 - val_loss: 0.1153 - val_binary_crossentropy: 0.0344 - val_generalized_dice_coefficient: 0.8019
# Epoch 67/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1207 - binary_crossentropy: 0.0416 - generalized_dice_coefficient: 0.8002
# Epoch 67: val_loss improved from 0.11502 to 0.11468, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_67.h5
# 20/20 [==============================] - 4s 224ms/step - loss: 0.1207 - binary_crossentropy: 0.0416 - generalized_dice_coefficient: 0.8002 - val_loss: 0.1147 - val_binary_crossentropy: 0.0347 - val_generalized_dice_coefficient: 0.8034
# Epoch 68/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1185 - binary_crossentropy: 0.0387 - generalized_dice_coefficient: 0.8017
# Epoch 68: val_loss did not improve from 0.11468
# 20/20 [==============================] - 4s 207ms/step - loss: 0.1185 - binary_crossentropy: 0.0387 - generalized_dice_coefficient: 0.8017 - val_loss: 0.1154 - val_binary_crossentropy: 0.0349 - val_generalized_dice_coefficient: 0.8024
# Epoch 69/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1193 - binary_crossentropy: 0.0410 - generalized_dice_coefficient: 0.8025
# Epoch 69: val_loss improved from 0.11468 to 0.11401, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_69.h5
# 20/20 [==============================] - 4s 226ms/step - loss: 0.1193 - binary_crossentropy: 0.0410 - generalized_dice_coefficient: 0.8025 - val_loss: 0.1140 - val_binary_crossentropy: 0.0343 - val_generalized_dice_coefficient: 0.8043
# Epoch 70/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1199 - binary_crossentropy: 0.0400 - generalized_dice_coefficient: 0.8002
# Epoch 70: val_loss did not improve from 0.11401
# 20/20 [==============================] - 4s 208ms/step - loss: 0.1199 - binary_crossentropy: 0.0400 - generalized_dice_coefficient: 0.8002 - val_loss: 0.1150 - val_binary_crossentropy: 0.0353 - val_generalized_dice_coefficient: 0.8035
# Epoch 71/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1195 - binary_crossentropy: 0.0391 - generalized_dice_coefficient: 0.8000
# Epoch 71: val_loss did not improve from 0.11401
# 20/20 [==============================] - 4s 207ms/step - loss: 0.1195 - binary_crossentropy: 0.0391 - generalized_dice_coefficient: 0.8000 - val_loss: 0.1145 - val_binary_crossentropy: 0.0350 - val_generalized_dice_coefficient: 0.8040
# Epoch 72/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1177 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8043
# Epoch 72: val_loss improved from 0.11401 to 0.11396, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_72.h5
# 20/20 [==============================] - 4s 226ms/step - loss: 0.1177 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8043 - val_loss: 0.1140 - val_binary_crossentropy: 0.0347 - val_generalized_dice_coefficient: 0.8049
# Epoch 73/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1188 - binary_crossentropy: 0.0387 - generalized_dice_coefficient: 0.8011
# Epoch 73: val_loss improved from 0.11396 to 0.11249, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_73.h5
# 20/20 [==============================] - 4s 226ms/step - loss: 0.1188 - binary_crossentropy: 0.0387 - generalized_dice_coefficient: 0.8011 - val_loss: 0.1125 - val_binary_crossentropy: 0.0350 - val_generalized_dice_coefficient: 0.8082
# Epoch 74/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1182 - binary_crossentropy: 0.0408 - generalized_dice_coefficient: 0.8045
# Epoch 74: val_loss did not improve from 0.11249
# 20/20 [==============================] - 4s 208ms/step - loss: 0.1182 - binary_crossentropy: 0.0408 - generalized_dice_coefficient: 0.8045 - val_loss: 0.1126 - val_binary_crossentropy: 0.0343 - val_generalized_dice_coefficient: 0.8072
# Epoch 75/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1169 - binary_crossentropy: 0.0386 - generalized_dice_coefficient: 0.8049
# Epoch 75: val_loss did not improve from 0.11249
# 20/20 [==============================] - 4s 207ms/step - loss: 0.1169 - binary_crossentropy: 0.0386 - generalized_dice_coefficient: 0.8049 - val_loss: 0.1137 - val_binary_crossentropy: 0.0354 - val_generalized_dice_coefficient: 0.8060
# Epoch 76/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1169 - binary_crossentropy: 0.0394 - generalized_dice_coefficient: 0.8057
# Epoch 76: val_loss improved from 0.11249 to 0.11235, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_76.h5
# 20/20 [==============================] - 4s 225ms/step - loss: 0.1169 - binary_crossentropy: 0.0394 - generalized_dice_coefficient: 0.8057 - val_loss: 0.1124 - val_binary_crossentropy: 0.0344 - val_generalized_dice_coefficient: 0.8078
# Epoch 77/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1150 - binary_crossentropy: 0.0384 - generalized_dice_coefficient: 0.8084
# Epoch 77: val_loss improved from 0.11235 to 0.11102, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_77.h5
# 20/20 [==============================] - 4s 225ms/step - loss: 0.1150 - binary_crossentropy: 0.0384 - generalized_dice_coefficient: 0.8084 - val_loss: 0.1110 - val_binary_crossentropy: 0.0343 - val_generalized_dice_coefficient: 0.8103
# Epoch 78/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1165 - binary_crossentropy: 0.0384 - generalized_dice_coefficient: 0.8053
# Epoch 78: val_loss improved from 0.11102 to 0.11081, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_78.h5
# 20/20 [==============================] - 5s 228ms/step - loss: 0.1165 - binary_crossentropy: 0.0384 - generalized_dice_coefficient: 0.8053 - val_loss: 0.1108 - val_binary_crossentropy: 0.0338 - val_generalized_dice_coefficient: 0.8102
# Epoch 79/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1165 - binary_crossentropy: 0.0388 - generalized_dice_coefficient: 0.8058
# Epoch 79: val_loss did not improve from 0.11081
# 20/20 [==============================] - 4s 207ms/step - loss: 0.1165 - binary_crossentropy: 0.0388 - generalized_dice_coefficient: 0.8058 - val_loss: 0.1113 - val_binary_crossentropy: 0.0337 - val_generalized_dice_coefficient: 0.8092
# Epoch 80/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1151 - binary_crossentropy: 0.0378 - generalized_dice_coefficient: 0.8076
# Epoch 80: val_loss improved from 0.11081 to 0.11047, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_80.h5
# 20/20 [==============================] - 4s 226ms/step - loss: 0.1151 - binary_crossentropy: 0.0378 - generalized_dice_coefficient: 0.8076 - val_loss: 0.1105 - val_binary_crossentropy: 0.0340 - val_generalized_dice_coefficient: 0.8112
# Epoch 81/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1143 - binary_crossentropy: 0.0370 - generalized_dice_coefficient: 0.8084
# Epoch 81: val_loss did not improve from 0.11047
# 20/20 [==============================] - 4s 207ms/step - loss: 0.1143 - binary_crossentropy: 0.0370 - generalized_dice_coefficient: 0.8084 - val_loss: 0.1111 - val_binary_crossentropy: 0.0342 - val_generalized_dice_coefficient: 0.8102
# Epoch 82/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1166 - binary_crossentropy: 0.0389 - generalized_dice_coefficient: 0.8058
# Epoch 82: val_loss improved from 0.11047 to 0.11011, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_82.h5
# 20/20 [==============================] - 4s 225ms/step - loss: 0.1166 - binary_crossentropy: 0.0389 - generalized_dice_coefficient: 0.8058 - val_loss: 0.1101 - val_binary_crossentropy: 0.0340 - val_generalized_dice_coefficient: 0.8119
# Epoch 83/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1139 - binary_crossentropy: 0.0384 - generalized_dice_coefficient: 0.8106
# Epoch 83: val_loss improved from 0.11011 to 0.10948, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_83.h5
# 20/20 [==============================] - 4s 225ms/step - loss: 0.1139 - binary_crossentropy: 0.0384 - generalized_dice_coefficient: 0.8106 - val_loss: 0.1095 - val_binary_crossentropy: 0.0330 - val_generalized_dice_coefficient: 0.8122
# Epoch 84/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1135 - binary_crossentropy: 0.0363 - generalized_dice_coefficient: 0.8092
# Epoch 84: val_loss did not improve from 0.10948
# 20/20 [==============================] - 4s 207ms/step - loss: 0.1135 - binary_crossentropy: 0.0363 - generalized_dice_coefficient: 0.8092 - val_loss: 0.1107 - val_binary_crossentropy: 0.0339 - val_generalized_dice_coefficient: 0.8105
# Epoch 85/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1157 - binary_crossentropy: 0.0379 - generalized_dice_coefficient: 0.8066
# Epoch 85: val_loss improved from 0.10948 to 0.10911, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_85.h5
# 20/20 [==============================] - 4s 226ms/step - loss: 0.1157 - binary_crossentropy: 0.0379 - generalized_dice_coefficient: 0.8066 - val_loss: 0.1091 - val_binary_crossentropy: 0.0337 - val_generalized_dice_coefficient: 0.8136
# Epoch 86/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1142 - binary_crossentropy: 0.0388 - generalized_dice_coefficient: 0.8103
# Epoch 86: val_loss did not improve from 0.10911
# 20/20 [==============================] - 4s 207ms/step - loss: 0.1142 - binary_crossentropy: 0.0388 - generalized_dice_coefficient: 0.8103 - val_loss: 0.1095 - val_binary_crossentropy: 0.0331 - val_generalized_dice_coefficient: 0.8121
# Epoch 87/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1157 - binary_crossentropy: 0.0371 - generalized_dice_coefficient: 0.8058
# Epoch 87: val_loss did not improve from 0.10911
# 20/20 [==============================] - 4s 208ms/step - loss: 0.1157 - binary_crossentropy: 0.0371 - generalized_dice_coefficient: 0.8058 - val_loss: 0.1113 - val_binary_crossentropy: 0.0342 - val_generalized_dice_coefficient: 0.8095
# Epoch 88/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1169 - binary_crossentropy: 0.0415 - generalized_dice_coefficient: 0.8078
# Epoch 88: val_loss did not improve from 0.10911
# 20/20 [==============================] - 4s 207ms/step - loss: 0.1169 - binary_crossentropy: 0.0415 - generalized_dice_coefficient: 0.8078 - val_loss: 0.1096 - val_binary_crossentropy: 0.0334 - val_generalized_dice_coefficient: 0.8124
# Epoch 89/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1163 - binary_crossentropy: 0.0373 - generalized_dice_coefficient: 0.8048
# Epoch 89: val_loss improved from 0.10911 to 0.10866, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_89.h5
# 20/20 [==============================] - 4s 226ms/step - loss: 0.1163 - binary_crossentropy: 0.0373 - generalized_dice_coefficient: 0.8048 - val_loss: 0.1087 - val_binary_crossentropy: 0.0329 - val_generalized_dice_coefficient: 0.8138
# Epoch 90/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1137 - binary_crossentropy: 0.0372 - generalized_dice_coefficient: 0.8099
# Epoch 90: val_loss did not improve from 0.10866
# 20/20 [==============================] - 4s 208ms/step - loss: 0.1137 - binary_crossentropy: 0.0372 - generalized_dice_coefficient: 0.8099 - val_loss: 0.1107 - val_binary_crossentropy: 0.0341 - val_generalized_dice_coefficient: 0.8110
# Epoch 91/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1131 - binary_crossentropy: 0.0377 - generalized_dice_coefficient: 0.8115
# Epoch 91: val_loss did not improve from 0.10866
# 20/20 [==============================] - 4s 207ms/step - loss: 0.1131 - binary_crossentropy: 0.0377 - generalized_dice_coefficient: 0.8115 - val_loss: 0.1099 - val_binary_crossentropy: 0.0332 - val_generalized_dice_coefficient: 0.8116
# Epoch 92/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1135 - binary_crossentropy: 0.0364 - generalized_dice_coefficient: 0.8094
# Epoch 92: val_loss improved from 0.10866 to 0.10787, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_92.h5
# 20/20 [==============================] - 4s 226ms/step - loss: 0.1135 - binary_crossentropy: 0.0364 - generalized_dice_coefficient: 0.8094 - val_loss: 0.1079 - val_binary_crossentropy: 0.0323 - val_generalized_dice_coefficient: 0.8147
# Epoch 93/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1125 - binary_crossentropy: 0.0361 - generalized_dice_coefficient: 0.8111
# Epoch 93: val_loss did not improve from 0.10787
# 20/20 [==============================] - 4s 208ms/step - loss: 0.1125 - binary_crossentropy: 0.0361 - generalized_dice_coefficient: 0.8111 - val_loss: 0.1102 - val_binary_crossentropy: 0.0334 - val_generalized_dice_coefficient: 0.8113
# Epoch 94/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1113 - binary_crossentropy: 0.0357 - generalized_dice_coefficient: 0.8132
# Epoch 94: val_loss did not improve from 0.10787
# 20/20 [==============================] - 4s 207ms/step - loss: 0.1113 - binary_crossentropy: 0.0357 - generalized_dice_coefficient: 0.8132 - val_loss: 0.1081 - val_binary_crossentropy: 0.0328 - val_generalized_dice_coefficient: 0.8148
# Epoch 95/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1118 - binary_crossentropy: 0.0347 - generalized_dice_coefficient: 0.8110
# Epoch 95: val_loss improved from 0.10787 to 0.10758, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_95.h5
# 20/20 [==============================] - 5s 227ms/step - loss: 0.1118 - binary_crossentropy: 0.0347 - generalized_dice_coefficient: 0.8110 - val_loss: 0.1076 - val_binary_crossentropy: 0.0323 - val_generalized_dice_coefficient: 0.8153
# Epoch 96/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1140 - binary_crossentropy: 0.0370 - generalized_dice_coefficient: 0.8089
# Epoch 96: val_loss did not improve from 0.10758
# 20/20 [==============================] - 4s 207ms/step - loss: 0.1140 - binary_crossentropy: 0.0370 - generalized_dice_coefficient: 0.8089 - val_loss: 0.1091 - val_binary_crossentropy: 0.0336 - val_generalized_dice_coefficient: 0.8137
# Epoch 97/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1109 - binary_crossentropy: 0.0371 - generalized_dice_coefficient: 0.8153
# Epoch 97: val_loss improved from 0.10758 to 0.10687, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_97.h5
# 20/20 [==============================] - 4s 226ms/step - loss: 0.1109 - binary_crossentropy: 0.0371 - generalized_dice_coefficient: 0.8153 - val_loss: 0.1069 - val_binary_crossentropy: 0.0332 - val_generalized_dice_coefficient: 0.8177
# Epoch 98/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1124 - binary_crossentropy: 0.0361 - generalized_dice_coefficient: 0.8113
# Epoch 98: val_loss did not improve from 0.10687
# 20/20 [==============================] - 4s 207ms/step - loss: 0.1124 - binary_crossentropy: 0.0361 - generalized_dice_coefficient: 0.8113 - val_loss: 0.1075 - val_binary_crossentropy: 0.0325 - val_generalized_dice_coefficient: 0.8157
# Epoch 99/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1129 - binary_crossentropy: 0.0371 - generalized_dice_coefficient: 0.8113
# Epoch 99: val_loss did not improve from 0.10687
# 20/20 [==============================] - 4s 207ms/step - loss: 0.1129 - binary_crossentropy: 0.0371 - generalized_dice_coefficient: 0.8113 - val_loss: 0.1085 - val_binary_crossentropy: 0.0337 - val_generalized_dice_coefficient: 0.8149
# ...
# Epoch 165/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0988 - binary_crossentropy: 0.0292 - generalized_dice_coefficient: 0.8316
# Epoch 165: val_loss did not improve from 0.10153
# 20/20 [==============================] - 4s 208ms/step - loss: 0.0988 - binary_crossentropy: 0.0292 - generalized_dice_coefficient: 0.8316 - val_loss: 0.1018 - val_binary_crossentropy: 0.0290 - val_generalized_dice_coefficient: 0.8235
# Epoch 166/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0984 - binary_crossentropy: 0.0285 - generalized_dice_coefficient: 0.8318
# Epoch 166: val_loss did not improve from 0.10153
# 20/20 [==============================] - 4s 208ms/step - loss: 0.0984 - binary_crossentropy: 0.0285 - generalized_dice_coefficient: 0.8318 - val_loss: 0.1037 - val_binary_crossentropy: 0.0299 - val_generalized_dice_coefficient: 0.8205
# Epoch 167/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0989 - binary_crossentropy: 0.0296 - generalized_dice_coefficient: 0.8317
# Epoch 167: val_loss did not improve from 0.10153
# 20/20 [==============================] - 4s 207ms/step - loss: 0.0989 - binary_crossentropy: 0.0296 - generalized_dice_coefficient: 0.8317 - val_loss: 0.1022 - val_binary_crossentropy: 0.0307 - val_generalized_dice_coefficient: 0.8246
# Epoch 168/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0993 - binary_crossentropy: 0.0302 - generalized_dice_coefficient: 0.8316
# Epoch 168: val_loss improved from 0.10153 to 0.10096, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_168.h5
# 20/20 [==============================] - 4s 226ms/step - loss: 0.0993 - binary_crossentropy: 0.0302 - generalized_dice_coefficient: 0.8316 - val_loss: 0.1010 - val_binary_crossentropy: 0.0302 - val_generalized_dice_coefficient: 0.8266
# Epoch 169/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0986 - binary_crossentropy: 0.0299 - generalized_dice_coefficient: 0.8326
# Epoch 169: val_loss did not improve from 0.10096
# 20/20 [==============================] - 4s 208ms/step - loss: 0.0986 - binary_crossentropy: 0.0299 - generalized_dice_coefficient: 0.8326 - val_loss: 0.1011 - val_binary_crossentropy: 0.0294 - val_generalized_dice_coefficient: 0.8253
# Epoch 170/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0988 - binary_crossentropy: 0.0298 - generalized_dice_coefficient: 0.8322
# Epoch 170: val_loss did not improve from 0.10096
# 20/20 [==============================] - 4s 207ms/step - loss: 0.0988 - binary_crossentropy: 0.0298 - generalized_dice_coefficient: 0.8322 - val_loss: 0.1022 - val_binary_crossentropy: 0.0299 - val_generalized_dice_coefficient: 0.8236
# Epoch 171/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1005 - binary_crossentropy: 0.0302 - generalized_dice_coefficient: 0.8292
# Epoch 171: val_loss did not improve from 0.10096
# 20/20 [==============================] - 4s 208ms/step - loss: 0.1005 - binary_crossentropy: 0.0302 - generalized_dice_coefficient: 0.8292 - val_loss: 0.1027 - val_binary_crossentropy: 0.0303 - val_generalized_dice_coefficient: 0.8231
# Epoch 172/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0988 - binary_crossentropy: 0.0301 - generalized_dice_coefficient: 0.8324
# Epoch 172: val_loss improved from 0.10096 to 0.10057, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_172.h5
# 20/20 [==============================] - 4s 225ms/step - loss: 0.0988 - binary_crossentropy: 0.0301 - generalized_dice_coefficient: 0.8324 - val_loss: 0.1006 - val_binary_crossentropy: 0.0289 - val_generalized_dice_coefficient: 0.8260
# Epoch 173/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1009 - binary_crossentropy: 0.0311 - generalized_dice_coefficient: 0.8292
# Epoch 173: val_loss did not improve from 0.10057
# 20/20 [==============================] - 4s 207ms/step - loss: 0.1009 - binary_crossentropy: 0.0311 - generalized_dice_coefficient: 0.8292 - val_loss: 0.1018 - val_binary_crossentropy: 0.0303 - val_generalized_dice_coefficient: 0.8249
# Epoch 174/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1014 - binary_crossentropy: 0.0316 - generalized_dice_coefficient: 0.8287
# Epoch 174: val_loss did not improve from 0.10057
# 20/20 [==============================] - 4s 208ms/step - loss: 0.1014 - binary_crossentropy: 0.0316 - generalized_dice_coefficient: 0.8287 - val_loss: 0.1026 - val_binary_crossentropy: 0.0295 - val_generalized_dice_coefficient: 0.8224
# Epoch 175/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0987 - binary_crossentropy: 0.0300 - generalized_dice_coefficient: 0.8326
# Epoch 175: val_loss did not improve from 0.10057
# 20/20 [==============================] - 4s 208ms/step - loss: 0.0987 - binary_crossentropy: 0.0300 - generalized_dice_coefficient: 0.8326 - val_loss: 0.1052 - val_binary_crossentropy: 0.0299 - val_generalized_dice_coefficient: 0.8176
# Epoch 176/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0989 - binary_crossentropy: 0.0298 - generalized_dice_coefficient: 0.8319
# Epoch 176: val_loss did not improve from 0.10057
# 20/20 [==============================] - 4s 207ms/step - loss: 0.0989 - binary_crossentropy: 0.0298 - generalized_dice_coefficient: 0.8319 - val_loss: 0.1028 - val_binary_crossentropy: 0.0296 - val_generalized_dice_coefficient: 0.8222
# Epoch 177/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0990 - binary_crossentropy: 0.0298 - generalized_dice_coefficient: 0.8318
# Epoch 177: val_loss did not improve from 0.10057
# 20/20 [==============================] - 4s 208ms/step - loss: 0.0990 - binary_crossentropy: 0.0298 - generalized_dice_coefficient: 0.8318 - val_loss: 0.1012 - val_binary_crossentropy: 0.0282 - val_generalized_dice_coefficient: 0.8239
# Epoch 178/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0979 - binary_crossentropy: 0.0286 - generalized_dice_coefficient: 0.8328
# Epoch 178: val_loss did not improve from 0.10057
# 20/20 [==============================] - 4s 208ms/step - loss: 0.0979 - binary_crossentropy: 0.0286 - generalized_dice_coefficient: 0.8328 - val_loss: 0.1016 - val_binary_crossentropy: 0.0297 - val_generalized_dice_coefficient: 0.8248
# Epoch 179/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0999 - binary_crossentropy: 0.0294 - generalized_dice_coefficient: 0.8297
# Epoch 179: val_loss did not improve from 0.10057
# 20/20 [==============================] - 4s 207ms/step - loss: 0.0999 - binary_crossentropy: 0.0294 - generalized_dice_coefficient: 0.8297 - val_loss: 0.1044 - val_binary_crossentropy: 0.0301 - val_generalized_dice_coefficient: 0.8195
# Epoch 180/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0999 - binary_crossentropy: 0.0311 - generalized_dice_coefficient: 0.8312
# Epoch 180: val_loss did not improve from 0.10057
# 20/20 [==============================] - 4s 208ms/step - loss: 0.0999 - binary_crossentropy: 0.0311 - generalized_dice_coefficient: 0.8312 - val_loss: 0.1030 - val_binary_crossentropy: 0.0306 - val_generalized_dice_coefficient: 0.8226
# Epoch 181/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0985 - binary_crossentropy: 0.0295 - generalized_dice_coefficient: 0.8324
# Epoch 181: val_loss did not improve from 0.10057
# 20/20 [==============================] - 4s 208ms/step - loss: 0.0985 - binary_crossentropy: 0.0295 - generalized_dice_coefficient: 0.8324 - val_loss: 0.1017 - val_binary_crossentropy: 0.0287 - val_generalized_dice_coefficient: 0.8234
# Epoch 182/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0970 - binary_crossentropy: 0.0283 - generalized_dice_coefficient: 0.8343
# Epoch 182: val_loss did not improve from 0.10057
# 20/20 [==============================] - 4s 208ms/step - loss: 0.0970 - binary_crossentropy: 0.0283 - generalized_dice_coefficient: 0.8343 - val_loss: 0.1012 - val_binary_crossentropy: 0.0289 - val_generalized_dice_coefficient: 0.8247
# Epoch 183/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1016 - binary_crossentropy: 0.0296 - generalized_dice_coefficient: 0.8263
# Epoch 183: val_loss did not improve from 0.10057
# 20/20 [==============================] - 4s 208ms/step - loss: 0.1016 - binary_crossentropy: 0.0296 - generalized_dice_coefficient: 0.8263 - val_loss: 0.1062 - val_binary_crossentropy: 0.0317 - val_generalized_dice_coefficient: 0.8175
# Epoch 184/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1080 - binary_crossentropy: 0.0383 - generalized_dice_coefficient: 0.8222
# Epoch 184: val_loss did not improve from 0.10057
# 20/20 [==============================] - 4s 207ms/step - loss: 0.1080 - binary_crossentropy: 0.0383 - generalized_dice_coefficient: 0.8222 - val_loss: 0.1050 - val_binary_crossentropy: 0.0325 - val_generalized_dice_coefficient: 0.8207
# Epoch 185/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1058 - binary_crossentropy: 0.0350 - generalized_dice_coefficient: 0.8234
# Epoch 185: val_loss did not improve from 0.10057
# 20/20 [==============================] - 4s 208ms/step - loss: 0.1058 - binary_crossentropy: 0.0350 - generalized_dice_coefficient: 0.8234 - val_loss: 0.1013 - val_binary_crossentropy: 0.0281 - val_generalized_dice_coefficient: 0.8238
# Epoch 186/200
# 20/20 [==============================] - ETA: 0s - loss: 0.1001 - binary_crossentropy: 0.0293 - generalized_dice_coefficient: 0.8291
# Epoch 186: val_loss improved from 0.10057 to 0.10019, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_186.h5
# 20/20 [==============================] - 4s 225ms/step - loss: 0.1001 - binary_crossentropy: 0.0293 - generalized_dice_coefficient: 0.8291 - val_loss: 0.1002 - val_binary_crossentropy: 0.0269 - val_generalized_dice_coefficient: 0.8247
# Epoch 187/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0990 - binary_crossentropy: 0.0279 - generalized_dice_coefficient: 0.8299
# Epoch 187: val_loss did not improve from 0.10019
# 20/20 [==============================] - 4s 208ms/step - loss: 0.0990 - binary_crossentropy: 0.0279 - generalized_dice_coefficient: 0.8299 - val_loss: 0.1002 - val_binary_crossentropy: 0.0270 - val_generalized_dice_coefficient: 0.8247
# Epoch 188/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0985 - binary_crossentropy: 0.0278 - generalized_dice_coefficient: 0.8308
# Epoch 188: val_loss did not improve from 0.10019
# 20/20 [==============================] - 4s 208ms/step - loss: 0.0985 - binary_crossentropy: 0.0278 - generalized_dice_coefficient: 0.8308 - val_loss: 0.1041 - val_binary_crossentropy: 0.0296 - val_generalized_dice_coefficient: 0.8196
# Epoch 189/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0980 - binary_crossentropy: 0.0290 - generalized_dice_coefficient: 0.8330
# Epoch 189: val_loss did not improve from 0.10019
# 20/20 [==============================] - 4s 208ms/step - loss: 0.0980 - binary_crossentropy: 0.0290 - generalized_dice_coefficient: 0.8330 - val_loss: 0.1008 - val_binary_crossentropy: 0.0287 - val_generalized_dice_coefficient: 0.8253
# Epoch 190/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0978 - binary_crossentropy: 0.0282 - generalized_dice_coefficient: 0.8325
# Epoch 190: val_loss improved from 0.10019 to 0.09947, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_190.h5
# 20/20 [==============================] - 4s 225ms/step - loss: 0.0978 - binary_crossentropy: 0.0282 - generalized_dice_coefficient: 0.8325 - val_loss: 0.0995 - val_binary_crossentropy: 0.0280 - val_generalized_dice_coefficient: 0.8274
# Epoch 191/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0965 - binary_crossentropy: 0.0281 - generalized_dice_coefficient: 0.8350
# Epoch 191: val_loss did not improve from 0.09947
# 20/20 [==============================] - 4s 208ms/step - loss: 0.0965 - binary_crossentropy: 0.0281 - generalized_dice_coefficient: 0.8350 - val_loss: 0.1002 - val_binary_crossentropy: 0.0279 - val_generalized_dice_coefficient: 0.8258
# Epoch 192/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0990 - binary_crossentropy: 0.0302 - generalized_dice_coefficient: 0.8323
# Epoch 192: val_loss did not improve from 0.09947
# 20/20 [==============================] - 4s 208ms/step - loss: 0.0990 - binary_crossentropy: 0.0302 - generalized_dice_coefficient: 0.8323 - val_loss: 0.1010 - val_binary_crossentropy: 0.0290 - val_generalized_dice_coefficient: 0.8252
# Epoch 193/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0984 - binary_crossentropy: 0.0292 - generalized_dice_coefficient: 0.8324
# Epoch 193: val_loss did not improve from 0.09947
# 20/20 [==============================] - 4s 208ms/step - loss: 0.0984 - binary_crossentropy: 0.0292 - generalized_dice_coefficient: 0.8324 - val_loss: 0.1033 - val_binary_crossentropy: 0.0284 - val_generalized_dice_coefficient: 0.8198
# Epoch 194/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0967 - binary_crossentropy: 0.0278 - generalized_dice_coefficient: 0.8345
# Epoch 194: val_loss did not improve from 0.09947
# 20/20 [==============================] - 4s 208ms/step - loss: 0.0967 - binary_crossentropy: 0.0278 - generalized_dice_coefficient: 0.8345 - val_loss: 0.1004 - val_binary_crossentropy: 0.0289 - val_generalized_dice_coefficient: 0.8263
# Epoch 195/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0960 - binary_crossentropy: 0.0285 - generalized_dice_coefficient: 0.8365
# Epoch 195: val_loss did not improve from 0.09947
# 20/20 [==============================] - 4s 208ms/step - loss: 0.0960 - binary_crossentropy: 0.0285 - generalized_dice_coefficient: 0.8365 - val_loss: 0.1018 - val_binary_crossentropy: 0.0295 - val_generalized_dice_coefficient: 0.8242
# Epoch 196/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0977 - binary_crossentropy: 0.0290 - generalized_dice_coefficient: 0.8337
# Epoch 196: val_loss did not improve from 0.09947
# 20/20 [==============================] - 4s 208ms/step - loss: 0.0977 - binary_crossentropy: 0.0290 - generalized_dice_coefficient: 0.8337 - val_loss: 0.1022 - val_binary_crossentropy: 0.0291 - val_generalized_dice_coefficient: 0.8227
# Epoch 197/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0971 - binary_crossentropy: 0.0286 - generalized_dice_coefficient: 0.8343
# Epoch 197: val_loss did not improve from 0.09947
# 20/20 [==============================] - 4s 208ms/step - loss: 0.0971 - binary_crossentropy: 0.0286 - generalized_dice_coefficient: 0.8343 - val_loss: 0.1003 - val_binary_crossentropy: 0.0295 - val_generalized_dice_coefficient: 0.8273
# Epoch 198/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0956 - binary_crossentropy: 0.0280 - generalized_dice_coefficient: 0.8367
# Epoch 198: val_loss did not improve from 0.09947
# 20/20 [==============================] - 4s 208ms/step - loss: 0.0956 - binary_crossentropy: 0.0280 - generalized_dice_coefficient: 0.8367 - val_loss: 0.1021 - val_binary_crossentropy: 0.0278 - val_generalized_dice_coefficient: 0.8217
# Epoch 199/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0944 - binary_crossentropy: 0.0275 - generalized_dice_coefficient: 0.8386
# Epoch 199: val_loss did not improve from 0.09947
# 20/20 [==============================] - 4s 208ms/step - loss: 0.0944 - binary_crossentropy: 0.0275 - generalized_dice_coefficient: 0.8386 - val_loss: 0.1000 - val_binary_crossentropy: 0.0287 - val_generalized_dice_coefficient: 0.8269
# Epoch 200/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0992 - binary_crossentropy: 0.0292 - generalized_dice_coefficient: 0.8308
# Epoch 200: val_loss did not improve from 0.09947
# 20/20 [==============================] - 4s 207ms/step - loss: 0.0992 - binary_crossentropy: 0.0292 - generalized_dice_coefficient: 0.8308 - val_loss: 0.1017 - val_binary_crossentropy: 0.0309 - val_generalized_dice_coefficient: 0.8260

# %%
np.shape(train_imgs[0])
# Out:
# (1024, 256)

# %%
prediction = np.array([train_imgs[0]])

# %%
pred_img = model.predict(prediction)
# Out:
# 1/1 [==============================] - 1s 769ms/step

# %%
np.shape(pred_img)
# Out:
# (1, 1024, 256, 1)

# %%
pltImg = np.squeeze(pred_img)

# %%
plt.imshow(pltImg)
plt.show()

# %%
plt.imshow(train_msks[0])
plt.show()

# %%
srcPath = "/content/drive/MyDrive/Bone_SPECT/upload.zip"
dstPath = "/content/drive/MyDrive/Bone_SPECT"

import zipfile

with zipfile.ZipFile(srcPath, 'r') as zip_ref:
    zip_ref.extractall(dstPath)
