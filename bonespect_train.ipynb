# %% [markdown]
# <a href="https://colab.research.google.com/github/sunmarknatecom/01_markcv/blob/master/bonespect_train.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from glob import glob
import numpy as np
import cv2, os, copy, shutil
import matplotlib.pyplot as plt
from PIL import Image
from random import randint

# DEEP LEARNING MODULES
import tensorflow as tf
from keras import backend as K
from keras.losses import binary_crossentropy
from keras.optimizers import Adam

from keras.layers import Input, Conv2D, MaxPooling2D, Conv2DTranspose, BatchNormalization, concatenate
from keras.models import Model
from skimage.metrics import structural_similarity as ssim

# %%
inputNpyList = sorted(glob("/content/drive/MyDrive/Bone_SPECT/inputData/*.npy"))
labelNpyList = sorted(glob("/content/drive/MyDrive/Bone_SPECT/labelData/*.npy"))

# %%
inputNpyList[0]
# Out:
# '/content/drive/MyDrive/Bone_SPECT/inputData/23060101_input.npy'

# %%
testImg = np.load(inputNpyList[0])

# %%
plt.imshow(testImg, cmap='gray_r')
plt.show()

# %%
for i in range(238):
    tempInput = inputNpyList[i].split("/")[-1][-18:-10]
    tempLabel = labelNpyList[i].split("/")[-1][-18:-10]
    if tempInput != tempLabel:
        print(i)
    else:
        continue

# %%
inputObj = []
labelObj = []
sizesImg = []

for i in range(238):
    tempInputObj = np.load(inputNpyList[i])
    tempInputObj = np.array(tempInputObj, dtype=np.uint16)
    tempLabelObj = np.load(labelNpyList[i])
    tempLabelObj = np.array(tempLabelObj, dtype=np.uint16)
    sizesImg.append(np.shape(tempInputObj)[0])
    inputObj.append(tempInputObj)
    labelObj.append(tempLabelObj)

# %%
MAX_SIZE = 1024

# %%
train_imgs = []
train_lbls = []

# %%
for i in range(238):
    io_x, ioy = np.shape(inputObj[i])
    if io_x != MAX_SIZE:
        diffIOx = MAX_SIZE - io_x
        zeroPadding = np.zeros((diffIOx,256))
        tempInput = np.vstack([inputObj[i],zeroPadding])
        tempLabel = np.vstack([labelObj[i],zeroPadding])
        train_imgs.append(tempInput)
        train_lbls.append(tempLabel)
    else:
        train_imgs.append(inputObj[i])
        train_lbls.append(labelObj[i])

# %%
temp_train_imgs = np.array(train_imgs)
temp_train_lbls = np.array(train_lbls)

# %%
temp_train_lbls[temp_train_lbls >=1] = 1

# %%
split_num = 200

# %%
train_imgs = temp_train_imgs[:split_num,...]
valid_imgs = temp_train_imgs[split_num:,...]
train_msks = temp_train_lbls[:split_num,...]
valid_msks = temp_train_lbls[split_num:,...]

# %%
train_imgs = np.array(train_imgs, dtype=np.float32)
train_msks = np.array(train_msks, dtype=np.float32)
valid_imgs = np.array(valid_imgs, dtype=np.float32)
valid_msks = np.array(valid_msks, dtype=np.float32)

train_msks = np.reshape(train_msks, (*train_msks.shape, 1))
valid_msks = np.reshape(valid_msks, (*valid_msks.shape, 1))

train_dataset = tf.data.Dataset.from_tensor_slices((train_imgs, train_msks))
test_dataset = tf.data.Dataset.from_tensor_slices((valid_imgs, valid_msks))

# %%
# %matplotlib inline

rand_num = randint(1,len(train_imgs))

fig = plt.figure(0, figsize=(20, 20))
fig.add_subplot(1, 2, 1)
plt.imshow(train_imgs[rand_num], cmap='gray_r')
fig.add_subplot(1, 2, 2)
plt.imshow(np.squeeze(train_msks[rand_num]), cmap='gray_r')

# %%
test_img = train_imgs[10] * np.squeeze(train_msks[10])

# %%
plt.figure(0, figsize=(20, 20))
plt.imshow(test_img, cmap="gray_r")
plt.show()

# %%
inputs = Input((MAX_SIZE, 256, 1))
bnorm1 = BatchNormalization()(inputs)
conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(bnorm1)
conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv1)
pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(pool1)
conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv2)
pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(pool2)
conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv3)
pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(pool3)
conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv4)
pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)

conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(pool4)
conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(conv5)

up6 = concatenate([Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(conv5), conv4], axis=3)
conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(up6)
conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv6)

up7 = concatenate([Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(conv6), conv3], axis=3)
conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(up7)
conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv7)

up8 = concatenate([Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(conv7), conv2], axis=3)
conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(up8)
conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv8)

up9 = concatenate([Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(conv8), conv1], axis=3)
conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(up9)
conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv9)

conv10 = Conv2D(1, (1, 1), activation='sigmoid')(conv9)

model = Model(inputs=[inputs], outputs=[conv10])

# %%
import tensorflow as tf
import keras.backend as K
from keras.losses import binary_crossentropy

beta = 0.25
alpha = 0.25
gamma = 2
epsilon = 1e-5
smooth = 1

def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + K.epsilon()) / (K.sum(y_true_f) + K.sum(y_pred_f) + K.epsilon())

def generalized_dice_coefficient(y_true, y_pred):
    smooth = 1.
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    score = (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return score

def dice_loss(y_true, y_pred):
    loss = 1 - generalized_dice_coefficient(y_true, y_pred)
    return loss

def bce_dice_loss(y_true, y_pred):
    loss = binary_crossentropy(y_true, y_pred) + dice_loss(y_true, y_pred)
    return loss / 2.0

# %%
initial_learning_rate = 5e-6

lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate,
    decay_steps=100000,
    decay_rate=0.96,
    staircase=True)

callbacks = [tf.keras.callbacks.ModelCheckpoint(
    filepath="mymodel_{epoch}.h5",
    save_best_only=True,
    monitor='val_loss',
    verbose=1)]

# %%
model.compile(Adam(learning_rate=lr_schedule), bce_dice_loss, metrics=[binary_crossentropy, generalized_dice_coefficient])

# %%
model.fit(train_imgs, train_msks, batch_size=10, epochs=50, callbacks=callbacks, validation_data=(valid_imgs, valid_msks))
# Out:
# Epoch 1/50
# 20/20 [==============================] - ETA: 0s - loss: 0.8183 - binary_crossentropy: 0.6675 - generalized_dice_coefficient: 0.0309
# Epoch 1: val_loss improved from inf to 0.81703, saving model to mymodel_1.h5
# 20/20 [==============================] - 23s 325ms/step - loss: 0.8183 - binary_crossentropy: 0.6675 - generalized_dice_coefficient: 0.0309 - val_loss: 0.8170 - val_binary_crossentropy: 0.6593 - val_generalized_dice_coefficient: 0.0252
# Epoch 2/50
# 20/20 [==============================] - ETA: 0s - loss: 0.8169 - binary_crossentropy: 0.6642 - generalized_dice_coefficient: 0.0303
# Epoch 2: val_loss improved from 0.81703 to 0.81659, saving model to mymodel_2.h5
# 20/20 [==============================] - 4s 219ms/step - loss: 0.8169 - binary_crossentropy: 0.6642 - generalized_dice_coefficient: 0.0303 - val_loss: 0.8166 - val_binary_crossentropy: 0.6601 - val_generalized_dice_coefficient: 0.0269
# Epoch 3/50
# 20/20 [==============================] - ETA: 0s - loss: 0.8155 - binary_crossentropy: 0.6607 - generalized_dice_coefficient: 0.0297
# Epoch 3: val_loss improved from 0.81659 to 0.81555, saving model to mymodel_3.h5
# 20/20 [==============================] - 4s 216ms/step - loss: 0.8155 - binary_crossentropy: 0.6607 - generalized_dice_coefficient: 0.0297 - val_loss: 0.8155 - val_binary_crossentropy: 0.6586 - val_generalized_dice_coefficient: 0.0274
# Epoch 4/50
# 20/20 [==============================] - ETA: 0s - loss: 0.8138 - binary_crossentropy: 0.6565 - generalized_dice_coefficient: 0.0289
# Epoch 4: val_loss improved from 0.81555 to 0.81397, saving model to mymodel_4.h5
# 20/20 [==============================] - 4s 217ms/step - loss: 0.8138 - binary_crossentropy: 0.6565 - generalized_dice_coefficient: 0.0289 - val_loss: 0.8140 - val_binary_crossentropy: 0.6555 - val_generalized_dice_coefficient: 0.0275
# Epoch 5/50
# 20/20 [==============================] - ETA: 0s - loss: 0.8118 - binary_crossentropy: 0.6520 - generalized_dice_coefficient: 0.0283
# Epoch 5: val_loss improved from 0.81397 to 0.81192, saving model to mymodel_5.h5
# 20/20 [==============================] - 4s 217ms/step - loss: 0.8118 - binary_crossentropy: 0.6520 - generalized_dice_coefficient: 0.0283 - val_loss: 0.8119 - val_binary_crossentropy: 0.6512 - val_generalized_dice_coefficient: 0.0273
# Epoch 6/50
# 20/20 [==============================] - ETA: 0s - loss: 0.8092 - binary_crossentropy: 0.6460 - generalized_dice_coefficient: 0.0275
# Epoch 6: val_loss improved from 0.81192 to 0.80924, saving model to mymodel_6.h5
# 20/20 [==============================] - 4s 219ms/step - loss: 0.8092 - binary_crossentropy: 0.6460 - generalized_dice_coefficient: 0.0275 - val_loss: 0.8092 - val_binary_crossentropy: 0.6454 - val_generalized_dice_coefficient: 0.0269
# Epoch 7/50
# 20/20 [==============================] - ETA: 0s - loss: 0.8061 - binary_crossentropy: 0.6387 - generalized_dice_coefficient: 0.0266
# Epoch 7: val_loss improved from 0.80924 to 0.80566, saving model to mymodel_7.h5
# 20/20 [==============================] - 4s 217ms/step - loss: 0.8061 - binary_crossentropy: 0.6387 - generalized_dice_coefficient: 0.0266 - val_loss: 0.8057 - val_binary_crossentropy: 0.6375 - val_generalized_dice_coefficient: 0.0261
# Epoch 8/50
# 20/20 [==============================] - ETA: 0s - loss: 0.8015 - binary_crossentropy: 0.6284 - generalized_dice_coefficient: 0.0254
# Epoch 8: val_loss improved from 0.80566 to 0.79940, saving model to mymodel_8.h5
# 20/20 [==============================] - 4s 216ms/step - loss: 0.8015 - binary_crossentropy: 0.6284 - generalized_dice_coefficient: 0.0254 - val_loss: 0.7994 - val_binary_crossentropy: 0.6235 - val_generalized_dice_coefficient: 0.0246
# Epoch 9/50
# 20/20 [==============================] - ETA: 0s - loss: 0.7901 - binary_crossentropy: 0.6028 - generalized_dice_coefficient: 0.0226
# Epoch 9: val_loss improved from 0.79940 to 0.78085, saving model to mymodel_9.h5
# 20/20 [==============================] - 4s 216ms/step - loss: 0.7901 - binary_crossentropy: 0.6028 - generalized_dice_coefficient: 0.0226 - val_loss: 0.7809 - val_binary_crossentropy: 0.5821 - val_generalized_dice_coefficient: 0.0204
# Epoch 10/50
# 20/20 [==============================] - ETA: 0s - loss: 0.7495 - binary_crossentropy: 0.5139 - generalized_dice_coefficient: 0.0148
# Epoch 10: val_loss improved from 0.78085 to 0.71322, saving model to mymodel_10.h5
# 20/20 [==============================] - 4s 216ms/step - loss: 0.7495 - binary_crossentropy: 0.5139 - generalized_dice_coefficient: 0.0148 - val_loss: 0.7132 - val_binary_crossentropy: 0.4348 - val_generalized_dice_coefficient: 0.0084
# Epoch 11/50
# 20/20 [==============================] - ETA: 0s - loss: 0.6685 - binary_crossentropy: 0.3435 - generalized_dice_coefficient: 0.0064
# Epoch 11: val_loss improved from 0.71322 to 0.65966, saving model to mymodel_11.h5
# 20/20 [==============================] - 4s 215ms/step - loss: 0.6685 - binary_crossentropy: 0.3435 - generalized_dice_coefficient: 0.0064 - val_loss: 0.6597 - val_binary_crossentropy: 0.3219 - val_generalized_dice_coefficient: 0.0026
# Epoch 12/50
# 20/20 [==============================] - ETA: 0s - loss: 0.6373 - binary_crossentropy: 0.2805 - generalized_dice_coefficient: 0.0058
# Epoch 12: val_loss improved from 0.65966 to 0.63121, saving model to mymodel_12.h5
# 20/20 [==============================] - 4s 221ms/step - loss: 0.6373 - binary_crossentropy: 0.2805 - generalized_dice_coefficient: 0.0058 - val_loss: 0.6312 - val_binary_crossentropy: 0.2677 - val_generalized_dice_coefficient: 0.0054
# Epoch 13/50
# 20/20 [==============================] - ETA: 0s - loss: 0.6153 - binary_crossentropy: 0.2374 - generalized_dice_coefficient: 0.0068
# Epoch 13: val_loss improved from 0.63121 to 0.61030, saving model to mymodel_13.h5
# 20/20 [==============================] - 4s 218ms/step - loss: 0.6153 - binary_crossentropy: 0.2374 - generalized_dice_coefficient: 0.0068 - val_loss: 0.6103 - val_binary_crossentropy: 0.2275 - val_generalized_dice_coefficient: 0.0071
# Epoch 14/50
# 20/20 [==============================] - ETA: 0s - loss: 0.5971 - binary_crossentropy: 0.2038 - generalized_dice_coefficient: 0.0095
# Epoch 14: val_loss improved from 0.61030 to 0.59161, saving model to mymodel_14.h5
# 20/20 [==============================] - 4s 216ms/step - loss: 0.5971 - binary_crossentropy: 0.2038 - generalized_dice_coefficient: 0.0095 - val_loss: 0.5916 - val_binary_crossentropy: 0.1936 - val_generalized_dice_coefficient: 0.0106
# Epoch 15/50
# 20/20 [==============================] - ETA: 0s - loss: 0.5798 - binary_crossentropy: 0.1728 - generalized_dice_coefficient: 0.0133
# Epoch 15: val_loss improved from 0.59161 to 0.57277, saving model to mymodel_15.h5
# 20/20 [==============================] - 4s 216ms/step - loss: 0.5798 - binary_crossentropy: 0.1728 - generalized_dice_coefficient: 0.0133 - val_loss: 0.5728 - val_binary_crossentropy: 0.1613 - val_generalized_dice_coefficient: 0.0160
# Epoch 16/50
# 20/20 [==============================] - ETA: 0s - loss: 0.5624 - binary_crossentropy: 0.1427 - generalized_dice_coefficient: 0.0180
# Epoch 16: val_loss improved from 0.57277 to 0.55270, saving model to mymodel_16.h5
# 20/20 [==============================] - 4s 218ms/step - loss: 0.5624 - binary_crossentropy: 0.1427 - generalized_dice_coefficient: 0.0180 - val_loss: 0.5527 - val_binary_crossentropy: 0.1316 - val_generalized_dice_coefficient: 0.0266
# Epoch 17/50
# 20/20 [==============================] - ETA: 0s - loss: 0.5425 - binary_crossentropy: 0.1146 - generalized_dice_coefficient: 0.0297
# Epoch 17: val_loss improved from 0.55270 to 0.52689, saving model to mymodel_17.h5
# 20/20 [==============================] - 4s 217ms/step - loss: 0.5425 - binary_crossentropy: 0.1146 - generalized_dice_coefficient: 0.0297 - val_loss: 0.5269 - val_binary_crossentropy: 0.1013 - val_generalized_dice_coefficient: 0.0477
# Epoch 18/50
# 20/20 [==============================] - ETA: 0s - loss: 0.5136 - binary_crossentropy: 0.0865 - generalized_dice_coefficient: 0.0593
# Epoch 18: val_loss improved from 0.52689 to 0.48764, saving model to mymodel_18.h5
# 20/20 [==============================] - 4s 216ms/step - loss: 0.5136 - binary_crossentropy: 0.0865 - generalized_dice_coefficient: 0.0593 - val_loss: 0.4876 - val_binary_crossentropy: 0.0753 - val_generalized_dice_coefficient: 0.0997
# Epoch 19/50
# 20/20 [==============================] - ETA: 0s - loss: 0.4699 - binary_crossentropy: 0.0660 - generalized_dice_coefficient: 0.1262
# Epoch 19: val_loss improved from 0.48764 to 0.44160, saving model to mymodel_19.h5
# 20/20 [==============================] - 4s 218ms/step - loss: 0.4699 - binary_crossentropy: 0.0660 - generalized_dice_coefficient: 0.1262 - val_loss: 0.4416 - val_binary_crossentropy: 0.0602 - val_generalized_dice_coefficient: 0.1764
# Epoch 20/50
# 20/20 [==============================] - ETA: 0s - loss: 0.4350 - binary_crossentropy: 0.0656 - generalized_dice_coefficient: 0.1955
# Epoch 20: val_loss improved from 0.44160 to 0.41808, saving model to mymodel_20.h5
# 20/20 [==============================] - 4s 217ms/step - loss: 0.4350 - binary_crossentropy: 0.0656 - generalized_dice_coefficient: 0.1955 - val_loss: 0.4181 - val_binary_crossentropy: 0.0614 - val_generalized_dice_coefficient: 0.2245
# Epoch 21/50
# 20/20 [==============================] - ETA: 0s - loss: 0.4172 - binary_crossentropy: 0.0662 - generalized_dice_coefficient: 0.2318
# Epoch 21: val_loss improved from 0.41808 to 0.40082, saving model to mymodel_21.h5
# 20/20 [==============================] - 4s 217ms/step - loss: 0.4172 - binary_crossentropy: 0.0662 - generalized_dice_coefficient: 0.2318 - val_loss: 0.4008 - val_binary_crossentropy: 0.0576 - val_generalized_dice_coefficient: 0.2553
# Epoch 22/50
# 20/20 [==============================] - ETA: 0s - loss: 0.3978 - binary_crossentropy: 0.0615 - generalized_dice_coefficient: 0.2659
# Epoch 22: val_loss improved from 0.40082 to 0.38027, saving model to mymodel_22.h5
# 20/20 [==============================] - 4s 217ms/step - loss: 0.3978 - binary_crossentropy: 0.0615 - generalized_dice_coefficient: 0.2659 - val_loss: 0.3803 - val_binary_crossentropy: 0.0525 - val_generalized_dice_coefficient: 0.2915
# Epoch 23/50
# 20/20 [==============================] - ETA: 0s - loss: 0.3732 - binary_crossentropy: 0.0561 - generalized_dice_coefficient: 0.3097
# Epoch 23: val_loss improved from 0.38027 to 0.35218, saving model to mymodel_23.h5
# 20/20 [==============================] - 4s 217ms/step - loss: 0.3732 - binary_crossentropy: 0.0561 - generalized_dice_coefficient: 0.3097 - val_loss: 0.3522 - val_binary_crossentropy: 0.0452 - val_generalized_dice_coefficient: 0.3407
# Epoch 24/50
# 20/20 [==============================] - ETA: 0s - loss: 0.3421 - binary_crossentropy: 0.0515 - generalized_dice_coefficient: 0.3673
# Epoch 24: val_loss improved from 0.35218 to 0.31790, saving model to mymodel_24.h5
# 20/20 [==============================] - 4s 216ms/step - loss: 0.3421 - binary_crossentropy: 0.0515 - generalized_dice_coefficient: 0.3673 - val_loss: 0.3179 - val_binary_crossentropy: 0.0376 - val_generalized_dice_coefficient: 0.4015
# Epoch 25/50
# 20/20 [==============================] - ETA: 0s - loss: 0.3108 - binary_crossentropy: 0.0459 - generalized_dice_coefficient: 0.4243
# Epoch 25: val_loss improved from 0.31790 to 0.29284, saving model to mymodel_25.h5
# 20/20 [==============================] - 4s 217ms/step - loss: 0.3108 - binary_crossentropy: 0.0459 - generalized_dice_coefficient: 0.4243 - val_loss: 0.2928 - val_binary_crossentropy: 0.0331 - val_generalized_dice_coefficient: 0.4462
# Epoch 26/50
# 20/20 [==============================] - ETA: 0s - loss: 0.2937 - binary_crossentropy: 0.0422 - generalized_dice_coefficient: 0.4549
# Epoch 26: val_loss improved from 0.29284 to 0.27867, saving model to mymodel_26.h5
# 20/20 [==============================] - 4s 216ms/step - loss: 0.2937 - binary_crossentropy: 0.0422 - generalized_dice_coefficient: 0.4549 - val_loss: 0.2787 - val_binary_crossentropy: 0.0322 - val_generalized_dice_coefficient: 0.4735
# Epoch 27/50
# 20/20 [==============================] - ETA: 0s - loss: 0.2830 - binary_crossentropy: 0.0450 - generalized_dice_coefficient: 0.4789
# Epoch 27: val_loss improved from 0.27867 to 0.26957, saving model to mymodel_27.h5
# 20/20 [==============================] - 4s 217ms/step - loss: 0.2830 - binary_crossentropy: 0.0450 - generalized_dice_coefficient: 0.4789 - val_loss: 0.2696 - val_binary_crossentropy: 0.0306 - val_generalized_dice_coefficient: 0.4900
# Epoch 28/50
# 20/20 [==============================] - ETA: 0s - loss: 0.2734 - binary_crossentropy: 0.0436 - generalized_dice_coefficient: 0.4967
# Epoch 28: val_loss improved from 0.26957 to 0.26184, saving model to mymodel_28.h5
# 20/20 [==============================] - 4s 217ms/step - loss: 0.2734 - binary_crossentropy: 0.0436 - generalized_dice_coefficient: 0.4967 - val_loss: 0.2618 - val_binary_crossentropy: 0.0298 - val_generalized_dice_coefficient: 0.5049
# Epoch 29/50
# 20/20 [==============================] - ETA: 0s - loss: 0.2662 - binary_crossentropy: 0.0435 - generalized_dice_coefficient: 0.5111
# Epoch 29: val_loss improved from 0.26184 to 0.25544, saving model to mymodel_29.h5
# 20/20 [==============================] - 4s 215ms/step - loss: 0.2662 - binary_crossentropy: 0.0435 - generalized_dice_coefficient: 0.5111 - val_loss: 0.2554 - val_binary_crossentropy: 0.0286 - val_generalized_dice_coefficient: 0.5165
# Epoch 30/50
# 20/20 [==============================] - ETA: 0s - loss: 0.2606 - binary_crossentropy: 0.0409 - generalized_dice_coefficient: 0.5198
# Epoch 30: val_loss improved from 0.25544 to 0.25275, saving model to mymodel_30.h5
# 20/20 [==============================] - 4s 216ms/step - loss: 0.2606 - binary_crossentropy: 0.0409 - generalized_dice_coefficient: 0.5198 - val_loss: 0.2527 - val_binary_crossentropy: 0.0306 - val_generalized_dice_coefficient: 0.5237
# Epoch 31/50
# 20/20 [==============================] - ETA: 0s - loss: 0.2536 - binary_crossentropy: 0.0414 - generalized_dice_coefficient: 0.5343
# Epoch 31: val_loss improved from 0.25275 to 0.24417, saving model to mymodel_31.h5
# 20/20 [==============================] - 4s 216ms/step - loss: 0.2536 - binary_crossentropy: 0.0414 - generalized_dice_coefficient: 0.5343 - val_loss: 0.2442 - val_binary_crossentropy: 0.0274 - val_generalized_dice_coefficient: 0.5377
# Epoch 32/50
# 20/20 [==============================] - ETA: 0s - loss: 0.2476 - binary_crossentropy: 0.0388 - generalized_dice_coefficient: 0.5436
# Epoch 32: val_loss did not improve from 0.24417
# 20/20 [==============================] - 4s 204ms/step - loss: 0.2476 - binary_crossentropy: 0.0388 - generalized_dice_coefficient: 0.5436 - val_loss: 0.2449 - val_binary_crossentropy: 0.0267 - val_generalized_dice_coefficient: 0.5358
# Epoch 33/50
# 20/20 [==============================] - ETA: 0s - loss: 0.2426 - binary_crossentropy: 0.0371 - generalized_dice_coefficient: 0.5519
# Epoch 33: val_loss improved from 0.24417 to 0.23481, saving model to mymodel_33.h5
# 20/20 [==============================] - 4s 215ms/step - loss: 0.2426 - binary_crossentropy: 0.0371 - generalized_dice_coefficient: 0.5519 - val_loss: 0.2348 - val_binary_crossentropy: 0.0283 - val_generalized_dice_coefficient: 0.5575
# Epoch 34/50
# 20/20 [==============================] - ETA: 0s - loss: 0.2358 - binary_crossentropy: 0.0369 - generalized_dice_coefficient: 0.5653
# Epoch 34: val_loss improved from 0.23481 to 0.22911, saving model to mymodel_34.h5
# 20/20 [==============================] - 4s 216ms/step - loss: 0.2358 - binary_crossentropy: 0.0369 - generalized_dice_coefficient: 0.5653 - val_loss: 0.2291 - val_binary_crossentropy: 0.0269 - val_generalized_dice_coefficient: 0.5673
# Epoch 35/50
# 20/20 [==============================] - ETA: 0s - loss: 0.2284 - binary_crossentropy: 0.0351 - generalized_dice_coefficient: 0.5782
# Epoch 35: val_loss improved from 0.22911 to 0.22381, saving model to mymodel_35.h5
# 20/20 [==============================] - 4s 215ms/step - loss: 0.2284 - binary_crossentropy: 0.0351 - generalized_dice_coefficient: 0.5782 - val_loss: 0.2238 - val_binary_crossentropy: 0.0266 - val_generalized_dice_coefficient: 0.5778
# Epoch 36/50
# 20/20 [==============================] - ETA: 0s - loss: 0.2234 - binary_crossentropy: 0.0359 - generalized_dice_coefficient: 0.5890
# Epoch 36: val_loss improved from 0.22381 to 0.21870, saving model to mymodel_36.h5
# 20/20 [==============================] - 4s 215ms/step - loss: 0.2234 - binary_crossentropy: 0.0359 - generalized_dice_coefficient: 0.5890 - val_loss: 0.2187 - val_binary_crossentropy: 0.0264 - val_generalized_dice_coefficient: 0.5878
# Epoch 37/50
# 20/20 [==============================] - ETA: 0s - loss: 0.2174 - binary_crossentropy: 0.0339 - generalized_dice_coefficient: 0.5992
# Epoch 37: val_loss improved from 0.21870 to 0.21404, saving model to mymodel_37.h5
# 20/20 [==============================] - 4s 217ms/step - loss: 0.2174 - binary_crossentropy: 0.0339 - generalized_dice_coefficient: 0.5992 - val_loss: 0.2140 - val_binary_crossentropy: 0.0253 - val_generalized_dice_coefficient: 0.5959
# Epoch 38/50
# 20/20 [==============================] - ETA: 0s - loss: 0.2115 - binary_crossentropy: 0.0331 - generalized_dice_coefficient: 0.6100
# Epoch 38: val_loss improved from 0.21404 to 0.20815, saving model to mymodel_38.h5
# 20/20 [==============================] - 4s 217ms/step - loss: 0.2115 - binary_crossentropy: 0.0331 - generalized_dice_coefficient: 0.6100 - val_loss: 0.2082 - val_binary_crossentropy: 0.0254 - val_generalized_dice_coefficient: 0.6077
# Epoch 39/50
# 20/20 [==============================] - ETA: 0s - loss: 0.2066 - binary_crossentropy: 0.0316 - generalized_dice_coefficient: 0.6184
# Epoch 39: val_loss improved from 0.20815 to 0.20257, saving model to mymodel_39.h5
# 20/20 [==============================] - 4s 217ms/step - loss: 0.2066 - binary_crossentropy: 0.0316 - generalized_dice_coefficient: 0.6184 - val_loss: 0.2026 - val_binary_crossentropy: 0.0249 - val_generalized_dice_coefficient: 0.6185
# Epoch 40/50
# 20/20 [==============================] - ETA: 0s - loss: 0.1964 - binary_crossentropy: 0.0302 - generalized_dice_coefficient: 0.6374
# Epoch 40: val_loss improved from 0.20257 to 0.19500, saving model to mymodel_40.h5
# 20/20 [==============================] - 4s 216ms/step - loss: 0.1964 - binary_crossentropy: 0.0302 - generalized_dice_coefficient: 0.6374 - val_loss: 0.1950 - val_binary_crossentropy: 0.0254 - val_generalized_dice_coefficient: 0.6340
# Epoch 41/50
# 20/20 [==============================] - ETA: 0s - loss: 0.1908 - binary_crossentropy: 0.0306 - generalized_dice_coefficient: 0.6489
# Epoch 41: val_loss improved from 0.19500 to 0.18715, saving model to mymodel_41.h5
# 20/20 [==============================] - 4s 216ms/step - loss: 0.1908 - binary_crossentropy: 0.0306 - generalized_dice_coefficient: 0.6489 - val_loss: 0.1871 - val_binary_crossentropy: 0.0251 - val_generalized_dice_coefficient: 0.6493
# Epoch 42/50
# 20/20 [==============================] - ETA: 0s - loss: 0.1803 - binary_crossentropy: 0.0292 - generalized_dice_coefficient: 0.6685
# Epoch 42: val_loss improved from 0.18715 to 0.17685, saving model to mymodel_42.h5
# 20/20 [==============================] - 4s 217ms/step - loss: 0.1803 - binary_crossentropy: 0.0292 - generalized_dice_coefficient: 0.6685 - val_loss: 0.1769 - val_binary_crossentropy: 0.0260 - val_generalized_dice_coefficient: 0.6712
# Epoch 43/50
# 20/20 [==============================] - ETA: 0s - loss: 0.1697 - binary_crossentropy: 0.0288 - generalized_dice_coefficient: 0.6895
# Epoch 43: val_loss improved from 0.17685 to 0.16634, saving model to mymodel_43.h5
# 20/20 [==============================] - 4s 218ms/step - loss: 0.1697 - binary_crossentropy: 0.0288 - generalized_dice_coefficient: 0.6895 - val_loss: 0.1663 - val_binary_crossentropy: 0.0260 - val_generalized_dice_coefficient: 0.6915
# Epoch 44/50
# 20/20 [==============================] - ETA: 0s - loss: 0.1597 - binary_crossentropy: 0.0303 - generalized_dice_coefficient: 0.7109
# Epoch 44: val_loss improved from 0.16634 to 0.15320, saving model to mymodel_44.h5
# 20/20 [==============================] - 4s 217ms/step - loss: 0.1597 - binary_crossentropy: 0.0303 - generalized_dice_coefficient: 0.7109 - val_loss: 0.1532 - val_binary_crossentropy: 0.0289 - val_generalized_dice_coefficient: 0.7210
# Epoch 45/50
# 20/20 [==============================] - ETA: 0s - loss: 0.1507 - binary_crossentropy: 0.0333 - generalized_dice_coefficient: 0.7319
# Epoch 45: val_loss improved from 0.15320 to 0.15116, saving model to mymodel_45.h5
# 20/20 [==============================] - 4s 218ms/step - loss: 0.1507 - binary_crossentropy: 0.0333 - generalized_dice_coefficient: 0.7319 - val_loss: 0.1512 - val_binary_crossentropy: 0.0370 - val_generalized_dice_coefficient: 0.7329
# Epoch 46/50
# 20/20 [==============================] - ETA: 0s - loss: 0.1461 - binary_crossentropy: 0.0365 - generalized_dice_coefficient: 0.7443
# Epoch 46: val_loss improved from 0.15116 to 0.13706, saving model to mymodel_46.h5
# 20/20 [==============================] - 4s 216ms/step - loss: 0.1461 - binary_crossentropy: 0.0365 - generalized_dice_coefficient: 0.7443 - val_loss: 0.1371 - val_binary_crossentropy: 0.0338 - val_generalized_dice_coefficient: 0.7578
# Epoch 47/50
# 20/20 [==============================] - ETA: 0s - loss: 0.1349 - binary_crossentropy: 0.0358 - generalized_dice_coefficient: 0.7661
# Epoch 47: val_loss improved from 0.13706 to 0.13188, saving model to mymodel_47.h5
# 20/20 [==============================] - 4s 216ms/step - loss: 0.1349 - binary_crossentropy: 0.0358 - generalized_dice_coefficient: 0.7661 - val_loss: 0.1319 - val_binary_crossentropy: 0.0330 - val_generalized_dice_coefficient: 0.7671
# Epoch 48/50
# 20/20 [==============================] - ETA: 0s - loss: 0.1326 - binary_crossentropy: 0.0352 - generalized_dice_coefficient: 0.7699
# Epoch 48: val_loss improved from 0.13188 to 0.12951, saving model to mymodel_48.h5
# 20/20 [==============================] - 4s 219ms/step - loss: 0.1326 - binary_crossentropy: 0.0352 - generalized_dice_coefficient: 0.7699 - val_loss: 0.1295 - val_binary_crossentropy: 0.0332 - val_generalized_dice_coefficient: 0.7721
# Epoch 49/50
# 20/20 [==============================] - ETA: 0s - loss: 0.1321 - binary_crossentropy: 0.0378 - generalized_dice_coefficient: 0.7736
# Epoch 49: val_loss did not improve from 0.12951
# 20/20 [==============================] - 4s 205ms/step - loss: 0.1321 - binary_crossentropy: 0.0378 - generalized_dice_coefficient: 0.7736 - val_loss: 0.1312 - val_binary_crossentropy: 0.0345 - val_generalized_dice_coefficient: 0.7699
# Epoch 50/50
# 20/20 [==============================] - ETA: 0s - loss: 0.1277 - binary_crossentropy: 0.0369 - generalized_dice_coefficient: 0.7814
# Epoch 50: val_loss improved from 0.12951 to 0.12484, saving model to mymodel_50.h5
# 20/20 [==============================] - 4s 216ms/step - loss: 0.1277 - binary_crossentropy: 0.0369 - generalized_dice_coefficient: 0.7814 - val_loss: 0.1248 - val_binary_crossentropy: 0.0353 - val_generalized_dice_coefficient: 0.7836

# %%
srcPath = "/content/drive/MyDrive/Bone_SPECT/upload.zip"
dstPath = "/content/drive/MyDrive/Bone_SPECT"

import zipfile

with zipfile.ZipFile(srcPath, 'r') as zip_ref:
    zip_ref.extractall(dstPath)
