# %% [markdown]
# <a href="https://colab.research.google.com/github/sunmarknatecom/01_markcv/blob/master/s2_training_class_only_reexe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from glob import glob
import numpy as np
import cv2, os, copy, shutil
import matplotlib.pyplot as plt
from random import randint

# DEEP LEARNING MODULES
import tensorflow as tf
from keras import backend as K
from keras.losses import binary_crossentropy
from keras.optimizers import Adam

from keras.layers import Input, Conv2D, MaxPooling2D, Conv2DTranspose, BatchNormalization, concatenate
from keras.models import Model

import tensorflow as tf
import keras.backend as K
from keras.losses import binary_crossentropy
from keras.losses import categorical_crossentropy

# %% [markdown]
# 1. data/inputData -> normalization
# 2. data/inputRawData --> 원래
# 3. data/labelData -> 위치보정 label

# %%
MAX_SIZE = 512
split_num = 500
model_path = "/content/drive/MyDrive/Bone_SPECT/models/mymodel_local_{epoch}.h5"
model_summary_path = "/content/drive/MyDrive/Bone_SPECT/training_history_local.pkl"
basic_learning_rate = 5e-5

# %%
temp_train_imgs = np.load("/content/drive/MyDrive/Bone_SPECT/data/inputData.npy")
temp_train_lbls = np.load("/content/drive/MyDrive/Bone_SPECT/data/labelData.npy")

# %%
# 0: BG, 1: C, 2: T, 3: L
temp_train_lbls[temp_train_lbls<=0]=0
temp_train_lbls[temp_train_lbls>1]=1

# %%
np.unique(temp_train_lbls[0])
# Out:
# array([0, 1], dtype=uint16)

# %%
# temp_train_lbls = tf.one_hot(temp_train_lbls, depth=4, dtype=tf.uint8)

# %%
train_imgs = temp_train_imgs[:split_num,...]
valid_imgs = temp_train_imgs[split_num:,...]
train_msks = temp_train_lbls[:split_num,...]
valid_msks = temp_train_lbls[split_num:,...]

# %%
train_imgs = np.array(train_imgs, dtype=np.float32)
train_msks = np.array(train_msks, dtype=np.float32)
valid_imgs = np.array(valid_imgs, dtype=np.float32)
valid_msks = np.array(valid_msks, dtype=np.float32)

train_msks = np.reshape(train_msks, (*train_msks.shape, 1))
valid_msks = np.reshape(valid_msks, (*valid_msks.shape, 1))

train_dataset = tf.data.Dataset.from_tensor_slices((train_imgs, train_msks))
test_dataset = tf.data.Dataset.from_tensor_slices((valid_imgs, valid_msks))

# %%
print(np.shape(train_imgs))
print(np.shape(train_msks))
# Out:
# (500, 512, 256)
# (500, 512, 256, 1)

# %%
# %matplotlib inline

rand_num = randint(1,len(train_imgs))

fig = plt.figure(0, figsize=(20, 20))
fig.add_subplot(1, 2, 1)
plt.imshow(train_imgs[rand_num]*13, cmap='gray_r')
fig.add_subplot(1, 2, 2)
plt.imshow(train_msks[rand_num], cmap='gray_r')

# %% [markdown]
# # Construct the model

# %%
CLASS_NUM = 1

# %%
inputs = Input((MAX_SIZE, 256, 1))
bnorm1 = BatchNormalization()(inputs)
conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(bnorm1)
conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv1)
pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(pool1)
conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv2)
pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(pool2)
conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv3)
pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(pool3)
conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv4)
pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)

conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(pool4)
conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(conv5)

up6 = concatenate([Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(conv5), conv4], axis=3)
conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(up6)
conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv6)

up7 = concatenate([Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(conv6), conv3], axis=3)
conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(up7)
conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv7)

up8 = concatenate([Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(conv7), conv2], axis=3)
conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(up8)
conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv8)

up9 = concatenate([Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(conv8), conv1], axis=3)
conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(up9)
conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv9)

conv10 = Conv2D(CLASS_NUM, (1, 1), activation='sigmoid')(conv9)

model = Model(inputs=[inputs], outputs=[conv10])

# %%
# reference https://github.com/SoftwareImpacts/SIMPAC-2021-46/tree/master

beta = 0.25
alpha = 0.25
gamma = 2
epsilon = 1e-5
smooth = 1

def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + K.epsilon()) / (K.sum(y_true_f) + K.sum(y_pred_f) + K.epsilon())

def generalized_dice_coefficient(y_true, y_pred):
    smooth = 1.
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    score = (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return score

def dice_loss(y_true, y_pred):
    loss = 1 - generalized_dice_coefficient(y_true, y_pred)
    return loss

def bce_dice_loss(y_true, y_pred):
    loss = binary_crossentropy(y_true, y_pred) + dice_loss(y_true, y_pred)
    return loss / 2.0

def cce_dice_loss(y_true, y_pred):
    ce_loss = categorical_crossentropy(y_true, y_pred)
    dice = dice_loss(y_true, y_pred)
    loss = ce_loss + dice
    return loss

# %%
initial_learning_rate = basic_learning_rate

lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate,
    decay_steps=10,
    decay_rate=0.96,
    staircase=True)

callbacks = [tf.keras.callbacks.ModelCheckpoint(
    filepath=model_path,
    save_best_only=True,
    monitor='val_loss',
    verbose=1)]

# %%
model.compile(Adam(learning_rate=lr_schedule), bce_dice_loss, metrics=[binary_crossentropy, generalized_dice_coefficient])

# %%
model_history = model.fit(train_imgs, train_msks, batch_size=20, epochs=200, callbacks=callbacks, validation_data=(valid_imgs, valid_msks))
# Out:
# Epoch 1/200
# 25/25 [==============================] - ETA: 0s - loss: 0.8102 - binary_crossentropy: 0.6950 - generalized_dice_coefficient: 0.0745
# Epoch 1: val_loss improved from inf to 0.81054, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_local_1.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 25/25 [==============================] - 28s 294ms/step - loss: 0.8102 - binary_crossentropy: 0.6950 - generalized_dice_coefficient: 0.0745 - val_loss: 0.8105 - val_binary_crossentropy: 0.6898 - val_generalized_dice_coefficient: 0.0688
# Epoch 2/200
# 25/25 [==============================] - ETA: 0s - loss: 0.7906 - binary_crossentropy: 0.6538 - generalized_dice_coefficient: 0.0726
# Epoch 2: val_loss improved from 0.81054 to 0.80046, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_local_2.h5
# 25/25 [==============================] - 3s 138ms/step - loss: 0.7906 - binary_crossentropy: 0.6538 - generalized_dice_coefficient: 0.0726 - val_loss: 0.8005 - val_binary_crossentropy: 0.6691 - val_generalized_dice_coefficient: 0.0682
# Epoch 3/200
# 25/25 [==============================] - ETA: 0s - loss: 0.6257 - binary_crossentropy: 0.3096 - generalized_dice_coefficient: 0.0583
# Epoch 3: val_loss improved from 0.80046 to 0.70948, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_local_3.h5
# 25/25 [==============================] - 3s 137ms/step - loss: 0.6257 - binary_crossentropy: 0.3096 - generalized_dice_coefficient: 0.0583 - val_loss: 0.7095 - val_binary_crossentropy: 0.4892 - val_generalized_dice_coefficient: 0.0703
# Epoch 4/200
# 25/25 [==============================] - ETA: 0s - loss: 0.4916 - binary_crossentropy: 0.1393 - generalized_dice_coefficient: 0.1561
# Epoch 4: val_loss improved from 0.70948 to 0.58272, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_local_4.h5
# 25/25 [==============================] - 3s 136ms/step - loss: 0.4916 - binary_crossentropy: 0.1393 - generalized_dice_coefficient: 0.1561 - val_loss: 0.5827 - val_binary_crossentropy: 0.2739 - val_generalized_dice_coefficient: 0.1085
# Epoch 5/200
# 25/25 [==============================] - ETA: 0s - loss: 0.4231 - binary_crossentropy: 0.1231 - generalized_dice_coefficient: 0.2769
# Epoch 5: val_loss improved from 0.58272 to 0.54105, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_local_5.h5
# 25/25 [==============================] - 3s 137ms/step - loss: 0.4231 - binary_crossentropy: 0.1231 - generalized_dice_coefficient: 0.2769 - val_loss: 0.5410 - val_binary_crossentropy: 0.2227 - val_generalized_dice_coefficient: 0.1406
# Epoch 6/200
# 25/25 [==============================] - ETA: 0s - loss: 0.3218 - binary_crossentropy: 0.0765 - generalized_dice_coefficient: 0.4330
# Epoch 6: val_loss improved from 0.54105 to 0.39500, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_local_6.h5
# 25/25 [==============================] - 4s 171ms/step - loss: 0.3218 - binary_crossentropy: 0.0765 - generalized_dice_coefficient: 0.4330 - val_loss: 0.3950 - val_binary_crossentropy: 0.0984 - val_generalized_dice_coefficient: 0.3084
# Epoch 7/200
# 25/25 [==============================] - ETA: 0s - loss: 0.2402 - binary_crossentropy: 0.0595 - generalized_dice_coefficient: 0.5792
# Epoch 7: val_loss improved from 0.39500 to 0.38615, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_local_7.h5
# 25/25 [==============================] - 3s 138ms/step - loss: 0.2402 - binary_crossentropy: 0.0595 - generalized_dice_coefficient: 0.5792 - val_loss: 0.3862 - val_binary_crossentropy: 0.0997 - val_generalized_dice_coefficient: 0.3275
# Epoch 8/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1886 - binary_crossentropy: 0.0493 - generalized_dice_coefficient: 0.6721
# Epoch 8: val_loss improved from 0.38615 to 0.31695, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_local_8.h5
# 25/25 [==============================] - 3s 137ms/step - loss: 0.1886 - binary_crossentropy: 0.0493 - generalized_dice_coefficient: 0.6721 - val_loss: 0.3169 - val_binary_crossentropy: 0.0686 - val_generalized_dice_coefficient: 0.4348
# Epoch 9/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1589 - binary_crossentropy: 0.0456 - generalized_dice_coefficient: 0.7279
# Epoch 9: val_loss improved from 0.31695 to 0.31329, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_local_9.h5
# 25/25 [==============================] - 3s 139ms/step - loss: 0.1589 - binary_crossentropy: 0.0456 - generalized_dice_coefficient: 0.7279 - val_loss: 0.3133 - val_binary_crossentropy: 0.0749 - val_generalized_dice_coefficient: 0.4483
# Epoch 10/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1422 - binary_crossentropy: 0.0472 - generalized_dice_coefficient: 0.7628
# Epoch 10: val_loss improved from 0.31329 to 0.24242, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_local_10.h5
# 25/25 [==============================] - 3s 138ms/step - loss: 0.1422 - binary_crossentropy: 0.0472 - generalized_dice_coefficient: 0.7628 - val_loss: 0.2424 - val_binary_crossentropy: 0.0534 - val_generalized_dice_coefficient: 0.5686
# Epoch 11/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1219 - binary_crossentropy: 0.0477 - generalized_dice_coefficient: 0.8039
# Epoch 11: val_loss improved from 0.24242 to 0.19613, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_local_11.h5
# 25/25 [==============================] - 3s 138ms/step - loss: 0.1219 - binary_crossentropy: 0.0477 - generalized_dice_coefficient: 0.8039 - val_loss: 0.1961 - val_binary_crossentropy: 0.0475 - val_generalized_dice_coefficient: 0.6552
# Epoch 12/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1129 - binary_crossentropy: 0.0483 - generalized_dice_coefficient: 0.8225
# Epoch 12: val_loss improved from 0.19613 to 0.15393, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_local_12.h5
# 25/25 [==============================] - 3s 137ms/step - loss: 0.1129 - binary_crossentropy: 0.0483 - generalized_dice_coefficient: 0.8225 - val_loss: 0.1539 - val_binary_crossentropy: 0.0376 - val_generalized_dice_coefficient: 0.7298
# Epoch 13/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1277 - binary_crossentropy: 0.0578 - generalized_dice_coefficient: 0.8025
# Epoch 13: val_loss improved from 0.15393 to 0.14779, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_local_13.h5
# 25/25 [==============================] - 3s 137ms/step - loss: 0.1277 - binary_crossentropy: 0.0578 - generalized_dice_coefficient: 0.8025 - val_loss: 0.1478 - val_binary_crossentropy: 0.0365 - val_generalized_dice_coefficient: 0.7409
# Epoch 14/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1138 - binary_crossentropy: 0.0464 - generalized_dice_coefficient: 0.8187
# Epoch 14: val_loss did not improve from 0.14779
# 25/25 [==============================] - 3s 123ms/step - loss: 0.1138 - binary_crossentropy: 0.0464 - generalized_dice_coefficient: 0.8187 - val_loss: 0.1523 - val_binary_crossentropy: 0.0404 - val_generalized_dice_coefficient: 0.7358
# Epoch 15/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1089 - binary_crossentropy: 0.0448 - generalized_dice_coefficient: 0.8270
# Epoch 15: val_loss improved from 0.14779 to 0.13892, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_local_15.h5
# 25/25 [==============================] - 3s 138ms/step - loss: 0.1089 - binary_crossentropy: 0.0448 - generalized_dice_coefficient: 0.8270 - val_loss: 0.1389 - val_binary_crossentropy: 0.0389 - val_generalized_dice_coefficient: 0.7611
# Epoch 16/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1053 - binary_crossentropy: 0.0431 - generalized_dice_coefficient: 0.8324
# Epoch 16: val_loss improved from 0.13892 to 0.13138, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_local_16.h5
# 25/25 [==============================] - 3s 138ms/step - loss: 0.1053 - binary_crossentropy: 0.0431 - generalized_dice_coefficient: 0.8324 - val_loss: 0.1314 - val_binary_crossentropy: 0.0384 - val_generalized_dice_coefficient: 0.7757
# Epoch 17/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1026 - binary_crossentropy: 0.0426 - generalized_dice_coefficient: 0.8375
# Epoch 17: val_loss improved from 0.13138 to 0.12440, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_local_17.h5
# 25/25 [==============================] - 4s 153ms/step - loss: 0.1026 - binary_crossentropy: 0.0426 - generalized_dice_coefficient: 0.8375 - val_loss: 0.1244 - val_binary_crossentropy: 0.0384 - val_generalized_dice_coefficient: 0.7897
# Epoch 18/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1038 - binary_crossentropy: 0.0436 - generalized_dice_coefficient: 0.8360
# Epoch 18: val_loss improved from 0.12440 to 0.12015, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_local_18.h5
# 25/25 [==============================] - 3s 139ms/step - loss: 0.1038 - binary_crossentropy: 0.0436 - generalized_dice_coefficient: 0.8360 - val_loss: 0.1202 - val_binary_crossentropy: 0.0385 - val_generalized_dice_coefficient: 0.7982
# Epoch 19/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1020 - binary_crossentropy: 0.0420 - generalized_dice_coefficient: 0.8380
# Epoch 19: val_loss improved from 0.12015 to 0.11626, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_local_19.h5
# 25/25 [==============================] - 3s 139ms/step - loss: 0.1020 - binary_crossentropy: 0.0420 - generalized_dice_coefficient: 0.8380 - val_loss: 0.1163 - val_binary_crossentropy: 0.0379 - val_generalized_dice_coefficient: 0.8054
# Epoch 20/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1017 - binary_crossentropy: 0.0424 - generalized_dice_coefficient: 0.8390
# Epoch 20: val_loss improved from 0.11626 to 0.11420, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_local_20.h5
# 25/25 [==============================] - 3s 136ms/step - loss: 0.1017 - binary_crossentropy: 0.0424 - generalized_dice_coefficient: 0.8390 - val_loss: 0.1142 - val_binary_crossentropy: 0.0394 - val_generalized_dice_coefficient: 0.8110
# Epoch 21/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1011 - binary_crossentropy: 0.0420 - generalized_dice_coefficient: 0.8397
# Epoch 21: val_loss did not improve from 0.11420
# 25/25 [==============================] - 3s 123ms/step - loss: 0.1011 - binary_crossentropy: 0.0420 - generalized_dice_coefficient: 0.8397 - val_loss: 0.1181 - val_binary_crossentropy: 0.0425 - val_generalized_dice_coefficient: 0.8063
# Epoch 22/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1006 - binary_crossentropy: 0.0417 - generalized_dice_coefficient: 0.8406
# Epoch 22: val_loss improved from 0.11420 to 0.11263, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_local_22.h5
# 25/25 [==============================] - 3s 137ms/step - loss: 0.1006 - binary_crossentropy: 0.0417 - generalized_dice_coefficient: 0.8406 - val_loss: 0.1126 - val_binary_crossentropy: 0.0411 - val_generalized_dice_coefficient: 0.8158
# Epoch 23/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1005 - binary_crossentropy: 0.0421 - generalized_dice_coefficient: 0.8411
# Epoch 23: val_loss did not improve from 0.11263
# 25/25 [==============================] - 3s 123ms/step - loss: 0.1005 - binary_crossentropy: 0.0421 - generalized_dice_coefficient: 0.8411 - val_loss: 0.1130 - val_binary_crossentropy: 0.0429 - val_generalized_dice_coefficient: 0.8169
# Epoch 24/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0993 - binary_crossentropy: 0.0413 - generalized_dice_coefficient: 0.8427
# Epoch 24: val_loss improved from 0.11263 to 0.11147, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_local_24.h5
# 25/25 [==============================] - 3s 138ms/step - loss: 0.0993 - binary_crossentropy: 0.0413 - generalized_dice_coefficient: 0.8427 - val_loss: 0.1115 - val_binary_crossentropy: 0.0429 - val_generalized_dice_coefficient: 0.8200
# Epoch 25/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0990 - binary_crossentropy: 0.0408 - generalized_dice_coefficient: 0.8428
# Epoch 25: val_loss did not improve from 0.11147
# 25/25 [==============================] - 3s 122ms/step - loss: 0.0990 - binary_crossentropy: 0.0408 - generalized_dice_coefficient: 0.8428 - val_loss: 0.1129 - val_binary_crossentropy: 0.0449 - val_generalized_dice_coefficient: 0.8190
# Epoch 26/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0986 - binary_crossentropy: 0.0409 - generalized_dice_coefficient: 0.8438
# Epoch 26: val_loss improved from 0.11147 to 0.10937, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_local_26.h5
# 25/25 [==============================] - 3s 136ms/step - loss: 0.0986 - binary_crossentropy: 0.0409 - generalized_dice_coefficient: 0.8438 - val_loss: 0.1094 - val_binary_crossentropy: 0.0431 - val_generalized_dice_coefficient: 0.8244
# Epoch 27/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0981 - binary_crossentropy: 0.0407 - generalized_dice_coefficient: 0.8445
# Epoch 27: val_loss did not improve from 0.10937
# 25/25 [==============================] - 3s 122ms/step - loss: 0.0981 - binary_crossentropy: 0.0407 - generalized_dice_coefficient: 0.8445 - val_loss: 0.1117 - val_binary_crossentropy: 0.0452 - val_generalized_dice_coefficient: 0.8218
# Epoch 28/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0979 - binary_crossentropy: 0.0406 - generalized_dice_coefficient: 0.8448
# Epoch 28: val_loss improved from 0.10937 to 0.10928, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_local_28.h5
# 25/25 [==============================] - 3s 138ms/step - loss: 0.0979 - binary_crossentropy: 0.0406 - generalized_dice_coefficient: 0.8448 - val_loss: 0.1093 - val_binary_crossentropy: 0.0443 - val_generalized_dice_coefficient: 0.8258
# Epoch 29/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0981 - binary_crossentropy: 0.0407 - generalized_dice_coefficient: 0.8445
# Epoch 29: val_loss did not improve from 0.10928
# 25/25 [==============================] - 3s 122ms/step - loss: 0.0981 - binary_crossentropy: 0.0407 - generalized_dice_coefficient: 0.8445 - val_loss: 0.1093 - val_binary_crossentropy: 0.0444 - val_generalized_dice_coefficient: 0.8258
# Epoch 30/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0972 - binary_crossentropy: 0.0402 - generalized_dice_coefficient: 0.8457
# Epoch 30: val_loss improved from 0.10928 to 0.10874, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_local_30.h5
# 25/25 [==============================] - 3s 138ms/step - loss: 0.0972 - binary_crossentropy: 0.0402 - generalized_dice_coefficient: 0.8457 - val_loss: 0.1087 - val_binary_crossentropy: 0.0446 - val_generalized_dice_coefficient: 0.8271
# Epoch 31/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0970 - binary_crossentropy: 0.0402 - generalized_dice_coefficient: 0.8462
# Epoch 31: val_loss improved from 0.10874 to 0.10819, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_local_31.h5
# 25/25 [==============================] - 3s 137ms/step - loss: 0.0970 - binary_crossentropy: 0.0402 - generalized_dice_coefficient: 0.8462 - val_loss: 0.1082 - val_binary_crossentropy: 0.0444 - val_generalized_dice_coefficient: 0.8281
# Epoch 32/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0971 - binary_crossentropy: 0.0402 - generalized_dice_coefficient: 0.8461
# Epoch 32: val_loss did not improve from 0.10819
# 25/25 [==============================] - 3s 122ms/step - loss: 0.0971 - binary_crossentropy: 0.0402 - generalized_dice_coefficient: 0.8461 - val_loss: 0.1088 - val_binary_crossentropy: 0.0453 - val_generalized_dice_coefficient: 0.8277
# Epoch 33/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0974 - binary_crossentropy: 0.0406 - generalized_dice_coefficient: 0.8458
# Epoch 33: val_loss did not improve from 0.10819
# 25/25 [==============================] - 3s 123ms/step - loss: 0.0974 - binary_crossentropy: 0.0406 - generalized_dice_coefficient: 0.8458 - val_loss: 0.1092 - val_binary_crossentropy: 0.0452 - val_generalized_dice_coefficient: 0.8269
# Epoch 34/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0970 - binary_crossentropy: 0.0403 - generalized_dice_coefficient: 0.8463
# Epoch 34: val_loss improved from 0.10819 to 0.10813, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_local_34.h5
# 25/25 [==============================] - 3s 138ms/step - loss: 0.0970 - binary_crossentropy: 0.0403 - generalized_dice_coefficient: 0.8463 - val_loss: 0.1081 - val_binary_crossentropy: 0.0445 - val_generalized_dice_coefficient: 0.8283
# Epoch 35/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0968 - binary_crossentropy: 0.0400 - generalized_dice_coefficient: 0.8464
# Epoch 35: val_loss did not improve from 0.10813
# 25/25 [==============================] - 3s 123ms/step - loss: 0.0968 - binary_crossentropy: 0.0400 - generalized_dice_coefficient: 0.8464 - val_loss: 0.1089 - val_binary_crossentropy: 0.0457 - val_generalized_dice_coefficient: 0.8279
# Epoch 36/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0965 - binary_crossentropy: 0.0400 - generalized_dice_coefficient: 0.8471
# Epoch 36: val_loss did not improve from 0.10813
# 25/25 [==============================] - 3s 123ms/step - loss: 0.0965 - binary_crossentropy: 0.0400 - generalized_dice_coefficient: 0.8471 - val_loss: 0.1088 - val_binary_crossentropy: 0.0456 - val_generalized_dice_coefficient: 0.8280
# Epoch 37/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0966 - binary_crossentropy: 0.0400 - generalized_dice_coefficient: 0.8469
# Epoch 37: val_loss did not improve from 0.10813
# 25/25 [==============================] - 3s 122ms/step - loss: 0.0966 - binary_crossentropy: 0.0400 - generalized_dice_coefficient: 0.8469 - val_loss: 0.1094 - val_binary_crossentropy: 0.0459 - val_generalized_dice_coefficient: 0.8272
# Epoch 38/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0966 - binary_crossentropy: 0.0400 - generalized_dice_coefficient: 0.8467
# Epoch 38: val_loss did not improve from 0.10813
# 25/25 [==============================] - 3s 122ms/step - loss: 0.0966 - binary_crossentropy: 0.0400 - generalized_dice_coefficient: 0.8467 - val_loss: 0.1083 - val_binary_crossentropy: 0.0453 - val_generalized_dice_coefficient: 0.8289
# Epoch 39/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0962 - binary_crossentropy: 0.0398 - generalized_dice_coefficient: 0.8474
# Epoch 39: val_loss did not improve from 0.10813
# 25/25 [==============================] - 3s 122ms/step - loss: 0.0962 - binary_crossentropy: 0.0398 - generalized_dice_coefficient: 0.8474 - val_loss: 0.1094 - val_binary_crossentropy: 0.0459 - val_generalized_dice_coefficient: 0.8271
# Epoch 40/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0963 - binary_crossentropy: 0.0398 - generalized_dice_coefficient: 0.8473
# Epoch 40: val_loss did not improve from 0.10813
# 25/25 [==============================] - 3s 122ms/step - loss: 0.0963 - binary_crossentropy: 0.0398 - generalized_dice_coefficient: 0.8473 - val_loss: 0.1082 - val_binary_crossentropy: 0.0454 - val_generalized_dice_coefficient: 0.8289
# Epoch 41/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0961 - binary_crossentropy: 0.0397 - generalized_dice_coefficient: 0.8475
# Epoch 41: val_loss improved from 0.10813 to 0.10805, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_local_41.h5
# 25/25 [==============================] - 3s 137ms/step - loss: 0.0961 - binary_crossentropy: 0.0397 - generalized_dice_coefficient: 0.8475 - val_loss: 0.1080 - val_binary_crossentropy: 0.0453 - val_generalized_dice_coefficient: 0.8292
# Epoch 42/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0960 - binary_crossentropy: 0.0398 - generalized_dice_coefficient: 0.8478
# Epoch 42: val_loss improved from 0.10805 to 0.10781, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_local_42.h5
# 25/25 [==============================] - 3s 137ms/step - loss: 0.0960 - binary_crossentropy: 0.0398 - generalized_dice_coefficient: 0.8478 - val_loss: 0.1078 - val_binary_crossentropy: 0.0453 - val_generalized_dice_coefficient: 0.8297
# Epoch 43/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0961 - binary_crossentropy: 0.0399 - generalized_dice_coefficient: 0.8477
# Epoch 43: val_loss did not improve from 0.10781
# 25/25 [==============================] - 3s 121ms/step - loss: 0.0961 - binary_crossentropy: 0.0399 - generalized_dice_coefficient: 0.8477 - val_loss: 0.1078 - val_binary_crossentropy: 0.0452 - val_generalized_dice_coefficient: 0.8296
# Epoch 44/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0958 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8480
# Epoch 44: val_loss did not improve from 0.10781
# 25/25 [==============================] - 3s 123ms/step - loss: 0.0958 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8480 - val_loss: 0.1085 - val_binary_crossentropy: 0.0457 - val_generalized_dice_coefficient: 0.8287
# Epoch 45/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0960 - binary_crossentropy: 0.0398 - generalized_dice_coefficient: 0.8478
# Epoch 45: val_loss did not improve from 0.10781
# 25/25 [==============================] - 3s 123ms/step - loss: 0.0960 - binary_crossentropy: 0.0398 - generalized_dice_coefficient: 0.8478 - val_loss: 0.1083 - val_binary_crossentropy: 0.0456 - val_generalized_dice_coefficient: 0.8291
# Epoch 46/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0956 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8483
# Epoch 46: val_loss did not improve from 0.10781
# 25/25 [==============================] - 3s 122ms/step - loss: 0.0956 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8483 - val_loss: 0.1087 - val_binary_crossentropy: 0.0454 - val_generalized_dice_coefficient: 0.8280
# Epoch 47/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0962 - binary_crossentropy: 0.0399 - generalized_dice_coefficient: 0.8476
# Epoch 47: val_loss improved from 0.10781 to 0.10769, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_local_47.h5
# 25/25 [==============================] - 3s 137ms/step - loss: 0.0962 - binary_crossentropy: 0.0399 - generalized_dice_coefficient: 0.8476 - val_loss: 0.1077 - val_binary_crossentropy: 0.0452 - val_generalized_dice_coefficient: 0.8298
# Epoch 48/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0959 - binary_crossentropy: 0.0397 - generalized_dice_coefficient: 0.8479
# Epoch 48: val_loss improved from 0.10769 to 0.10768, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_local_48.h5
# 25/25 [==============================] - 3s 136ms/step - loss: 0.0959 - binary_crossentropy: 0.0397 - generalized_dice_coefficient: 0.8479 - val_loss: 0.1077 - val_binary_crossentropy: 0.0452 - val_generalized_dice_coefficient: 0.8299
# Epoch 49/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0958 - binary_crossentropy: 0.0397 - generalized_dice_coefficient: 0.8481
# Epoch 49: val_loss improved from 0.10768 to 0.10763, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_local_49.h5
# 25/25 [==============================] - 3s 138ms/step - loss: 0.0958 - binary_crossentropy: 0.0397 - generalized_dice_coefficient: 0.8481 - val_loss: 0.1076 - val_binary_crossentropy: 0.0451 - val_generalized_dice_coefficient: 0.8299
# Epoch 50/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0961 - binary_crossentropy: 0.0398 - generalized_dice_coefficient: 0.8476
# Epoch 50: val_loss improved from 0.10763 to 0.10756, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_local_50.h5
# 25/25 [==============================] - 3s 138ms/step - loss: 0.0961 - binary_crossentropy: 0.0398 - generalized_dice_coefficient: 0.8476 - val_loss: 0.1076 - val_binary_crossentropy: 0.0451 - val_generalized_dice_coefficient: 0.8300
# Epoch 51/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0958 - binary_crossentropy: 0.0397 - generalized_dice_coefficient: 0.8481
# Epoch 51: val_loss did not improve from 0.10756
# 25/25 [==============================] - 3s 123ms/step - loss: 0.0958 - binary_crossentropy: 0.0397 - generalized_dice_coefficient: 0.8481 - val_loss: 0.1081 - val_binary_crossentropy: 0.0455 - val_generalized_dice_coefficient: 0.8293
# Epoch 52/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0957 - binary_crossentropy: 0.0397 - generalized_dice_coefficient: 0.8483
# Epoch 52: val_loss did not improve from 0.10756
# 25/25 [==============================] - 3s 123ms/step - loss: 0.0957 - binary_crossentropy: 0.0397 - generalized_dice_coefficient: 0.8483 - val_loss: 0.1077 - val_binary_crossentropy: 0.0452 - val_generalized_dice_coefficient: 0.8298
# Epoch 53/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0956 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8484
# Epoch 53: val_loss did not improve from 0.10756
# 25/25 [==============================] - 3s 123ms/step - loss: 0.0956 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8484 - val_loss: 0.1077 - val_binary_crossentropy: 0.0452 - val_generalized_dice_coefficient: 0.8299
# Epoch 54/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0957 - binary_crossentropy: 0.0397 - generalized_dice_coefficient: 0.8483
# Epoch 54: val_loss did not improve from 0.10756
# 25/25 [==============================] - 3s 122ms/step - loss: 0.0957 - binary_crossentropy: 0.0397 - generalized_dice_coefficient: 0.8483 - val_loss: 0.1077 - val_binary_crossentropy: 0.0453 - val_generalized_dice_coefficient: 0.8298
# Epoch 55/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0957 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8482
# Epoch 55: val_loss did not improve from 0.10756
# 25/25 [==============================] - 3s 122ms/step - loss: 0.0957 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8482 - val_loss: 0.1076 - val_binary_crossentropy: 0.0451 - val_generalized_dice_coefficient: 0.8300
# Epoch 56/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0956 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8483
# Epoch 56: val_loss did not improve from 0.10756
# 25/25 [==============================] - 3s 122ms/step - loss: 0.0956 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8483 - val_loss: 0.1077 - val_binary_crossentropy: 0.0452 - val_generalized_dice_coefficient: 0.8299
# Epoch 57/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0955 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8486
# Epoch 57: val_loss did not improve from 0.10756
# 25/25 [==============================] - 3s 123ms/step - loss: 0.0955 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8486 - val_loss: 0.1078 - val_binary_crossentropy: 0.0454 - val_generalized_dice_coefficient: 0.8297
# Epoch 58/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0954 - binary_crossentropy: 0.0395 - generalized_dice_coefficient: 0.8486
# Epoch 58: val_loss did not improve from 0.10756
# 25/25 [==============================] - 3s 122ms/step - loss: 0.0954 - binary_crossentropy: 0.0395 - generalized_dice_coefficient: 0.8486 - val_loss: 0.1076 - val_binary_crossentropy: 0.0452 - val_generalized_dice_coefficient: 0.8300
# Epoch 59/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0955 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8485
# Epoch 59: val_loss did not improve from 0.10756
# 25/25 [==============================] - 3s 122ms/step - loss: 0.0955 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8485 - val_loss: 0.1077 - val_binary_crossentropy: 0.0453 - val_generalized_dice_coefficient: 0.8299
# Epoch 60/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0953 - binary_crossentropy: 0.0395 - generalized_dice_coefficient: 0.8488
# Epoch 60: val_loss did not improve from 0.10756
# 25/25 [==============================] - 3s 124ms/step - loss: 0.0953 - binary_crossentropy: 0.0395 - generalized_dice_coefficient: 0.8488 - val_loss: 0.1076 - val_binary_crossentropy: 0.0452 - val_generalized_dice_coefficient: 0.8301
# Epoch 61/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0957 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8483
# Epoch 61: val_loss did not improve from 0.10756
# 25/25 [==============================] - 3s 123ms/step - loss: 0.0957 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8483 - val_loss: 0.1076 - val_binary_crossentropy: 0.0453 - val_generalized_dice_coefficient: 0.8300
# Epoch 62/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0956 - binary_crossentropy: 0.0397 - generalized_dice_coefficient: 0.8485
# Epoch 62: val_loss did not improve from 0.10756
# 25/25 [==============================] - 3s 123ms/step - loss: 0.0956 - binary_crossentropy: 0.0397 - generalized_dice_coefficient: 0.8485 - val_loss: 0.1077 - val_binary_crossentropy: 0.0453 - val_generalized_dice_coefficient: 0.8300
# Epoch 63/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0955 - binary_crossentropy: 0.0395 - generalized_dice_coefficient: 0.8486
# Epoch 63: val_loss did not improve from 0.10756
# 25/25 [==============================] - 3s 123ms/step - loss: 0.0955 - binary_crossentropy: 0.0395 - generalized_dice_coefficient: 0.8486 - val_loss: 0.1076 - val_binary_crossentropy: 0.0453 - val_generalized_dice_coefficient: 0.8300
# Epoch 64/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0954 - binary_crossentropy: 0.0395 - generalized_dice_coefficient: 0.8487
# Epoch 64: val_loss did not improve from 0.10756
# 25/25 [==============================] - 3s 122ms/step - loss: 0.0954 - binary_crossentropy: 0.0395 - generalized_dice_coefficient: 0.8487 - val_loss: 0.1076 - val_binary_crossentropy: 0.0452 - val_generalized_dice_coefficient: 0.8301
# Epoch 65/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0956 - binary_crossentropy: 0.0395 - generalized_dice_coefficient: 0.8483
# Epoch 65: val_loss did not improve from 0.10756
# 25/25 [==============================] - 3s 122ms/step - loss: 0.0956 - binary_crossentropy: 0.0395 - generalized_dice_coefficient: 0.8483 - val_loss: 0.1076 - val_binary_crossentropy: 0.0452 - val_generalized_dice_coefficient: 0.8301
# Epoch 66/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0954 - binary_crossentropy: 0.0395 - generalized_dice_coefficient: 0.8486
# Epoch 66: val_loss did not improve from 0.10756
# 25/25 [==============================] - 3s 122ms/step - loss: 0.0954 - binary_crossentropy: 0.0395 - generalized_dice_coefficient: 0.8486 - val_loss: 0.1077 - val_binary_crossentropy: 0.0453 - val_generalized_dice_coefficient: 0.8300
# Epoch 67/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0954 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8488
# Epoch 67: val_loss did not improve from 0.10756
# 25/25 [==============================] - 3s 122ms/step - loss: 0.0954 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8488 - val_loss: 0.1076 - val_binary_crossentropy: 0.0453 - val_generalized_dice_coefficient: 0.8300
# Epoch 68/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0953 - binary_crossentropy: 0.0395 - generalized_dice_coefficient: 0.8488
# Epoch 68: val_loss did not improve from 0.10756
# 25/25 [==============================] - 3s 123ms/step - loss: 0.0953 - binary_crossentropy: 0.0395 - generalized_dice_coefficient: 0.8488 - val_loss: 0.1076 - val_binary_crossentropy: 0.0453 - val_generalized_dice_coefficient: 0.8301
# Epoch 69/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0955 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8487
# Epoch 69: val_loss did not improve from 0.10756
# 25/25 [==============================] - 3s 122ms/step - loss: 0.0955 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8487 - val_loss: 0.1076 - val_binary_crossentropy: 0.0453 - val_generalized_dice_coefficient: 0.8300
# Epoch 70/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0955 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8486
# Epoch 70: val_loss did not improve from 0.10756
# 25/25 [==============================] - 3s 123ms/step - loss: 0.0955 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8486 - val_loss: 0.1076 - val_binary_crossentropy: 0.0453 - val_generalized_dice_coefficient: 0.8300
# Epoch 71/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0955 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8486
# Epoch 71: val_loss did not improve from 0.10756
# 25/25 [==============================] - 3s 123ms/step - loss: 0.0955 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8486 - val_loss: 0.1076 - val_binary_crossentropy: 0.0452 - val_generalized_dice_coefficient: 0.8301
# Epoch 72/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0954 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8487
# Epoch 72: val_loss did not improve from 0.10756
# 25/25 [==============================] - 3s 123ms/step - loss: 0.0954 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8487 - val_loss: 0.1076 - val_binary_crossentropy: 0.0453 - val_generalized_dice_coefficient: 0.8301
# Epoch 73/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0956 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8485
# Epoch 73: val_loss did not improve from 0.10756
# 25/25 [==============================] - 3s 122ms/step - loss: 0.0956 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8485 - val_loss: 0.1076 - val_binary_crossentropy: 0.0452 - val_generalized_dice_coefficient: 0.8301
# Epoch 74/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0956 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8485
# Epoch 74: val_loss did not improve from 0.10756
# 25/25 [==============================] - 3s 123ms/step - loss: 0.0956 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8485 - val_loss: 0.1076 - val_binary_crossentropy: 0.0452 - val_generalized_dice_coefficient: 0.8301
# Epoch 75/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0954 - binary_crossentropy: 0.0395 - generalized_dice_coefficient: 0.8487
# Epoch 75: val_loss did not improve from 0.10756
# 25/25 [==============================] - 3s 123ms/step - loss: 0.0954 - binary_crossentropy: 0.0395 - generalized_dice_coefficient: 0.8487 - val_loss: 0.1076 - val_binary_crossentropy: 0.0452 - val_generalized_dice_coefficient: 0.8301
# Epoch 76/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0954 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8487
# Epoch 76: val_loss did not improve from 0.10756
# 25/25 [==============================] - 3s 124ms/step - loss: 0.0954 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8487 - val_loss: 0.1076 - val_binary_crossentropy: 0.0452 - val_generalized_dice_coefficient: 0.8301
# Epoch 77/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0955 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8486
# Epoch 77: val_loss did not improve from 0.10756
# 25/25 [==============================] - 3s 123ms/step - loss: 0.0955 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8486 - val_loss: 0.1076 - val_binary_crossentropy: 0.0452 - val_generalized_dice_coefficient: 0.8301
# Epoch 78/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0955 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8485
# Epoch 78: val_loss did not improve from 0.10756
# 25/25 [==============================] - 3s 122ms/step - loss: 0.0955 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8485 - val_loss: 0.1076 - val_binary_crossentropy: 0.0452 - val_generalized_dice_coefficient: 0.8301
# Epoch 79/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0954 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8487
# Epoch 79: val_loss did not improve from 0.10756
# 25/25 [==============================] - 3s 123ms/step - loss: 0.0954 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8487 - val_loss: 0.1076 - val_binary_crossentropy: 0.0453 - val_generalized_dice_coefficient: 0.8301
# Epoch 80/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0954 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8487
# Epoch 80: val_loss did not improve from 0.10756
# 25/25 [==============================] - 3s 122ms/step - loss: 0.0954 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8487 - val_loss: 0.1076 - val_binary_crossentropy: 0.0453 - val_generalized_dice_coefficient: 0.8301
# Epoch 81/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0956 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8484
# Epoch 81: val_loss did not improve from 0.10756
# 25/25 [==============================] - 3s 122ms/step - loss: 0.0956 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8484 - val_loss: 0.1076 - val_binary_crossentropy: 0.0453 - val_generalized_dice_coefficient: 0.8301
# Epoch 82/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0957 - binary_crossentropy: 0.0397 - generalized_dice_coefficient: 0.8483
# Epoch 82: val_loss did not improve from 0.10756
# 25/25 [==============================] - 3s 123ms/step - loss: 0.0957 - binary_crossentropy: 0.0397 - generalized_dice_coefficient: 0.8483 - val_loss: 0.1076 - val_binary_crossentropy: 0.0453 - val_generalized_dice_coefficient: 0.8301
# Epoch 83/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0954 - binary_crossentropy: 0.0395 - generalized_dice_coefficient: 0.8488
# Epoch 83: val_loss did not improve from 0.10756
# 25/25 [==============================] - 3s 123ms/step - loss: 0.0954 - binary_crossentropy: 0.0395 - generalized_dice_coefficient: 0.8488 - val_loss: 0.1076 - val_binary_crossentropy: 0.0452 - val_generalized_dice_coefficient: 0.8301
# Epoch 84/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0954 - binary_crossentropy: 0.0395 - generalized_dice_coefficient: 0.8488
# Epoch 84: val_loss did not improve from 0.10756
# 25/25 [==============================] - 3s 123ms/step - loss: 0.0954 - binary_crossentropy: 0.0395 - generalized_dice_coefficient: 0.8488 - val_loss: 0.1076 - val_binary_crossentropy: 0.0453 - val_generalized_dice_coefficient: 0.8301
# Epoch 85/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0953 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8490
# Epoch 85: val_loss did not improve from 0.10756
# 25/25 [==============================] - 3s 122ms/step - loss: 0.0953 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8490 - val_loss: 0.1076 - val_binary_crossentropy: 0.0453 - val_generalized_dice_coefficient: 0.8301
# Epoch 86/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0955 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8487
# Epoch 86: val_loss did not improve from 0.10756
# 25/25 [==============================] - 3s 123ms/step - loss: 0.0955 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8487 - val_loss: 0.1076 - val_binary_crossentropy: 0.0453 - val_generalized_dice_coefficient: 0.8301
# Epoch 87/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0956 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8485
# Epoch 87: val_loss did not improve from 0.10756
# 25/25 [==============================] - 3s 122ms/step - loss: 0.0956 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8485 - val_loss: 0.1076 - val_binary_crossentropy: 0.0452 - val_generalized_dice_coefficient: 0.8301
# Epoch 88/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0953 - binary_crossentropy: 0.0395 - generalized_dice_coefficient: 0.8489
# Epoch 88: val_loss did not improve from 0.10756
# 25/25 [==============================] - 3s 123ms/step - loss: 0.0953 - binary_crossentropy: 0.0395 - generalized_dice_coefficient: 0.8489 - val_loss: 0.1076 - val_binary_crossentropy: 0.0453 - val_generalized_dice_coefficient: 0.8301
# Epoch 89/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0956 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8485
# Epoch 89: val_loss did not improve from 0.10756
# 25/25 [==============================] - 3s 122ms/step - loss: 0.0956 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8485 - val_loss: 0.1076 - val_binary_crossentropy: 0.0453 - val_generalized_dice_coefficient: 0.8301
# Epoch 90/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0955 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8486
# Epoch 90: val_loss did not improve from 0.10756
# 25/25 [==============================] - 3s 123ms/step - loss: 0.0955 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8486 - val_loss: 0.1076 - val_binary_crossentropy: 0.0452 - val_generalized_dice_coefficient: 0.8301
# Epoch 91/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0955 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8486
# Epoch 91: val_loss did not improve from 0.10756
# 25/25 [==============================] - 3s 123ms/step - loss: 0.0955 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8486 - val_loss: 0.1076 - val_binary_crossentropy: 0.0453 - val_generalized_dice_coefficient: 0.8301
# Epoch 92/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0954 - binary_crossentropy: 0.0395 - generalized_dice_coefficient: 0.8487
# Epoch 92: val_loss did not improve from 0.10756
# 25/25 [==============================] - 3s 122ms/step - loss: 0.0954 - binary_crossentropy: 0.0395 - generalized_dice_coefficient: 0.8487 - val_loss: 0.1076 - val_binary_crossentropy: 0.0453 - val_generalized_dice_coefficient: 0.8301
# Epoch 93/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0952 - binary_crossentropy: 0.0395 - generalized_dice_coefficient: 0.8490
# Epoch 93: val_loss did not improve from 0.10756
# 25/25 [==============================] - 3s 122ms/step - loss: 0.0952 - binary_crossentropy: 0.0395 - generalized_dice_coefficient: 0.8490 - val_loss: 0.1076 - val_binary_crossentropy: 0.0453 - val_generalized_dice_coefficient: 0.8301
# Epoch 94/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0952 - binary_crossentropy: 0.0395 - generalized_dice_coefficient: 0.8490
# Epoch 94: val_loss did not improve from 0.10756
# 25/25 [==============================] - 3s 122ms/step - loss: 0.0952 - binary_crossentropy: 0.0395 - generalized_dice_coefficient: 0.8490 - val_loss: 0.1076 - val_binary_crossentropy: 0.0453 - val_generalized_dice_coefficient: 0.8301
# Epoch 95/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0955 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8485
# Epoch 95: val_loss did not improve from 0.10756
# 25/25 [==============================] - 3s 122ms/step - loss: 0.0955 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8485 - val_loss: 0.1076 - val_binary_crossentropy: 0.0453 - val_generalized_dice_coefficient: 0.8301
# Epoch 96/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0955 - binary_crossentropy: 0.0395 - generalized_dice_coefficient: 0.8486
# Epoch 96: val_loss did not improve from 0.10756
# 25/25 [==============================] - 3s 122ms/step - loss: 0.0955 - binary_crossentropy: 0.0395 - generalized_dice_coefficient: 0.8486 - val_loss: 0.1076 - val_binary_crossentropy: 0.0453 - val_generalized_dice_coefficient: 0.8301
# Epoch 97/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0955 - binary_crossentropy: 0.0395 - generalized_dice_coefficient: 0.8486
# Epoch 97: val_loss did not improve from 0.10756
# 25/25 [==============================] - 3s 122ms/step - loss: 0.0955 - binary_crossentropy: 0.0395 - generalized_dice_coefficient: 0.8486 - val_loss: 0.1076 - val_binary_crossentropy: 0.0453 - val_generalized_dice_coefficient: 0.8301
# Epoch 98/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0956 - binary_crossentropy: 0.0397 - generalized_dice_coefficient: 0.8484
# Epoch 98: val_loss did not improve from 0.10756
# 25/25 [==============================] - 3s 123ms/step - loss: 0.0956 - binary_crossentropy: 0.0397 - generalized_dice_coefficient: 0.8484 - val_loss: 0.1076 - val_binary_crossentropy: 0.0453 - val_generalized_dice_coefficient: 0.8301
# Epoch 99/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0954 - binary_crossentropy: 0.0395 - generalized_dice_coefficient: 0.8487
# Epoch 99: val_loss did not improve from 0.10756
# 25/25 [==============================] - 3s 122ms/step - loss: 0.0954 - binary_crossentropy: 0.0395 - generalized_dice_coefficient: 0.8487 - val_loss: 0.1076 - val_binary_crossentropy: 0.0453 - val_generalized_dice_coefficient: 0.8301
# Epoch 100/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0955 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8486
# Epoch 100: val_loss did not improve from 0.10756
# 25/25 [==============================] - 3s 122ms/step - loss: 0.0955 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8486 - val_loss: 0.1076 - val_binary_crossentropy: 0.0453 - val_generalized_dice_coefficient: 0.8301
# Epoch 101/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0956 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8485
# Epoch 101: val_loss did not improve from 0.10756
# 25/25 [==============================] - 3s 122ms/step - loss: 0.0956 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8485 - val_loss: 0.1076 - val_binary_crossentropy: 0.0453 - val_generalized_dice_coefficient: 0.8301
# Epoch 102/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0954 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8487
# Epoch 102: val_loss did not improve from 0.10756
# 25/25 [==============================] - 3s 123ms/step - loss: 0.0954 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8487 - val_loss: 0.1076 - val_binary_crossentropy: 0.0453 - val_generalized_dice_coefficient: 0.8301
# Epoch 103/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0955 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8486
# Epoch 103: val_loss did not improve from 0.10756
# 25/25 [==============================] - 3s 122ms/step - loss: 0.0955 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8486 - val_loss: 0.1076 - val_binary_crossentropy: 0.0453 - val_generalized_dice_coefficient: 0.8301
# Epoch 104/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0956 - binary_crossentropy: 0.0397 - generalized_dice_coefficient: 0.8485
# Epoch 104: val_loss did not improve from 0.10756
# 25/25 [==============================] - 3s 122ms/step - loss: 0.0956 - binary_crossentropy: 0.0397 - generalized_dice_coefficient: 0.8485 - val_loss: 0.1076 - val_binary_crossentropy: 0.0453 - val_generalized_dice_coefficient: 0.8301
# Epoch 105/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0954 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8488
# Epoch 105: val_loss did not improve from 0.10756
# 25/25 [==============================] - 3s 121ms/step - loss: 0.0954 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8488 - val_loss: 0.1076 - val_binary_crossentropy: 0.0453 - val_generalized_dice_coefficient: 0.8301
# Epoch 106/200
# ...
# Epoch 164/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0954 - binary_crossentropy: 0.0395 - generalized_dice_coefficient: 0.8487
# Epoch 164: val_loss did not improve from 0.10756
# 25/25 [==============================] - 3s 123ms/step - loss: 0.0954 - binary_crossentropy: 0.0395 - generalized_dice_coefficient: 0.8487 - val_loss: 0.1076 - val_binary_crossentropy: 0.0453 - val_generalized_dice_coefficient: 0.8301
# Epoch 165/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0953 - binary_crossentropy: 0.0395 - generalized_dice_coefficient: 0.8489
# Epoch 165: val_loss did not improve from 0.10756
# 25/25 [==============================] - 3s 123ms/step - loss: 0.0953 - binary_crossentropy: 0.0395 - generalized_dice_coefficient: 0.8489 - val_loss: 0.1076 - val_binary_crossentropy: 0.0453 - val_generalized_dice_coefficient: 0.8301
# Epoch 166/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0956 - binary_crossentropy: 0.0397 - generalized_dice_coefficient: 0.8484
# Epoch 166: val_loss did not improve from 0.10756
# 25/25 [==============================] - 3s 123ms/step - loss: 0.0956 - binary_crossentropy: 0.0397 - generalized_dice_coefficient: 0.8484 - val_loss: 0.1076 - val_binary_crossentropy: 0.0453 - val_generalized_dice_coefficient: 0.8301
# Epoch 167/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0955 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8485
# Epoch 167: val_loss did not improve from 0.10756
# 25/25 [==============================] - 3s 122ms/step - loss: 0.0955 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8485 - val_loss: 0.1076 - val_binary_crossentropy: 0.0453 - val_generalized_dice_coefficient: 0.8301
# Epoch 168/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0954 - binary_crossentropy: 0.0395 - generalized_dice_coefficient: 0.8487
# Epoch 168: val_loss did not improve from 0.10756
# 25/25 [==============================] - 3s 122ms/step - loss: 0.0954 - binary_crossentropy: 0.0395 - generalized_dice_coefficient: 0.8487 - val_loss: 0.1076 - val_binary_crossentropy: 0.0453 - val_generalized_dice_coefficient: 0.8301
# Epoch 169/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0955 - binary_crossentropy: 0.0397 - generalized_dice_coefficient: 0.8486
# Epoch 169: val_loss did not improve from 0.10756
# 25/25 [==============================] - 3s 123ms/step - loss: 0.0955 - binary_crossentropy: 0.0397 - generalized_dice_coefficient: 0.8486 - val_loss: 0.1076 - val_binary_crossentropy: 0.0453 - val_generalized_dice_coefficient: 0.8301
# Epoch 170/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0956 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8484
# Epoch 170: val_loss did not improve from 0.10756
# 25/25 [==============================] - 3s 122ms/step - loss: 0.0956 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8484 - val_loss: 0.1076 - val_binary_crossentropy: 0.0453 - val_generalized_dice_coefficient: 0.8301
# Epoch 171/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0956 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8485
# Epoch 171: val_loss did not improve from 0.10756
# 25/25 [==============================] - 3s 123ms/step - loss: 0.0956 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8485 - val_loss: 0.1076 - val_binary_crossentropy: 0.0453 - val_generalized_dice_coefficient: 0.8301
# Epoch 172/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0955 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8486
# Epoch 172: val_loss did not improve from 0.10756
# 25/25 [==============================] - 3s 122ms/step - loss: 0.0955 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8486 - val_loss: 0.1076 - val_binary_crossentropy: 0.0453 - val_generalized_dice_coefficient: 0.8301
# Epoch 173/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0954 - binary_crossentropy: 0.0395 - generalized_dice_coefficient: 0.8488
# Epoch 173: val_loss did not improve from 0.10756
# 25/25 [==============================] - 3s 123ms/step - loss: 0.0954 - binary_crossentropy: 0.0395 - generalized_dice_coefficient: 0.8488 - val_loss: 0.1076 - val_binary_crossentropy: 0.0453 - val_generalized_dice_coefficient: 0.8301
# Epoch 174/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0954 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8488
# Epoch 174: val_loss did not improve from 0.10756
# 25/25 [==============================] - 3s 123ms/step - loss: 0.0954 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8488 - val_loss: 0.1076 - val_binary_crossentropy: 0.0453 - val_generalized_dice_coefficient: 0.8301
# Epoch 175/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0956 - binary_crossentropy: 0.0397 - generalized_dice_coefficient: 0.8486
# Epoch 175: val_loss did not improve from 0.10756
# 25/25 [==============================] - 3s 123ms/step - loss: 0.0956 - binary_crossentropy: 0.0397 - generalized_dice_coefficient: 0.8486 - val_loss: 0.1076 - val_binary_crossentropy: 0.0453 - val_generalized_dice_coefficient: 0.8301
# Epoch 176/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0957 - binary_crossentropy: 0.0397 - generalized_dice_coefficient: 0.8482
# Epoch 176: val_loss did not improve from 0.10756
# 25/25 [==============================] - 3s 122ms/step - loss: 0.0957 - binary_crossentropy: 0.0397 - generalized_dice_coefficient: 0.8482 - val_loss: 0.1076 - val_binary_crossentropy: 0.0453 - val_generalized_dice_coefficient: 0.8301
# Epoch 177/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0954 - binary_crossentropy: 0.0395 - generalized_dice_coefficient: 0.8487
# Epoch 177: val_loss did not improve from 0.10756
# 25/25 [==============================] - 3s 122ms/step - loss: 0.0954 - binary_crossentropy: 0.0395 - generalized_dice_coefficient: 0.8487 - val_loss: 0.1076 - val_binary_crossentropy: 0.0453 - val_generalized_dice_coefficient: 0.8301
# Epoch 178/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0955 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8487
# Epoch 178: val_loss did not improve from 0.10756
# 25/25 [==============================] - 3s 122ms/step - loss: 0.0955 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8487 - val_loss: 0.1076 - val_binary_crossentropy: 0.0453 - val_generalized_dice_coefficient: 0.8301
# Epoch 179/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0954 - binary_crossentropy: 0.0395 - generalized_dice_coefficient: 0.8486
# Epoch 179: val_loss did not improve from 0.10756
# 25/25 [==============================] - 3s 122ms/step - loss: 0.0954 - binary_crossentropy: 0.0395 - generalized_dice_coefficient: 0.8486 - val_loss: 0.1076 - val_binary_crossentropy: 0.0453 - val_generalized_dice_coefficient: 0.8301
# Epoch 180/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0954 - binary_crossentropy: 0.0395 - generalized_dice_coefficient: 0.8486
# Epoch 180: val_loss did not improve from 0.10756
# 25/25 [==============================] - 3s 122ms/step - loss: 0.0954 - binary_crossentropy: 0.0395 - generalized_dice_coefficient: 0.8486 - val_loss: 0.1076 - val_binary_crossentropy: 0.0453 - val_generalized_dice_coefficient: 0.8301
# Epoch 181/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0955 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8487
# Epoch 181: val_loss did not improve from 0.10756
# 25/25 [==============================] - 3s 123ms/step - loss: 0.0955 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8487 - val_loss: 0.1076 - val_binary_crossentropy: 0.0453 - val_generalized_dice_coefficient: 0.8301
# Epoch 182/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0955 - binary_crossentropy: 0.0395 - generalized_dice_coefficient: 0.8485
# Epoch 182: val_loss did not improve from 0.10756
# 25/25 [==============================] - 3s 122ms/step - loss: 0.0955 - binary_crossentropy: 0.0395 - generalized_dice_coefficient: 0.8485 - val_loss: 0.1076 - val_binary_crossentropy: 0.0453 - val_generalized_dice_coefficient: 0.8301
# Epoch 183/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0955 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8486
# Epoch 183: val_loss did not improve from 0.10756
# 25/25 [==============================] - 3s 123ms/step - loss: 0.0955 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8486 - val_loss: 0.1076 - val_binary_crossentropy: 0.0452 - val_generalized_dice_coefficient: 0.8301
# Epoch 184/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0953 - binary_crossentropy: 0.0395 - generalized_dice_coefficient: 0.8488
# Epoch 184: val_loss did not improve from 0.10756
# 25/25 [==============================] - 3s 123ms/step - loss: 0.0953 - binary_crossentropy: 0.0395 - generalized_dice_coefficient: 0.8488 - val_loss: 0.1076 - val_binary_crossentropy: 0.0452 - val_generalized_dice_coefficient: 0.8301
# Epoch 185/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0954 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8488
# Epoch 185: val_loss did not improve from 0.10756
# 25/25 [==============================] - 3s 123ms/step - loss: 0.0954 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8488 - val_loss: 0.1076 - val_binary_crossentropy: 0.0452 - val_generalized_dice_coefficient: 0.8301
# Epoch 186/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0956 - binary_crossentropy: 0.0397 - generalized_dice_coefficient: 0.8484
# Epoch 186: val_loss did not improve from 0.10756
# 25/25 [==============================] - 3s 123ms/step - loss: 0.0956 - binary_crossentropy: 0.0397 - generalized_dice_coefficient: 0.8484 - val_loss: 0.1076 - val_binary_crossentropy: 0.0452 - val_generalized_dice_coefficient: 0.8301
# Epoch 187/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0957 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8483
# Epoch 187: val_loss did not improve from 0.10756
# 25/25 [==============================] - 3s 124ms/step - loss: 0.0957 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8483 - val_loss: 0.1076 - val_binary_crossentropy: 0.0453 - val_generalized_dice_coefficient: 0.8301
# Epoch 188/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0953 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8489
# Epoch 188: val_loss did not improve from 0.10756
# 25/25 [==============================] - 3s 123ms/step - loss: 0.0953 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8489 - val_loss: 0.1076 - val_binary_crossentropy: 0.0453 - val_generalized_dice_coefficient: 0.8301
# Epoch 189/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0958 - binary_crossentropy: 0.0398 - generalized_dice_coefficient: 0.8482
# Epoch 189: val_loss did not improve from 0.10756
# 25/25 [==============================] - 3s 122ms/step - loss: 0.0958 - binary_crossentropy: 0.0398 - generalized_dice_coefficient: 0.8482 - val_loss: 0.1076 - val_binary_crossentropy: 0.0453 - val_generalized_dice_coefficient: 0.8301
# Epoch 190/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0955 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8485
# Epoch 190: val_loss did not improve from 0.10756
# 25/25 [==============================] - 3s 123ms/step - loss: 0.0955 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8485 - val_loss: 0.1076 - val_binary_crossentropy: 0.0453 - val_generalized_dice_coefficient: 0.8301
# Epoch 191/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0955 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8486
# Epoch 191: val_loss did not improve from 0.10756
# 25/25 [==============================] - 3s 123ms/step - loss: 0.0955 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8486 - val_loss: 0.1076 - val_binary_crossentropy: 0.0453 - val_generalized_dice_coefficient: 0.8301
# Epoch 192/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0954 - binary_crossentropy: 0.0395 - generalized_dice_coefficient: 0.8486
# Epoch 192: val_loss did not improve from 0.10756
# 25/25 [==============================] - 3s 122ms/step - loss: 0.0954 - binary_crossentropy: 0.0395 - generalized_dice_coefficient: 0.8486 - val_loss: 0.1076 - val_binary_crossentropy: 0.0453 - val_generalized_dice_coefficient: 0.8301
# Epoch 193/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0955 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8487
# Epoch 193: val_loss did not improve from 0.10756
# 25/25 [==============================] - 3s 123ms/step - loss: 0.0955 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8487 - val_loss: 0.1076 - val_binary_crossentropy: 0.0453 - val_generalized_dice_coefficient: 0.8301
# Epoch 194/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0956 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8485
# Epoch 194: val_loss did not improve from 0.10756
# 25/25 [==============================] - 3s 123ms/step - loss: 0.0956 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8485 - val_loss: 0.1076 - val_binary_crossentropy: 0.0452 - val_generalized_dice_coefficient: 0.8301
# Epoch 195/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0954 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8487
# Epoch 195: val_loss did not improve from 0.10756
# 25/25 [==============================] - 3s 124ms/step - loss: 0.0954 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8487 - val_loss: 0.1076 - val_binary_crossentropy: 0.0452 - val_generalized_dice_coefficient: 0.8301
# Epoch 196/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0954 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8487
# Epoch 196: val_loss did not improve from 0.10756
# 25/25 [==============================] - 3s 123ms/step - loss: 0.0954 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8487 - val_loss: 0.1076 - val_binary_crossentropy: 0.0453 - val_generalized_dice_coefficient: 0.8301
# Epoch 197/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0954 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8487
# Epoch 197: val_loss did not improve from 0.10756
# 25/25 [==============================] - 3s 122ms/step - loss: 0.0954 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8487 - val_loss: 0.1076 - val_binary_crossentropy: 0.0453 - val_generalized_dice_coefficient: 0.8301
# Epoch 198/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0953 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8489
# Epoch 198: val_loss did not improve from 0.10756
# 25/25 [==============================] - 3s 123ms/step - loss: 0.0953 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8489 - val_loss: 0.1076 - val_binary_crossentropy: 0.0453 - val_generalized_dice_coefficient: 0.8301
# Epoch 199/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0955 - binary_crossentropy: 0.0395 - generalized_dice_coefficient: 0.8486
# Epoch 199: val_loss did not improve from 0.10756
# 25/25 [==============================] - 3s 122ms/step - loss: 0.0955 - binary_crossentropy: 0.0395 - generalized_dice_coefficient: 0.8486 - val_loss: 0.1076 - val_binary_crossentropy: 0.0453 - val_generalized_dice_coefficient: 0.8301
# Epoch 200/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0956 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8485
# Epoch 200: val_loss did not improve from 0.10756
# 25/25 [==============================] - 3s 122ms/step - loss: 0.0956 - binary_crossentropy: 0.0396 - generalized_dice_coefficient: 0.8485 - val_loss: 0.1076 - val_binary_crossentropy: 0.0453 - val_generalized_dice_coefficient: 0.8301

# %%
prd_img = model.predict(np.array([train_imgs[0]]))
# Out:
# 1/1 [==============================] - 1s 1s/step

# %%
plt.imshow(np.round(np.squeeze(prd_img[0])), cmap='gray_r')
plt.show()

# %%
output_img = np.round(np.squeeze(prd_img[0]))

# %%
import pickle
with open(model_summary_path, 'wb') as file:
    pickle.dump(model_history.history, file)

# %%
loss = model_history.history['loss']
val_loss = model_history.history['val_loss']

plt.figure()
plt.plot(model_history.epoch, loss, 'r', label='Training loss')
plt.plot(model_history.epoch, val_loss, 'bo', label='Validation loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss Value')
plt.ylim([0, 1])
plt.legend()
plt.show()

# %%
# 재시도시
del model
