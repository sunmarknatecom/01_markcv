# %% [markdown]
# <a href="https://colab.research.google.com/github/sunmarknatecom/01_markcv/blob/master/bonespect_train_whole_spine_11132.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from glob import glob
import numpy as np
import cv2, os, copy, shutil
import matplotlib.pyplot as plt
from PIL import Image
from random import randint

# DEEP LEARNING MODULES
import tensorflow as tf
from keras import backend as K
from keras.losses import binary_crossentropy
from keras.optimizers import Adam

from keras.layers import Input, Conv2D, MaxPooling2D, Conv2DTranspose, BatchNormalization, concatenate
from keras.models import Model
from skimage.metrics import structural_similarity as ssim

# %% [markdown]
# 1. data/inputData -> normalization
# 2. data/inputRawData --> 원래
# 3. data/labelData -> 위치보정 label

# %%
inputDataPath = sorted(glob("/content/drive/MyDrive/Bone_SPECT/data/inputData/*.npy"))
labelDataPath = sorted(glob("/content/drive/MyDrive/Bone_SPECT/data/labelData/*.npy"))

# %%
totalNum = len(inputDataPath)

# %%
for i in range(totalNum):
    tempInput = os.path.basename(inputDataPath[i])[:8]
    tempLabel = os.path.basename(labelDataPath[i])[:8]
    if tempInput != tempLabel:
        print(i)
    else:
        continue

# %%
inputObj = []
labelObj = []

for i in range(totalNum):
    tempInputObj = np.load(inputDataPath[i])
    tempInputObj = np.array(tempInputObj, dtype=np.float64)
    tempLabelObj = np.load(labelDataPath[i])
    tempLabelObj = np.array(tempLabelObj, dtype=np.uint16)
    inputObj.append(tempInputObj)
    labelObj.append(tempLabelObj)

# %%
def padObj(srcObj, targetSize):
    '''
    inputs: source array(images, labels), and wanted height size(int, ex: 1024))
    return: destinate array
    '''
    io_x, ioy = np.shape(srcObj)
    if io_x != targetSize:
        diffIOx = targetSize - io_x
        zeroPadding = np.zeros((diffIOx,256))
        dstObj = np.vstack([srcObj,zeroPadding])
    else:
        dstObj = srcObj
    return dstObj

# %%
MAX_SIZE = 512

# %%
if MAX_SIZE == 1024:
    train_imgs = []
    train_lbls = []
    for i in range(totalNum):
        train_imgs.append(padObj(inputObj[i],MAX_SIZE))
        train_lbls.append(padObj(labelObj[i],MAX_SIZE))
elif MAX_SIZE == 512:
    train_imgs = []
    train_lbls = []
    for i in range(totalNum):
        train_imgs.append(inputObj[i][:512,:])
        train_lbls.append(labelObj[i][:512,:])

# %%
temp_train_imgs = np.array(train_imgs)
temp_train_lbls = np.array(train_lbls)

# %%
# 0: BG, 1: C, 2: T, 3: L
temp_train_lbls = np.where((temp_train_lbls>=2)&(temp_train_lbls<14),2,temp_train_lbls)
temp_train_lbls[temp_train_lbls>13]=3

# %%
# whole spine
temp_train_lbls[temp_train_lbls >= 1] = 1

# %%
split_num = 800

# %%
train_imgs = temp_train_imgs[:split_num,...]
valid_imgs = temp_train_imgs[split_num:,...]
train_msks = temp_train_lbls[:split_num,...]
valid_msks = temp_train_lbls[split_num:,...]

# %%
train_imgs = np.array(train_imgs, dtype=np.float32)
train_msks = np.array(train_msks, dtype=np.float32)
valid_imgs = np.array(valid_imgs, dtype=np.float32)
valid_msks = np.array(valid_msks, dtype=np.float32)

train_msks = np.reshape(train_msks, (*train_msks.shape, 1))
valid_msks = np.reshape(valid_msks, (*valid_msks.shape, 1))

train_dataset = tf.data.Dataset.from_tensor_slices((train_imgs, train_msks))
test_dataset = tf.data.Dataset.from_tensor_slices((valid_imgs, valid_msks))

# %%
# %matplotlib inline

rand_num = randint(1,len(train_imgs))

fig = plt.figure(0, figsize=(20, 20))
fig.add_subplot(1, 2, 1)
plt.imshow(train_imgs[rand_num]*13, cmap='gray_r')
fig.add_subplot(1, 2, 2)
plt.imshow(np.squeeze(train_msks[rand_num]), cmap='gray_r')

# %% [markdown]
# # Construct the model

# %%
inputs = Input((MAX_SIZE, 256, 1))
bnorm1 = BatchNormalization()(inputs)
conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(bnorm1)
conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv1)
pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(pool1)
conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv2)
pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(pool2)
conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv3)
pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(pool3)
conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv4)
pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)

conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(pool4)
conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(conv5)

up6 = concatenate([Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(conv5), conv4], axis=3)
conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(up6)
conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv6)

up7 = concatenate([Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(conv6), conv3], axis=3)
conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(up7)
conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv7)

up8 = concatenate([Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(conv7), conv2], axis=3)
conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(up8)
conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv8)

up9 = concatenate([Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(conv8), conv1], axis=3)
conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(up9)
conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv9)

conv10 = Conv2D(1, (1, 1), activation='sigmoid')(conv9)

model = Model(inputs=[inputs], outputs=[conv10])

# %%
import tensorflow as tf
import keras.backend as K
from keras.losses import binary_crossentropy

beta = 0.25
alpha = 0.25
gamma = 2
epsilon = 1e-5
smooth = 1

def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + K.epsilon()) / (K.sum(y_true_f) + K.sum(y_pred_f) + K.epsilon())

def generalized_dice_coefficient(y_true, y_pred):
    smooth = 1.
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    score = (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return score

def dice_loss(y_true, y_pred):
    loss = 1 - generalized_dice_coefficient(y_true, y_pred)
    return loss

def bce_dice_loss(y_true, y_pred):
    loss = binary_crossentropy(y_true, y_pred) + dice_loss(y_true, y_pred)
    return loss / 2.0

# %%
initial_learning_rate = 9e-6

lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate,
    decay_steps=100,
    decay_rate=0.96,
    staircase=True)

callbacks = [tf.keras.callbacks.ModelCheckpoint(
    filepath="/content/drive/MyDrive/Bone_SPECT/models/mymodel_{epoch}.h5",
    save_best_only=True,
    monitor='val_loss',
    verbose=1)]

# %%
model.compile(Adam(learning_rate=lr_schedule), bce_dice_loss, metrics=[binary_crossentropy, generalized_dice_coefficient])

# %%
model_history = model.fit(train_imgs, train_msks, batch_size=10, epochs=200, callbacks=callbacks, validation_data=(valid_imgs, valid_msks))
# Out:
# Epoch 1/200
# 80/80 [==============================] - ETA: 0s - loss: 0.8089 - binary_crossentropy: 0.6894 - generalized_dice_coefficient: 0.0716
# Epoch 1: val_loss improved from inf to 0.81001, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_1.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 80/80 [==============================] - 29s 127ms/step - loss: 0.8089 - binary_crossentropy: 0.6894 - generalized_dice_coefficient: 0.0716 - val_loss: 0.8100 - val_binary_crossentropy: 0.6898 - val_generalized_dice_coefficient: 0.0698
# Epoch 2/200
# 80/80 [==============================] - ETA: 0s - loss: 0.8009 - binary_crossentropy: 0.6700 - generalized_dice_coefficient: 0.0683
# Epoch 2: val_loss improved from 0.81001 to 0.80394, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_2.h5
# 80/80 [==============================] - 9s 108ms/step - loss: 0.8009 - binary_crossentropy: 0.6700 - generalized_dice_coefficient: 0.0683 - val_loss: 0.8039 - val_binary_crossentropy: 0.6766 - val_generalized_dice_coefficient: 0.0687
# Epoch 3/200
# 80/80 [==============================] - ETA: 0s - loss: 0.6631 - binary_crossentropy: 0.3685 - generalized_dice_coefficient: 0.0423
# Epoch 3: val_loss improved from 0.80394 to 0.61510, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_3.h5
# 80/80 [==============================] - 9s 108ms/step - loss: 0.6631 - binary_crossentropy: 0.3685 - generalized_dice_coefficient: 0.0423 - val_loss: 0.6151 - val_binary_crossentropy: 0.3051 - val_generalized_dice_coefficient: 0.0749
# Epoch 4/200
# 80/80 [==============================] - ETA: 0s - loss: 0.4464 - binary_crossentropy: 0.1274 - generalized_dice_coefficient: 0.2345
# Epoch 4: val_loss improved from 0.61510 to 0.41755, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_4.h5
# 80/80 [==============================] - 9s 109ms/step - loss: 0.4464 - binary_crossentropy: 0.1274 - generalized_dice_coefficient: 0.2345 - val_loss: 0.4175 - val_binary_crossentropy: 0.1095 - val_generalized_dice_coefficient: 0.2746
# Epoch 5/200
# 80/80 [==============================] - ETA: 0s - loss: 0.2784 - binary_crossentropy: 0.0747 - generalized_dice_coefficient: 0.5180
# Epoch 5: val_loss improved from 0.41755 to 0.26520, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_5.h5
# 80/80 [==============================] - 9s 108ms/step - loss: 0.2784 - binary_crossentropy: 0.0747 - generalized_dice_coefficient: 0.5180 - val_loss: 0.2652 - val_binary_crossentropy: 0.0549 - val_generalized_dice_coefficient: 0.5248
# Epoch 6/200
# 80/80 [==============================] - ETA: 0s - loss: 0.1984 - binary_crossentropy: 0.0535 - generalized_dice_coefficient: 0.6567
# Epoch 6: val_loss improved from 0.26520 to 0.17459, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_6.h5
# 80/80 [==============================] - 9s 109ms/step - loss: 0.1984 - binary_crossentropy: 0.0535 - generalized_dice_coefficient: 0.6567 - val_loss: 0.1746 - val_binary_crossentropy: 0.0434 - val_generalized_dice_coefficient: 0.6946
# Epoch 7/200
# 80/80 [==============================] - ETA: 0s - loss: 0.1473 - binary_crossentropy: 0.0576 - generalized_dice_coefficient: 0.7630
# Epoch 7: val_loss improved from 0.17459 to 0.13938, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_7.h5
# 80/80 [==============================] - 9s 108ms/step - loss: 0.1473 - binary_crossentropy: 0.0576 - generalized_dice_coefficient: 0.7630 - val_loss: 0.1394 - val_binary_crossentropy: 0.0537 - val_generalized_dice_coefficient: 0.7753
# Epoch 8/200
# 80/80 [==============================] - ETA: 0s - loss: 0.1383 - binary_crossentropy: 0.0616 - generalized_dice_coefficient: 0.7849
# Epoch 8: val_loss improved from 0.13938 to 0.12926, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_8.h5
# 80/80 [==============================] - 9s 109ms/step - loss: 0.1383 - binary_crossentropy: 0.0616 - generalized_dice_coefficient: 0.7849 - val_loss: 0.1293 - val_binary_crossentropy: 0.0490 - val_generalized_dice_coefficient: 0.7908
# Epoch 9/200
# 80/80 [==============================] - ETA: 0s - loss: 0.1234 - binary_crossentropy: 0.0519 - generalized_dice_coefficient: 0.8051
# Epoch 9: val_loss improved from 0.12926 to 0.12791, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_9.h5
# 80/80 [==============================] - 9s 109ms/step - loss: 0.1234 - binary_crossentropy: 0.0519 - generalized_dice_coefficient: 0.8051 - val_loss: 0.1279 - val_binary_crossentropy: 0.0572 - val_generalized_dice_coefficient: 0.8015
# Epoch 10/200
# 80/80 [==============================] - ETA: 0s - loss: 0.1178 - binary_crossentropy: 0.0489 - generalized_dice_coefficient: 0.8132
# Epoch 10: val_loss improved from 0.12791 to 0.12720, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_10.h5
# 80/80 [==============================] - 9s 109ms/step - loss: 0.1178 - binary_crossentropy: 0.0489 - generalized_dice_coefficient: 0.8132 - val_loss: 0.1272 - val_binary_crossentropy: 0.0571 - val_generalized_dice_coefficient: 0.8030
# Epoch 11/200
# 80/80 [==============================] - ETA: 0s - loss: 0.1162 - binary_crossentropy: 0.0487 - generalized_dice_coefficient: 0.8163
# Epoch 11: val_loss improved from 0.12720 to 0.11496, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_11.h5
# 80/80 [==============================] - 9s 113ms/step - loss: 0.1162 - binary_crossentropy: 0.0487 - generalized_dice_coefficient: 0.8163 - val_loss: 0.1150 - val_binary_crossentropy: 0.0477 - val_generalized_dice_coefficient: 0.8181
# Epoch 12/200
# 80/80 [==============================] - ETA: 0s - loss: 0.1131 - binary_crossentropy: 0.0464 - generalized_dice_coefficient: 0.8202
# Epoch 12: val_loss did not improve from 0.11496
# 80/80 [==============================] - 8s 105ms/step - loss: 0.1131 - binary_crossentropy: 0.0464 - generalized_dice_coefficient: 0.8202 - val_loss: 0.1209 - val_binary_crossentropy: 0.0506 - val_generalized_dice_coefficient: 0.8089
# Epoch 13/200
# 80/80 [==============================] - ETA: 0s - loss: 0.1141 - binary_crossentropy: 0.0467 - generalized_dice_coefficient: 0.8185
# Epoch 13: val_loss improved from 0.11496 to 0.11211, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_13.h5
# 80/80 [==============================] - 9s 109ms/step - loss: 0.1141 - binary_crossentropy: 0.0467 - generalized_dice_coefficient: 0.8185 - val_loss: 0.1121 - val_binary_crossentropy: 0.0454 - val_generalized_dice_coefficient: 0.8214
# Epoch 14/200
# 80/80 [==============================] - ETA: 0s - loss: 0.1129 - binary_crossentropy: 0.0469 - generalized_dice_coefficient: 0.8211
# Epoch 14: val_loss did not improve from 0.11211
# 80/80 [==============================] - 8s 104ms/step - loss: 0.1129 - binary_crossentropy: 0.0469 - generalized_dice_coefficient: 0.8211 - val_loss: 0.1132 - val_binary_crossentropy: 0.0480 - val_generalized_dice_coefficient: 0.8218
# Epoch 15/200
# 80/80 [==============================] - ETA: 0s - loss: 0.1099 - binary_crossentropy: 0.0442 - generalized_dice_coefficient: 0.8245
# Epoch 15: val_loss did not improve from 0.11211
# 80/80 [==============================] - 8s 104ms/step - loss: 0.1099 - binary_crossentropy: 0.0442 - generalized_dice_coefficient: 0.8245 - val_loss: 0.1302 - val_binary_crossentropy: 0.0584 - val_generalized_dice_coefficient: 0.7981
# Epoch 16/200
# 80/80 [==============================] - ETA: 0s - loss: 0.1139 - binary_crossentropy: 0.0463 - generalized_dice_coefficient: 0.8186
# Epoch 16: val_loss improved from 0.11211 to 0.11071, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_16.h5
# 80/80 [==============================] - 9s 108ms/step - loss: 0.1139 - binary_crossentropy: 0.0463 - generalized_dice_coefficient: 0.8186 - val_loss: 0.1107 - val_binary_crossentropy: 0.0454 - val_generalized_dice_coefficient: 0.8243
# Epoch 17/200
# 80/80 [==============================] - ETA: 0s - loss: 0.1107 - binary_crossentropy: 0.0452 - generalized_dice_coefficient: 0.8238
# Epoch 17: val_loss did not improve from 0.11071
# 80/80 [==============================] - 8s 105ms/step - loss: 0.1107 - binary_crossentropy: 0.0452 - generalized_dice_coefficient: 0.8238 - val_loss: 0.1108 - val_binary_crossentropy: 0.0454 - val_generalized_dice_coefficient: 0.8240
# Epoch 18/200
# 80/80 [==============================] - ETA: 0s - loss: 0.1087 - binary_crossentropy: 0.0442 - generalized_dice_coefficient: 0.8269
# Epoch 18: val_loss improved from 0.11071 to 0.10642, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_18.h5
# 80/80 [==============================] - 9s 109ms/step - loss: 0.1087 - binary_crossentropy: 0.0442 - generalized_dice_coefficient: 0.8269 - val_loss: 0.1064 - val_binary_crossentropy: 0.0428 - val_generalized_dice_coefficient: 0.8302
# Epoch 19/200
# 80/80 [==============================] - ETA: 0s - loss: 0.1123 - binary_crossentropy: 0.0463 - generalized_dice_coefficient: 0.8217
# Epoch 19: val_loss did not improve from 0.10642
# 80/80 [==============================] - 8s 105ms/step - loss: 0.1123 - binary_crossentropy: 0.0463 - generalized_dice_coefficient: 0.8217 - val_loss: 0.1083 - val_binary_crossentropy: 0.0435 - val_generalized_dice_coefficient: 0.8271
# Epoch 20/200
# 80/80 [==============================] - ETA: 0s - loss: 0.1044 - binary_crossentropy: 0.0419 - generalized_dice_coefficient: 0.8331
# Epoch 20: val_loss did not improve from 0.10642
# 80/80 [==============================] - 8s 105ms/step - loss: 0.1044 - binary_crossentropy: 0.0419 - generalized_dice_coefficient: 0.8331 - val_loss: 0.1160 - val_binary_crossentropy: 0.0497 - val_generalized_dice_coefficient: 0.8178
# Epoch 21/200
# 80/80 [==============================] - ETA: 0s - loss: 0.1066 - binary_crossentropy: 0.0433 - generalized_dice_coefficient: 0.8301
# Epoch 21: val_loss did not improve from 0.10642
# 80/80 [==============================] - 8s 104ms/step - loss: 0.1066 - binary_crossentropy: 0.0433 - generalized_dice_coefficient: 0.8301 - val_loss: 0.1065 - val_binary_crossentropy: 0.0435 - val_generalized_dice_coefficient: 0.8308
# Epoch 22/200
# 80/80 [==============================] - ETA: 0s - loss: 0.1039 - binary_crossentropy: 0.0424 - generalized_dice_coefficient: 0.8346
# Epoch 22: val_loss improved from 0.10642 to 0.10355, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_22.h5
# 80/80 [==============================] - 9s 109ms/step - loss: 0.1039 - binary_crossentropy: 0.0424 - generalized_dice_coefficient: 0.8346 - val_loss: 0.1035 - val_binary_crossentropy: 0.0406 - val_generalized_dice_coefficient: 0.8337
# Epoch 23/200
# 80/80 [==============================] - ETA: 0s - loss: 0.1035 - binary_crossentropy: 0.0416 - generalized_dice_coefficient: 0.8345
# Epoch 23: val_loss did not improve from 0.10355
# 80/80 [==============================] - 8s 104ms/step - loss: 0.1035 - binary_crossentropy: 0.0416 - generalized_dice_coefficient: 0.8345 - val_loss: 0.1036 - val_binary_crossentropy: 0.0422 - val_generalized_dice_coefficient: 0.8352
# Epoch 24/200
# 80/80 [==============================] - ETA: 0s - loss: 0.1023 - binary_crossentropy: 0.0411 - generalized_dice_coefficient: 0.8366
# Epoch 24: val_loss improved from 0.10355 to 0.10108, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_24.h5
# 80/80 [==============================] - 9s 108ms/step - loss: 0.1023 - binary_crossentropy: 0.0411 - generalized_dice_coefficient: 0.8366 - val_loss: 0.1011 - val_binary_crossentropy: 0.0404 - val_generalized_dice_coefficient: 0.8385
# Epoch 25/200
# 80/80 [==============================] - ETA: 0s - loss: 0.1028 - binary_crossentropy: 0.0415 - generalized_dice_coefficient: 0.8359
# Epoch 25: val_loss did not improve from 0.10108
# 80/80 [==============================] - 8s 104ms/step - loss: 0.1028 - binary_crossentropy: 0.0415 - generalized_dice_coefficient: 0.8359 - val_loss: 0.1042 - val_binary_crossentropy: 0.0427 - val_generalized_dice_coefficient: 0.8345
# Epoch 26/200
# 80/80 [==============================] - ETA: 0s - loss: 0.1030 - binary_crossentropy: 0.0417 - generalized_dice_coefficient: 0.8357
# Epoch 26: val_loss did not improve from 0.10108
# 80/80 [==============================] - 8s 105ms/step - loss: 0.1030 - binary_crossentropy: 0.0417 - generalized_dice_coefficient: 0.8357 - val_loss: 0.1038 - val_binary_crossentropy: 0.0419 - val_generalized_dice_coefficient: 0.8346
# Epoch 27/200
# 80/80 [==============================] - ETA: 0s - loss: 0.1017 - binary_crossentropy: 0.0408 - generalized_dice_coefficient: 0.8374
# Epoch 27: val_loss improved from 0.10108 to 0.10028, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_27.h5
# 80/80 [==============================] - 9s 109ms/step - loss: 0.1017 - binary_crossentropy: 0.0408 - generalized_dice_coefficient: 0.8374 - val_loss: 0.1003 - val_binary_crossentropy: 0.0397 - val_generalized_dice_coefficient: 0.8394
# Epoch 28/200
# 80/80 [==============================] - ETA: 0s - loss: 0.1083 - binary_crossentropy: 0.0452 - generalized_dice_coefficient: 0.8287
# Epoch 28: val_loss did not improve from 0.10028
# 80/80 [==============================] - 8s 104ms/step - loss: 0.1083 - binary_crossentropy: 0.0452 - generalized_dice_coefficient: 0.8287 - val_loss: 0.1109 - val_binary_crossentropy: 0.0465 - val_generalized_dice_coefficient: 0.8249
# Epoch 29/200
# 80/80 [==============================] - ETA: 0s - loss: 0.1029 - binary_crossentropy: 0.0407 - generalized_dice_coefficient: 0.8350
# Epoch 29: val_loss did not improve from 0.10028
# 80/80 [==============================] - 8s 105ms/step - loss: 0.1029 - binary_crossentropy: 0.0407 - generalized_dice_coefficient: 0.8350 - val_loss: 0.1022 - val_binary_crossentropy: 0.0414 - val_generalized_dice_coefficient: 0.8373
# Epoch 30/200
# 80/80 [==============================] - ETA: 0s - loss: 0.1011 - binary_crossentropy: 0.0407 - generalized_dice_coefficient: 0.8385
# Epoch 30: val_loss did not improve from 0.10028
# 80/80 [==============================] - 8s 104ms/step - loss: 0.1011 - binary_crossentropy: 0.0407 - generalized_dice_coefficient: 0.8385 - val_loss: 0.1046 - val_binary_crossentropy: 0.0435 - val_generalized_dice_coefficient: 0.8344
# Epoch 31/200
# 80/80 [==============================] - ETA: 0s - loss: 0.1006 - binary_crossentropy: 0.0403 - generalized_dice_coefficient: 0.8390
# Epoch 31: val_loss did not improve from 0.10028
# 80/80 [==============================] - 8s 104ms/step - loss: 0.1006 - binary_crossentropy: 0.0403 - generalized_dice_coefficient: 0.8390 - val_loss: 0.1183 - val_binary_crossentropy: 0.0524 - val_generalized_dice_coefficient: 0.8157
# Epoch 32/200
# 80/80 [==============================] - ETA: 0s - loss: 0.1040 - binary_crossentropy: 0.0427 - generalized_dice_coefficient: 0.8347
# Epoch 32: val_loss did not improve from 0.10028
# 80/80 [==============================] - 8s 105ms/step - loss: 0.1040 - binary_crossentropy: 0.0427 - generalized_dice_coefficient: 0.8347 - val_loss: 0.1057 - val_binary_crossentropy: 0.0436 - val_generalized_dice_coefficient: 0.8324
# Epoch 33/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0996 - binary_crossentropy: 0.0398 - generalized_dice_coefficient: 0.8406
# Epoch 33: val_loss did not improve from 0.10028
# 80/80 [==============================] - 8s 104ms/step - loss: 0.0996 - binary_crossentropy: 0.0398 - generalized_dice_coefficient: 0.8406 - val_loss: 0.1005 - val_binary_crossentropy: 0.0403 - val_generalized_dice_coefficient: 0.8394
# Epoch 34/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0993 - binary_crossentropy: 0.0399 - generalized_dice_coefficient: 0.8414
# Epoch 34: val_loss did not improve from 0.10028
# 80/80 [==============================] - 8s 104ms/step - loss: 0.0993 - binary_crossentropy: 0.0399 - generalized_dice_coefficient: 0.8414 - val_loss: 0.1039 - val_binary_crossentropy: 0.0423 - val_generalized_dice_coefficient: 0.8346
# Epoch 35/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0989 - binary_crossentropy: 0.0395 - generalized_dice_coefficient: 0.8417
# Epoch 35: val_loss improved from 0.10028 to 0.09743, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_35.h5
# 80/80 [==============================] - 9s 109ms/step - loss: 0.0989 - binary_crossentropy: 0.0395 - generalized_dice_coefficient: 0.8417 - val_loss: 0.0974 - val_binary_crossentropy: 0.0389 - val_generalized_dice_coefficient: 0.8443
# Epoch 36/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0983 - binary_crossentropy: 0.0394 - generalized_dice_coefficient: 0.8429
# Epoch 36: val_loss did not improve from 0.09743
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0983 - binary_crossentropy: 0.0394 - generalized_dice_coefficient: 0.8429 - val_loss: 0.0990 - val_binary_crossentropy: 0.0391 - val_generalized_dice_coefficient: 0.8413
# Epoch 37/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0992 - binary_crossentropy: 0.0395 - generalized_dice_coefficient: 0.8412
# Epoch 37: val_loss did not improve from 0.09743
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0992 - binary_crossentropy: 0.0395 - generalized_dice_coefficient: 0.8412 - val_loss: 0.1242 - val_binary_crossentropy: 0.0541 - val_generalized_dice_coefficient: 0.8059
# Epoch 38/200
# 80/80 [==============================] - ETA: 0s - loss: 0.1016 - binary_crossentropy: 0.0413 - generalized_dice_coefficient: 0.8380
# Epoch 38: val_loss did not improve from 0.09743
# 80/80 [==============================] - 8s 104ms/step - loss: 0.1016 - binary_crossentropy: 0.0413 - generalized_dice_coefficient: 0.8380 - val_loss: 0.0990 - val_binary_crossentropy: 0.0388 - val_generalized_dice_coefficient: 0.8411
# Epoch 39/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0973 - binary_crossentropy: 0.0387 - generalized_dice_coefficient: 0.8441
# Epoch 39: val_loss did not improve from 0.09743
# 80/80 [==============================] - 8s 104ms/step - loss: 0.0973 - binary_crossentropy: 0.0387 - generalized_dice_coefficient: 0.8441 - val_loss: 0.0980 - val_binary_crossentropy: 0.0384 - val_generalized_dice_coefficient: 0.8425
# Epoch 40/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0980 - binary_crossentropy: 0.0391 - generalized_dice_coefficient: 0.8432
# Epoch 40: val_loss improved from 0.09743 to 0.09696, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_40.h5
# 80/80 [==============================] - 9s 108ms/step - loss: 0.0980 - binary_crossentropy: 0.0391 - generalized_dice_coefficient: 0.8432 - val_loss: 0.0970 - val_binary_crossentropy: 0.0388 - val_generalized_dice_coefficient: 0.8451
# Epoch 41/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0983 - binary_crossentropy: 0.0395 - generalized_dice_coefficient: 0.8429
# Epoch 41: val_loss did not improve from 0.09696
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0983 - binary_crossentropy: 0.0395 - generalized_dice_coefficient: 0.8429 - val_loss: 0.0973 - val_binary_crossentropy: 0.0385 - val_generalized_dice_coefficient: 0.8441
# Epoch 42/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0986 - binary_crossentropy: 0.0394 - generalized_dice_coefficient: 0.8423
# Epoch 42: val_loss did not improve from 0.09696
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0986 - binary_crossentropy: 0.0394 - generalized_dice_coefficient: 0.8423 - val_loss: 0.0972 - val_binary_crossentropy: 0.0385 - val_generalized_dice_coefficient: 0.8443
# Epoch 43/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0971 - binary_crossentropy: 0.0387 - generalized_dice_coefficient: 0.8445
# Epoch 43: val_loss did not improve from 0.09696
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0971 - binary_crossentropy: 0.0387 - generalized_dice_coefficient: 0.8445 - val_loss: 0.1010 - val_binary_crossentropy: 0.0406 - val_generalized_dice_coefficient: 0.8389
# Epoch 44/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0964 - binary_crossentropy: 0.0387 - generalized_dice_coefficient: 0.8460
# Epoch 44: val_loss improved from 0.09696 to 0.09524, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_44.h5
# 80/80 [==============================] - 9s 108ms/step - loss: 0.0964 - binary_crossentropy: 0.0387 - generalized_dice_coefficient: 0.8460 - val_loss: 0.0952 - val_binary_crossentropy: 0.0377 - val_generalized_dice_coefficient: 0.8474
# Epoch 45/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0959 - binary_crossentropy: 0.0382 - generalized_dice_coefficient: 0.8464
# Epoch 45: val_loss did not improve from 0.09524
# 80/80 [==============================] - 8s 104ms/step - loss: 0.0959 - binary_crossentropy: 0.0382 - generalized_dice_coefficient: 0.8464 - val_loss: 0.0955 - val_binary_crossentropy: 0.0380 - val_generalized_dice_coefficient: 0.8471
# Epoch 46/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0996 - binary_crossentropy: 0.0404 - generalized_dice_coefficient: 0.8411
# Epoch 46: val_loss did not improve from 0.09524
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0996 - binary_crossentropy: 0.0404 - generalized_dice_coefficient: 0.8411 - val_loss: 0.1066 - val_binary_crossentropy: 0.0449 - val_generalized_dice_coefficient: 0.8318
# Epoch 47/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0970 - binary_crossentropy: 0.0387 - generalized_dice_coefficient: 0.8447
# Epoch 47: val_loss did not improve from 0.09524
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0970 - binary_crossentropy: 0.0387 - generalized_dice_coefficient: 0.8447 - val_loss: 0.0967 - val_binary_crossentropy: 0.0374 - val_generalized_dice_coefficient: 0.8442
# Epoch 48/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0986 - binary_crossentropy: 0.0397 - generalized_dice_coefficient: 0.8425
# Epoch 48: val_loss did not improve from 0.09524
# 80/80 [==============================] - 8s 104ms/step - loss: 0.0986 - binary_crossentropy: 0.0397 - generalized_dice_coefficient: 0.8425 - val_loss: 0.1080 - val_binary_crossentropy: 0.0461 - val_generalized_dice_coefficient: 0.8302
# Epoch 49/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0964 - binary_crossentropy: 0.0383 - generalized_dice_coefficient: 0.8456
# Epoch 49: val_loss did not improve from 0.09524
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0964 - binary_crossentropy: 0.0383 - generalized_dice_coefficient: 0.8456 - val_loss: 0.0953 - val_binary_crossentropy: 0.0373 - val_generalized_dice_coefficient: 0.8469
# Epoch 50/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0956 - binary_crossentropy: 0.0380 - generalized_dice_coefficient: 0.8469
# Epoch 50: val_loss did not improve from 0.09524
# 80/80 [==============================] - 8s 104ms/step - loss: 0.0956 - binary_crossentropy: 0.0380 - generalized_dice_coefficient: 0.8469 - val_loss: 0.0977 - val_binary_crossentropy: 0.0391 - val_generalized_dice_coefficient: 0.8438
# Epoch 51/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0957 - binary_crossentropy: 0.0382 - generalized_dice_coefficient: 0.8469
# Epoch 51: val_loss did not improve from 0.09524
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0957 - binary_crossentropy: 0.0382 - generalized_dice_coefficient: 0.8469 - val_loss: 0.0961 - val_binary_crossentropy: 0.0382 - val_generalized_dice_coefficient: 0.8461
# Epoch 52/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0974 - binary_crossentropy: 0.0390 - generalized_dice_coefficient: 0.8442
# Epoch 52: val_loss did not improve from 0.09524
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0974 - binary_crossentropy: 0.0390 - generalized_dice_coefficient: 0.8442 - val_loss: 0.1109 - val_binary_crossentropy: 0.0504 - val_generalized_dice_coefficient: 0.8287
# Epoch 53/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0973 - binary_crossentropy: 0.0391 - generalized_dice_coefficient: 0.8445
# Epoch 53: val_loss did not improve from 0.09524
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0973 - binary_crossentropy: 0.0391 - generalized_dice_coefficient: 0.8445 - val_loss: 0.0975 - val_binary_crossentropy: 0.0383 - val_generalized_dice_coefficient: 0.8436
# Epoch 54/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0954 - binary_crossentropy: 0.0379 - generalized_dice_coefficient: 0.8472
# Epoch 54: val_loss did not improve from 0.09524
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0954 - binary_crossentropy: 0.0379 - generalized_dice_coefficient: 0.8472 - val_loss: 0.0954 - val_binary_crossentropy: 0.0376 - val_generalized_dice_coefficient: 0.8469
# Epoch 55/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0945 - binary_crossentropy: 0.0376 - generalized_dice_coefficient: 0.8485
# Epoch 55: val_loss did not improve from 0.09524
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0945 - binary_crossentropy: 0.0376 - generalized_dice_coefficient: 0.8485 - val_loss: 0.0964 - val_binary_crossentropy: 0.0379 - val_generalized_dice_coefficient: 0.8454
# Epoch 56/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0951 - binary_crossentropy: 0.0378 - generalized_dice_coefficient: 0.8476
# Epoch 56: val_loss did not improve from 0.09524
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0951 - binary_crossentropy: 0.0378 - generalized_dice_coefficient: 0.8476 - val_loss: 0.0961 - val_binary_crossentropy: 0.0380 - val_generalized_dice_coefficient: 0.8460
# Epoch 57/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0945 - binary_crossentropy: 0.0375 - generalized_dice_coefficient: 0.8485
# Epoch 57: val_loss improved from 0.09524 to 0.09427, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_57.h5
# 80/80 [==============================] - 9s 108ms/step - loss: 0.0945 - binary_crossentropy: 0.0375 - generalized_dice_coefficient: 0.8485 - val_loss: 0.0943 - val_binary_crossentropy: 0.0379 - val_generalized_dice_coefficient: 0.8496
# Epoch 58/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0948 - binary_crossentropy: 0.0377 - generalized_dice_coefficient: 0.8480
# Epoch 58: val_loss improved from 0.09427 to 0.09422, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_58.h5
# 80/80 [==============================] - 9s 109ms/step - loss: 0.0948 - binary_crossentropy: 0.0377 - generalized_dice_coefficient: 0.8480 - val_loss: 0.0942 - val_binary_crossentropy: 0.0370 - val_generalized_dice_coefficient: 0.8487
# Epoch 59/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0948 - binary_crossentropy: 0.0376 - generalized_dice_coefficient: 0.8480
# Epoch 59: val_loss did not improve from 0.09422
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0948 - binary_crossentropy: 0.0376 - generalized_dice_coefficient: 0.8480 - val_loss: 0.0958 - val_binary_crossentropy: 0.0374 - val_generalized_dice_coefficient: 0.8459
# Epoch 60/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0940 - binary_crossentropy: 0.0373 - generalized_dice_coefficient: 0.8493
# Epoch 60: val_loss did not improve from 0.09422
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0940 - binary_crossentropy: 0.0373 - generalized_dice_coefficient: 0.8493 - val_loss: 0.0944 - val_binary_crossentropy: 0.0375 - val_generalized_dice_coefficient: 0.8490
# Epoch 61/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0940 - binary_crossentropy: 0.0374 - generalized_dice_coefficient: 0.8495
# Epoch 61: val_loss improved from 0.09422 to 0.09396, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_61.h5
# 80/80 [==============================] - 9s 109ms/step - loss: 0.0940 - binary_crossentropy: 0.0374 - generalized_dice_coefficient: 0.8495 - val_loss: 0.0940 - val_binary_crossentropy: 0.0366 - val_generalized_dice_coefficient: 0.8489
# Epoch 62/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0945 - binary_crossentropy: 0.0375 - generalized_dice_coefficient: 0.8485
# Epoch 62: val_loss did not improve from 0.09396
# 80/80 [==============================] - 8s 104ms/step - loss: 0.0945 - binary_crossentropy: 0.0375 - generalized_dice_coefficient: 0.8485 - val_loss: 0.0997 - val_binary_crossentropy: 0.0398 - val_generalized_dice_coefficient: 0.8407
# Epoch 63/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0947 - binary_crossentropy: 0.0377 - generalized_dice_coefficient: 0.8483
# Epoch 63: val_loss improved from 0.09396 to 0.09306, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_63.h5
# 80/80 [==============================] - 9s 109ms/step - loss: 0.0947 - binary_crossentropy: 0.0377 - generalized_dice_coefficient: 0.8483 - val_loss: 0.0931 - val_binary_crossentropy: 0.0375 - val_generalized_dice_coefficient: 0.8516
# Epoch 64/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0939 - binary_crossentropy: 0.0374 - generalized_dice_coefficient: 0.8496
# Epoch 64: val_loss improved from 0.09306 to 0.09249, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_64.h5
# 80/80 [==============================] - 9s 108ms/step - loss: 0.0939 - binary_crossentropy: 0.0374 - generalized_dice_coefficient: 0.8496 - val_loss: 0.0925 - val_binary_crossentropy: 0.0362 - val_generalized_dice_coefficient: 0.8514
# Epoch 65/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0936 - binary_crossentropy: 0.0371 - generalized_dice_coefficient: 0.8498
# Epoch 65: val_loss improved from 0.09249 to 0.09242, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_65.h5
# 80/80 [==============================] - 9s 109ms/step - loss: 0.0936 - binary_crossentropy: 0.0371 - generalized_dice_coefficient: 0.8498 - val_loss: 0.0924 - val_binary_crossentropy: 0.0367 - val_generalized_dice_coefficient: 0.8520
# Epoch 66/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0938 - binary_crossentropy: 0.0373 - generalized_dice_coefficient: 0.8497
# Epoch 66: val_loss improved from 0.09242 to 0.09215, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_66.h5
# 80/80 [==============================] - 9s 108ms/step - loss: 0.0938 - binary_crossentropy: 0.0373 - generalized_dice_coefficient: 0.8497 - val_loss: 0.0922 - val_binary_crossentropy: 0.0364 - val_generalized_dice_coefficient: 0.8523
# Epoch 67/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0938 - binary_crossentropy: 0.0372 - generalized_dice_coefficient: 0.8497
# Epoch 67: val_loss did not improve from 0.09215
# 80/80 [==============================] - 8s 104ms/step - loss: 0.0938 - binary_crossentropy: 0.0372 - generalized_dice_coefficient: 0.8497 - val_loss: 0.0936 - val_binary_crossentropy: 0.0366 - val_generalized_dice_coefficient: 0.8495
# Epoch 68/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0940 - binary_crossentropy: 0.0375 - generalized_dice_coefficient: 0.8494
# Epoch 68: val_loss did not improve from 0.09215
# 80/80 [==============================] - 8s 104ms/step - loss: 0.0940 - binary_crossentropy: 0.0375 - generalized_dice_coefficient: 0.8494 - val_loss: 0.0929 - val_binary_crossentropy: 0.0362 - val_generalized_dice_coefficient: 0.8506
# Epoch 69/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0933 - binary_crossentropy: 0.0371 - generalized_dice_coefficient: 0.8505
# Epoch 69: val_loss improved from 0.09215 to 0.09186, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_69.h5
# 80/80 [==============================] - 9s 109ms/step - loss: 0.0933 - binary_crossentropy: 0.0371 - generalized_dice_coefficient: 0.8505 - val_loss: 0.0919 - val_binary_crossentropy: 0.0366 - val_generalized_dice_coefficient: 0.8530
# Epoch 70/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0934 - binary_crossentropy: 0.0371 - generalized_dice_coefficient: 0.8502
# Epoch 70: val_loss did not improve from 0.09186
# 80/80 [==============================] - 8s 104ms/step - loss: 0.0934 - binary_crossentropy: 0.0371 - generalized_dice_coefficient: 0.8502 - val_loss: 0.0922 - val_binary_crossentropy: 0.0364 - val_generalized_dice_coefficient: 0.8522
# Epoch 71/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0932 - binary_crossentropy: 0.0371 - generalized_dice_coefficient: 0.8508
# Epoch 71: val_loss improved from 0.09186 to 0.09158, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_71.h5
# 80/80 [==============================] - 9s 108ms/step - loss: 0.0932 - binary_crossentropy: 0.0371 - generalized_dice_coefficient: 0.8508 - val_loss: 0.0916 - val_binary_crossentropy: 0.0360 - val_generalized_dice_coefficient: 0.8530
# Epoch 72/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0931 - binary_crossentropy: 0.0370 - generalized_dice_coefficient: 0.8507
# Epoch 72: val_loss improved from 0.09158 to 0.09147, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_72.h5
# 80/80 [==============================] - 9s 109ms/step - loss: 0.0931 - binary_crossentropy: 0.0370 - generalized_dice_coefficient: 0.8507 - val_loss: 0.0915 - val_binary_crossentropy: 0.0360 - val_generalized_dice_coefficient: 0.8532
# Epoch 73/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0933 - binary_crossentropy: 0.0370 - generalized_dice_coefficient: 0.8504
# Epoch 73: val_loss did not improve from 0.09147
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0933 - binary_crossentropy: 0.0370 - generalized_dice_coefficient: 0.8504 - val_loss: 0.0952 - val_binary_crossentropy: 0.0380 - val_generalized_dice_coefficient: 0.8478
# Epoch 74/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0929 - binary_crossentropy: 0.0369 - generalized_dice_coefficient: 0.8510
# Epoch 74: val_loss improved from 0.09147 to 0.09141, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_74.h5
# 80/80 [==============================] - 9s 108ms/step - loss: 0.0929 - binary_crossentropy: 0.0369 - generalized_dice_coefficient: 0.8510 - val_loss: 0.0914 - val_binary_crossentropy: 0.0361 - val_generalized_dice_coefficient: 0.8534
# Epoch 75/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0933 - binary_crossentropy: 0.0369 - generalized_dice_coefficient: 0.8503
# Epoch 75: val_loss did not improve from 0.09141
# 80/80 [==============================] - 8s 104ms/step - loss: 0.0933 - binary_crossentropy: 0.0369 - generalized_dice_coefficient: 0.8503 - val_loss: 0.0918 - val_binary_crossentropy: 0.0364 - val_generalized_dice_coefficient: 0.8530
# Epoch 76/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0930 - binary_crossentropy: 0.0369 - generalized_dice_coefficient: 0.8509
# Epoch 76: val_loss did not improve from 0.09141
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0930 - binary_crossentropy: 0.0369 - generalized_dice_coefficient: 0.8509 - val_loss: 0.0921 - val_binary_crossentropy: 0.0364 - val_generalized_dice_coefficient: 0.8523
# Epoch 77/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0930 - binary_crossentropy: 0.0370 - generalized_dice_coefficient: 0.8510
# Epoch 77: val_loss did not improve from 0.09141
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0930 - binary_crossentropy: 0.0370 - generalized_dice_coefficient: 0.8510 - val_loss: 0.0951 - val_binary_crossentropy: 0.0374 - val_generalized_dice_coefficient: 0.8475
# Epoch 78/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0932 - binary_crossentropy: 0.0370 - generalized_dice_coefficient: 0.8506
# Epoch 78: val_loss improved from 0.09141 to 0.09135, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_78.h5
# 80/80 [==============================] - 9s 108ms/step - loss: 0.0932 - binary_crossentropy: 0.0370 - generalized_dice_coefficient: 0.8506 - val_loss: 0.0913 - val_binary_crossentropy: 0.0361 - val_generalized_dice_coefficient: 0.8536
# Epoch 79/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0931 - binary_crossentropy: 0.0369 - generalized_dice_coefficient: 0.8507
# Epoch 79: val_loss did not improve from 0.09135
# 80/80 [==============================] - 8s 104ms/step - loss: 0.0931 - binary_crossentropy: 0.0369 - generalized_dice_coefficient: 0.8507 - val_loss: 0.0918 - val_binary_crossentropy: 0.0365 - val_generalized_dice_coefficient: 0.8530
# Epoch 80/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0926 - binary_crossentropy: 0.0369 - generalized_dice_coefficient: 0.8517
# Epoch 80: val_loss did not improve from 0.09135
# 80/80 [==============================] - 8s 104ms/step - loss: 0.0926 - binary_crossentropy: 0.0369 - generalized_dice_coefficient: 0.8517 - val_loss: 0.0919 - val_binary_crossentropy: 0.0363 - val_generalized_dice_coefficient: 0.8526
# Epoch 81/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0927 - binary_crossentropy: 0.0367 - generalized_dice_coefficient: 0.8512
# Epoch 81: val_loss did not improve from 0.09135
# 80/80 [==============================] - 8s 104ms/step - loss: 0.0927 - binary_crossentropy: 0.0367 - generalized_dice_coefficient: 0.8512 - val_loss: 0.0946 - val_binary_crossentropy: 0.0380 - val_generalized_dice_coefficient: 0.8489
# Epoch 82/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0935 - binary_crossentropy: 0.0373 - generalized_dice_coefficient: 0.8502
# Epoch 82: val_loss did not improve from 0.09135
# 80/80 [==============================] - 8s 104ms/step - loss: 0.0935 - binary_crossentropy: 0.0373 - generalized_dice_coefficient: 0.8502 - val_loss: 0.0914 - val_binary_crossentropy: 0.0360 - val_generalized_dice_coefficient: 0.8534
# Epoch 83/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0930 - binary_crossentropy: 0.0370 - generalized_dice_coefficient: 0.8510
# Epoch 83: val_loss did not improve from 0.09135
# 80/80 [==============================] - 8s 104ms/step - loss: 0.0930 - binary_crossentropy: 0.0370 - generalized_dice_coefficient: 0.8510 - val_loss: 0.0925 - val_binary_crossentropy: 0.0368 - val_generalized_dice_coefficient: 0.8520
# Epoch 84/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0937 - binary_crossentropy: 0.0372 - generalized_dice_coefficient: 0.8499
# Epoch 84: val_loss improved from 0.09135 to 0.09125, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_84.h5
# 80/80 [==============================] - 9s 108ms/step - loss: 0.0937 - binary_crossentropy: 0.0372 - generalized_dice_coefficient: 0.8499 - val_loss: 0.0913 - val_binary_crossentropy: 0.0360 - val_generalized_dice_coefficient: 0.8537
# Epoch 85/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0925 - binary_crossentropy: 0.0366 - generalized_dice_coefficient: 0.8516
# Epoch 85: val_loss did not improve from 0.09125
# 80/80 [==============================] - 8s 104ms/step - loss: 0.0925 - binary_crossentropy: 0.0366 - generalized_dice_coefficient: 0.8516 - val_loss: 0.0923 - val_binary_crossentropy: 0.0360 - val_generalized_dice_coefficient: 0.8515
# Epoch 86/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0921 - binary_crossentropy: 0.0365 - generalized_dice_coefficient: 0.8523
# Epoch 86: val_loss improved from 0.09125 to 0.09084, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_86.h5
# 80/80 [==============================] - 9s 109ms/step - loss: 0.0921 - binary_crossentropy: 0.0365 - generalized_dice_coefficient: 0.8523 - val_loss: 0.0908 - val_binary_crossentropy: 0.0359 - val_generalized_dice_coefficient: 0.8544
# Epoch 87/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0920 - binary_crossentropy: 0.0364 - generalized_dice_coefficient: 0.8523
# Epoch 87: val_loss did not improve from 0.09084
# 80/80 [==============================] - 8s 104ms/step - loss: 0.0920 - binary_crossentropy: 0.0364 - generalized_dice_coefficient: 0.8523 - val_loss: 0.0911 - val_binary_crossentropy: 0.0360 - val_generalized_dice_coefficient: 0.8539
# Epoch 88/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0921 - binary_crossentropy: 0.0366 - generalized_dice_coefficient: 0.8524
# Epoch 88: val_loss did not improve from 0.09084
# 80/80 [==============================] - 8s 104ms/step - loss: 0.0921 - binary_crossentropy: 0.0366 - generalized_dice_coefficient: 0.8524 - val_loss: 0.0928 - val_binary_crossentropy: 0.0364 - val_generalized_dice_coefficient: 0.8509
# Epoch 89/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0924 - binary_crossentropy: 0.0366 - generalized_dice_coefficient: 0.8518
# Epoch 89: val_loss did not improve from 0.09084
# 80/80 [==============================] - 8s 104ms/step - loss: 0.0924 - binary_crossentropy: 0.0366 - generalized_dice_coefficient: 0.8518 - val_loss: 0.0916 - val_binary_crossentropy: 0.0357 - val_generalized_dice_coefficient: 0.8526
# Epoch 90/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0920 - binary_crossentropy: 0.0364 - generalized_dice_coefficient: 0.8525
# Epoch 90: val_loss improved from 0.09084 to 0.09058, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_90.h5
# 80/80 [==============================] - 9s 109ms/step - loss: 0.0920 - binary_crossentropy: 0.0364 - generalized_dice_coefficient: 0.8525 - val_loss: 0.0906 - val_binary_crossentropy: 0.0355 - val_generalized_dice_coefficient: 0.8545
# Epoch 91/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0923 - binary_crossentropy: 0.0366 - generalized_dice_coefficient: 0.8520
# Epoch 91: val_loss did not improve from 0.09058
# 80/80 [==============================] - 8s 104ms/step - loss: 0.0923 - binary_crossentropy: 0.0366 - generalized_dice_coefficient: 0.8520 - val_loss: 0.0910 - val_binary_crossentropy: 0.0363 - val_generalized_dice_coefficient: 0.8544
# Epoch 92/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0924 - binary_crossentropy: 0.0366 - generalized_dice_coefficient: 0.8518
# Epoch 92: val_loss did not improve from 0.09058
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0924 - binary_crossentropy: 0.0366 - generalized_dice_coefficient: 0.8518 - val_loss: 0.0921 - val_binary_crossentropy: 0.0363 - val_generalized_dice_coefficient: 0.8523
# Epoch 93/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0919 - binary_crossentropy: 0.0366 - generalized_dice_coefficient: 0.8527
# Epoch 93: val_loss did not improve from 0.09058
# 80/80 [==============================] - 8s 104ms/step - loss: 0.0919 - binary_crossentropy: 0.0366 - generalized_dice_coefficient: 0.8527 - val_loss: 0.0924 - val_binary_crossentropy: 0.0369 - val_generalized_dice_coefficient: 0.8523
# Epoch 94/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0927 - binary_crossentropy: 0.0367 - generalized_dice_coefficient: 0.8513
# Epoch 94: val_loss improved from 0.09058 to 0.09043, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_94.h5
# 80/80 [==============================] - 9s 109ms/step - loss: 0.0927 - binary_crossentropy: 0.0367 - generalized_dice_coefficient: 0.8513 - val_loss: 0.0904 - val_binary_crossentropy: 0.0354 - val_generalized_dice_coefficient: 0.8547
# Epoch 95/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0919 - binary_crossentropy: 0.0364 - generalized_dice_coefficient: 0.8527
# Epoch 95: val_loss did not improve from 0.09043
# 80/80 [==============================] - 8s 104ms/step - loss: 0.0919 - binary_crossentropy: 0.0364 - generalized_dice_coefficient: 0.8527 - val_loss: 0.0911 - val_binary_crossentropy: 0.0358 - val_generalized_dice_coefficient: 0.8538
# Epoch 96/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0923 - binary_crossentropy: 0.0365 - generalized_dice_coefficient: 0.8520
# Epoch 96: val_loss did not improve from 0.09043
# 80/80 [==============================] - 8s 104ms/step - loss: 0.0923 - binary_crossentropy: 0.0365 - generalized_dice_coefficient: 0.8520 - val_loss: 0.0906 - val_binary_crossentropy: 0.0354 - val_generalized_dice_coefficient: 0.8542
# Epoch 97/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0920 - binary_crossentropy: 0.0365 - generalized_dice_coefficient: 0.8525
# Epoch 97: val_loss did not improve from 0.09043
# 80/80 [==============================] - 8s 104ms/step - loss: 0.0920 - binary_crossentropy: 0.0365 - generalized_dice_coefficient: 0.8525 - val_loss: 0.0905 - val_binary_crossentropy: 0.0355 - val_generalized_dice_coefficient: 0.8546
# Epoch 98/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0917 - binary_crossentropy: 0.0363 - generalized_dice_coefficient: 0.8529
# Epoch 98: val_loss did not improve from 0.09043
# 80/80 [==============================] - 8s 104ms/step - loss: 0.0917 - binary_crossentropy: 0.0363 - generalized_dice_coefficient: 0.8529 - val_loss: 0.0924 - val_binary_crossentropy: 0.0362 - val_generalized_dice_coefficient: 0.8515
# Epoch 99/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0922 - binary_crossentropy: 0.0365 - generalized_dice_coefficient: 0.8521
# Epoch 99: val_loss improved from 0.09043 to 0.09021, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_99.h5
# 80/80 [==============================] - 9s 108ms/step - loss: 0.0922 - binary_crossentropy: 0.0365 - generalized_dice_coefficient: 0.8521 - val_loss: 0.0902 - val_binary_crossentropy: 0.0356 - val_generalized_dice_coefficient: 0.8553
# Epoch 100/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0915 - binary_crossentropy: 0.0362 - generalized_dice_coefficient: 0.8532
# Epoch 100: val_loss improved from 0.09021 to 0.09013, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_100.h5
# 80/80 [==============================] - 9s 109ms/step - loss: 0.0915 - binary_crossentropy: 0.0362 - generalized_dice_coefficient: 0.8532 - val_loss: 0.0901 - val_binary_crossentropy: 0.0354 - val_generalized_dice_coefficient: 0.8553
# Epoch 101/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0917 - binary_crossentropy: 0.0362 - generalized_dice_coefficient: 0.8528
# Epoch 101: val_loss did not improve from 0.09013
# 80/80 [==============================] - 8s 104ms/step - loss: 0.0917 - binary_crossentropy: 0.0362 - generalized_dice_coefficient: 0.8528 - val_loss: 0.0902 - val_binary_crossentropy: 0.0356 - val_generalized_dice_coefficient: 0.8555
# Epoch 102/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0922 - binary_crossentropy: 0.0366 - generalized_dice_coefficient: 0.8523
# Epoch 102: val_loss did not improve from 0.09013
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0922 - binary_crossentropy: 0.0366 - generalized_dice_coefficient: 0.8523 - val_loss: 0.0904 - val_binary_crossentropy: 0.0356 - val_generalized_dice_coefficient: 0.8550
# Epoch 103/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0920 - binary_crossentropy: 0.0365 - generalized_dice_coefficient: 0.8524
# Epoch 103: val_loss did not improve from 0.09013
# 80/80 [==============================] - 8s 104ms/step - loss: 0.0920 - binary_crossentropy: 0.0365 - generalized_dice_coefficient: 0.8524 - val_loss: 0.0935 - val_binary_crossentropy: 0.0367 - val_generalized_dice_coefficient: 0.8498
# Epoch 104/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0917 - binary_crossentropy: 0.0364 - generalized_dice_coefficient: 0.8529
# Epoch 104: val_loss did not improve from 0.09013
# 80/80 [==============================] - 8s 104ms/step - loss: 0.0917 - binary_crossentropy: 0.0364 - generalized_dice_coefficient: 0.8529 - val_loss: 0.0909 - val_binary_crossentropy: 0.0357 - val_generalized_dice_coefficient: 0.8540
# Epoch 105/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0918 - binary_crossentropy: 0.0362 - generalized_dice_coefficient: 0.8527
# Epoch 105: val_loss did not improve from 0.09013
# ...
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0906 - binary_crossentropy: 0.0359 - generalized_dice_coefficient: 0.8546 - val_loss: 0.0895 - val_binary_crossentropy: 0.0353 - val_generalized_dice_coefficient: 0.8565
# Epoch 165/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0911 - binary_crossentropy: 0.0362 - generalized_dice_coefficient: 0.8540
# Epoch 165: val_loss did not improve from 0.08939
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0911 - binary_crossentropy: 0.0362 - generalized_dice_coefficient: 0.8540 - val_loss: 0.0896 - val_binary_crossentropy: 0.0352 - val_generalized_dice_coefficient: 0.8562
# Epoch 166/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0909 - binary_crossentropy: 0.0360 - generalized_dice_coefficient: 0.8543
# Epoch 166: val_loss did not improve from 0.08939
# 80/80 [==============================] - 8s 104ms/step - loss: 0.0909 - binary_crossentropy: 0.0360 - generalized_dice_coefficient: 0.8543 - val_loss: 0.0896 - val_binary_crossentropy: 0.0353 - val_generalized_dice_coefficient: 0.8563
# Epoch 167/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0910 - binary_crossentropy: 0.0360 - generalized_dice_coefficient: 0.8540
# Epoch 167: val_loss did not improve from 0.08939
# 80/80 [==============================] - 8s 104ms/step - loss: 0.0910 - binary_crossentropy: 0.0360 - generalized_dice_coefficient: 0.8540 - val_loss: 0.0895 - val_binary_crossentropy: 0.0353 - val_generalized_dice_coefficient: 0.8565
# Epoch 168/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0908 - binary_crossentropy: 0.0359 - generalized_dice_coefficient: 0.8544
# Epoch 168: val_loss did not improve from 0.08939
# 80/80 [==============================] - 8s 104ms/step - loss: 0.0908 - binary_crossentropy: 0.0359 - generalized_dice_coefficient: 0.8544 - val_loss: 0.0895 - val_binary_crossentropy: 0.0352 - val_generalized_dice_coefficient: 0.8564
# Epoch 169/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0909 - binary_crossentropy: 0.0360 - generalized_dice_coefficient: 0.8542
# Epoch 169: val_loss did not improve from 0.08939
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0909 - binary_crossentropy: 0.0360 - generalized_dice_coefficient: 0.8542 - val_loss: 0.0894 - val_binary_crossentropy: 0.0353 - val_generalized_dice_coefficient: 0.8566
# Epoch 170/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0910 - binary_crossentropy: 0.0361 - generalized_dice_coefficient: 0.8542
# Epoch 170: val_loss did not improve from 0.08939
# 80/80 [==============================] - 8s 104ms/step - loss: 0.0910 - binary_crossentropy: 0.0361 - generalized_dice_coefficient: 0.8542 - val_loss: 0.0894 - val_binary_crossentropy: 0.0352 - val_generalized_dice_coefficient: 0.8564
# Epoch 171/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0912 - binary_crossentropy: 0.0361 - generalized_dice_coefficient: 0.8538
# Epoch 171: val_loss did not improve from 0.08939
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0912 - binary_crossentropy: 0.0361 - generalized_dice_coefficient: 0.8538 - val_loss: 0.0894 - val_binary_crossentropy: 0.0353 - val_generalized_dice_coefficient: 0.8566
# Epoch 172/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0907 - binary_crossentropy: 0.0359 - generalized_dice_coefficient: 0.8545
# Epoch 172: val_loss did not improve from 0.08939
# 80/80 [==============================] - 8s 104ms/step - loss: 0.0907 - binary_crossentropy: 0.0359 - generalized_dice_coefficient: 0.8545 - val_loss: 0.0895 - val_binary_crossentropy: 0.0353 - val_generalized_dice_coefficient: 0.8565
# Epoch 173/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0909 - binary_crossentropy: 0.0359 - generalized_dice_coefficient: 0.8542
# Epoch 173: val_loss did not improve from 0.08939
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0909 - binary_crossentropy: 0.0359 - generalized_dice_coefficient: 0.8542 - val_loss: 0.0894 - val_binary_crossentropy: 0.0353 - val_generalized_dice_coefficient: 0.8565
# Epoch 174/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0910 - binary_crossentropy: 0.0360 - generalized_dice_coefficient: 0.8541
# Epoch 174: val_loss did not improve from 0.08939
# 80/80 [==============================] - 8s 104ms/step - loss: 0.0910 - binary_crossentropy: 0.0360 - generalized_dice_coefficient: 0.8541 - val_loss: 0.0894 - val_binary_crossentropy: 0.0353 - val_generalized_dice_coefficient: 0.8566
# Epoch 175/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0909 - binary_crossentropy: 0.0360 - generalized_dice_coefficient: 0.8543
# Epoch 175: val_loss did not improve from 0.08939
# 80/80 [==============================] - 8s 104ms/step - loss: 0.0909 - binary_crossentropy: 0.0360 - generalized_dice_coefficient: 0.8543 - val_loss: 0.0894 - val_binary_crossentropy: 0.0352 - val_generalized_dice_coefficient: 0.8566
# Epoch 176/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0909 - binary_crossentropy: 0.0360 - generalized_dice_coefficient: 0.8542
# Epoch 176: val_loss improved from 0.08939 to 0.08937, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_176.h5
# 80/80 [==============================] - 9s 109ms/step - loss: 0.0909 - binary_crossentropy: 0.0360 - generalized_dice_coefficient: 0.8542 - val_loss: 0.0894 - val_binary_crossentropy: 0.0352 - val_generalized_dice_coefficient: 0.8566
# Epoch 177/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0908 - binary_crossentropy: 0.0359 - generalized_dice_coefficient: 0.8543
# Epoch 177: val_loss did not improve from 0.08937
# 80/80 [==============================] - 8s 104ms/step - loss: 0.0908 - binary_crossentropy: 0.0359 - generalized_dice_coefficient: 0.8543 - val_loss: 0.0895 - val_binary_crossentropy: 0.0352 - val_generalized_dice_coefficient: 0.8564
# Epoch 178/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0908 - binary_crossentropy: 0.0359 - generalized_dice_coefficient: 0.8543
# Epoch 178: val_loss did not improve from 0.08937
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0908 - binary_crossentropy: 0.0359 - generalized_dice_coefficient: 0.8543 - val_loss: 0.0894 - val_binary_crossentropy: 0.0352 - val_generalized_dice_coefficient: 0.8565
# Epoch 179/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0909 - binary_crossentropy: 0.0360 - generalized_dice_coefficient: 0.8542
# Epoch 179: val_loss did not improve from 0.08937
# 80/80 [==============================] - 8s 104ms/step - loss: 0.0909 - binary_crossentropy: 0.0360 - generalized_dice_coefficient: 0.8542 - val_loss: 0.0895 - val_binary_crossentropy: 0.0352 - val_generalized_dice_coefficient: 0.8564
# Epoch 180/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0911 - binary_crossentropy: 0.0361 - generalized_dice_coefficient: 0.8540
# Epoch 180: val_loss did not improve from 0.08937
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0911 - binary_crossentropy: 0.0361 - generalized_dice_coefficient: 0.8540 - val_loss: 0.0895 - val_binary_crossentropy: 0.0352 - val_generalized_dice_coefficient: 0.8563
# Epoch 181/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0909 - binary_crossentropy: 0.0361 - generalized_dice_coefficient: 0.8543
# Epoch 181: val_loss did not improve from 0.08937
# 80/80 [==============================] - 8s 104ms/step - loss: 0.0909 - binary_crossentropy: 0.0361 - generalized_dice_coefficient: 0.8543 - val_loss: 0.0895 - val_binary_crossentropy: 0.0352 - val_generalized_dice_coefficient: 0.8564
# Epoch 182/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0909 - binary_crossentropy: 0.0360 - generalized_dice_coefficient: 0.8542
# Epoch 182: val_loss did not improve from 0.08937
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0909 - binary_crossentropy: 0.0360 - generalized_dice_coefficient: 0.8542 - val_loss: 0.0894 - val_binary_crossentropy: 0.0353 - val_generalized_dice_coefficient: 0.8566
# Epoch 183/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0907 - binary_crossentropy: 0.0360 - generalized_dice_coefficient: 0.8545
# Epoch 183: val_loss did not improve from 0.08937
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0907 - binary_crossentropy: 0.0360 - generalized_dice_coefficient: 0.8545 - val_loss: 0.0894 - val_binary_crossentropy: 0.0352 - val_generalized_dice_coefficient: 0.8565
# Epoch 184/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0907 - binary_crossentropy: 0.0359 - generalized_dice_coefficient: 0.8545
# Epoch 184: val_loss did not improve from 0.08937
# 80/80 [==============================] - 8s 104ms/step - loss: 0.0907 - binary_crossentropy: 0.0359 - generalized_dice_coefficient: 0.8545 - val_loss: 0.0895 - val_binary_crossentropy: 0.0352 - val_generalized_dice_coefficient: 0.8564
# Epoch 185/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0907 - binary_crossentropy: 0.0359 - generalized_dice_coefficient: 0.8544
# Epoch 185: val_loss did not improve from 0.08937
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0907 - binary_crossentropy: 0.0359 - generalized_dice_coefficient: 0.8544 - val_loss: 0.0894 - val_binary_crossentropy: 0.0352 - val_generalized_dice_coefficient: 0.8566
# Epoch 186/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0909 - binary_crossentropy: 0.0360 - generalized_dice_coefficient: 0.8543
# Epoch 186: val_loss improved from 0.08937 to 0.08936, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_186.h5
# 80/80 [==============================] - 9s 109ms/step - loss: 0.0909 - binary_crossentropy: 0.0360 - generalized_dice_coefficient: 0.8543 - val_loss: 0.0894 - val_binary_crossentropy: 0.0352 - val_generalized_dice_coefficient: 0.8566
# Epoch 187/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0908 - binary_crossentropy: 0.0359 - generalized_dice_coefficient: 0.8544
# Epoch 187: val_loss did not improve from 0.08936
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0908 - binary_crossentropy: 0.0359 - generalized_dice_coefficient: 0.8544 - val_loss: 0.0894 - val_binary_crossentropy: 0.0352 - val_generalized_dice_coefficient: 0.8566
# Epoch 188/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0908 - binary_crossentropy: 0.0359 - generalized_dice_coefficient: 0.8544
# Epoch 188: val_loss did not improve from 0.08936
# 80/80 [==============================] - 8s 104ms/step - loss: 0.0908 - binary_crossentropy: 0.0359 - generalized_dice_coefficient: 0.8544 - val_loss: 0.0894 - val_binary_crossentropy: 0.0353 - val_generalized_dice_coefficient: 0.8566
# Epoch 189/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0909 - binary_crossentropy: 0.0360 - generalized_dice_coefficient: 0.8542
# Epoch 189: val_loss did not improve from 0.08936
# 80/80 [==============================] - 8s 104ms/step - loss: 0.0909 - binary_crossentropy: 0.0360 - generalized_dice_coefficient: 0.8542 - val_loss: 0.0894 - val_binary_crossentropy: 0.0352 - val_generalized_dice_coefficient: 0.8566
# Epoch 190/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0907 - binary_crossentropy: 0.0360 - generalized_dice_coefficient: 0.8546
# Epoch 190: val_loss improved from 0.08936 to 0.08936, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_190.h5
# 80/80 [==============================] - 9s 109ms/step - loss: 0.0907 - binary_crossentropy: 0.0360 - generalized_dice_coefficient: 0.8546 - val_loss: 0.0894 - val_binary_crossentropy: 0.0352 - val_generalized_dice_coefficient: 0.8567
# Epoch 191/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0907 - binary_crossentropy: 0.0359 - generalized_dice_coefficient: 0.8546
# Epoch 191: val_loss did not improve from 0.08936
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0907 - binary_crossentropy: 0.0359 - generalized_dice_coefficient: 0.8546 - val_loss: 0.0894 - val_binary_crossentropy: 0.0352 - val_generalized_dice_coefficient: 0.8565
# Epoch 192/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0909 - binary_crossentropy: 0.0360 - generalized_dice_coefficient: 0.8543
# Epoch 192: val_loss did not improve from 0.08936
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0909 - binary_crossentropy: 0.0360 - generalized_dice_coefficient: 0.8543 - val_loss: 0.0894 - val_binary_crossentropy: 0.0353 - val_generalized_dice_coefficient: 0.8566
# Epoch 193/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0910 - binary_crossentropy: 0.0361 - generalized_dice_coefficient: 0.8541
# Epoch 193: val_loss did not improve from 0.08936
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0910 - binary_crossentropy: 0.0361 - generalized_dice_coefficient: 0.8541 - val_loss: 0.0894 - val_binary_crossentropy: 0.0352 - val_generalized_dice_coefficient: 0.8565
# Epoch 194/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0908 - binary_crossentropy: 0.0359 - generalized_dice_coefficient: 0.8543
# Epoch 194: val_loss did not improve from 0.08936
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0908 - binary_crossentropy: 0.0359 - generalized_dice_coefficient: 0.8543 - val_loss: 0.0894 - val_binary_crossentropy: 0.0352 - val_generalized_dice_coefficient: 0.8565
# Epoch 195/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0908 - binary_crossentropy: 0.0360 - generalized_dice_coefficient: 0.8544
# Epoch 195: val_loss did not improve from 0.08936
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0908 - binary_crossentropy: 0.0360 - generalized_dice_coefficient: 0.8544 - val_loss: 0.0894 - val_binary_crossentropy: 0.0352 - val_generalized_dice_coefficient: 0.8565
# Epoch 196/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0908 - binary_crossentropy: 0.0360 - generalized_dice_coefficient: 0.8543
# Epoch 196: val_loss did not improve from 0.08936
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0908 - binary_crossentropy: 0.0360 - generalized_dice_coefficient: 0.8543 - val_loss: 0.0894 - val_binary_crossentropy: 0.0352 - val_generalized_dice_coefficient: 0.8566
# Epoch 197/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0909 - binary_crossentropy: 0.0359 - generalized_dice_coefficient: 0.8542
# Epoch 197: val_loss did not improve from 0.08936
# 80/80 [==============================] - 8s 104ms/step - loss: 0.0909 - binary_crossentropy: 0.0359 - generalized_dice_coefficient: 0.8542 - val_loss: 0.0894 - val_binary_crossentropy: 0.0352 - val_generalized_dice_coefficient: 0.8566
# Epoch 198/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0908 - binary_crossentropy: 0.0359 - generalized_dice_coefficient: 0.8543
# Epoch 198: val_loss did not improve from 0.08936
# 80/80 [==============================] - 8s 104ms/step - loss: 0.0908 - binary_crossentropy: 0.0359 - generalized_dice_coefficient: 0.8543 - val_loss: 0.0894 - val_binary_crossentropy: 0.0352 - val_generalized_dice_coefficient: 0.8566
# Epoch 199/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0907 - binary_crossentropy: 0.0359 - generalized_dice_coefficient: 0.8544
# Epoch 199: val_loss did not improve from 0.08936
# 80/80 [==============================] - 8s 104ms/step - loss: 0.0907 - binary_crossentropy: 0.0359 - generalized_dice_coefficient: 0.8544 - val_loss: 0.0894 - val_binary_crossentropy: 0.0352 - val_generalized_dice_coefficient: 0.8566
# Epoch 200/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0909 - binary_crossentropy: 0.0360 - generalized_dice_coefficient: 0.8542
# Epoch 200: val_loss did not improve from 0.08936
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0909 - binary_crossentropy: 0.0360 - generalized_dice_coefficient: 0.8542 - val_loss: 0.0894 - val_binary_crossentropy: 0.0352 - val_generalized_dice_coefficient: 0.8566

# %%
del model

# %%
import pickle
with open("/content/drive/MyDrive/Bone_SPECT/training_historyWS2.pkl", 'wb') as file:
    pickle.dump(model_history.history, file)

# %%
loss = model_history.history['loss']
val_loss = model_history.history['val_loss']

plt.figure()
plt.plot(model_history.epoch, loss, 'r', label='Training loss')
plt.plot(model_history.epoch, val_loss, 'bo', label='Validation loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss Value')
plt.ylim([0, 1])
plt.legend()
plt.show()

# %%
temp_train_imgs = np.array(temp_train_imgs, dtype=np.float64)
temp_train_lbls = np.array(temp_train_lbls, dtype=np.uint8)

# %%
inputNP = np.save("/content/drive/MyDrive/Bone_SPECT/data/input.npy", temp_train_imgs)
labelNP = np.save("/content/drive/MyDrive/Bone_SPECT/data/label.npy", temp_train_lbls)
