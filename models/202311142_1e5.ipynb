# %% [markdown]
# <a href="https://colab.research.google.com/github/sunmarknatecom/01_markcv/blob/master/202311142_1e5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from glob import glob
import numpy as np
import cv2, os, copy, shutil
import matplotlib.pyplot as plt
from PIL import Image
from random import randint

# DEEP LEARNING MODULES
import tensorflow as tf
from keras import backend as K
from keras.losses import binary_crossentropy
from keras.optimizers import Adam

from keras.layers import Input, Conv2D, MaxPooling2D, Conv2DTranspose, BatchNormalization, concatenate
from keras.models import Model
from skimage.metrics import structural_similarity as ssim

# %% [markdown]
# 1. data/inputData -> normalization
# 2. data/inputRawData --> 원래
# 3. data/labelData -> 위치보정 label

# %%
MAX_SIZE = 512
split_num = 800

# %%
temp_train_imgs = np.load("/content/drive/MyDrive/Bone_SPECT/data/inputData.npy")
temp_train_lbls = np.load("/content/drive/MyDrive/Bone_SPECT/data/labelData.npy")

# %%
# 0: BG, 1: C, 2: T, 3: L
temp_train_lbls = np.where((temp_train_lbls>=2)&(temp_train_lbls<14),2,temp_train_lbls)
temp_train_lbls[temp_train_lbls>13]=3

# %%
# whole spine
temp_train_lbls[temp_train_lbls >= 1] = 1

# %%
train_imgs = temp_train_imgs[:split_num,...]
valid_imgs = temp_train_imgs[split_num:,...]
train_msks = temp_train_lbls[:split_num,...]
valid_msks = temp_train_lbls[split_num:,...]

# %%
train_imgs = np.array(train_imgs, dtype=np.float32)
train_msks = np.array(train_msks, dtype=np.float32)
valid_imgs = np.array(valid_imgs, dtype=np.float32)
valid_msks = np.array(valid_msks, dtype=np.float32)

train_msks = np.reshape(train_msks, (*train_msks.shape, 1))
valid_msks = np.reshape(valid_msks, (*valid_msks.shape, 1))

train_dataset = tf.data.Dataset.from_tensor_slices((train_imgs, train_msks))
test_dataset = tf.data.Dataset.from_tensor_slices((valid_imgs, valid_msks))

# %%
# %matplotlib inline

rand_num = randint(1,len(train_imgs))

fig = plt.figure(0, figsize=(20, 20))
fig.add_subplot(1, 2, 1)
plt.imshow(train_imgs[rand_num]*13, cmap='gray_r')
fig.add_subplot(1, 2, 2)
plt.imshow(np.squeeze(train_msks[rand_num]), cmap='gray_r')

# %% [markdown]
# # Construct the model

# %%
inputs = Input((MAX_SIZE, 256, 1))
bnorm1 = BatchNormalization()(inputs)
conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(bnorm1)
conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv1)
pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(pool1)
conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv2)
pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(pool2)
conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv3)
pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(pool3)
conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv4)
pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)

conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(pool4)
conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(conv5)

up6 = concatenate([Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(conv5), conv4], axis=3)
conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(up6)
conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv6)

up7 = concatenate([Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(conv6), conv3], axis=3)
conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(up7)
conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv7)

up8 = concatenate([Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(conv7), conv2], axis=3)
conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(up8)
conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv8)

up9 = concatenate([Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(conv8), conv1], axis=3)
conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(up9)
conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv9)

conv10 = Conv2D(1, (1, 1), activation='sigmoid')(conv9)

model = Model(inputs=[inputs], outputs=[conv10])

# %%
import tensorflow as tf
import keras.backend as K
from keras.losses import binary_crossentropy

beta = 0.25
alpha = 0.25
gamma = 2
epsilon = 1e-5
smooth = 1

def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + K.epsilon()) / (K.sum(y_true_f) + K.sum(y_pred_f) + K.epsilon())

def generalized_dice_coefficient(y_true, y_pred):
    smooth = 1.
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    score = (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return score

def dice_loss(y_true, y_pred):
    loss = 1 - generalized_dice_coefficient(y_true, y_pred)
    return loss

def bce_dice_loss(y_true, y_pred):
    loss = binary_crossentropy(y_true, y_pred) + dice_loss(y_true, y_pred)
    return loss / 2.0

# %%
initial_learning_rate = 5e-5

lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate,
    decay_steps=100,
    decay_rate=0.96,
    staircase=True)

callbacks = [tf.keras.callbacks.ModelCheckpoint(
    filepath="/content/drive/MyDrive/Bone_SPECT/models/mymodel_{epoch}.h5",
    save_best_only=True,
    monitor='val_loss',
    verbose=1)]

# %%
model.compile(Adam(learning_rate=lr_schedule), bce_dice_loss, metrics=[binary_crossentropy, generalized_dice_coefficient])

# %%
model_history = model.fit(train_imgs, train_msks, batch_size=10, epochs=200, callbacks=callbacks, validation_data=(valid_imgs, valid_msks))
# Out:
# Epoch 1/200
# 80/80 [==============================] - ETA: 0s - loss: 0.6957 - binary_crossentropy: 0.4573 - generalized_dice_coefficient: 0.0658
# Epoch 1: val_loss improved from inf to 0.61434, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_1.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 80/80 [==============================] - 31s 167ms/step - loss: 0.6957 - binary_crossentropy: 0.4573 - generalized_dice_coefficient: 0.0658 - val_loss: 0.6143 - val_binary_crossentropy: 0.3219 - val_generalized_dice_coefficient: 0.0933
# Epoch 2/200
# 80/80 [==============================] - ETA: 0s - loss: 0.2623 - binary_crossentropy: 0.0749 - generalized_dice_coefficient: 0.5503
# Epoch 2: val_loss improved from 0.61434 to 0.32252, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_2.h5
# 80/80 [==============================] - 11s 136ms/step - loss: 0.2623 - binary_crossentropy: 0.0749 - generalized_dice_coefficient: 0.5503 - val_loss: 0.3225 - val_binary_crossentropy: 0.0719 - val_generalized_dice_coefficient: 0.4270
# Epoch 3/200
# 80/80 [==============================] - ETA: 0s - loss: 0.1337 - binary_crossentropy: 0.0536 - generalized_dice_coefficient: 0.7863
# Epoch 3: val_loss improved from 0.32252 to 0.24106, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_3.h5
# 80/80 [==============================] - 11s 136ms/step - loss: 0.1337 - binary_crossentropy: 0.0536 - generalized_dice_coefficient: 0.7863 - val_loss: 0.2411 - val_binary_crossentropy: 0.0546 - val_generalized_dice_coefficient: 0.5727
# Epoch 4/200
# 80/80 [==============================] - ETA: 0s - loss: 0.1178 - binary_crossentropy: 0.0516 - generalized_dice_coefficient: 0.8159
# Epoch 4: val_loss improved from 0.24106 to 0.16043, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_4.h5
# 80/80 [==============================] - 11s 133ms/step - loss: 0.1178 - binary_crossentropy: 0.0516 - generalized_dice_coefficient: 0.8159 - val_loss: 0.1604 - val_binary_crossentropy: 0.0346 - val_generalized_dice_coefficient: 0.7140
# Epoch 5/200
# 80/80 [==============================] - ETA: 0s - loss: 0.1103 - binary_crossentropy: 0.0463 - generalized_dice_coefficient: 0.8256
# Epoch 5: val_loss improved from 0.16043 to 0.12600, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_5.h5
# 80/80 [==============================] - 11s 135ms/step - loss: 0.1103 - binary_crossentropy: 0.0463 - generalized_dice_coefficient: 0.8256 - val_loss: 0.1260 - val_binary_crossentropy: 0.0338 - val_generalized_dice_coefficient: 0.7821
# Epoch 6/200
# 80/80 [==============================] - ETA: 0s - loss: 0.1047 - binary_crossentropy: 0.0426 - generalized_dice_coefficient: 0.8332
# Epoch 6: val_loss improved from 0.12600 to 0.12387, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_6.h5
# 80/80 [==============================] - 11s 136ms/step - loss: 0.1047 - binary_crossentropy: 0.0426 - generalized_dice_coefficient: 0.8332 - val_loss: 0.1239 - val_binary_crossentropy: 0.0462 - val_generalized_dice_coefficient: 0.7985
# Epoch 7/200
# 80/80 [==============================] - ETA: 0s - loss: 0.1019 - binary_crossentropy: 0.0417 - generalized_dice_coefficient: 0.8380
# Epoch 7: val_loss improved from 0.12387 to 0.09550, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_7.h5
# 80/80 [==============================] - 10s 132ms/step - loss: 0.1019 - binary_crossentropy: 0.0417 - generalized_dice_coefficient: 0.8380 - val_loss: 0.0955 - val_binary_crossentropy: 0.0329 - val_generalized_dice_coefficient: 0.8421
# Epoch 8/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0957 - binary_crossentropy: 0.0387 - generalized_dice_coefficient: 0.8473
# Epoch 8: val_loss improved from 0.09550 to 0.09331, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_8.h5
# 80/80 [==============================] - 10s 128ms/step - loss: 0.0957 - binary_crossentropy: 0.0387 - generalized_dice_coefficient: 0.8473 - val_loss: 0.0933 - val_binary_crossentropy: 0.0368 - val_generalized_dice_coefficient: 0.8503
# Epoch 9/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0953 - binary_crossentropy: 0.0387 - generalized_dice_coefficient: 0.8481
# Epoch 9: val_loss did not improve from 0.09331
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0953 - binary_crossentropy: 0.0387 - generalized_dice_coefficient: 0.8481 - val_loss: 0.1031 - val_binary_crossentropy: 0.0431 - val_generalized_dice_coefficient: 0.8371
# Epoch 10/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0943 - binary_crossentropy: 0.0377 - generalized_dice_coefficient: 0.8492
# Epoch 10: val_loss improved from 0.09331 to 0.08860, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_10.h5
# 80/80 [==============================] - 9s 109ms/step - loss: 0.0943 - binary_crossentropy: 0.0377 - generalized_dice_coefficient: 0.8492 - val_loss: 0.0886 - val_binary_crossentropy: 0.0331 - val_generalized_dice_coefficient: 0.8561
# Epoch 11/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0980 - binary_crossentropy: 0.0398 - generalized_dice_coefficient: 0.8437
# Epoch 11: val_loss did not improve from 0.08860
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0980 - binary_crossentropy: 0.0398 - generalized_dice_coefficient: 0.8437 - val_loss: 0.0976 - val_binary_crossentropy: 0.0412 - val_generalized_dice_coefficient: 0.8463
# Epoch 12/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0920 - binary_crossentropy: 0.0373 - generalized_dice_coefficient: 0.8533
# Epoch 12: val_loss did not improve from 0.08860
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0920 - binary_crossentropy: 0.0373 - generalized_dice_coefficient: 0.8533 - val_loss: 0.0923 - val_binary_crossentropy: 0.0356 - val_generalized_dice_coefficient: 0.8512
# Epoch 13/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0922 - binary_crossentropy: 0.0362 - generalized_dice_coefficient: 0.8517
# Epoch 13: val_loss did not improve from 0.08860
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0922 - binary_crossentropy: 0.0362 - generalized_dice_coefficient: 0.8517 - val_loss: 0.0894 - val_binary_crossentropy: 0.0348 - val_generalized_dice_coefficient: 0.8562
# Epoch 14/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0876 - binary_crossentropy: 0.0343 - generalized_dice_coefficient: 0.8592
# Epoch 14: val_loss improved from 0.08860 to 0.08809, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_14.h5
# 80/80 [==============================] - 9s 109ms/step - loss: 0.0876 - binary_crossentropy: 0.0343 - generalized_dice_coefficient: 0.8592 - val_loss: 0.0881 - val_binary_crossentropy: 0.0348 - val_generalized_dice_coefficient: 0.8587
# Epoch 15/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0861 - binary_crossentropy: 0.0336 - generalized_dice_coefficient: 0.8614
# Epoch 15: val_loss improved from 0.08809 to 0.08634, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_15.h5
# 80/80 [==============================] - 9s 110ms/step - loss: 0.0861 - binary_crossentropy: 0.0336 - generalized_dice_coefficient: 0.8614 - val_loss: 0.0863 - val_binary_crossentropy: 0.0347 - val_generalized_dice_coefficient: 0.8622
# Epoch 16/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0875 - binary_crossentropy: 0.0343 - generalized_dice_coefficient: 0.8592
# Epoch 16: val_loss improved from 0.08634 to 0.08205, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_16.h5
# 80/80 [==============================] - 9s 109ms/step - loss: 0.0875 - binary_crossentropy: 0.0343 - generalized_dice_coefficient: 0.8592 - val_loss: 0.0820 - val_binary_crossentropy: 0.0308 - val_generalized_dice_coefficient: 0.8668
# Epoch 17/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0852 - binary_crossentropy: 0.0328 - generalized_dice_coefficient: 0.8624
# Epoch 17: val_loss improved from 0.08205 to 0.07877, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_17.h5
# 80/80 [==============================] - 9s 109ms/step - loss: 0.0852 - binary_crossentropy: 0.0328 - generalized_dice_coefficient: 0.8624 - val_loss: 0.0788 - val_binary_crossentropy: 0.0288 - val_generalized_dice_coefficient: 0.8714
# Epoch 18/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0879 - binary_crossentropy: 0.0341 - generalized_dice_coefficient: 0.8583
# Epoch 18: val_loss did not improve from 0.07877
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0879 - binary_crossentropy: 0.0341 - generalized_dice_coefficient: 0.8583 - val_loss: 0.0995 - val_binary_crossentropy: 0.0387 - val_generalized_dice_coefficient: 0.8399
# Epoch 19/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0857 - binary_crossentropy: 0.0333 - generalized_dice_coefficient: 0.8620
# Epoch 19: val_loss did not improve from 0.07877
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0857 - binary_crossentropy: 0.0333 - generalized_dice_coefficient: 0.8620 - val_loss: 0.0828 - val_binary_crossentropy: 0.0323 - val_generalized_dice_coefficient: 0.8668
# Epoch 20/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0821 - binary_crossentropy: 0.0311 - generalized_dice_coefficient: 0.8669
# Epoch 20: val_loss improved from 0.07877 to 0.07775, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_20.h5
# 80/80 [==============================] - 9s 109ms/step - loss: 0.0821 - binary_crossentropy: 0.0311 - generalized_dice_coefficient: 0.8669 - val_loss: 0.0777 - val_binary_crossentropy: 0.0303 - val_generalized_dice_coefficient: 0.8749
# Epoch 21/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0845 - binary_crossentropy: 0.0333 - generalized_dice_coefficient: 0.8644
# Epoch 21: val_loss did not improve from 0.07775
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0845 - binary_crossentropy: 0.0333 - generalized_dice_coefficient: 0.8644 - val_loss: 0.0783 - val_binary_crossentropy: 0.0278 - val_generalized_dice_coefficient: 0.8714
# Epoch 22/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0805 - binary_crossentropy: 0.0301 - generalized_dice_coefficient: 0.8690
# Epoch 22: val_loss did not improve from 0.07775
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0805 - binary_crossentropy: 0.0301 - generalized_dice_coefficient: 0.8690 - val_loss: 0.0812 - val_binary_crossentropy: 0.0308 - val_generalized_dice_coefficient: 0.8684
# Epoch 23/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0830 - binary_crossentropy: 0.0316 - generalized_dice_coefficient: 0.8655
# Epoch 23: val_loss did not improve from 0.07775
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0830 - binary_crossentropy: 0.0316 - generalized_dice_coefficient: 0.8655 - val_loss: 0.0820 - val_binary_crossentropy: 0.0314 - val_generalized_dice_coefficient: 0.8676
# Epoch 24/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0793 - binary_crossentropy: 0.0304 - generalized_dice_coefficient: 0.8717
# Epoch 24: val_loss did not improve from 0.07775
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0793 - binary_crossentropy: 0.0304 - generalized_dice_coefficient: 0.8717 - val_loss: 0.0849 - val_binary_crossentropy: 0.0320 - val_generalized_dice_coefficient: 0.8624
# Epoch 25/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0800 - binary_crossentropy: 0.0301 - generalized_dice_coefficient: 0.8702
# Epoch 25: val_loss did not improve from 0.07775
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0800 - binary_crossentropy: 0.0301 - generalized_dice_coefficient: 0.8702 - val_loss: 0.0806 - val_binary_crossentropy: 0.0315 - val_generalized_dice_coefficient: 0.8705
# Epoch 26/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0800 - binary_crossentropy: 0.0305 - generalized_dice_coefficient: 0.8704
# Epoch 26: val_loss did not improve from 0.07775
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0800 - binary_crossentropy: 0.0305 - generalized_dice_coefficient: 0.8704 - val_loss: 0.0910 - val_binary_crossentropy: 0.0343 - val_generalized_dice_coefficient: 0.8524
# Epoch 27/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0801 - binary_crossentropy: 0.0303 - generalized_dice_coefficient: 0.8700
# Epoch 27: val_loss improved from 0.07775 to 0.07587, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_27.h5
# 80/80 [==============================] - 9s 109ms/step - loss: 0.0801 - binary_crossentropy: 0.0303 - generalized_dice_coefficient: 0.8700 - val_loss: 0.0759 - val_binary_crossentropy: 0.0284 - val_generalized_dice_coefficient: 0.8767
# Epoch 28/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0773 - binary_crossentropy: 0.0294 - generalized_dice_coefficient: 0.8748
# Epoch 28: val_loss improved from 0.07587 to 0.07499, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_28.h5
# 80/80 [==============================] - 9s 110ms/step - loss: 0.0773 - binary_crossentropy: 0.0294 - generalized_dice_coefficient: 0.8748 - val_loss: 0.0750 - val_binary_crossentropy: 0.0275 - val_generalized_dice_coefficient: 0.8776
# Epoch 29/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0762 - binary_crossentropy: 0.0291 - generalized_dice_coefficient: 0.8767
# Epoch 29: val_loss improved from 0.07499 to 0.07337, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_29.h5
# 80/80 [==============================] - 9s 109ms/step - loss: 0.0762 - binary_crossentropy: 0.0291 - generalized_dice_coefficient: 0.8767 - val_loss: 0.0734 - val_binary_crossentropy: 0.0265 - val_generalized_dice_coefficient: 0.8799
# Epoch 30/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0753 - binary_crossentropy: 0.0283 - generalized_dice_coefficient: 0.8776
# Epoch 30: val_loss improved from 0.07337 to 0.07233, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_30.h5
# 80/80 [==============================] - 9s 109ms/step - loss: 0.0753 - binary_crossentropy: 0.0283 - generalized_dice_coefficient: 0.8776 - val_loss: 0.0723 - val_binary_crossentropy: 0.0272 - val_generalized_dice_coefficient: 0.8826
# Epoch 31/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0747 - binary_crossentropy: 0.0282 - generalized_dice_coefficient: 0.8788
# Epoch 31: val_loss did not improve from 0.07233
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0747 - binary_crossentropy: 0.0282 - generalized_dice_coefficient: 0.8788 - val_loss: 0.0734 - val_binary_crossentropy: 0.0273 - val_generalized_dice_coefficient: 0.8806
# Epoch 32/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0741 - binary_crossentropy: 0.0283 - generalized_dice_coefficient: 0.8800
# Epoch 32: val_loss did not improve from 0.07233
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0741 - binary_crossentropy: 0.0283 - generalized_dice_coefficient: 0.8800 - val_loss: 0.0725 - val_binary_crossentropy: 0.0273 - val_generalized_dice_coefficient: 0.8824
# Epoch 33/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0734 - binary_crossentropy: 0.0276 - generalized_dice_coefficient: 0.8808
# Epoch 33: val_loss did not improve from 0.07233
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0734 - binary_crossentropy: 0.0276 - generalized_dice_coefficient: 0.8808 - val_loss: 0.0735 - val_binary_crossentropy: 0.0280 - val_generalized_dice_coefficient: 0.8810
# Epoch 34/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0737 - binary_crossentropy: 0.0280 - generalized_dice_coefficient: 0.8806
# Epoch 34: val_loss did not improve from 0.07233
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0737 - binary_crossentropy: 0.0280 - generalized_dice_coefficient: 0.8806 - val_loss: 0.0752 - val_binary_crossentropy: 0.0280 - val_generalized_dice_coefficient: 0.8776
# Epoch 35/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0728 - binary_crossentropy: 0.0275 - generalized_dice_coefficient: 0.8819
# Epoch 35: val_loss improved from 0.07233 to 0.07177, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_35.h5
# 80/80 [==============================] - 9s 109ms/step - loss: 0.0728 - binary_crossentropy: 0.0275 - generalized_dice_coefficient: 0.8819 - val_loss: 0.0718 - val_binary_crossentropy: 0.0269 - val_generalized_dice_coefficient: 0.8835
# Epoch 36/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0721 - binary_crossentropy: 0.0273 - generalized_dice_coefficient: 0.8830
# Epoch 36: val_loss did not improve from 0.07177
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0721 - binary_crossentropy: 0.0273 - generalized_dice_coefficient: 0.8830 - val_loss: 0.0723 - val_binary_crossentropy: 0.0280 - val_generalized_dice_coefficient: 0.8835
# Epoch 37/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0717 - binary_crossentropy: 0.0273 - generalized_dice_coefficient: 0.8839
# Epoch 37: val_loss did not improve from 0.07177
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0717 - binary_crossentropy: 0.0273 - generalized_dice_coefficient: 0.8839 - val_loss: 0.0745 - val_binary_crossentropy: 0.0286 - val_generalized_dice_coefficient: 0.8798
# Epoch 38/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0722 - binary_crossentropy: 0.0274 - generalized_dice_coefficient: 0.8830
# Epoch 38: val_loss improved from 0.07177 to 0.07176, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_38.h5
# 80/80 [==============================] - 9s 109ms/step - loss: 0.0722 - binary_crossentropy: 0.0274 - generalized_dice_coefficient: 0.8830 - val_loss: 0.0718 - val_binary_crossentropy: 0.0261 - val_generalized_dice_coefficient: 0.8827
# Epoch 39/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0711 - binary_crossentropy: 0.0269 - generalized_dice_coefficient: 0.8848
# Epoch 39: val_loss improved from 0.07176 to 0.06935, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_39.h5
# 80/80 [==============================] - 9s 110ms/step - loss: 0.0711 - binary_crossentropy: 0.0269 - generalized_dice_coefficient: 0.8848 - val_loss: 0.0693 - val_binary_crossentropy: 0.0260 - val_generalized_dice_coefficient: 0.8874
# Epoch 40/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0706 - binary_crossentropy: 0.0266 - generalized_dice_coefficient: 0.8854
# Epoch 40: val_loss did not improve from 0.06935
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0706 - binary_crossentropy: 0.0266 - generalized_dice_coefficient: 0.8854 - val_loss: 0.0725 - val_binary_crossentropy: 0.0278 - val_generalized_dice_coefficient: 0.8830
# Epoch 41/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0707 - binary_crossentropy: 0.0269 - generalized_dice_coefficient: 0.8855
# Epoch 41: val_loss did not improve from 0.06935
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0707 - binary_crossentropy: 0.0269 - generalized_dice_coefficient: 0.8855 - val_loss: 0.0738 - val_binary_crossentropy: 0.0287 - val_generalized_dice_coefficient: 0.8812
# Epoch 42/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0703 - binary_crossentropy: 0.0267 - generalized_dice_coefficient: 0.8860
# Epoch 42: val_loss improved from 0.06935 to 0.06735, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_42.h5
# 80/80 [==============================] - 9s 109ms/step - loss: 0.0703 - binary_crossentropy: 0.0267 - generalized_dice_coefficient: 0.8860 - val_loss: 0.0673 - val_binary_crossentropy: 0.0245 - val_generalized_dice_coefficient: 0.8899
# Epoch 43/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0703 - binary_crossentropy: 0.0266 - generalized_dice_coefficient: 0.8861
# Epoch 43: val_loss did not improve from 0.06735
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0703 - binary_crossentropy: 0.0266 - generalized_dice_coefficient: 0.8861 - val_loss: 0.0704 - val_binary_crossentropy: 0.0264 - val_generalized_dice_coefficient: 0.8858
# Epoch 44/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0695 - binary_crossentropy: 0.0264 - generalized_dice_coefficient: 0.8874
# Epoch 44: val_loss did not improve from 0.06735
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0695 - binary_crossentropy: 0.0264 - generalized_dice_coefficient: 0.8874 - val_loss: 0.0711 - val_binary_crossentropy: 0.0277 - val_generalized_dice_coefficient: 0.8855
# Epoch 45/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0690 - binary_crossentropy: 0.0262 - generalized_dice_coefficient: 0.8883
# Epoch 45: val_loss did not improve from 0.06735
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0690 - binary_crossentropy: 0.0262 - generalized_dice_coefficient: 0.8883 - val_loss: 0.0705 - val_binary_crossentropy: 0.0274 - val_generalized_dice_coefficient: 0.8865
# Epoch 46/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0680 - binary_crossentropy: 0.0257 - generalized_dice_coefficient: 0.8897
# Epoch 46: val_loss did not improve from 0.06735
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0680 - binary_crossentropy: 0.0257 - generalized_dice_coefficient: 0.8897 - val_loss: 0.0735 - val_binary_crossentropy: 0.0295 - val_generalized_dice_coefficient: 0.8826
# Epoch 47/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0685 - binary_crossentropy: 0.0261 - generalized_dice_coefficient: 0.8892
# Epoch 47: val_loss did not improve from 0.06735
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0685 - binary_crossentropy: 0.0261 - generalized_dice_coefficient: 0.8892 - val_loss: 0.0699 - val_binary_crossentropy: 0.0270 - val_generalized_dice_coefficient: 0.8874
# Epoch 48/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0673 - binary_crossentropy: 0.0254 - generalized_dice_coefficient: 0.8907
# Epoch 48: val_loss did not improve from 0.06735
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0673 - binary_crossentropy: 0.0254 - generalized_dice_coefficient: 0.8907 - val_loss: 0.0693 - val_binary_crossentropy: 0.0263 - val_generalized_dice_coefficient: 0.8878
# Epoch 49/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0669 - binary_crossentropy: 0.0254 - generalized_dice_coefficient: 0.8916
# Epoch 49: val_loss did not improve from 0.06735
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0669 - binary_crossentropy: 0.0254 - generalized_dice_coefficient: 0.8916 - val_loss: 0.0682 - val_binary_crossentropy: 0.0266 - val_generalized_dice_coefficient: 0.8903
# Epoch 50/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0665 - binary_crossentropy: 0.0251 - generalized_dice_coefficient: 0.8922
# Epoch 50: val_loss did not improve from 0.06735
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0665 - binary_crossentropy: 0.0251 - generalized_dice_coefficient: 0.8922 - val_loss: 0.0729 - val_binary_crossentropy: 0.0284 - val_generalized_dice_coefficient: 0.8827
# Epoch 51/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0665 - binary_crossentropy: 0.0252 - generalized_dice_coefficient: 0.8922
# Epoch 51: val_loss improved from 0.06735 to 0.06705, saving model to /content/drive/MyDrive/Bone_SPECT/models/mymodel_51.h5
# 80/80 [==============================] - 9s 109ms/step - loss: 0.0665 - binary_crossentropy: 0.0252 - generalized_dice_coefficient: 0.8922 - val_loss: 0.0670 - val_binary_crossentropy: 0.0258 - val_generalized_dice_coefficient: 0.8918
# Epoch 52/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0657 - binary_crossentropy: 0.0249 - generalized_dice_coefficient: 0.8934
# Epoch 52: val_loss did not improve from 0.06705
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0657 - binary_crossentropy: 0.0249 - generalized_dice_coefficient: 0.8934 - val_loss: 0.0671 - val_binary_crossentropy: 0.0254 - val_generalized_dice_coefficient: 0.8913
# Epoch 53/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0654 - binary_crossentropy: 0.0247 - generalized_dice_coefficient: 0.8939
# Epoch 53: val_loss did not improve from 0.06705
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0654 - binary_crossentropy: 0.0247 - generalized_dice_coefficient: 0.8939 - val_loss: 0.0701 - val_binary_crossentropy: 0.0278 - val_generalized_dice_coefficient: 0.8878
# Epoch 54/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0649 - binary_crossentropy: 0.0246 - generalized_dice_coefficient: 0.8948
# Epoch 54: val_loss did not improve from 0.06705
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0649 - binary_crossentropy: 0.0246 - generalized_dice_coefficient: 0.8948 - val_loss: 0.0713 - val_binary_crossentropy: 0.0283 - val_generalized_dice_coefficient: 0.8858
# Epoch 55/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0645 - binary_crossentropy: 0.0244 - generalized_dice_coefficient: 0.8953
# Epoch 55: val_loss did not improve from 0.06705
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0645 - binary_crossentropy: 0.0244 - generalized_dice_coefficient: 0.8953 - val_loss: 0.0717 - val_binary_crossentropy: 0.0290 - val_generalized_dice_coefficient: 0.8856
# Epoch 56/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0643 - binary_crossentropy: 0.0244 - generalized_dice_coefficient: 0.8957
# Epoch 56: val_loss did not improve from 0.06705
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0643 - binary_crossentropy: 0.0244 - generalized_dice_coefficient: 0.8957 - val_loss: 0.0695 - val_binary_crossentropy: 0.0276 - val_generalized_dice_coefficient: 0.8886
# Epoch 57/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0637 - binary_crossentropy: 0.0241 - generalized_dice_coefficient: 0.8967
# Epoch 57: val_loss did not improve from 0.06705
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0637 - binary_crossentropy: 0.0241 - generalized_dice_coefficient: 0.8967 - val_loss: 0.0700 - val_binary_crossentropy: 0.0286 - val_generalized_dice_coefficient: 0.8888
# Epoch 58/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0639 - binary_crossentropy: 0.0242 - generalized_dice_coefficient: 0.8965
# Epoch 58: val_loss did not improve from 0.06705
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0639 - binary_crossentropy: 0.0242 - generalized_dice_coefficient: 0.8965 - val_loss: 0.0688 - val_binary_crossentropy: 0.0270 - val_generalized_dice_coefficient: 0.8895
# Epoch 59/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0634 - binary_crossentropy: 0.0240 - generalized_dice_coefficient: 0.8973
# Epoch 59: val_loss did not improve from 0.06705
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0634 - binary_crossentropy: 0.0240 - generalized_dice_coefficient: 0.8973 - val_loss: 0.0687 - val_binary_crossentropy: 0.0274 - val_generalized_dice_coefficient: 0.8900
# Epoch 60/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0633 - binary_crossentropy: 0.0240 - generalized_dice_coefficient: 0.8974
# Epoch 60: val_loss did not improve from 0.06705
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0633 - binary_crossentropy: 0.0240 - generalized_dice_coefficient: 0.8974 - val_loss: 0.0679 - val_binary_crossentropy: 0.0266 - val_generalized_dice_coefficient: 0.8908
# Epoch 61/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0629 - binary_crossentropy: 0.0239 - generalized_dice_coefficient: 0.8981
# Epoch 61: val_loss did not improve from 0.06705
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0629 - binary_crossentropy: 0.0239 - generalized_dice_coefficient: 0.8981 - val_loss: 0.0695 - val_binary_crossentropy: 0.0282 - val_generalized_dice_coefficient: 0.8894
# Epoch 62/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0624 - binary_crossentropy: 0.0236 - generalized_dice_coefficient: 0.8988
# Epoch 62: val_loss did not improve from 0.06705
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0624 - binary_crossentropy: 0.0236 - generalized_dice_coefficient: 0.8988 - val_loss: 0.0686 - val_binary_crossentropy: 0.0271 - val_generalized_dice_coefficient: 0.8901
# Epoch 63/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0620 - binary_crossentropy: 0.0235 - generalized_dice_coefficient: 0.8994
# Epoch 63: val_loss did not improve from 0.06705
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0620 - binary_crossentropy: 0.0235 - generalized_dice_coefficient: 0.8994 - val_loss: 0.0684 - val_binary_crossentropy: 0.0278 - val_generalized_dice_coefficient: 0.8910
# Epoch 64/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0620 - binary_crossentropy: 0.0236 - generalized_dice_coefficient: 0.8995
# Epoch 64: val_loss did not improve from 0.06705
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0620 - binary_crossentropy: 0.0236 - generalized_dice_coefficient: 0.8995 - val_loss: 0.0712 - val_binary_crossentropy: 0.0296 - val_generalized_dice_coefficient: 0.8872
# Epoch 65/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0616 - binary_crossentropy: 0.0234 - generalized_dice_coefficient: 0.9001
# Epoch 65: val_loss did not improve from 0.06705
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0616 - binary_crossentropy: 0.0234 - generalized_dice_coefficient: 0.9001 - val_loss: 0.0697 - val_binary_crossentropy: 0.0288 - val_generalized_dice_coefficient: 0.8894
# Epoch 66/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0613 - binary_crossentropy: 0.0232 - generalized_dice_coefficient: 0.9005
# Epoch 66: val_loss did not improve from 0.06705
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0613 - binary_crossentropy: 0.0232 - generalized_dice_coefficient: 0.9005 - val_loss: 0.0693 - val_binary_crossentropy: 0.0282 - val_generalized_dice_coefficient: 0.8897
# Epoch 67/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0609 - binary_crossentropy: 0.0230 - generalized_dice_coefficient: 0.9012
# Epoch 67: val_loss did not improve from 0.06705
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0609 - binary_crossentropy: 0.0230 - generalized_dice_coefficient: 0.9012 - val_loss: 0.0692 - val_binary_crossentropy: 0.0290 - val_generalized_dice_coefficient: 0.8908
# Epoch 68/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0606 - binary_crossentropy: 0.0231 - generalized_dice_coefficient: 0.9018
# Epoch 68: val_loss did not improve from 0.06705
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0606 - binary_crossentropy: 0.0231 - generalized_dice_coefficient: 0.9018 - val_loss: 0.0685 - val_binary_crossentropy: 0.0274 - val_generalized_dice_coefficient: 0.8904
# Epoch 69/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0604 - binary_crossentropy: 0.0228 - generalized_dice_coefficient: 0.9021
# Epoch 69: val_loss did not improve from 0.06705
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0604 - binary_crossentropy: 0.0228 - generalized_dice_coefficient: 0.9021 - val_loss: 0.0706 - val_binary_crossentropy: 0.0296 - val_generalized_dice_coefficient: 0.8885
# Epoch 70/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0604 - binary_crossentropy: 0.0230 - generalized_dice_coefficient: 0.9021
# Epoch 70: val_loss did not improve from 0.06705
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0604 - binary_crossentropy: 0.0230 - generalized_dice_coefficient: 0.9021 - val_loss: 0.0699 - val_binary_crossentropy: 0.0293 - val_generalized_dice_coefficient: 0.8895
# Epoch 71/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0605 - binary_crossentropy: 0.0230 - generalized_dice_coefficient: 0.9020
# Epoch 71: val_loss did not improve from 0.06705
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0605 - binary_crossentropy: 0.0230 - generalized_dice_coefficient: 0.9020 - val_loss: 0.0697 - val_binary_crossentropy: 0.0296 - val_generalized_dice_coefficient: 0.8902
# Epoch 72/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0600 - binary_crossentropy: 0.0228 - generalized_dice_coefficient: 0.9027
# Epoch 72: val_loss did not improve from 0.06705
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0600 - binary_crossentropy: 0.0228 - generalized_dice_coefficient: 0.9027 - val_loss: 0.0688 - val_binary_crossentropy: 0.0287 - val_generalized_dice_coefficient: 0.8911
# Epoch 73/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0598 - binary_crossentropy: 0.0228 - generalized_dice_coefficient: 0.9031
# Epoch 73: val_loss did not improve from 0.06705
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0598 - binary_crossentropy: 0.0228 - generalized_dice_coefficient: 0.9031 - val_loss: 0.0688 - val_binary_crossentropy: 0.0290 - val_generalized_dice_coefficient: 0.8914
# Epoch 74/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0596 - binary_crossentropy: 0.0227 - generalized_dice_coefficient: 0.9034
# Epoch 74: val_loss did not improve from 0.06705
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0596 - binary_crossentropy: 0.0227 - generalized_dice_coefficient: 0.9034 - val_loss: 0.0720 - val_binary_crossentropy: 0.0305 - val_generalized_dice_coefficient: 0.8866
# Epoch 75/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0597 - binary_crossentropy: 0.0227 - generalized_dice_coefficient: 0.9033
# Epoch 75: val_loss did not improve from 0.06705
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0597 - binary_crossentropy: 0.0227 - generalized_dice_coefficient: 0.9033 - val_loss: 0.0689 - val_binary_crossentropy: 0.0285 - val_generalized_dice_coefficient: 0.8908
# Epoch 76/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0592 - binary_crossentropy: 0.0225 - generalized_dice_coefficient: 0.9041
# Epoch 76: val_loss did not improve from 0.06705
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0592 - binary_crossentropy: 0.0225 - generalized_dice_coefficient: 0.9041 - val_loss: 0.0686 - val_binary_crossentropy: 0.0283 - val_generalized_dice_coefficient: 0.8912
# Epoch 77/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0590 - binary_crossentropy: 0.0224 - generalized_dice_coefficient: 0.9045
# Epoch 77: val_loss did not improve from 0.06705
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0590 - binary_crossentropy: 0.0224 - generalized_dice_coefficient: 0.9045 - val_loss: 0.0697 - val_binary_crossentropy: 0.0295 - val_generalized_dice_coefficient: 0.8902
# Epoch 78/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0591 - binary_crossentropy: 0.0225 - generalized_dice_coefficient: 0.9042
# Epoch 78: val_loss did not improve from 0.06705
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0591 - binary_crossentropy: 0.0225 - generalized_dice_coefficient: 0.9042 - val_loss: 0.0695 - val_binary_crossentropy: 0.0294 - val_generalized_dice_coefficient: 0.8905
# Epoch 79/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0587 - binary_crossentropy: 0.0222 - generalized_dice_coefficient: 0.9049
# Epoch 79: val_loss did not improve from 0.06705
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0587 - binary_crossentropy: 0.0222 - generalized_dice_coefficient: 0.9049 - val_loss: 0.0690 - val_binary_crossentropy: 0.0291 - val_generalized_dice_coefficient: 0.8911
# Epoch 80/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0585 - binary_crossentropy: 0.0222 - generalized_dice_coefficient: 0.9051
# Epoch 80: val_loss did not improve from 0.06705
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0585 - binary_crossentropy: 0.0222 - generalized_dice_coefficient: 0.9051 - val_loss: 0.0685 - val_binary_crossentropy: 0.0290 - val_generalized_dice_coefficient: 0.8922
# Epoch 81/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0585 - binary_crossentropy: 0.0222 - generalized_dice_coefficient: 0.9052
# Epoch 81: val_loss did not improve from 0.06705
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0585 - binary_crossentropy: 0.0222 - generalized_dice_coefficient: 0.9052 - val_loss: 0.0687 - val_binary_crossentropy: 0.0293 - val_generalized_dice_coefficient: 0.8921
# Epoch 82/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0582 - binary_crossentropy: 0.0221 - generalized_dice_coefficient: 0.9057
# Epoch 82: val_loss did not improve from 0.06705
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0582 - binary_crossentropy: 0.0221 - generalized_dice_coefficient: 0.9057 - val_loss: 0.0705 - val_binary_crossentropy: 0.0300 - val_generalized_dice_coefficient: 0.8891
# Epoch 83/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0586 - binary_crossentropy: 0.0223 - generalized_dice_coefficient: 0.9051
# Epoch 83: val_loss did not improve from 0.06705
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0586 - binary_crossentropy: 0.0223 - generalized_dice_coefficient: 0.9051 - val_loss: 0.0698 - val_binary_crossentropy: 0.0299 - val_generalized_dice_coefficient: 0.8905
# Epoch 84/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0580 - binary_crossentropy: 0.0220 - generalized_dice_coefficient: 0.9059
# Epoch 84: val_loss did not improve from 0.06705
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0580 - binary_crossentropy: 0.0220 - generalized_dice_coefficient: 0.9059 - val_loss: 0.0684 - val_binary_crossentropy: 0.0288 - val_generalized_dice_coefficient: 0.8921
# Epoch 85/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0578 - binary_crossentropy: 0.0220 - generalized_dice_coefficient: 0.9063
# Epoch 85: val_loss did not improve from 0.06705
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0578 - binary_crossentropy: 0.0220 - generalized_dice_coefficient: 0.9063 - val_loss: 0.0704 - val_binary_crossentropy: 0.0307 - val_generalized_dice_coefficient: 0.8900
# Epoch 86/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0578 - binary_crossentropy: 0.0220 - generalized_dice_coefficient: 0.9063
# Epoch 86: val_loss did not improve from 0.06705
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0578 - binary_crossentropy: 0.0220 - generalized_dice_coefficient: 0.9063 - val_loss: 0.0709 - val_binary_crossentropy: 0.0305 - val_generalized_dice_coefficient: 0.8889
# Epoch 87/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0575 - binary_crossentropy: 0.0218 - generalized_dice_coefficient: 0.9068
# Epoch 87: val_loss did not improve from 0.06705
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0575 - binary_crossentropy: 0.0218 - generalized_dice_coefficient: 0.9068 - val_loss: 0.0694 - val_binary_crossentropy: 0.0300 - val_generalized_dice_coefficient: 0.8914
# Epoch 88/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0574 - binary_crossentropy: 0.0218 - generalized_dice_coefficient: 0.9071
# Epoch 88: val_loss did not improve from 0.06705
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0574 - binary_crossentropy: 0.0218 - generalized_dice_coefficient: 0.9071 - val_loss: 0.0702 - val_binary_crossentropy: 0.0307 - val_generalized_dice_coefficient: 0.8905
# Epoch 89/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0577 - binary_crossentropy: 0.0220 - generalized_dice_coefficient: 0.9066
# Epoch 89: val_loss did not improve from 0.06705
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0577 - binary_crossentropy: 0.0220 - generalized_dice_coefficient: 0.9066 - val_loss: 0.0690 - val_binary_crossentropy: 0.0295 - val_generalized_dice_coefficient: 0.8916
# Epoch 90/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0573 - binary_crossentropy: 0.0218 - generalized_dice_coefficient: 0.9072
# Epoch 90: val_loss did not improve from 0.06705
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0573 - binary_crossentropy: 0.0218 - generalized_dice_coefficient: 0.9072 - val_loss: 0.0685 - val_binary_crossentropy: 0.0294 - val_generalized_dice_coefficient: 0.8925
# Epoch 91/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0574 - binary_crossentropy: 0.0218 - generalized_dice_coefficient: 0.9071
# Epoch 91: val_loss did not improve from 0.06705
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0574 - binary_crossentropy: 0.0218 - generalized_dice_coefficient: 0.9071 - val_loss: 0.0691 - val_binary_crossentropy: 0.0300 - val_generalized_dice_coefficient: 0.8919
# Epoch 92/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0573 - binary_crossentropy: 0.0218 - generalized_dice_coefficient: 0.9071
# Epoch 92: val_loss did not improve from 0.06705
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0573 - binary_crossentropy: 0.0218 - generalized_dice_coefficient: 0.9071 - val_loss: 0.0698 - val_binary_crossentropy: 0.0304 - val_generalized_dice_coefficient: 0.8910
# Epoch 93/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0571 - binary_crossentropy: 0.0218 - generalized_dice_coefficient: 0.9076
# Epoch 93: val_loss did not improve from 0.06705
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0571 - binary_crossentropy: 0.0218 - generalized_dice_coefficient: 0.9076 - val_loss: 0.0688 - val_binary_crossentropy: 0.0297 - val_generalized_dice_coefficient: 0.8922
# Epoch 94/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0570 - binary_crossentropy: 0.0216 - generalized_dice_coefficient: 0.9077
# Epoch 94: val_loss did not improve from 0.06705
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0570 - binary_crossentropy: 0.0216 - generalized_dice_coefficient: 0.9077 - val_loss: 0.0698 - val_binary_crossentropy: 0.0304 - val_generalized_dice_coefficient: 0.8908
# Epoch 95/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0570 - binary_crossentropy: 0.0216 - generalized_dice_coefficient: 0.9077
# Epoch 95: val_loss did not improve from 0.06705
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0570 - binary_crossentropy: 0.0216 - generalized_dice_coefficient: 0.9077 - val_loss: 0.0707 - val_binary_crossentropy: 0.0311 - val_generalized_dice_coefficient: 0.8898
# Epoch 96/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0567 - binary_crossentropy: 0.0216 - generalized_dice_coefficient: 0.9082
# Epoch 96: val_loss did not improve from 0.06705
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0567 - binary_crossentropy: 0.0216 - generalized_dice_coefficient: 0.9082 - val_loss: 0.0703 - val_binary_crossentropy: 0.0306 - val_generalized_dice_coefficient: 0.8902
# Epoch 97/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0569 - binary_crossentropy: 0.0217 - generalized_dice_coefficient: 0.9079
# Epoch 97: val_loss did not improve from 0.06705
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0569 - binary_crossentropy: 0.0217 - generalized_dice_coefficient: 0.9079 - val_loss: 0.0682 - val_binary_crossentropy: 0.0292 - val_generalized_dice_coefficient: 0.8929
# Epoch 98/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0565 - binary_crossentropy: 0.0215 - generalized_dice_coefficient: 0.9085
# Epoch 98: val_loss did not improve from 0.06705
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0565 - binary_crossentropy: 0.0215 - generalized_dice_coefficient: 0.9085 - val_loss: 0.0692 - val_binary_crossentropy: 0.0300 - val_generalized_dice_coefficient: 0.8917
# Epoch 99/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0565 - binary_crossentropy: 0.0215 - generalized_dice_coefficient: 0.9085
# Epoch 99: val_loss did not improve from 0.06705
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0565 - binary_crossentropy: 0.0215 - generalized_dice_coefficient: 0.9085 - val_loss: 0.0694 - val_binary_crossentropy: 0.0304 - val_generalized_dice_coefficient: 0.8917
# Epoch 100/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0565 - binary_crossentropy: 0.0215 - generalized_dice_coefficient: 0.9086
# Epoch 100: val_loss did not improve from 0.06705
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0565 - binary_crossentropy: 0.0215 - generalized_dice_coefficient: 0.9086 - val_loss: 0.0705 - val_binary_crossentropy: 0.0309 - val_generalized_dice_coefficient: 0.8900
# Epoch 101/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0564 - binary_crossentropy: 0.0214 - generalized_dice_coefficient: 0.9086
# Epoch 101: val_loss did not improve from 0.06705
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0564 - binary_crossentropy: 0.0214 - generalized_dice_coefficient: 0.9086 - val_loss: 0.0698 - val_binary_crossentropy: 0.0305 - val_generalized_dice_coefficient: 0.8910
# Epoch 102/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0563 - binary_crossentropy: 0.0214 - generalized_dice_coefficient: 0.9088
# Epoch 102: val_loss did not improve from 0.06705
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0563 - binary_crossentropy: 0.0214 - generalized_dice_coefficient: 0.9088 - val_loss: 0.0699 - val_binary_crossentropy: 0.0307 - val_generalized_dice_coefficient: 0.8911
# Epoch 103/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0562 - binary_crossentropy: 0.0214 - generalized_dice_coefficient: 0.9090
# Epoch 103: val_loss did not improve from 0.06705
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0562 - binary_crossentropy: 0.0214 - generalized_dice_coefficient: 0.9090 - val_loss: 0.0699 - val_binary_crossentropy: 0.0306 - val_generalized_dice_coefficient: 0.8908
# Epoch 104/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0563 - binary_crossentropy: 0.0214 - generalized_dice_coefficient: 0.9088
# Epoch 104: val_loss did not improve from 0.06705
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0563 - binary_crossentropy: 0.0214 - generalized_dice_coefficient: 0.9088 - val_loss: 0.0696 - val_binary_crossentropy: 0.0306 - val_generalized_dice_coefficient: 0.8915
# Epoch 105/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0561 - binary_crossentropy: 0.0214 - generalized_dice_coefficient: 0.9092
# Epoch 105: val_loss did not improve from 0.06705
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0561 - binary_crossentropy: 0.0214 - generalized_dice_coefficient: 0.9092 - val_loss: 0.0695 - val_binary_crossentropy: 0.0306 - val_generalized_dice_coefficient: 0.8916
# Epoch 106/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0560 - binary_crossentropy: 0.0213 - generalized_dice_coefficient: 0.9093
# Epoch 106: val_loss did not improve from 0.06705
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0560 - binary_crossentropy: 0.0213 - generalized_dice_coefficient: 0.9093 - val_loss: 0.0710 - val_binary_crossentropy: 0.0317 - val_generalized_dice_coefficient: 0.8899
# Epoch 107/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0560 - binary_crossentropy: 0.0213 - generalized_dice_coefficient: 0.9094
# Epoch 107: val_loss did not improve from 0.06705
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0560 - binary_crossentropy: 0.0213 - generalized_dice_coefficient: 0.9094 - val_loss: 0.0699 - val_binary_crossentropy: 0.0311 - val_generalized_dice_coefficient: 0.8914
# Epoch 108/200
# ...
# Epoch 164/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0542 - binary_crossentropy: 0.0207 - generalized_dice_coefficient: 0.9122
# Epoch 164: val_loss did not improve from 0.06705
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0542 - binary_crossentropy: 0.0207 - generalized_dice_coefficient: 0.9122 - val_loss: 0.0705 - val_binary_crossentropy: 0.0320 - val_generalized_dice_coefficient: 0.8911
# Epoch 165/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0541 - binary_crossentropy: 0.0206 - generalized_dice_coefficient: 0.9124
# Epoch 165: val_loss did not improve from 0.06705
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0541 - binary_crossentropy: 0.0206 - generalized_dice_coefficient: 0.9124 - val_loss: 0.0707 - val_binary_crossentropy: 0.0322 - val_generalized_dice_coefficient: 0.8909
# Epoch 166/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0542 - binary_crossentropy: 0.0207 - generalized_dice_coefficient: 0.9123
# Epoch 166: val_loss did not improve from 0.06705
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0542 - binary_crossentropy: 0.0207 - generalized_dice_coefficient: 0.9123 - val_loss: 0.0703 - val_binary_crossentropy: 0.0319 - val_generalized_dice_coefficient: 0.8914
# Epoch 167/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0542 - binary_crossentropy: 0.0206 - generalized_dice_coefficient: 0.9123
# Epoch 167: val_loss did not improve from 0.06705
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0542 - binary_crossentropy: 0.0206 - generalized_dice_coefficient: 0.9123 - val_loss: 0.0703 - val_binary_crossentropy: 0.0319 - val_generalized_dice_coefficient: 0.8914
# Epoch 168/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0542 - binary_crossentropy: 0.0207 - generalized_dice_coefficient: 0.9122
# Epoch 168: val_loss did not improve from 0.06705
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0542 - binary_crossentropy: 0.0207 - generalized_dice_coefficient: 0.9122 - val_loss: 0.0704 - val_binary_crossentropy: 0.0321 - val_generalized_dice_coefficient: 0.8914
# Epoch 169/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0541 - binary_crossentropy: 0.0206 - generalized_dice_coefficient: 0.9124
# Epoch 169: val_loss did not improve from 0.06705
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0541 - binary_crossentropy: 0.0206 - generalized_dice_coefficient: 0.9124 - val_loss: 0.0703 - val_binary_crossentropy: 0.0319 - val_generalized_dice_coefficient: 0.8914
# Epoch 170/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0543 - binary_crossentropy: 0.0208 - generalized_dice_coefficient: 0.9121
# Epoch 170: val_loss did not improve from 0.06705
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0543 - binary_crossentropy: 0.0208 - generalized_dice_coefficient: 0.9121 - val_loss: 0.0702 - val_binary_crossentropy: 0.0319 - val_generalized_dice_coefficient: 0.8916
# Epoch 171/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0542 - binary_crossentropy: 0.0207 - generalized_dice_coefficient: 0.9122
# Epoch 171: val_loss did not improve from 0.06705
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0542 - binary_crossentropy: 0.0207 - generalized_dice_coefficient: 0.9122 - val_loss: 0.0707 - val_binary_crossentropy: 0.0322 - val_generalized_dice_coefficient: 0.8909
# Epoch 172/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0542 - binary_crossentropy: 0.0207 - generalized_dice_coefficient: 0.9123
# Epoch 172: val_loss did not improve from 0.06705
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0542 - binary_crossentropy: 0.0207 - generalized_dice_coefficient: 0.9123 - val_loss: 0.0707 - val_binary_crossentropy: 0.0322 - val_generalized_dice_coefficient: 0.8908
# Epoch 173/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0543 - binary_crossentropy: 0.0207 - generalized_dice_coefficient: 0.9122
# Epoch 173: val_loss did not improve from 0.06705
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0543 - binary_crossentropy: 0.0207 - generalized_dice_coefficient: 0.9122 - val_loss: 0.0705 - val_binary_crossentropy: 0.0321 - val_generalized_dice_coefficient: 0.8911
# Epoch 174/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0542 - binary_crossentropy: 0.0207 - generalized_dice_coefficient: 0.9123
# Epoch 174: val_loss did not improve from 0.06705
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0542 - binary_crossentropy: 0.0207 - generalized_dice_coefficient: 0.9123 - val_loss: 0.0704 - val_binary_crossentropy: 0.0321 - val_generalized_dice_coefficient: 0.8913
# Epoch 175/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0541 - binary_crossentropy: 0.0207 - generalized_dice_coefficient: 0.9124
# Epoch 175: val_loss did not improve from 0.06705
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0541 - binary_crossentropy: 0.0207 - generalized_dice_coefficient: 0.9124 - val_loss: 0.0703 - val_binary_crossentropy: 0.0319 - val_generalized_dice_coefficient: 0.8915
# Epoch 176/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0543 - binary_crossentropy: 0.0207 - generalized_dice_coefficient: 0.9122
# Epoch 176: val_loss did not improve from 0.06705
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0543 - binary_crossentropy: 0.0207 - generalized_dice_coefficient: 0.9122 - val_loss: 0.0706 - val_binary_crossentropy: 0.0321 - val_generalized_dice_coefficient: 0.8911
# Epoch 177/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0542 - binary_crossentropy: 0.0207 - generalized_dice_coefficient: 0.9124
# Epoch 177: val_loss did not improve from 0.06705
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0542 - binary_crossentropy: 0.0207 - generalized_dice_coefficient: 0.9124 - val_loss: 0.0703 - val_binary_crossentropy: 0.0320 - val_generalized_dice_coefficient: 0.8914
# Epoch 178/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0540 - binary_crossentropy: 0.0206 - generalized_dice_coefficient: 0.9126
# Epoch 178: val_loss did not improve from 0.06705
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0540 - binary_crossentropy: 0.0206 - generalized_dice_coefficient: 0.9126 - val_loss: 0.0706 - val_binary_crossentropy: 0.0321 - val_generalized_dice_coefficient: 0.8911
# Epoch 179/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0540 - binary_crossentropy: 0.0205 - generalized_dice_coefficient: 0.9126
# Epoch 179: val_loss did not improve from 0.06705
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0540 - binary_crossentropy: 0.0205 - generalized_dice_coefficient: 0.9126 - val_loss: 0.0703 - val_binary_crossentropy: 0.0320 - val_generalized_dice_coefficient: 0.8914
# Epoch 180/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0541 - binary_crossentropy: 0.0206 - generalized_dice_coefficient: 0.9125
# Epoch 180: val_loss did not improve from 0.06705
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0541 - binary_crossentropy: 0.0206 - generalized_dice_coefficient: 0.9125 - val_loss: 0.0704 - val_binary_crossentropy: 0.0320 - val_generalized_dice_coefficient: 0.8913
# Epoch 181/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0541 - binary_crossentropy: 0.0206 - generalized_dice_coefficient: 0.9125
# Epoch 181: val_loss did not improve from 0.06705
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0541 - binary_crossentropy: 0.0206 - generalized_dice_coefficient: 0.9125 - val_loss: 0.0704 - val_binary_crossentropy: 0.0321 - val_generalized_dice_coefficient: 0.8913
# Epoch 182/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0540 - binary_crossentropy: 0.0206 - generalized_dice_coefficient: 0.9125
# Epoch 182: val_loss did not improve from 0.06705
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0540 - binary_crossentropy: 0.0206 - generalized_dice_coefficient: 0.9125 - val_loss: 0.0705 - val_binary_crossentropy: 0.0320 - val_generalized_dice_coefficient: 0.8911
# Epoch 183/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0540 - binary_crossentropy: 0.0206 - generalized_dice_coefficient: 0.9125
# Epoch 183: val_loss did not improve from 0.06705
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0540 - binary_crossentropy: 0.0206 - generalized_dice_coefficient: 0.9125 - val_loss: 0.0704 - val_binary_crossentropy: 0.0319 - val_generalized_dice_coefficient: 0.8912
# Epoch 184/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0541 - binary_crossentropy: 0.0206 - generalized_dice_coefficient: 0.9125
# Epoch 184: val_loss did not improve from 0.06705
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0541 - binary_crossentropy: 0.0206 - generalized_dice_coefficient: 0.9125 - val_loss: 0.0704 - val_binary_crossentropy: 0.0320 - val_generalized_dice_coefficient: 0.8913
# Epoch 185/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0541 - binary_crossentropy: 0.0206 - generalized_dice_coefficient: 0.9125
# Epoch 185: val_loss did not improve from 0.06705
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0541 - binary_crossentropy: 0.0206 - generalized_dice_coefficient: 0.9125 - val_loss: 0.0703 - val_binary_crossentropy: 0.0319 - val_generalized_dice_coefficient: 0.8913
# Epoch 186/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0541 - binary_crossentropy: 0.0206 - generalized_dice_coefficient: 0.9124
# Epoch 186: val_loss did not improve from 0.06705
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0541 - binary_crossentropy: 0.0206 - generalized_dice_coefficient: 0.9124 - val_loss: 0.0703 - val_binary_crossentropy: 0.0319 - val_generalized_dice_coefficient: 0.8915
# Epoch 187/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0539 - binary_crossentropy: 0.0205 - generalized_dice_coefficient: 0.9126
# Epoch 187: val_loss did not improve from 0.06705
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0539 - binary_crossentropy: 0.0205 - generalized_dice_coefficient: 0.9126 - val_loss: 0.0704 - val_binary_crossentropy: 0.0320 - val_generalized_dice_coefficient: 0.8913
# Epoch 188/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0540 - binary_crossentropy: 0.0206 - generalized_dice_coefficient: 0.9125
# Epoch 188: val_loss did not improve from 0.06705
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0540 - binary_crossentropy: 0.0206 - generalized_dice_coefficient: 0.9125 - val_loss: 0.0703 - val_binary_crossentropy: 0.0320 - val_generalized_dice_coefficient: 0.8914
# Epoch 189/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0541 - binary_crossentropy: 0.0207 - generalized_dice_coefficient: 0.9124
# Epoch 189: val_loss did not improve from 0.06705
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0541 - binary_crossentropy: 0.0207 - generalized_dice_coefficient: 0.9124 - val_loss: 0.0705 - val_binary_crossentropy: 0.0321 - val_generalized_dice_coefficient: 0.8911
# Epoch 190/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0540 - binary_crossentropy: 0.0206 - generalized_dice_coefficient: 0.9126
# Epoch 190: val_loss did not improve from 0.06705
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0540 - binary_crossentropy: 0.0206 - generalized_dice_coefficient: 0.9126 - val_loss: 0.0703 - val_binary_crossentropy: 0.0319 - val_generalized_dice_coefficient: 0.8914
# Epoch 191/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0542 - binary_crossentropy: 0.0207 - generalized_dice_coefficient: 0.9123
# Epoch 191: val_loss did not improve from 0.06705
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0542 - binary_crossentropy: 0.0207 - generalized_dice_coefficient: 0.9123 - val_loss: 0.0702 - val_binary_crossentropy: 0.0319 - val_generalized_dice_coefficient: 0.8916
# Epoch 192/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0541 - binary_crossentropy: 0.0207 - generalized_dice_coefficient: 0.9125
# Epoch 192: val_loss did not improve from 0.06705
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0541 - binary_crossentropy: 0.0207 - generalized_dice_coefficient: 0.9125 - val_loss: 0.0706 - val_binary_crossentropy: 0.0322 - val_generalized_dice_coefficient: 0.8910
# Epoch 193/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0541 - binary_crossentropy: 0.0206 - generalized_dice_coefficient: 0.9124
# Epoch 193: val_loss did not improve from 0.06705
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0541 - binary_crossentropy: 0.0206 - generalized_dice_coefficient: 0.9124 - val_loss: 0.0703 - val_binary_crossentropy: 0.0320 - val_generalized_dice_coefficient: 0.8914
# Epoch 194/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0541 - binary_crossentropy: 0.0207 - generalized_dice_coefficient: 0.9124
# Epoch 194: val_loss did not improve from 0.06705
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0541 - binary_crossentropy: 0.0207 - generalized_dice_coefficient: 0.9124 - val_loss: 0.0705 - val_binary_crossentropy: 0.0321 - val_generalized_dice_coefficient: 0.8912
# Epoch 195/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0540 - binary_crossentropy: 0.0206 - generalized_dice_coefficient: 0.9125
# Epoch 195: val_loss did not improve from 0.06705
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0540 - binary_crossentropy: 0.0206 - generalized_dice_coefficient: 0.9125 - val_loss: 0.0703 - val_binary_crossentropy: 0.0320 - val_generalized_dice_coefficient: 0.8914
# Epoch 196/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0541 - binary_crossentropy: 0.0206 - generalized_dice_coefficient: 0.9125
# Epoch 196: val_loss did not improve from 0.06705
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0541 - binary_crossentropy: 0.0206 - generalized_dice_coefficient: 0.9125 - val_loss: 0.0704 - val_binary_crossentropy: 0.0321 - val_generalized_dice_coefficient: 0.8913
# Epoch 197/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0540 - binary_crossentropy: 0.0206 - generalized_dice_coefficient: 0.9125
# Epoch 197: val_loss did not improve from 0.06705
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0540 - binary_crossentropy: 0.0206 - generalized_dice_coefficient: 0.9125 - val_loss: 0.0702 - val_binary_crossentropy: 0.0320 - val_generalized_dice_coefficient: 0.8916
# Epoch 198/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0540 - binary_crossentropy: 0.0206 - generalized_dice_coefficient: 0.9126
# Epoch 198: val_loss did not improve from 0.06705
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0540 - binary_crossentropy: 0.0206 - generalized_dice_coefficient: 0.9126 - val_loss: 0.0705 - val_binary_crossentropy: 0.0321 - val_generalized_dice_coefficient: 0.8912
# Epoch 199/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0539 - binary_crossentropy: 0.0205 - generalized_dice_coefficient: 0.9128
# Epoch 199: val_loss did not improve from 0.06705
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0539 - binary_crossentropy: 0.0205 - generalized_dice_coefficient: 0.9128 - val_loss: 0.0704 - val_binary_crossentropy: 0.0321 - val_generalized_dice_coefficient: 0.8913
# Epoch 200/200
# 80/80 [==============================] - ETA: 0s - loss: 0.0539 - binary_crossentropy: 0.0206 - generalized_dice_coefficient: 0.9127
# Epoch 200: val_loss did not improve from 0.06705
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0539 - binary_crossentropy: 0.0206 - generalized_dice_coefficient: 0.9127 - val_loss: 0.0706 - val_binary_crossentropy: 0.0322 - val_generalized_dice_coefficient: 0.8911

# %%
import pickle
with open("/content/drive/MyDrive/Bone_SPECT/training_historyWS3.pkl", 'wb') as file:
    pickle.dump(model_history.history, file)

# %%
loss = model_history.history['loss']
val_loss = model_history.history['val_loss']

plt.figure()
plt.plot(model_history.epoch, loss, 'r', label='Training loss')
plt.plot(model_history.epoch, val_loss, 'bo', label='Validation loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss Value')
plt.ylim([0, 1])
plt.legend()
plt.show()

# %%
# 재시도시
del model
